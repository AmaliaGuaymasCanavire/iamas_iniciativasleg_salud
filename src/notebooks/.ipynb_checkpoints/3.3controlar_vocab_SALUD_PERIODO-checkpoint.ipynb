# %% [markdown]
# # 3.3  Análisis de vocabulario para comparar períodos de 5 años
#
# * Explorar frecuencias de palabras: Filtrado por frecuencia mínima.
#
# * Vocabulario: Medir qué proporción del vocabulario permanece activo (por encima del umbral de frecuencia) en los tres períodos.
#
# * Identificar palabras emergentes: detectar palabras que aparecen o aumentan significativamente su uso en un período respecto a otro.

# %% [markdown]
# ## Consideraciones previas
# ### Preprocesamiento de texto para la generación de corpus
# * En base a las 35179 iniciativas legislativas entre 2009 a 2024
#
# #### Normalización
# Antes de entrenar los modelos de word embeddings y con el objetivo de mejorar la calidad semántica del análisis, se aplicó un proceso de normalización  sobre los títulos de las iniciativas legislativas.Este procedimiento incluyó :
#
# * Eliminar  caracteres como puntos, comas, comillas, espacios, brackets, etc.
# * Convertir los números a su equivalente a palabras.
# * Convertir a minúsculas.
# * Lematizar.
# * Remover stopwords.
#
# **Limpieza de términos dominantes**
#
# Dado el carácter jurídico y político del los títulos, se identificó presencia de términos de dominio legislativo, particularmente se tuvo en cuenta los asociados a proyectos de ley, que si bien frecuentes no aportan valor semántico específico al análisis temático sobre salud. Se implementó un filtro de n-gramas más frecuentes (n=2 a n=5).
#
# Un n-grama es una secuencia de n elementos consecutivos de un texto o discurso. Los elementos pueden ser palabras, números, símbolos, fonemas, sílabas, letras, o pares de bases.
#
# * Se identificaron 552988 combinaciones de n-gramas de 2 a 5 con un número de frecuencia mínima de 1 vez.
#
# Los n-gramas más frecuentes (n=2 a n=5) a eliminar por dominio :
#
#     * 'ley modificacion articulo',
#     * 'incorporacion articulo bis',
#     * 'contrato trabajo ley',
#     * 'ley modificacion',
#     * 'modificacion articulo',
#     * 'reproduccion expediente',
#     * 'codigo penal',
#     * 'articulo bis',
#     * 'incorporacion articulo',
#     * 'modificacion ley',
#     * 'contrato trabajo',
#     * 'trabajo ley'
#
# Estas frases o combinaciones de palabras fueron eliminados del los títulos buscando preservar aquellas palabras con contenido temático relevante para el análisis semántico en salud. Esta estrategia constribuye a reducir el ruido y a mejorar la estabilidad y expresividad de los embeddings entrenados por período, aunque también afecta la cantidad de tokens en el corpus y los modelos de lenguaje a aplicar.

# %% [markdown]
# **VOCABULARIO**
# lista única de todas las palabras (o tokens) presentes en un conjunto de textos
#
# **Palabras en base a normalización**
# * 12865 palabras únicas en la muestra de 35179 iniciativas legislativas.
#     * En promedio 27 veces de ocurrencia en la muestra, mediana 3 veces. Se identifican palabras con ocurrencia extremas.
#         * Rango de frecuencia: [1- 10119]
#         * Desviación estándar de frecuencia: 164 veces. Es decir, las mayor parte de las frecuencias de palabras de la muestra tienden a estar lejos de su media, se extienden sobre un rango de valores más amplio.
#         * Top 4 palabras con mayores frecuencias:  nacional (10119), creacion (6033), regimen(5828), ley(5262). No se las eliminaron aún.

# %% [markdown]
# **Cantidad de palabras (token) por títulos**
#
# * Cant_token (títulos no normalizado): promedio 21, std	11, min 2, mediana	19,  max 125
#
# * Cant_token_normalizado (titulos normalizados): promerdio	10, std	5, min	0, mediana 9, max 57

# %% [markdown]
# #### Iniciativa legislativa de ley sobre SALUD para período parlamentario entre 127 a 141
# * 2848 iniciativas legislativas
#
# **Tokens**
#
# * Cant_token: promedio	19, std	10, min	2, mediana	18, max 125
# * Cant_token_normalizado: promedio	10,	std 5,	min 1, mediana 9, max 50
#
# **De títulos normalizados**
#
# N-gramas más frecuentes top 6 (mas diferencia con el resto). Se observa n-gramas de n entre 2 a 5 con mínima frecuencia 1:
#
# 	* programa nacional  (2-grama)     208 veces
# 	* medico obligatorio (2-grama)     187 veces
# 	* programa medico obligatorio (3-grama)         153 veces
# 	* programa medico         153 veces
# 	* obligatorio pmo         150 veces
# 	* medico obligatorio pmo  150 veces
#
# **VOCABULARIO**
#
# Palabras más frecuentes
#
# * 3221 palabrás únicas (del total de 12865). En promedio 9 veces (27 en el total) de ocurrencia en título, mediana 2 veces (3 en el total). Se identifica palabras con frecuencias extremas.
#     * Rango: [1 - 836] ( [1- 10119] en el total)
#     * Desviación estándar: 31 veces (164 veces en el total). Es decir, las mayor parte de las frecuencias de palabras de la muestra tienden a estar lejos de su media, se extienden sobre un rango de valores más amplio.
#     * Top 5 palabras con mayores frecuencias:  nacional (836), creacion (628), programa (488), regimen	(485), salud (483).
#         *  nacional(10119),creacion(6033), regimen(5828),ley(5262) en el total

# %% [markdown]
# ## 1. EDA

# %%
# Importar librerias

from dotenv import load_dotenv
import os
import pandas as pd
import numpy as np
import pickle
import sweetviz as sv
import sys

# Visualización
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.lines import Line2D
import matplotlib.colors as mcolors
from matplotlib import colormaps

from collections import Counter
from itertools import islice

from tqdm import tqdm
tqdm.pandas()

# %%
import datetime
print(datetime.datetime.now().strftime("%Y%m%d%H%M"))
# Out:
# 202505091835

# %%
# Configurar path
load_dotenv() # Cargar las variables de entorno del archivo .env
BASE_DIR =  os.getenv("DIR_BASE")
RESULTADOS_DIR = os.getenv("DIR_DATOS_PROCESADOS") # Acceder a las variables de entorno
sys.path.append(BASE_DIR)
sys.path.append(RESULTADOS_DIR)

pd.set_option('display.max_colwidth', None)

# %%
# Abrir
with open(RESULTADOS_DIR + 'base_texto_df_ley_0924.pkl', 'rb') as file: 
    basetexto_df = pickle.load(file)

basetexto_df.describe(include='all').T
# Out:
#                                       count unique  \
# Proyecto.ID                           35179  35179
# Título                                35179  33168
# Título procesado                      35179  29558
# Título normalizado                    35179  28761
# Cant_token                          35179.0    NaN
# Cant_token_normalizado              35179.0    NaN
# Proyecto_girado_a_comisiones_SALUD  35179.0    NaN
# Proyecto_SALUD                      35179.0    NaN
# Resultado                             35179      6
# Max_Orden                           35179.0    NaN
# Tiene_antecedente_por_titulo_proy     35179      2
# Periodo                             33097.0    NaN
# Año                                 35179.0    NaN
# Tokens                                35179  26519
#
#                                                                                                                            top  \
# Proyecto.ID                                                                                                         HCDN246858
# Título                                                                                           JUICIO POR JURADOS. CREACION.
# Título procesado                    contrato de trabajo ley numero modificacion del articulo numero sobre licencias especiales
# Título normalizado                                                                                           licencia especial
# Cant_token                                                                                                                 NaN
# Cant_token_normalizado                                                                                                     NaN
# Proyecto_girado_a_comisiones_SALUD                                                                                         NaN
# Proyecto_SALUD                                                                                                             NaN
# Resultado                                                                            NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# Max_Orden                                                                                                                  NaN
# Tiene_antecedente_por_titulo_proy                                                                                        False
# Periodo                                                                                                                    NaN
# Año                                                                                                                        NaN
# Tokens                                                                                                    [licencia, especial]
#
#                                      freq         mean       std     min  \
# Proyecto.ID                             1          NaN       NaN     NaN
# Título                                 18          NaN       NaN     NaN
# Título procesado                       36          NaN       NaN     NaN
# Título normalizado                     39          NaN       NaN     NaN
# Cant_token                            NaN    21.123682  10.69187     2.0
# Cant_token_normalizado                NaN      9.76341  5.051387     0.0
# Proyecto_girado_a_comisiones_SALUD    NaN      0.12786  0.333939     0.0
# Proyecto_SALUD                        NaN     0.085761  0.280015     0.0
# Resultado                           34268          NaN       NaN     NaN
# Max_Orden                             NaN     2.253504  0.822105     1.0
# Tiene_antecedente_por_titulo_proy   33198          NaN       NaN     NaN
# Periodo                               NaN   134.111944  4.075721   127.0
# Año                                   NaN  2016.586913  4.376397  2009.0
# Tokens                                 42          NaN       NaN     NaN
#
#                                        25%     50%     75%     max
# Proyecto.ID                            NaN     NaN     NaN     NaN
# Título                                 NaN     NaN     NaN     NaN
# Título procesado                       NaN     NaN     NaN     NaN
# Título normalizado                     NaN     NaN     NaN     NaN
# Cant_token                            14.0    19.0    27.0   125.0
# Cant_token_normalizado                 6.0     9.0    12.0    57.0
# Proyecto_girado_a_comisiones_SALUD     0.0     0.0     0.0     1.0
# Proyecto_SALUD                         0.0     0.0     0.0     1.0
# Resultado                              NaN     NaN     NaN     NaN
# Max_Orden                              2.0     2.0     3.0     8.0
# Tiene_antecedente_por_titulo_proy      NaN     NaN     NaN     NaN
# Periodo                              131.0   134.0   137.0   141.0
# Año                                 2013.0  2017.0  2020.0  2024.0
# Tokens                                 NaN     NaN     NaN     NaN

# %%
# Seleccionando IL de Salud
basetexto_df = basetexto_df[basetexto_df['Proyecto_SALUD']==1]
print("Conj. de datos de proyecto_SALUD con Nan en Período:",basetexto_df.shape)
basetexto_df = basetexto_df[~basetexto_df['Periodo'].isna()]
print("Conj. de datos de proyecto_SALUD sin Nan en Período:",basetexto_df.shape)
# Out:
# Conj. de datos de proyecto_SALUD con Nan en Período: (3017, 14)
# Conj. de datos de proyecto_SALUD sin Nan en Período: (2848, 14)

# %%
basetexto_df = basetexto_df[~(basetexto_df['Título normalizado']==" ")]
print("Conj. de datos de proyecto_SALUD sin título vacio:",basetexto_df.shape)
# Out:
# Conj. de datos de proyecto_SALUD sin título vacio: (2848, 14)

# %%
basetexto_df[['Cant_token','Cant_token_normalizado']].describe()
# Out:
#         Cant_token  Cant_token_normalizado
# count  2848.000000             2848.000000
# mean     19.251053                9.766854
# std      10.004802                4.657696
# min       2.000000                1.000000
# 25%      12.000000                6.000000
# 50%      18.000000                9.000000
# 75%      24.000000               12.000000
# max     125.000000               50.000000

# %% [markdown]
# Calculamos el promedio de tokens anuales y luego el promedio de esos promedios para obtener un resumen de 16 años  (media de las medias).

# %%
Temp = pd.pivot_table(basetexto_df, values=['Cant_token','Cant_token_normalizado'], 
                      index=['Año'],
                       aggfunc={'Cant_token': 'median','Cant_token_normalizado': 'median'}).reset_index()
Temp
# Out:
#      Año  Cant_token  Cant_token_normalizado
# 0   2009        19.0                    10.0
# 1   2010        18.0                     9.0
# 2   2011        19.0                    10.0
# 3   2012        17.0                     8.0
# 4   2013        17.0                     9.0
# 5   2014        18.0                     9.0
# 6   2015        19.0                    10.0
# 7   2016        16.0                     8.0
# 8   2017        18.0                     9.0
# 9   2018        18.0                     9.0
# 10  2019        17.0                     8.0
# 11  2020        18.0                     9.0
# 12  2021        17.0                     9.0
# 13  2022        16.0                     8.0
# 14  2023        15.5                     9.0
# 15  2024        19.0                     9.0

# %% [markdown]
#  Para expresar el error asociado a este valor resumen, observamos las estadística descriptiva y calculamos el Error Estándar de la Media (SEM, Standard Error of the Mean) de los promedios anuales.

# %%
Temp.describe().T
# Out:
#                         count        mean       std     min      25%     50%  \
# Año                      16.0  2016.50000  4.760952  2009.0  2012.75  2016.5
# Cant_token               16.0    17.59375  1.143369    15.5    17.00    18.0
# Cant_token_normalizado   16.0     8.93750  0.680074     8.0     8.75     9.0
#
#                             75%     max
# Año                     2020.25  2024.0
# Cant_token                18.25    19.0
# Cant_token_normalizado     9.00    10.0

# %%
import matplotlib.ticker as ticker
sns.color_palette("pastel")
Temp1 = pd.melt(Temp, id_vars=['Año'], value_vars=['Cant_token_normalizado', 'Cant_token'])
Temp1.columns = ['Año','Texto','Cantidad de tokens promedio']
Temp1["Texto"] = Temp1["Texto"].map({'Cant_token': 'Sin procesamiento', 'Cant_token_normalizado': 'Con procesamiento'})

f, ax = plt.subplots(1, 1, figsize=(15, 5), sharey = True)
sns.lineplot(x='Año', y='Cantidad de tokens promedio', hue='Texto', data = Temp1, estimator='sum', errorbar= None , linestyle='-', ax = ax, marker="o")
legend_handles, _= ax.get_legend_handles_labels()

ax.set_title('Promedio Anual de Tokens')
plt.ylim(0, 25)
plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True, nbins=15))
#plt.savefig(BASE_DIR+"imagenes/evolucion_IL_a_tokennos.png")
plt.show()

# %%
from scipy import stats

# Calcula la media de los promedios anuales
promedios_anuales = Temp['Cant_token_normalizado']
n = len(promedios_anuales)
media_total = np.mean(promedios_anuales)

# Calcula la desviación estándar de los promedios anuales
desviacion_estandar = np.std(promedios_anuales, ddof=1) # ddof=1 para desviación estándar de la muestra

# Calcula el Error Estándar de la Media (SEM)
sem = desviacion_estandar / np.sqrt(n)
print('desviacion_estandar', desviacion_estandar)
print('sem',sem)

# Calcula el Intervalo de Confianza del 95%
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1
valor_critico_t = stats.t.ppf(1 - alpha / 2, grados_libertad)
intervalo_confianza = valor_critico_t * sem
# Out:
# desviacion_estandar 0.6800735254367721
# sem 0.17001838135919303

# %%
# --- Gráfico de Líneas con Punto Resumen y Error (SEM) ---
anos = Temp['Año']
plt.figure(figsize=(10,6))
plt.plot(anos, promedios_anuales, marker='o', linestyle='-', color='skyblue', label='Promedio Anual')
plt.errorbar(2024.5, media_total, yerr=sem, fmt='o', color='red', capsize=10, label=f'Promedio Total: {media_total:.2f} ± {sem:.2f} (SEM)')
plt.xlabel("Año")
plt.ylabel("Promedio de Tokens")
plt.title("Promedio Anual de Tokens y Promedio Total con Error Estándar")
plt.ylim(0, 12)
plt.xticks(anos.tolist() )
plt.legend()
plt.grid(False)
#plt.tight_layout()
plt.tight_layout(rect=[0, 0.05, 1, 0.95]) # Ajuste para evitar cortar etiquetas

plt.show()

# %%
# --- Gráfico de Líneas con Punto Resumen y Error (Intervalo de Confianza del 95%) ---
plt.figure(figsize=(10, 6))
plt.plot(anos, promedios_anuales, marker='o', linestyle='-', color='lightcoral', label='Promedio Anual')
plt.errorbar(2024.5, media_total, yerr=intervalo_confianza, fmt='o', color='darkred', capsize=10,
             label=f'Promedio Total: {media_total:.2f}\nIC 95%: [{media_total - intervalo_confianza:.2f}, {media_total + intervalo_confianza:.2f}]')
plt.xlabel("Año")
plt.ylabel("Promedio de Tokens")
plt.title("Promedio Anual de Tokens y Promedio Total con Intervalo de Confianza del 95%")
plt.ylim(0, 12)
plt.xticks(anos.tolist())
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Normalizado**
# * Media de los promedios anuales: 9
# * Desviación estándar de los promedios anuales: 1
# * SEM: 0.16
#
# El SEM da una idea de la precisión con la que la media de los promedios anuales estima la "verdadera" media del promedio anual de tokens para el periodo de 16 años. El SEM es pequeño indica que la media de los promedios anuales es probablemente una estimación más precisa de esa "verdadera" media.
#
# La media de 9 es una estimación del promedio anual de tokens para el periodo de 16 años.
# La mayoría de los promedios anuales de tokens se encuentran relativamente cerca de la media de 9.

# %% [markdown]
# ## 2. Corpus para los tres períodos

# %% [markdown]
# La selección de períodos de cada 5 años se basa a los periodos de presidencia. Es importante tener en cuenta a la hora de comparar el año 2020, dado que fue el año de inicio de pandemía covid 19, en donde se priorizaron proyectos de salud más que en los otros años. Ver notebook de EDA
#
# * Periodo: 10 de diciembre de 2023 al presente
#   Presidente Javier Milei
# Ministro de Defensa
# Dr. Luis Alfonso Petri
#
# * Periodo: 10 de agosto de 2021 al 10 de diciembre de 2023
# Presidente Alberto Fernández
# Ministro de Defensa
# Lic. Jorge Enrique Taiana
#
# * Periodo: 10 de diciembre de 2019 al 10 de Agosto 2021
# Presidente Alberto Fernández
# Ministro de Defensa
# Ing. Agustín Oscar Rossi
#
# * Periodo: 10 de diciembre de 2015 al 10 de diciembre de 2019
# Presidente Mauricio Macri
# Ministro de Defensa
# Ing. Julio César Martínez – 2015-2017
# Dr. Oscar Raúl Aguad – 2017 al 2019
#
# * Periodo: 10 de diciembre de 2011 al 10 de diciembre de 2015
# Presidenta Cristina Fernández de Kirchner. Re-elección
# Ministro de Defensa
# Ing. Agustín Oscar Rossi – 2013 - 2015
# Arturo Puricelli – 2011 - 2013
#
# * Periodo: 10 de diciembre de 2007 al 10 de diciembre de 2011
# Presidenta Cristina Fernández de Kirchner
# Ministro de Defensa
# Arturo Puricelli – 2010 - 2011
# Nilda Garré – 2007 - 2010

# %%
basetexto_df['Periodo_5anios'] = 2009
basetexto_df.loc[(basetexto_df['Año']>=2014) & (basetexto_df['Año']<2019), 'Periodo_5anios'] =  2014
basetexto_df.loc[(basetexto_df['Año']>=2019), 'Periodo_5anios'] =  2019

# %%
basetexto_df['Periodo_5anios'].value_counts() # frecuencia absoluto
# Out:
# Periodo_5anios
# 2019    1065
# 2014    1008
# 2009     775
# Name: count, dtype: int64

# %%
Temp = pd.pivot_table(basetexto_df, values=['Cant_token','Cant_token_normalizado'], 
                      index=['Periodo_5anios'],
                       aggfunc={'Cant_token': 'median','Cant_token_normalizado': 'median'}).reset_index()
Temp.columns = ['Periodo_5anios',	'promedio Cant_token',	'promedio Cant_token_normalizado']
Temp
# Out:
#    Periodo_5anios  promedio Cant_token  promedio Cant_token_normalizado
# 0            2009                 18.0                              9.0
# 1            2014                 18.0                              9.0
# 2            2019                 17.0                              9.0

# %%
#concatenando titulos IL
PER5anios_df = basetexto_df.groupby('Periodo_5anios')['Título normalizado'].progress_apply('.'.join).reset_index() 
PER5anios_df['corpus']= PER5anios_df['Título normalizado'].progress_apply(lambda x: [sent.split() for sent in x.split('.')])
PER5anios_df['corpus'] = PER5anios_df['corpus'].progress_apply(lambda x: [token.remove(' ') if ' ' in token else token  for token in x ])
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 998.80it/s]
# 100%|██████████| 3/3 [00:00<00:00, 754.96it/s]
# 100%|██████████| 3/3 [00:00<00:00, 1501.90it/s]

# %%
print(len(PER5anios_df['corpus'].values[0]))
PER5anios_df['corpus'].values[0]
# Out:
# 775
# [['paro',
#   'cardiorrespiratorio',
#   'espectaculo',
#   'publico',
#   'futbol',
#   'regimen',
#   'presupuesto',
#   'minimo',
#   'necesario',
#   'materia',
#   'prevencion',
#   'atencion',
#   'primaria',
#   'basica'],
#  ['creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion',
#   'registro',
#   'universal',
#   'sanitario',
#   'nacional'],
#  ['incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion',
#   'dosis',
#   'vacuna',
#   'varicela',
#   'caracter',
#   'obligatorio'],
#  ['atencion',
#   'medica',
#   'investigacion',
#   'clinico',
#   'epidemiologico',
#   'capacitacion',
#   'profesional',
#   'deteccion',
#   'diagnostico',
#   'difusion',
#   'tratamiento',
#   'alergia',
#   'alimentario',
#   'declaracion',
#   'inter',
#   'nacional'],
#  ['ley', 'tabaco', 'paquete', 'envase', 'producto', 'elaborado', 'tabaco'],
#  ['pesquisa',
#   'neonatal',
#   'incorporacion',
#   'diverso',
#   'estudio',
#   'recien',
#   'nacido'],
#  ['control',
#   'sanitario',
#   'personal',
#   'embarcacion',
#   'amarrir',
#   'suelo',
#   'argentino',
#   'proveniente',
#   'puerto',
#   'extranjero',
#   'regimen'],
#  ['cobertura',
#   'obra',
#   'social',
#   'entidad',
#   'medicina',
#   'prepagar',
#   'tira',
#   'reactiva',
#   'glucos',
#   'sangre'],
#  ['vacuna',
#   'rotavirus',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['vacuna',
#   'varicela',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['implementacion',
#   'estudio',
#   'oximetria',
#   'pulso',
#   'nino',
#   'recien',
#   'nacido'],
#  ['derecho',
#   'alimentacion',
#   'adecuado',
#   'seguridad',
#   'soberania',
#   'alimentario'],
#  ['establecer',
#   'funcionario',
#   'designado',
#   'director',
#   'subdirector',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'administracion',
#   'nacional',
#   'seguridad',
#   'social',
#   'ans',
#   'gozar',
#   'remuneracion',
#   'equivalente',
#   'nivel',
#   'escalafonario',
#   'grado',
#   'sistema',
#   'nacional',
#   'empleo',
#   'publico'],
#  ['ley',
#   'proteccion',
#   'embarazo',
#   'recien',
#   'nacido',
#   'modificacion',
#   'inciso',
#   'articulo',
#   'gratuidad',
#   'permanencia',
#   'acompanante',
#   'mujer',
#   'situacion',
#   'parto'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regulacion',
#   'kiosco',
#   'escolar'],
#  ['alimento',
#   'bebida',
#   'saludable',
#   'incorporacion',
#   'venta',
#   'maquina',
#   'automatica',
#   'expendedora'],
#  ['garantizar',
#   'disponibilidad',
#   'desfibrilador',
#   'externo',
#   'automatico',
#   'dea',
#   'institucion',
#   'deportivo',
#   'pais',
#   'comprendido',
#   'ley',
#   'ley',
#   'deporte'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'atencion',
#   'tratamiento',
#   'integral',
#   'paciente',
#   'ostomizado'],
#  ['perdido',
#   'audicion',
#   'advertencia',
#   'dispositivo',
#   'movil',
#   'reproduccion',
#   'musica'],
#  ['responsable', 'pila', 'bateria'],
#  ['lucha', 'sedentarismo', 'promocion', 'salud', 'actividad', 'fisico'],
#  ['prevencion', 'contralor', 'radiacion', 'perjudicial', 'salud', 'regimen'],
#  ['ejercicio', 'profesion', 'acompanant', 'terapeutico', 'regimen'],
#  ['campana',
#   'nacional',
#   'prevencion',
#   'concientizacion',
#   'efecto',
#   'nocivo',
#   'abusivo',
#   'videojuego',
#   'creacion'],
#  ['servicio',
#   'nacional',
#   'lucha',
#   'diabetes',
#   'cobertura',
#   'medico',
#   'asistencial',
#   'caracter',
#   'obligatorio'],
#  ['rotavirus', 'incorporar', 'calendario', 'nacional', 'vacunacion'],
#  ['nino',
#   'nacido',
#   'partos',
#   'domiciliario',
#   'regimen',
#   'inscripcion',
#   'registro',
#   'civil',
#   'capacidad',
#   'persona'],
#  ['ley',
#   'servicio',
#   'nacional',
#   'lucha',
#   'diabetes',
#   'modificacion',
#   'actualizacion',
#   'programa',
#   'nacional',
#   'ampliacion',
#   'nivel',
#   'cobertura',
#   'tratamiento',
#   'provision',
#   'integral',
#   'medicamento',
#   'insumo',
#   'reactivo',
#   'diagnostico'],
#  ['incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion',
#   'obligatoriedad',
#   'aplicacion',
#   'vacuna',
#   'rotavirus',
#   'nino',
#   'nina',
#   'edad',
#   'mes'],
#  ['programa', 'federal', 'salud', 'educacion', 'republica'],
#  ['ley', 'servicio', 'nacional', 'lucha', 'diabetes', 'modificacion'],
#  ['establecimiento',
#   'sistema',
#   'prestacion',
#   'basica',
#   'deteccion',
#   'prevencion',
#   'asistencia',
#   'dislexia'],
#  ['proteccion',
#   'integral',
#   'derecho',
#   'maternidad',
#   'paternidad',
#   'situacion',
#   'vulnerabilidad'],
#  ['testeado',
#   'animal',
#   'incluir',
#   'leyenda',
#   'identificatorio',
#   'producto',
#   'comercializado',
#   'pais'],
#  ['sistema',
#   'proteccion',
#   'salud',
#   'estudiante',
#   'terciario',
#   'universitario',
#   'regimen'],
#  ['ejercicio', 'profesional', 'cosmetologia', 'cosmiatrio', 'regimen'],
#  ['encuesta',
#   'nacional',
#   'nutricion',
#   'salud',
#   'discapacidad',
#   'ennsdi',
#   'regimen'],
#  ['observatorio', 'social', 'republica', 'argentino'],
#  ['prevencion',
#   'control',
#   'forma',
#   'transmision',
#   'enfermedad',
#   'chagas',
#   'considerar',
#   'prioritario',
#   'caracter',
#   'urgente',
#   'avance',
#   'concrecion',
#   'vacuna'],
#  ['medicamento',
#   'obligatoriedad',
#   'incluir',
#   'prospecto',
#   'leyenda',
#   'indicar',
#   'cantidad',
#   'contenido',
#   'gluten'],
#  ['proteccion', 'embrion', 'implantado'],
#  ['regulacion', 'parto', 'domiciliario'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'quater',
#   'asignacion',
#   'embarazo',
#   'proteccion',
#   'social'],
#  ['acordado',
#   'resolucion',
#   'direccion',
#   'ejecutivo',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'disponer',
#   'publicacion',
#   'boletin',
#   'oficial'],
#  ['incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'integral',
#   'leche',
#   'medicamentos',
#   'consumo',
#   'padecer',
#   'alergia',
#   'proteina',
#   'leche',
#   'vacuna',
#   'aplv'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'medioambiental',
#   'provincia',
#   'cordoba',
#   'prorrogable',
#   'consecuencia',
#   'incendio',
#   'desatado',
#   'setiembre'],
#  ['acceso',
#   'gratuito',
#   'curso',
#   'ensenanza',
#   'auxilio',
#   'reanimacion',
#   'cardiopulmonar'],
#  ['servicio',
#   'nacional',
#   'lucha',
#   'diabetes',
#   'cobertura',
#   'ciento',
#   'medicamento',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'pauta',
#   'antidiscriminatoria',
#   'ingreso',
#   'laboral'],
#  ['habitante',
#   'acreditar',
#   'padecimiento',
#   'fibromialgia',
#   'fibromiositi',
#   'fibrositi',
#   'sindrome',
#   'fatiga',
#   'cronico',
#   'sensibilidad',
#   'quimico',
#   'multiple',
#   'extension',
#   'beneficio',
#   'ley',
#   'sistema',
#   'proteccion',
#   'integral',
#   'persona',
#   'discapacitada',
#   'accesibilidad',
#   'persona',
#   'movilidad',
#   'reducido',
#   'fondo',
#   'permanente',
#   'recompensa'],
#  ['protesis',
#   'mamaria',
#   'estetico',
#   'permitir',
#   'implante',
#   'persona',
#   'capaz',
#   'anos',
#   'cirugia',
#   'reparadora'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'nina',
#   'nino',
#   'adolescente',
#   'regulacion'],
#  ['prohibicion',
#   'exhibicion',
#   'difusion',
#   'promocion',
#   'anuncio',
#   'publicitario',
#   'cualquiera',
#   'formato',
#   'juego',
#   'azar'],
#  ['declarar',
#   'zona',
#   'emergencia',
#   'catastrofir',
#   'localidad',
#   'caleta',
#   'olivia',
#   'provincia',
#   'santa',
#   'cruz',
#   'obra',
#   'necesario',
#   'normalizar',
#   'servicio',
#   'agua',
#   'potable'],
#  ['juego', 'azar', 'regulacion', 'publicidad', 'promocion', 'consumo'],
#  ['creacion',
#   'unidad',
#   'contencion',
#   'duelo',
#   'ucod',
#   'ambito',
#   'efector',
#   'publico',
#   'privado'],
#  ['declarar', 'inter', 'nacional', 'prevencion', 'control', 'fibromialgia'],
#  ['rotulo',
#   'leyendo',
#   'alimento',
#   'exceso',
#   'grasa',
#   'grasa',
#   'saturada',
#   'azucar',
#   'sodio',
#   'nutrient',
#   'identificacion',
#   'envase'],
#  ['declarar',
#   'zona',
#   'emergencia',
#   'desastre',
#   'plazo',
#   'prorrogable',
#   'territorio',
#   'comprendido',
#   'isla',
#   'apipe',
#   'provincia',
#   'corriente',
#   'consecuencia',
#   'apertura',
#   'compuerta',
#   'represa',
#   'yacyreta'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'modificacion',
#   'institucion',
#   'caracter',
#   'nacional',
#   'obligatorio',
#   'universal',
#   'financiamiento',
#   'monto',
#   'prestacion'],
#  ['creacion', 'programa', 'humanitario', 'nacional', 'salud', 'phunad'],
#  ['incentivo',
#   'economico',
#   'suceptibl',
#   'valoracion',
#   'pecuniario',
#   'producto',
#   'medico',
#   'biologico',
#   'farmaceutico',
#   'otorgado',
#   'profesional',
#   'medico',
#   'disponer',
#   'informar',
#   'situacion',
#   'autoridad',
#   'sanitario',
#   'nacional'],
#  ['derecho', 'salud', 'persona', 'problema', 'adiccion'],
#  ['creacion', 'plan', 'nacional', 'lucha', 'enfermedad', 'alzheimer'],
#  ['instituir',
#   'junio',
#   'ano',
#   'nacional',
#   'lucha',
#   'indebido',
#   'trafico',
#   'ilicito',
#   'droga'],
#  ['ley',
#   'identificacion',
#   'rotulo',
#   'medicamento',
#   'efecto',
#   'secundario',
#   'adverso',
#   'disminuir',
#   'capacidad',
#   'conduccion',
#   'vehiculo',
#   'automotor'],
#  ['bebida',
#   'azucarado',
#   'obligatoriedad',
#   'incluir',
#   'envase',
#   'leyenda',
#   'beber',
#   'bebida',
#   'azucarado',
#   'perjudicial',
#   'salud'],
#  ['regimen', 'promocion', 'desarrollo', 'economia', 'social', 'solidario'],
#  ['individualizacion', 'medicamento', 'sistema', 'braille'],
#  ['declarar',
#   'zona',
#   'emergencia',
#   'litoral',
#   'paranaense',
#   'provincia',
#   'mision',
#   'corriente',
#   'chaco',
#   'santa',
#   'rio',
#   'plazo',
#   'noventa',
#   'prorrogable'],
#  ['obligatoriedad',
#   'comunicar',
#   'ministerio',
#   'salud',
#   'nacion',
#   'oficio',
#   'sentencia',
#   'resolucion',
#   'interlocutoria',
#   'dictado',
#   'proceso',
#   'amparo',
#   'medida',
#   'cautelar',
#   'garantizar',
#   'derecho',
#   'salud'],
#  ['obligatoriedad',
#   'implementar',
#   'medida',
#   'seguridad',
#   'jardin',
#   'maternal',
#   'guarderia',
#   'instalacion',
#   'camara',
#   'circuito',
#   'cerrado',
#   'television',
#   'cctv'],
#  ['prevencion',
#   'suicidio',
#   'regimen',
#   'declarar',
#   'inter',
#   'nacional',
#   'atencion',
#   'medica'],
#  ['ley',
#   'programa',
#   'nutricion',
#   'alimentacion',
#   'nacional',
#   'correccion',
#   'retroactivo',
#   'evolucion',
#   'acumulado',
#   'salario',
#   'minimo',
#   'vital',
#   'movil',
#   'normalizacion',
#   'instituto',
#   'nacional',
#   'estadistica',
#   'censo',
#   'indec'],
#  ['instituir',
#   'marzo',
#   'nacional',
#   'medico',
#   'argentino',
#   'conmemoracion',
#   'nacimiento',
#   'profesor',
#   'doctor',
#   'ramon',
#   'carrillo'],
#  ['rotavirus',
#   'incluir',
#   'aplicacion',
#   'calendario',
#   'nacional',
#   'vacunacion'],
#  ['elaboracionir',
#   'plan',
#   'nacional',
#   'contingencia',
#   'caida',
#   'ceniza',
#   'volcanica'],
#  ['instalacion',
#   'videocamara',
#   'circuito',
#   'cerrado',
#   'jardin',
#   'infante',
#   'jardin',
#   'maternal',
#   'guarderia',
#   'geriatrico',
#   'regimen'],
#  ['reparacion',
#   'integral',
#   'igualitario',
#   'familiar',
#   'victima',
#   'fatal',
#   'victima',
#   'sobrevivient',
#   'masacre',
#   'cromanon'],
#  ['ley', 'nacional', 'salud'],
#  ['prevencion',
#   'lavado',
#   'activo',
#   'actividad',
#   'juegos',
#   'azar',
#   'regimen',
#   'modificacion'],
#  ['creacion',
#   'registro',
#   'unico',
#   'dador',
#   'voluntario',
#   'sangre',
#   'hemocomponent',
#   'nacion'],
#  ['regimen', 'proteccion', 'integral', 'persona', 'trasplantado'],
#  ['establecimiento', 'geriatrico', 'regimen'],
#  ['establecer',
#   'obligatoriedad',
#   'exhibir',
#   'listado',
#   'actualizado',
#   'centro',
#   'salud',
#   'farmacia',
#   'turno',
#   'correspondiente',
#   'localidad',
#   'encontrar',
#   'efector',
#   'salud'],
#  ['codigo',
#   'alimentario',
#   'argentino',
#   'porcentaje',
#   'jugo',
#   'bebida',
#   'alcohol'],
#  ['trastorno',
#   'generalizado',
#   'desarrollo',
#   'tgd',
#   'incorporar',
#   'cobertura',
#   'diagnostico',
#   'tratamiento',
#   'demas',
#   'prestacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['enfermedad',
#   'zoonotica',
#   'declarar',
#   'inter',
#   'nacional',
#   'prevencion',
#   'lucha',
#   'creasar',
#   'linea',
#   'gratuito',
#   'recepcion',
#   'denuncia'],
#  ['provision',
#   'agua',
#   'consumo',
#   'personal',
#   'centro',
#   'deportivo',
#   'club',
#   'gimnasio',
#   'publico',
#   'privado'],
#  ['obligatoriedad',
#   'identificacion',
#   'alimento',
#   'contengan',
#   'organismo',
#   'geneticamente',
#   'modificado',
#   'ogm',
#   'derivado'],
#  ['servicio', 'nacional', 'lucha', 'diabetes', 'cobertura', 'obra', 'social'],
#  ['adopcion', 'regimen', 'concientizacion', 'asistencia'],
#  ['consejo', 'nacional', 'evaluacion', 'programa', 'social', 'creacion'],
#  ['ley',
#   'trastorno',
#   'alimentario',
#   'inclusion',
#   'descripcion',
#   'contenido',
#   'calorico',
#   'alimento',
#   'preparado',
#   'envasar',
#   'vista',
#   'consumidor'],
#  ['exigencia',
#   'instalacion',
#   'camara',
#   'circuito',
#   'cerrado',
#   'television',
#   'jardin',
#   'maternal',
#   'guarderia',
#   'geriatrico'],
#  ['ley',
#   'salud',
#   'publicar',
#   'sancion',
#   'omision',
#   'notificacion',
#   'obligatorio',
#   'caso',
#   'enfermedad',
#   'infeccioso'],
#  ['trasplante', 'organo', 'material', 'anatomico', 'gasto', 'donante'],
#  ['obra',
#   'social',
#   'empresa',
#   'medicina',
#   'prepagar',
#   'ampliacion',
#   'cobertura',
#   'leche',
#   'maternizado',
#   'medicamentos'],
#  ['derecho',
#   'paciente',
#   'relacion',
#   'profesional',
#   'institucion',
#   'salud',
#   'ley',
#   'sustitucion',
#   'articulo',
#   'asiento',
#   'historia',
#   'clinico'],
#  ['codigo',
#   'alimentario',
#   'nacional',
#   'agua',
#   'potable',
#   'agua',
#   'gasificado',
#   'respectivamente'],
#  ['obligatoriedad',
#   'identificar',
#   'rotulado',
#   'claramente',
#   'visible',
#   'empaque',
#   'producto',
#   'geneticamente',
#   'modificado',
#   'origen',
#   'transgenico'],
#  ['refugio', 'digno', 'regimen'],
#  ['informacion',
#   'consumidor',
#   'etiquetado',
#   'alimento',
#   'bebida',
#   'transgenico',
#   'contener',
#   'organismo',
#   'geneticamente',
#   'modificado'],
#  ['informacion',
#   'consumidor',
#   'etiquetado',
#   'bebida',
#   'contenido',
#   'calorico',
#   'etiquetado',
#   'bebida',
#   'alcoholica'],
#  ['incorporacion',
#   'calendario',
#   'control',
#   'oftalmologico',
#   'examen',
#   'visual',
#   'plan',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'vigente'],
#  ['programa',
#   'nacional',
#   'prevencion',
#   'tratamiento',
#   'rehabilitacion',
#   'seguimiento',
#   'accidente',
#   'cerebrovascular',
#   'acv',
#   'acvo',
#   'creacion'],
#  ['creacion',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'derogacion',
#   'ley',
#   'modificatoria',
#   'decreto'],
#  ['programa',
#   'probienestar',
#   'sustituir',
#   'complemento',
#   'alimentario',
#   'otorgado',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'suma',
#   'dinero',
#   'equivalente'],
#  ['plan', 'nacional', 'lucha', 'enfermedad', 'alzheimer', 'creacion'],
#  ['instalacion',
#   'desfibrilador',
#   'externo',
#   'automatico',
#   'espacio',
#   'publico',
#   'privado'],
#  ['inundacion',
#   'ocurrido',
#   'abril',
#   'declarar',
#   'zona',
#   'desastre',
#   'prorrogable',
#   'diverso',
#   'barrio',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'diverso',
#   'localidad',
#   'provincia',
#   'aires'],
#  ['respuesta', 'solidario', 'inundacion', 'abril'],
#  ['declarar',
#   'emergencia',
#   'social',
#   'economio',
#   'habitacional',
#   'causa',
#   'inundacion',
#   'ocurrido',
#   'abril',
#   'afectar',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'provincia',
#   'aires',
#   'ciudad',
#   'plata',
#   'localidad',
#   'conurbano',
#   'bonaerense'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'establecimiento',
#   'regimen',
#   'reparacion',
#   'asistencia',
#   'favor',
#   'damnificado',
#   'inundacion',
#   'acaecido',
#   'abril',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'diverso',
#   'partido',
#   'provincia',
#   'aires'],
#  ['creacion', 'plan', 'nacional', 'enfermedad', 'alzheimer', 'demencia'],
#  ['asignacion', 'familiar', 'asignacion', 'ayuda', 'escolar'],
#  ['comercializacion', 'especialidad', 'medicinal', 'regulacion'],
#  ['instituto',
#   'nacional',
#   'promocion',
#   'salud',
#   'calidad',
#   'vida',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'termino',
#   'ciento',
#   'ochenta',
#   'prorrogable',
#   'distrito',
#   'plata',
#   'berisso',
#   'ensenada',
#   'provincia',
#   'ari'],
#  ['creacion', 'fondo', 'integral', 'reparacion', 'victima', 'inundacion'],
#  ['creacion',
#   'plan',
#   'nacional',
#   'solucion',
#   'integral',
#   'persona',
#   'afectado',
#   'inundacion'],
#  ['subsidio',
#   'especial',
#   'reparacion',
#   'victima',
#   'inundacion',
#   'ocurrido',
#   'abril',
#   'creacion'],
#  ['diverso',
#   'zona',
#   'provincia',
#   'aires',
#   'barrio',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social'],
#  ['incremento',
#   'asignacion',
#   'familiar',
#   'modificacion',
#   'parrafo',
#   'articulo',
#   'ley'],
#  ['obra',
#   'social',
#   'mutual',
#   'cooperativo',
#   'asociacion',
#   'entidad',
#   'cuidado',
#   'salud',
#   'recupero',
#   'costo',
#   'prestacion',
#   'caso',
#   'afiliado',
#   'doble',
#   'cobertura'],
#  ['creacion',
#   'asignacion',
#   'universal',
#   'ayuda',
#   'escolar',
#   'ley',
#   'asignacion',
#   'familiar',
#   'derogacion',
#   'inciso',
#   'articulo',
#   'articulo',
#   'inciso',
#   'articulo',
#   'articulo'],
#  ['regulacion',
#   'publicidad',
#   'promocion',
#   'consumo',
#   'producto',
#   'elaborado',
#   'tabaco',
#   'ley',
#   'numerir',
#   'modificacion',
#   'composicion',
#   'producto'],
#  ['creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion',
#   'registro',
#   'unico',
#   'tumor',
#   'maligno'],
#  ['incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'leches',
#   'medicamentosa',
#   'consumido',
#   'sufrir',
#   'alergia',
#   'proteina',
#   'leche',
#   'vacuna',
#   'aplv',
#   'sufrir',
#   'padecer',
#   'desorden',
#   'enfermedad',
#   'trastorno',
#   'gastrointestinal',
#   'eosinofilico'],
#  ['promover',
#   'difusion',
#   'concientizacion',
#   'relevancia',
#   'lavado',
#   'mano',
#   'accion',
#   'eficaz',
#   'prevenir',
#   'enfermedad',
#   'transmisibl',
#   'contacto'],
#  ['edificacion',
#   'centro',
#   'integral',
#   'rehabilitacion',
#   'persona',
#   'enfermedad',
#   'adiccion',
#   'atencion',
#   'salud',
#   'mental',
#   'denominado',
#   'san',
#   'expedito',
#   'municipio',
#   'mojon',
#   'provincia',
#   'mision'],
#  ['programa', 'nacional', 'prevencion', 'cancer', 'prostata', 'creacion'],
#  ['obligacion',
#   'indicar',
#   'etiqueta',
#   'producto',
#   'alimenticio',
#   'sustancia',
#   'alimenticio',
#   'bebida',
#   'cuyo',
#   'caracteristica',
#   'adaptar',
#   'consumo',
#   'persona',
#   'diabetica',
#   'leyenda',
#   'apto',
#   'diabetico'],
#  ['atencion',
#   'victima',
#   'delito',
#   'sexual',
#   'prevencion',
#   'enfermedad',
#   'regimen'],
#  ['jubilacion',
#   'pension',
#   'servicio',
#   'medico',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'persona',
#   'ano',
#   'edad',
#   'sexo',
#   'femenino',
#   'ano',
#   'edad',
#   'persona',
#   'sexo',
#   'masculino',
#   'acreditar',
#   'domicilio',
#   'pais',
#   'lapso',
#   'inferior',
#   'anos'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'ley', 'regulacion'],
#  ['ejercicio',
#   'profesion',
#   'terapeuta',
#   'ocupacional',
#   'terapista',
#   'ocupacional',
#   'licenciado',
#   'terapia',
#   'ocupacional',
#   'regimen'],
#  ['creacion',
#   'servicio',
#   'obligatorio',
#   'social',
#   'ciudadano',
#   'argentino',
#   'servicio',
#   'nacional',
#   'revestir',
#   'servicio',
#   'comunitario',
#   'servicio',
#   'militar',
#   'voluntario',
#   'tratamiento',
#   'rehabilitacion',
#   'adiccion'],
#  ['regimen', 'soberania', 'alimentario'],
#  ['obligatoriedad',
#   'rotulacion',
#   'adecuado',
#   'informar',
#   'fecha',
#   'vencimiento',
#   'producto',
#   'especialidad',
#   'medicinal'],
#  ['presupuesto',
#   'minimo',
#   'prevencion',
#   'accidente',
#   'grave',
#   'intervengar',
#   'sustancia',
#   'peligroso'],
#  ['modificacion',
#   'escala',
#   'prestacion',
#   'asignacion',
#   'hijo',
#   'asignacion',
#   'ayuda',
#   'escolar',
#   'anual',
#   'regimen',
#   'asignacion',
#   'familiar',
#   'ley'],
#  ['asistencia',
#   'alimentario',
#   'especial',
#   'paciente',
#   'diabetico',
#   'situacion',
#   'vulnerabilidad',
#   'inclusion',
#   'programa',
#   'asistencia',
#   'alimentario'],
#  ['programa',
#   'federal',
#   'desarrollo',
#   'tratamiento',
#   'efectivo',
#   'alzheimer',
#   'enfermedad',
#   'neurodegenerativo',
#   'relacionado',
#   'creacion'],
#  ['nacional',
#   'instituto',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'pami',
#   'instituir',
#   'mayo',
#   'ano'],
#  ['suplemento',
#   'dietario',
#   'creatin',
#   'monohidratado',
#   'comercializacion',
#   'exclusivo',
#   'farmacia',
#   'habilitado',
#   'prohibicion'],
#  ['hepatitis',
#   'incorporar',
#   'integrante',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'diagnostico',
#   'tratamiento'],
#  ['planta',
#   'medicinal',
#   'droga',
#   'vegetal',
#   'medicamento',
#   'fitoterapicos',
#   'promocion',
#   'distribucion',
#   'expendio',
#   'regimen',
#   'derogacion',
#   'articulo',
#   'ejercicio',
#   'actividad',
#   'farmaceutico'],
#  ['medicamento', 'braille', 'regimen'],
#  ['cuidado',
#   'paliativo',
#   'promover',
#   'muerte',
#   'natural',
#   'digno',
#   'creacion',
#   'comision',
#   'nacional',
#   'cuidado',
#   'paliativo',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['examen', 'medico', 'prenupcial'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'recoleccion',
#   'medicamento',
#   'vencido',
#   'domiciliario'],
#  ['celula',
#   'madr',
#   'cordon',
#   'umbilical',
#   'capacitacion',
#   'almacenamiento',
#   'investigacion',
#   'aplicacion',
#   'donacion',
#   'obligatorio',
#   'anonimo',
#   'gratuito'],
#  ['pediculosis',
#   'implementar',
#   'campana',
#   'lucha',
#   'transcurso',
#   'ano',
#   'lectivo'],
#  ['enfermedad',
#   'cronico',
#   'psoriasis',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'inclusion',
#   'resolucion',
#   'cobertura',
#   'medicamento'],
#  ['plan',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'inclusion',
#   'tratamiento',
#   'laser',
#   'malformacion',
#   'vascular',
#   'congenita',
#   'adquirido',
#   'llamado',
#   'mancha',
#   'vino',
#   'oporto'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'ciento',
#   'ochenta',
#   'prorrogable',
#   'diverso',
#   'municipio',
#   'valle',
#   'rio',
#   'negro'],
#  ['jardin',
#   'maternal',
#   'guarderia',
#   'geriatrico',
#   'centro',
#   'similar',
#   'caracteristica',
#   'instalacion',
#   'equipo',
#   'herramienta',
#   'tecnologica',
#   'permitir',
#   'monitoreo',
#   'permanente',
#   'dependencia',
#   'utilizar',
#   'prestar',
#   'servicio',
#   'albergue',
#   'atencion',
#   'cuidado'],
#  ['considerese',
#   'psoriasis',
#   'enfermedad',
#   'cronico',
#   'incluyendolo',
#   'resolucion',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['regular',
#   'acceso',
#   'gratuito',
#   'agua',
#   'beber',
#   'lugar',
#   'acceso',
#   'publico'],
#  ['creacion', 'region', 'sanitario', 'aires'],
#  ['sistema',
#   'integral',
#   'proteccion',
#   'persona',
#   'discapacitada',
#   'ley',
#   'efecto',
#   'articulo',
#   'considerar',
#   'persona',
#   'discapacidad',
#   'visceral',
#   'afectado',
#   'trastorno',
#   'hereditario',
#   'hemoglobina',
#   'requerir',
#   'tratamiento',
#   'permanente',
#   'sobrevivir',
#   'incorporacion',
#   'prestacion',
#   'obligatorio',
#   'obra',
#   'social',
#   'agente',
#   'salud'],
#  ['asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ley',
#   'decreto',
#   'actualizacion',
#   'periodico',
#   'automatico',
#   'modificar',
#   'salario',
#   'minimo',
#   'vital',
#   'movil'],
#  ['soberania', 'alimentario', 'regimen'],
#  ['programa',
#   'federal',
#   'equinoterapia',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['protector', 'solar', 'obligatoriedad', 'cobertura', 'obra', 'social'],
#  ['registro',
#   'nacional',
#   'infeccion',
#   'intrahospitalaria',
#   'nosocomial',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['maquina',
#   'tragamonedas',
#   'creasar',
#   'impuesto',
#   'emergencia',
#   'explotacion',
#   'mejorar',
#   'jubilacion',
#   'pension',
#   'minima',
#   'subsidio',
#   'persona',
#   'discapacidad'],
#  ['asignacion',
#   'familiar',
#   'ajuste',
#   'ayuda',
#   'escolar',
#   'anual',
#   'coeficiente',
#   'zonal',
#   'respectivamente'],
#  ['persona',
#   'enferma',
#   'miastenia',
#   'gravis',
#   'semana',
#   'lucha',
#   'miastenia',
#   'gravis',
#   'instituyase',
#   'junio',
#   'ano',
#   'semana',
#   'mes',
#   'comprender',
#   'respectivamente'],
#  ['creacion',
#   'regimen',
#   'represion',
#   'penal',
#   'juego',
#   'azar',
#   'apuesta',
#   'mutuo',
#   'actividad',
#   'conexa',
#   'caracter',
#   'clandestino'],
#  ['programa',
#   'nacional',
#   'universal',
#   'obligatorio',
#   'nutricion',
#   'infantil',
#   'estimulacion',
#   'pronin',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['regimen',
#   'especial',
#   'donacion',
#   'alimento',
#   'creacion',
#   'registro',
#   'nacional',
#   'entidad',
#   'receptor',
#   'donacion',
#   'alimenticio'],
#  ['ejercicio', 'enfermeria', 'resguardo', 'salud', 'fisico', 'psiquico'],
#  ['persona',
#   'nacido',
#   'fertilizacion',
#   'asistido',
#   'acceso',
#   'informacion',
#   'referente',
#   'identidad',
#   'genetico'],
#  ['calendario',
#   'nacional',
#   'vacunacion',
#   'incorporacion',
#   'obligatoriedad',
#   'gratuidad',
#   'administracion',
#   'vacuna',
#   'rotavirus',
#   'nino',
#   'mes'],
#  ['regimen', 'asignacion', 'familiar', 'actualizacion', 'beneficio'],
#  ['ley',
#   'celiaquia',
#   'ley',
#   'reduccion',
#   'alicuota',
#   'impuesto',
#   'valor',
#   'agregado',
#   'iva',
#   'producto',
#   'libre',
#   'gluten',
#   'destinado',
#   'persona',
#   'celiaca'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporacion',
#   'cobertura',
#   'tratamiento',
#   'psoriasis'],
#  ['responsable',
#   'pila',
#   'bateria',
#   'indicacion',
#   'advertencia',
#   'contaminacion',
#   'ambiental',
#   'envase',
#   'producto',
#   'requeir',
#   'utilizacion'],
#  ['regimen',
#   'asistencia',
#   'proteccion',
#   'integral',
#   'persona',
#   'trasplantado'],
#  ['regulacion',
#   'implementacion',
#   'politica',
#   'publicar',
#   'control',
#   'enfermedad',
#   'prevenibl',
#   'vacunacion'],
#  ['instituto',
#   'nacional',
#   'enfermedad',
#   'visual',
#   'inevi',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['obligatoriedad',
#   'contar',
#   'asiento',
#   'especial',
#   'obeso',
#   'reparticion',
#   'estatal',
#   'local',
#   'privado',
#   'atencion',
#   'publico'],
#  ['nacional', 'fibrosis', 'quistico', 'instituir', 'septiembre', 'ano'],
#  ['soberania',
#   'alimentario',
#   'instituir',
#   'octubre',
#   'ano',
#   'inclusion',
#   'calendario',
#   'escolar'],
#  ['epidermis',
#   'bulos',
#   'creacion',
#   'sistema',
#   'proteccion',
#   'integral',
#   'persona',
#   'padecer',
#   'enfermedad'],
#  ['accidente',
#   'cerebrovascular',
#   'acv',
#   'acvo',
#   'regimen',
#   'promover',
#   'prevencion',
#   'tratamiento',
#   'rehabilitacion',
#   'seguimiento',
#   'paciente'],
#  ['hotel',
#   'restaurante',
#   'confiteria',
#   'caf',
#   'obligatoriedad',
#   'incluir',
#   'menu',
#   'apto',
#   'diabetico'],
#  ['fortalecimiento',
#   'financiero',
#   'red',
#   'publicar',
#   'estatal',
#   'servicio',
#   'salud',
#   'regimen'],
#  ['lealtad', 'actividad', 'solidario', 'regimen'],
#  ['ejercicio', 'enfermeria', 'regimen', 'reforma', 'ley'],
#  ['registro',
#   'unico',
#   'voluntario',
#   'donante',
#   'sangre',
#   'hemocomponent',
#   'persona',
#   'cuyo',
#   'grupo',
#   'sanguineo',
#   'grupo',
#   'factor',
#   'cero',
#   'negativo',
#   'universal',
#   'creacion'],
#  ['programa',
#   'nacional',
#   'enfermedad',
#   'neurologica',
#   'cronica',
#   'pnenc',
#   'creacion'],
#  ['persona',
#   'ostomizada',
#   'incluir',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'tratamiento'],
#  ['fondo', 'ingreso', 'ciudadano', 'ninez', 'fincini', 'creacion'],
#  ['perdido',
#   'audicion',
#   'advertencia',
#   'dispositivo',
#   'movil',
#   'reproduccion',
#   'musica'],
#  ['comit', 'salud', 'condicion', 'ambiente', 'trabajo', 'creacion'],
#  ['desfibrilador',
#   'externo',
#   'automatico',
#   'establecer',
#   'instalacion',
#   'espacio',
#   'publico',
#   'cardioprotegido',
#   'cardioseguro'],
#  ['programa',
#   'nacional',
#   'nutricion',
#   'alimentacion',
#   'promocion',
#   'compra',
#   'alimento',
#   'producido',
#   'agricultor',
#   'inscripto',
#   'registro',
#   'nacional',
#   'agricultura',
#   'familiar',
#   'renaf'],
#  ['recurso',
#   'humano',
#   'anestesiologio',
#   'declaracion',
#   'emergencia',
#   'nacional',
#   'creacion',
#   'plan',
#   'nacional',
#   'desarrollo',
#   'anestesiologia'],
#  ['declarar',
#   'aceite',
#   'oliva',
#   'alimento',
#   'nacional',
#   'implementacion',
#   'programa',
#   'federal',
#   'promocion'],
#  ['investigacion', 'biomedico', 'humano', 'regulacion'],
#  ['alimento',
#   'golosina',
#   'apto',
#   'celiaco',
#   'obligatoriedad',
#   'comercializacion',
#   'establecimiento',
#   'educativo'],
#  ['inclusion',
#   'tratamiento',
#   'enfermedad',
#   'linfedema',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['creacion', 'consejo', 'nacional', 'bioetica'],
#  ['regimen',
#   'trazabilidad',
#   'verificacion',
#   'aptitud',
#   'tecnico',
#   'recurso',
#   'tecnologico',
#   'salud'],
#  ['necropsio',
#   'obligatoriedad',
#   'practica',
#   'muerte',
#   'extrainstitucional',
#   'nino',
#   'menor',
#   'ano',
#   'mediacion',
#   'intervencion',
#   'judicial'],
#  ['programa',
#   'federal',
#   'salud',
#   'profe',
#   'disponer',
#   'transferencia',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp'],
#  ['declarar',
#   'inter',
#   'camaro',
#   'xii',
#   'congreso',
#   'argentino',
#   'congreso',
#   'internacional',
#   'epidemiologia',
#   'control',
#   'infeccion',
#   'seguridad',
#   'paciente',
#   'realizar',
#   'el',
#   'septiembre',
#   'ciudad',
#   'autonoma',
#   'aires'],
#  ['creacion',
#   'marco',
#   'anses',
#   'registro',
#   'unico',
#   'beneficiario',
#   'plan',
#   'social',
#   'ministerio',
#   'desarrollo',
#   'social',
#   'nacion'],
#  ['garantiar',
#   'nacional',
#   'dignidad',
#   'integridad',
#   'confidencialidad',
#   'identidad',
#   'profesional',
#   'investigacion',
#   'salud'],
#  ['incorporacion', 'alimento', 'bebida', 'saludable', 'maquina', 'expendedor'],
#  ['institucion', 'paciente', 'junio', 'ano'],
#  ['ley',
#   'lucha',
#   'sida',
#   'universalizacion',
#   'realizacion',
#   'test',
#   'vih',
#   'mujer',
#   'embarazado'],
#  ['establecimiento',
#   'productivo',
#   'capacitacion',
#   'rehabilitacion',
#   'salud',
#   'mental',
#   'creacion'],
#  ['garantizar',
#   'cobertura',
#   'basico',
#   'menor',
#   'edad',
#   'sufrir',
#   'intolerancia',
#   'lactos'],
#  ['estudio',
#   'oximetria',
#   'pulso',
#   'nino',
#   'recien',
#   'nacido',
#   'implementacion',
#   'ley'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regulacion',
#   'kiosco',
#   'escolar'],
#  ['fondo',
#   'nacional',
#   'especial',
#   'atencion',
#   'enfermedad',
#   'catastrofica',
#   'creacion'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regulacion',
#   'kiosco',
#   'escolar'],
#  ['ley',
#   'presupuesto',
#   'minimo',
#   'gestion',
#   'ambiental',
#   'agua',
#   'elaboracion',
#   'relevamiento',
#   'consumo'],
#  ['comite',
#   'especialista',
#   'analisis',
#   'estudio',
#   'investigacion',
#   'prevencion',
#   'morbimortalidad',
#   'materno',
#   'traves',
#   'comit',
#   'hospitalarios',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['comida',
#   'hipercalorico',
#   'declarar',
#   'inter',
#   'nacional',
#   'lucha',
#   'proteccion',
#   'salud',
#   'nino',
#   'adolescente'],
#  ['obra', 'social', 'administracion', 'obra', 'social'],
#  ['percloroetileno',
#   'prohibicion',
#   'tintoreria',
#   'lavanderia',
#   'radicado',
#   'territorio',
#   'nacional'],
#  ['ejercicio', 'profesional', 'musicoterapia', 'regimen'],
#  ['sistema', 'historia', 'clinico', 'digital', 'creacion'],
#  ['sodio', 'regimen', 'promover', 'reduccion', 'consumo', 'poblacion'],
#  ['ejercicio',
#   'profesional',
#   'partero',
#   'licenciado',
#   'obstetrico',
#   'regulacion'],
#  ['declarar',
#   'nacional',
#   'argentina',
#   'chagas',
#   'viernes',
#   'mes',
#   'agosto',
#   'ano'],
#  ['prevencion',
#   'control',
#   'forma',
#   'transmision',
#   'enfermedad',
#   'chagas',
#   'realizacion',
#   'examen',
#   'forma',
#   'gratuito',
#   'establecimiento',
#   'sanitario',
#   'oficial',
#   'creacion',
#   'hospital',
#   'publico',
#   'consultorio',
#   'chaga',
#   'respectivamente'],
#  ['alimento',
#   'bebida',
#   'saludable',
#   'incorporacion',
#   'venta',
#   'maquina',
#   'automatica',
#   'expendedora'],
#  ['asignacion',
#   'familiar',
#   'top',
#   'salarial',
#   'acceder',
#   'beneficio',
#   'ajuste',
#   'automatico'],
#  ['declarar', 'abril', 'ano', 'cardiologia', 'argentino'],
#  ['salud',
#   'publicar',
#   'derecho',
#   'paciente',
#   'relacion',
#   'profesional',
#   'institucion',
#   'salud',
#   'ley',
#   'incorporacion',
#   'inciso',
#   'articulo',
#   'excepcion',
#   'consentimiento',
#   'informado',
#   'caso',
#   'vacunacion',
#   'obligatorio'],
#  ['daltonismo',
#   'declarar',
#   'inter',
#   'nacional',
#   'actividad',
#   'destinado',
#   'mitigar',
#   'contrarrestar',
#   'consecuencia'],
#  ['asignacion',
#   'familiar',
#   'ley',
#   'derogacion',
#   'articulo',
#   'exclusion',
#   'prestacion',
#   'eliminacion',
#   'top',
#   'maximo',
#   'remuneracion',
#   'establecido',
#   'articulo'],
#  ['amparo', 'alimentario', 'regimen'],
#  ['medicina', 'prepagar', 'sancion', 'incumplimiento'],
#  ['impuesto',
#   'emergencia',
#   'complementario',
#   'actividad',
#   'explotacion',
#   'privado',
#   'juego',
#   'azar',
#   'concesionada',
#   'loteria',
#   'nacional',
#   'sociedad',
#   'creacion'],
#  ['alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regimen',
#   'promocion',
#   'prevencion'],
#  ['muerte',
#   'subitar',
#   'regimen',
#   'prevencion',
#   'espacio',
#   'publico',
#   'privado',
#   'acceso',
#   'publico'],
#  ['reproduccion', 'humano', 'asistido', 'regimen'],
#  ['ley',
#   'enfermedad',
#   'celiaco',
#   'inclusion',
#   'menu',
#   'gastronomico',
#   'alimento',
#   'leyenda',
#   'libre',
#   'gluten'],
#  ['fertilizacion', 'humano', 'asistido'],
#  ['obra',
#   'social',
#   'inciso',
#   'articulo',
#   'continuidad',
#   'categoria',
#   'beneficiario',
#   'periodo',
#   'mes',
#   'contado',
#   'extincion'],
#  ['hipermercado',
#   'supermercado',
#   'cadena',
#   'comercio',
#   'alimento',
#   'bebida',
#   'obligatoriedad',
#   'incluir',
#   'gondola',
#   'alimento',
#   'bebida',
#   'apto',
#   'diabetico'],
#  ['nacional', 'medico', 'argentino', 'instituir', 'julio', 'ano'],
#  ['diverso',
#   'localidad',
#   'provincia',
#   'aires',
#   'declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'hidrico',
#   'economico',
#   'social',
#   'agropecuario',
#   'termino',
#   'prorrogable'],
#  ['declarar',
#   'emergencia',
#   'nacional',
#   'recurso',
#   'humano',
#   'enfermeria',
#   'promover',
#   'inclusion',
#   'articulo',
#   'ley',
#   'educacion',
#   'superior'],
#  ['creacion',
#   'fondo',
#   'promocion',
#   'difusion',
#   'educacion',
#   'salud',
#   'prevencion',
#   'enfermedad'],
#  ['diverso',
#   'departamento',
#   'provincia',
#   'rioja',
#   'declaracion',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'prorrogable',
#   'consecuencia',
#   'crecida',
#   'rio',
#   'tormenta',
#   'ocurrido',
#   'mes',
#   'enero',
#   'febrero'],
#  ['fertilizacion',
#   'asistido',
#   'inclusion',
#   'tratamiento',
#   'plan',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['sangre', 'informacion', 'relacionado', 'salud', 'donante', 'receptor'],
#  ['vacuna',
#   'virus',
#   'papiloma',
#   'humano',
#   'tipo',
#   'incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion',
#   'caracter',
#   'gratuito',
#   'obligatorio',
#   'mujer',
#   'anos',
#   'edad'],
#  ['obligatoriedad',
#   'examen',
#   'oftalmologico',
#   'caracter',
#   'anual',
#   'neonato',
#   'recien',
#   'nacido',
#   'nino',
#   'comprendido',
#   'etapa',
#   'infancia',
#   'anos',
#   'edad'],
#  ['declarar',
#   'inter',
#   'prioritario',
#   'sanitario',
#   'territorio',
#   'republica',
#   'argentino',
#   'enfermedad',
#   'alzheimer',
#   'demencia',
#   'senil'],
#  ['lent',
#   'pre',
#   'graduado',
#   'sol',
#   'autorizado',
#   'recetado',
#   'prohibir',
#   'importacion',
#   'distribucion',
#   'comercializacion',
#   'venta'],
#  ['producto', 'elaborado', 'tabaco', 'reduccion', 'consumo'],
#  ['sodio', 'regulacion', 'contenido', 'industria', 'alimentacion'],
#  ['regimen', 'fertilizacion', 'humano', 'asistido'],
#  ['creacion', 'plan', 'federal', 'formacion', 'empleo', 'enfermero'],
#  ['vacuna',
#   'rotavirus',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['nacional',
#   'reivindicacion',
#   'derecho',
#   'social',
#   'instituir',
#   'mayo',
#   'ano',
#   'conmemoracion',
#   'natalicio',
#   'maria',
#   'eva',
#   'duartar'],
#  ['declarar',
#   'nacional',
#   'tecnico',
#   'hemoterapia',
#   'inmunohematologia',
#   'noviembre',
#   'ano'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regimen'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'modificacion',
#   'top',
#   'rango',
#   'beneficio'],
#  ['programa',
#   'nacional',
#   'prevencion',
#   'tratamiento',
#   'seguimiento',
#   'enfermedad',
#   'denominado',
#   'retinoblastoma'],
#  ['obra',
#   'social',
#   'asociacion',
#   'obra',
#   'social',
#   'entidad',
#   'medicina',
#   'prepagar',
#   'obligatoriedad',
#   'aplicar',
#   'tecnica',
#   'deteccion',
#   'acido',
#   'nucleico',
#   'metodo',
#   'analisi',
#   'sanguineo',
#   'transfusion'],
#  ['asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ley',
#   'sustitucion',
#   'inciso',
#   'articulo',
#   'ter',
#   'control',
#   'sanitario',
#   'plan',
#   'vacunacion',
#   'acreditacion',
#   'concurrencia',
#   'establecimiento',
#   'educativo',
#   'publico',
#   'publico',
#   'gestion',
#   'privado'],
#  ['emergencia',
#   'hospitalario',
#   'sanitario',
#   'declarar',
#   'provincia',
#   'santa',
#   'cruz'],
#  ['vacuna',
#   'varicela',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['ley',
#   'ejercicio',
#   'medicina',
#   'odontologio',
#   'actividad',
#   'colaboracion',
#   'sustitucion',
#   'inciso',
#   'articulo',
#   'impresion',
#   'receta',
#   'dato',
#   'profesional'],
#  ['asignacion',
#   'familiar',
#   'derogacion',
#   'articulo',
#   'exclusion',
#   'prestacion',
#   'sustitucion',
#   'articulo',
#   'monto',
#   'prestacion',
#   'otorgar'],
#  ['prohibicion',
#   'comercializacion',
#   'aplicacion',
#   'herbicida',
#   'contener',
#   'glifosato'],
#  ['programa',
#   'nacional',
#   'deteccion',
#   'atencion',
#   'hipoacusia',
#   'financiamiento'],
#  ['prohibicion',
#   'emplear',
#   'cualquiera',
#   'elemento',
#   'medico',
#   'contenido',
#   'ftalato'],
#  ['asistencia',
#   'psicologico',
#   'psiquiatrico',
#   'cargo',
#   'persona',
#   'sufrir',
#   'algun',
#   'dano',
#   'consecuencia',
#   'accidente',
#   'catastrof'],
#  ['evaluacion',
#   'obligatorio',
#   'programa',
#   'social',
#   'creacion',
#   'agencia',
#   'nacional',
#   'evaluacion'],
#  ['obra', 'social', 'beneficiario'],
#  ['sindrome',
#   'prader',
#   'willi',
#   'spw',
#   'obligacion',
#   'estudio',
#   'cromosomatico',
#   'existir',
#   'posibilidad',
#   'anomalia',
#   'genetico',
#   'presentar',
#   'antecedente',
#   'cobertura',
#   'obra',
#   'social'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regimen'],
#  ['fondo',
#   'especial',
#   'fortalecimiento',
#   'atencion',
#   'primaria',
#   'salud',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['asignacion',
#   'familiar',
#   'bis',
#   'asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social'],
#  ['prevencion',
#   'sancion',
#   'manejo',
#   'espurio',
#   'fondo',
#   'publico',
#   'destinado',
#   'politica',
#   'social'],
#  ['trasplante',
#   'organo',
#   'material',
#   'anatomico',
#   'otorgamiento',
#   'empresa',
#   'transporte',
#   'aereo',
#   'plaza',
#   'incucai',
#   'solicitar',
#   'traslado',
#   'paciente',
#   'organo',
#   'asignado'],
#  ['ejercicio', 'profesional', 'obstetricia', 'regimen'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'ciento',
#   'ochenta',
#   'prorrogable',
#   'diverso',
#   'localidad',
#   'provincia',
#   'rio',
#   'negro'],
#  ['cuidado', 'paliativo', 'regimen'],
#  ['prevencion', 'tratamiento', 'infertilidad', 'regimen'],
#  ['cartel',
#   'leyenda',
#   'consumo',
#   'excesivo',
#   'sal',
#   'perjudicial',
#   'salud',
#   'exhibicion',
#   'lugar',
#   'acceso',
#   'publico',
#   'comercialicir',
#   'consumar',
#   'comida',
#   'bebida'],
#  ['regulacion',
#   'cadena',
#   'frio',
#   'medicamento',
#   'testigo',
#   'temperatura',
#   'sancion'],
#  ['asignacion', 'familiar', 'movilidad', 'topes', 'rango', 'remuneratorio'],
#  ['reconocimiento',
#   'medico',
#   'obligatorio',
#   'ciudadano',
#   'sexo',
#   'cumplir',
#   'edad',
#   'dieciseis',
#   'ano',
#   'establecimiento'],
#  ['clausula',
#   'actualizacion',
#   'asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ano',
#   'incorporacion',
#   'parrafo',
#   'articulo',
#   'ley',
#   'asignacion',
#   'familiar'],
#  ['aprobacion', 'pacto', 'federal', 'legislativo', 'salud'],
#  ['cobertura',
#   'obra',
#   'social',
#   'entidad',
#   'medicina',
#   'prepagar',
#   'tira',
#   'reactiva',
#   'glucos',
#   'sangre'],
#  ['investigacion',
#   'desarrollo',
#   'formulacion',
#   'produccion',
#   'acceso',
#   'medicamento',
#   'medida',
#   'nino',
#   'regimen'],
#  ['regimen', 'regulacion', 'practica', 'piercing', 'tatuaj', 'perforacion'],
#  ['instituir', 'octubre', 'ano', 'nacional', 'osteoporosis'],
#  ['instalacion',
#   'quiosco',
#   'saludable',
#   'colegio',
#   'ensenanza',
#   'primario',
#   'secundario',
#   'publicar',
#   'privado',
#   'regimen'],
#  ['regimen', 'ejercicio', 'profesional', 'musicoterapia'],
#  ['psoriasis',
#   'inclusion',
#   'cobertura',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'terapia',
#   'biologica',
#   'tratamiento'],
#  ['instalacion',
#   'desfibrilador',
#   'externo',
#   'automatico',
#   'espacio',
#   'publico',
#   'privado'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'investigacion',
#   'tratamiento',
#   'atrofia',
#   'muscular',
#   'espinal',
#   'ame'],
#  ['monodroga',
#   'denominado',
#   'misoprostol',
#   'prohibicion',
#   'produccion',
#   'distribucion',
#   'comercializacion',
#   'venta'],
#  ['codigo',
#   'alimentario',
#   'argentino',
#   'capitulo',
#   'norma',
#   'rotulacion',
#   'alimento',
#   'incorporacion',
#   'punto',
#   'rotulo',
#   'sistema',
#   'braille'],
#  ['ley', 'sangre', 'dato', 'salud', 'donante'],
#  ['tabaquismo',
#   'ley',
#   'exhibicion',
#   'leyenda',
#   'fumar',
#   'perjudicial',
#   'salud',
#   'escena',
#   'televisivo',
#   'cinematografica',
#   'consumar',
#   'producto',
#   'elaborado',
#   'tabaco'],
#  ['ley', 'sangre', 'exigencia', 'deber', 'cumplir', 'donante', 'cuestionario'],
#  ['consultoria',
#   'ciudadano',
#   'vida',
#   'situacion',
#   'mistanasica',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['codigo',
#   'alimentario',
#   'nacional',
#   'agua',
#   'potable',
#   'agua',
#   'gasificado'],
#  ['educacion', 'alimentario', 'nutricional', 'regimen'],
#  ['prohibicion',
#   'publicitar',
#   'modelo',
#   'cuyo',
#   'indice',
#   'masa',
#   'muscular',
#   'encontrar',
#   'parametro',
#   'saludable',
#   'establecido',
#   'organizacion',
#   'mundial',
#   'salud'],
#  ['derecho',
#   'establecimiento',
#   'salud',
#   'publicar',
#   'privado',
#   'proceso',
#   'nacimiento',
#   'gratuidad',
#   'permanencia',
#   'acompanante',
#   'mujer',
#   'situacion',
#   'parto'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regulacion'],
#  ['atencion',
#   'victima',
#   'delito',
#   'sexual',
#   'prevencion',
#   'enfermedad',
#   'regimen'],
#  ['departamento',
#   'san',
#   'pedro',
#   'ledesmo',
#   'provincia',
#   'jujuy',
#   'declarar',
#   'zona',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'prorrogable'],
#  ['quebrado',
#   'humahuaca',
#   'departamento',
#   'valle',
#   'provincia',
#   'jujuy',
#   'declaracion',
#   'zona',
#   'desastre',
#   'natural',
#   'plazo',
#   'prorrogable'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regimen'],
#  ['asignacion', 'familiar', 'asignacion', 'ayuda', 'escolar'],
#  ['prevencion',
#   'lavado',
#   'activo',
#   'actividad',
#   'juegos',
#   'azar',
#   'regimen',
#   'modificacion'],
#  ['creacion',
#   'instituto',
#   'nacional',
#   'promocion',
#   'salud',
#   'calidad',
#   'vida',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['sala',
#   'maternal',
#   'creacion',
#   'establecimiento',
#   'publico',
#   'privado',
#   'prestir',
#   'servicio',
#   'minimo',
#   'doscientos',
#   'trabajador',
#   'impuesto',
#   'ganancia',
#   'texto',
#   'ordenado',
#   'ganancia',
#   'minimo',
#   'presunto'],
#  ['plan', 'nacional', 'lucha', 'enfermedad', 'alzheimer', 'creacion'],
#  ['plan', 'aprovechamiento', 'economico', 'ceniza', 'volcanica', 'creacion'],
#  ['diagnostico', 'tratamiento', 'enfermedad', 'celiaca', 'cobertura'],
#  ['discontinuidad', 'produccion', 'comercializacion', 'medicamento'],
#  ['registro', 'nacional', 'poblacion', 'riesgo', 'sanitario', 'creacion'],
#  ['bebida',
#   'alcoholica',
#   'inclusion',
#   'informacion',
#   'consumidor',
#   'contenido',
#   'calorico',
#   'etiquetado'],
#  ['programa',
#   'federal',
#   'equinoterapia',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['programa',
#   'nacional',
#   'concientizacion',
#   'asistencia',
#   'materia',
#   'adopcion',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'desarrollo',
#   'social',
#   'nacion'],
#  ['programa',
#   'federal',
#   'desarrollo',
#   'tratamiento',
#   'efectivo',
#   'alzheimer',
#   'enfermedad',
#   'neurodegenerativo',
#   'relacionado',
#   'creacion'],
#  ['erupcion',
#   'volcan',
#   'puyehue',
#   'otorguese',
#   'jefe',
#   'jefa',
#   'familia',
#   'rural',
#   'dedicado',
#   'crianza',
#   'ovino',
#   'caprino',
#   'calidad',
#   'minifundista',
#   'area',
#   'rural',
#   'provincia',
#   'chubut',
#   'asignacion',
#   'mensual',
#   'equivalente',
#   'salario',
#   'minimo',
#   'vital',
#   'movil',
#   'plazo',
#   'ano',
#   'contado',
#   'enero',
#   'diciembre'],
#  ['nacional', 'voz', 'instituir', 'abril', 'ano'],
#  ['vacuna',
#   'varicela',
#   'zoster',
#   'incluir',
#   'aplicacion',
#   'calendario',
#   'nacional',
#   'inmunizacion',
#   'obligatorio',
#   'gratuito'],
#  ['enfermedad',
#   'parkinson',
#   'incorporacion',
#   'tratamiento',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cuestion',
#   'conexa'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'incorporacion',
#   'cobertura',
#   'dispositivo',
#   'necesario',
#   'persona',
#   'ostomizada'],
#  ['derecho',
#   'paciente',
#   'historia',
#   'clinico',
#   'consentimiento',
#   'informado',
#   'muerte',
#   'digno',
#   'cuidado',
#   'paliativo',
#   'integral'],
#  ['comision',
#   'nacional',
#   'asesora',
#   'lactancia',
#   'materno',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['fondo', 'especial', 'paciente', 'alto', 'complejidad', 'creacion'],
#  ['creacion',
#   'fondo',
#   'nacional',
#   'investigacion',
#   'desarrollo',
#   'produccion',
#   'vacuna',
#   'farmaco',
#   'metodo',
#   'diagnostico',
#   'masivo',
#   'estudio',
#   'epidemiologico',
#   'enfermedad',
#   'chaga'],
#  ['codigo',
#   'alimentario',
#   'nacional',
#   'agua',
#   'potable',
#   'agua',
#   'mineral',
#   'agua',
#   'gasificado',
#   'respectivamente'],
#  ['deteccion',
#   'diagnostico',
#   'tratamiento',
#   'enfermedad',
#   'celiaca',
#   'relacionado',
#   'implementacion',
#   'campana',
#   'anual',
#   'deteccion',
#   'realizacion',
#   'estudio',
#   'forma',
#   'gratuito'],
#  ['derecho',
#   'paciente',
#   'historia',
#   'clinico',
#   'consentimiento',
#   'informado',
#   'muerte',
#   'digno',
#   'cuidado',
#   'paliativo',
#   'integral'],
#  ['regulacion',
#   'publicidad',
#   'promocion',
#   'consumo',
#   'producto',
#   'elaborado',
#   'tabaco',
#   'ley',
#   'numerir',
#   'modificacion',
#   'composicion',
#   'producto'],
#  ['codigo',
#   'alimentario',
#   'argentino',
#   'porcentaje',
#   'jugo',
#   'bebida',
#   'alcohol'],
#  ['creacion',
#   'comision',
#   'nacional',
#   'vih',
#   'sida',
#   'conasido',
#   'ambito',
#   'jefatura',
#   'gabinete',
#   'ministros',
#   'derogacion',
#   'decreto'],
#  ['asignacion', 'familiar', 'monto', 'beneficio'],
#  ['animal',
#   'destinado',
#   'docencia',
#   'investigacion',
#   'control',
#   'calidad',
#   'prueba',
#   'laboratorio',
#   'cientifico',
#   'regimen',
#   'basico',
#   'utilizacion'],
#  ['asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ley',
#   'decreto',
#   'actualizacion',
#   'periodico',
#   'automatico',
#   'modificar',
#   'salario',
#   'minimo',
#   'vital',
#   'movil'],
#  ['sistema',
#   'nacional',
#   'vigilancia',
#   'mortalidad',
#   'materno',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['asignacion',
#   'familiar',
#   'bis',
#   'incorporacion',
#   'boleto',
#   'estudiantil',
#   'gratuito'],
#  ['incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'leches',
#   'medicamentosa',
#   'consumido',
#   'sufrir',
#   'alergia',
#   'proteina',
#   'leche',
#   'vacuna',
#   'aplv',
#   'sufrir',
#   'padecer',
#   'desorden',
#   'enfermedad',
#   'trastorno',
#   'gastrointestinal',
#   'eosinofilico'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'creacion',
#   'subsistema',
#   'contributivo',
#   'asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social'],
#  ['ablacion',
#   'mamario',
#   'mastectomia',
# ...
#   'seguridad',
#   'social'],
#  ['planta',
#   'medicinal',
#   'droga',
#   'vegetal',
#   'medicamento',
#   'fitoterapicos',
#   'promocion',
#   'distribucion',
#   'expendio',
#   'regimen',
#   'derogacion',
#   'articulo',
#   'ejercicio',
#   'actividad',
#   'farmaceutico'],
#  ['emergencia',
#   'sanitario',
#   'declarar',
#   'prorrogable',
#   'consecuencia',
#   'propagacion',
#   'virus',
#   'influenza'],
#  ['ley',
#   'nacional',
#   'salud',
#   'valor',
#   'principio',
#   'derecho',
#   'obligacion',
#   'organizacion',
#   'federal',
#   'salud',
#   'gestion',
#   'publicar',
#   'nacional',
#   'modelo',
#   'prestador',
#   'estrategio',
#   'atencion',
#   'primaria',
#   'salud',
#   'red',
#   'servicio',
#   'hospital',
#   'publico',
#   'derogacion',
#   'decreto',
#   'ley'],
#  ['obligacion',
#   'fabricante',
#   'medicamento',
#   'proporcionar',
#   'consumidor',
#   'informacion',
#   'necesario',
#   'utilizacion'],
#  ['gripe',
#   'causado',
#   'virus',
#   'influenza',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'aparicion',
#   'enfermedad'],
#  ['gripe',
#   'tipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'aparicion',
#   'enfermedad'],
#  ['medicamento',
#   'producto',
#   'destinado',
#   'combatir',
#   'virus',
#   'influenza',
#   'h1n1',
#   'exceptuan',
#   'tributar',
#   'arancel',
#   'importacion',
#   'impuesto',
#   'interno',
#   'periodo',
#   'pandemia',
#   'enfermedad',
#   'declarado',
#   'organizacion',
#   'mundial',
#   'salud',
#   'oms'],
#  ['gripe',
#   'tipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'enfermedad',
#   'creacion',
#   'fondo',
#   'especial',
#   'lucha'],
#  ['declarar',
#   'emergencia',
#   'nacional',
#   'salud',
#   'termino',
#   'sesenta',
#   'creacion',
#   'comite',
#   'nacional',
#   'crisis',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['gripe',
#   'tipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional'],
#  ['gripe',
#   'causado',
#   'virus',
#   'influenza',
#   'tipo',
#   'subtipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'pandemia',
#   'enfermedad'],
#  ['incorporacion',
#   'vacuna',
#   'antigripal',
#   'programa',
#   'ampliado',
#   'inmunizacion',
#   'aplicacion',
#   'gratuito',
#   'obligatorio',
#   'anos',
#   'embarazado',
#   'semana',
#   'gestacion'],
#  ['infertilidad',
#   'tecnica',
#   'fertilizacion',
#   'asistido',
#   'inclusion',
#   'tratamiento',
#   'diagnostico',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['administracion',
#   'nacional',
#   'laboratorio',
#   'instituto',
#   'salud',
#   'anlis',
#   'doctor',
#   'carlos',
#   'malbrar',
#   'ampliase',
#   'partida',
#   'presupuestario',
#   'asignado'],
#  ['plan',
#   'asistencia',
#   'integral',
#   'persona',
#   'enfermedad',
#   'frecuente',
#   'epf',
#   'creacion'],
#  ['psicologo', 'social', 'instituir', 'junio', 'ano'],
#  ['certificado',
#   'medico',
#   'aptitud',
#   'fisico',
#   'realizacion',
#   'actividad',
#   'fisica',
#   'deportivo',
#   'regimen'],
#  ['esclerosis',
#   'multiple',
#   'incluir',
#   'paciente',
#   'beneficiario',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'pami'],
#  ['ley',
#   'general',
#   'salud',
#   'poblacion',
#   'caracteristica',
#   'poblacional',
#   'servicio',
#   'poblacion',
#   'comportamiento',
#   'individual',
#   'colectivo',
#   'habitat',
#   'caracteristica',
#   'ambiental',
#   'servicio',
#   'ambiente',
#   'ordenamiento',
#   'territorial',
#   'sistema',
#   'salud',
#   'servicio',
#   'salud',
#   'fuerza',
#   'trabajo',
#   'financiamiento',
#   'salud',
#   'publicar',
#   'poblacion',
#   'caracteristica',
#   'poblacional'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'lucha',
#   'hidroarsenicismo',
#   'cronico',
#   'regional',
#   'endemico',
#   'hacre',
#   'creacion',
#   'programa',
#   'federal'],
#  ['instituto',
#   'medicina',
#   'tropical',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'recoleccion',
#   'medicamento',
#   'vencido',
#   'domiciliario'],
#  ['plan',
#   'federal',
#   'inclusion',
#   'familiar',
#   'denominado',
#   'plan',
#   'incluir',
#   'creacion',
#   'ambito',
#   'presidencia',
#   'nacion'],
#  ['creacion',
#   'programa',
#   'contencion',
#   'social',
#   'pcs',
#   'mision',
#   'combatir',
#   'situacion',
#   'pobreza',
#   'hogar',
#   'republica',
#   'argentino',
#   'promover',
#   'certificar',
#   'insercion',
#   'reinsercion',
#   'fuente',
#   'genuina',
#   'empleo',
#   'formal',
#   'jefe',
#   'jefas',
#   'hogar',
#   'pobre'],
#  ['creacion', 'region', 'sanitario', 'aires'],
#  ['creacion',
#   'programa',
#   'apoyo',
#   'enfermo',
#   'celiaco',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['regulacion', 'cadena', 'frio', 'medicamento', 'ter', 'sancion'],
#  ['ley',
#   'acupuntura',
#   'autoridad',
#   'aplicacion',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['obligatoriedad',
#   'venta',
#   'medicamento',
#   'contener',
#   'sustancia',
#   'activo',
#   'denominado',
#   'oseltamivir',
#   'rimantadin',
#   'zanamivir',
#   'efectuar',
#   'unicamente',
#   'exhibicion',
#   'receta',
#   'medico'],
#  ['glifosato', 'suspension', 'aplicacion'],
#  ['gripe',
#   'porcinar',
#   'declarar',
#   'prevencion',
#   'emergencia',
#   'sanitario',
#   'creacion',
#   'comite',
#   'hospital',
#   'aeropuerto'],
#  ['enfermedad',
#   'celiaco',
#   'rotulacion',
#   'contener',
#   'gluten',
#   'contener',
#   'gluten',
#   'envase'],
#  ['tabaco',
#   'regimen',
#   'limitacion',
#   'control',
#   'riesgo',
#   'control',
#   'producto',
#   'cigarrillo',
#   'comercializado',
#   'fabricado',
#   'argentina'],
#  ['plan',
#   'nacional',
#   'radicacion',
#   'profesional',
#   'salud',
#   'creacion',
#   'direccion',
#   'nacional',
#   'prestacion',
#   'sanitaria',
#   'comunitario',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['hepatitis',
#   'incorporar',
#   'integrante',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'diagnostico',
#   'tratamiento'],
#  ['creacion',
#   'programa',
#   'lucha',
#   'fiebre',
#   'hemorragico',
#   'argentino',
#   'fha'],
#  ['pediculosis',
#   'incorporacion',
#   'cobertura',
#   'prestacion',
#   'medica',
#   'obligatorio'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'emergencia',
#   'pmoe',
#   'incorporacion',
#   'cobertura',
#   'diagnostico',
#   'tratamiento',
#   'hepatitis'],
#  ['dengue',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'nacional',
#   'creacion',
#   'comision',
#   'nacional',
#   'seguimiento',
#   'epidemia'],
#  ['dengue',
#   'declaracion',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional',
#   'afectado'],
#  ['programa',
#   'nacional',
#   'prevencion',
#   'control',
#   'proteccion',
#   'integral',
#   'dengue',
#   'epidemia',
#   'enfermedad',
#   'emergente',
#   'reemergent',
#   'creacion'],
#  ['celula',
#   'madr',
#   'disponer',
#   'conservacion',
#   'envio',
#   'almacenamiento',
#   'banco',
#   'nacional',
#   'publico',
#   'celula',
#   'progenitora',
#   'hematopoyetica',
#   'funcionar',
#   'hospital',
#   'garrahaber'],
#  ['prohibicion',
#   'ingreso',
#   'persona',
#   'geriatrico',
#   'centro',
#   'salud',
#   'mental',
#   'rehabilitacion',
#   'fisico',
#   'mental',
#   'consentimiento',
#   'informado',
#   'orden',
#   'judicial',
#   'relevamiento'],
#  ['prohibir',
#   'consumo',
#   'directo',
#   'soja',
#   'transgenico',
#   'autoridad',
#   'aplicacion',
#   'ministerio',
#   'salud',
#   'secuestro',
#   'decomiso',
#   'incumplimiento'],
#  ['dengue', 'declarar', 'emergencia', 'sanitario'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'pais',
#   'brote',
#   'epidemico',
#   'dengue'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'control',
#   'dengue',
#   'creacion',
#   'programa',
#   'nacional',
#   'permanente',
#   'prevencion',
#   'control',
#   'dengue',
#   'enfermedad',
#   'tropical'],
#  ['enfermedad',
#   'dengue',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional',
#   'ciento',
#   'ochenta'],
#  ['enfermedad',
#   'dengue',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'odontologia',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['sodio', 'regulacion', 'contenido', 'industria', 'alimentacion'],
#  ['declaracion',
#   'interes',
#   'nacional',
#   'accion',
#   'dirigido',
#   'prevencion',
#   'atencion',
#   'salud',
#   'publicar',
#   'ratificacion',
#   'decreto',
#   'creacion',
#   'administracion',
#   'nacional',
#   'medicamento',
#   'alimento',
#   'tecnologia',
#   'medica',
#   'anmat'],
#  ['prohibicion',
#   'publicidad',
#   'promocion',
#   'distribucion',
#   'venta',
#   'entrega',
#   'regalo',
#   'producto',
#   'subproducto',
#   'tabaco',
#   'menor',
#   'edad'],
#  ['creacion',
#   'instituto',
#   'nacional',
#   'cancer',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['enfermedad',
#   'celiaco',
#   'obligatoriedad',
#   'obra',
#   'social',
#   'empresa',
#   'medicina',
#   'prepagar',
#   'brindar',
#   'atencion',
#   'medica',
#   'cobertura',
#   'integral',
#   'persona',
#   'padezcar',
#   'exencion',
#   'impositivo',
#   'producto',
#   'contener',
#   'gluten',
#   'derivado'],
#  ['dengue', 'declarar', 'emergencia', 'sanitario', 'territorio', 'nacional'],
#  ['alimento',
#   'envasado',
#   'inclusion',
#   'leyenda',
#   'aclarar',
#   'contener',
#   'gluten'],
#  ['servicio', 'nacional', 'lucha', 'diabetes', 'cobertura', 'obra', 'social'],
#  ['tatuaj', 'piercing', 'prevencion', 'regulacion'],
#  ['elemento',
#   'medico',
#   'mercurio',
#   'prohibir',
#   'utilizacion',
#   'establecimiento',
#   'salud',
#   'publico',
#   'privado'],
#  ['ecocardiografia',
#   'fetal',
#   'incorporacion',
#   'caracter',
#   'obligatorio',
#   'practica',
#   'rutinario',
#   'control'],
#  ['reconocimiento', 'oficial', 'acupuntura', 'acto', 'medico'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'provincia',
#   'chaco',
#   'afectado',
#   'dengue'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'asistencia',
#   'donante',
#   'vivo',
#   'organo',
#   'beneficio',
#   'recursos'],
#  ['prohibicion',
#   'importacion',
#   'fabricacion',
#   'expendio',
#   'indumentaria',
#   'contener',
#   'dimetilfumarato'],
#  ['calcetin',
#   'correccion',
#   'pie',
#   'equino',
#   'accionado',
#   'vendaje',
#   'tiro',
#   'zona',
#   'compresion',
#   'reforzado',
#   'punto',
#   'ataque',
#   'tipo',
#   'philipp',
#   'incorporacion',
#   'cobertura',
#   'prestacion',
#   'medica',
#   'obligatorio'],
#  ['creacion',
#   'programa',
#   'federal',
#   'salud',
#   'educacion',
#   'republica',
#   'ambito',
#   'consejo',
#   'nacional',
#   'coordinacion',
#   'politica',
#   'social'],
#  ['programa',
#   'nacional',
#   'investigacion',
#   'desarrollo',
#   'produccion',
#   'vacuna',
#   'demas',
#   'insumo',
#   'medico',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'ciencia',
#   'tecnologio',
#   'innovacion',
#   'productivo'],
#  ['farmacopea',
#   'ley',
#   'incorporacion',
#   'anexo',
#   'identificacion',
#   'color',
#   'droga',
#   'anestesiologico'],
#  ['sistema',
#   'integral',
#   'proteccion',
#   'persona',
#   'discapacitada',
#   'ley',
#   'efecto',
#   'articulo',
#   'considerar',
#   'persona',
#   'discapacidad',
#   'visceral',
#   'afectado',
#   'trastorno',
#   'hereditario',
#   'hemoglobina',
#   'requerir',
#   'tratamiento',
#   'permanente',
#   'sobrevivir',
#   'obra',
#   'social',
#   'agente',
#   'salud',
#   'incorporarar',
#   'prestacion',
#   'obligatorio'],
#  ['tratamiento',
#   'enfermedad',
#   'tipo',
#   'anticoagulante',
#   'incluir',
#   'prevencion',
#   'deteccion',
#   'mujer',
#   'edad',
#   'reproductivo',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'embarazo',
#   'partos',
#   'cesarea',
#   'puerperio',
#   'mujer',
#   'patologia',
#   'quedar',
#   'cubierto',
#   'plan',
#   'materno',
#   'infantil',
#   'pmi'],
#  ['nacional', 'medico', 'argentino', 'instituir', 'marzo', 'ano'],
#  ['acceso',
#   'reproduccion',
#   'humano',
#   'asistido',
#   'salud',
#   'sexual',
#   'procreacion',
#   'responsable',
#   'inciso',
#   'articulo',
#   'garantizar',
#   'acceso',
#   'poblacion',
#   'agregar',
#   'inciso',
#   'articulo',
#   'articulo',
#   'agregar',
#   'tercer',
#   'parrafo',
#   'articulo'],
#  ['proteccion',
#   'promocion',
#   'concientizacion',
#   'publicar',
#   'lactancia',
#   'materno',
#   'practica',
#   'optima',
#   'nutricion',
#   'seguro',
#   'lactant',
#   'nino',
#   'pequeno',
#   'anos',
#   'alcanz'],
#  ['pediculosis',
#   'implementar',
#   'campana',
#   'lucha',
#   'transcurso',
#   'ano',
#   'lectivo'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'zona',
#   'afectado',
#   'dengue',
#   'creacion',
#   'comite',
#   'emergencia',
#   'sanitario',
#   'dengue'],
#  ['enfermedad',
#   'cronico',
#   'psoriasis',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'inclusion',
#   'resolucion',
#   'cobertura',
#   'medicamento'],
#  ['enfermedad',
#   'hunter',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['creacion',
#   'observatorio',
#   'parlamentario',
#   'exclusion',
#   'social',
#   'ambito',
#   'congreso'],
#  ['cosmetologia',
#   'cosmiatrio',
#   'estetico',
#   'corporal',
#   'regulacion',
#   'profesion',
#   'naturaleza',
#   'finalidad',
#   'cosmetologo',
#   'cosmiatra',
#   'esteticista',
#   'corporal',
#   'principio',
#   'ejercicio',
#   'profesion',
#   'centro',
#   'formacion',
#   'prohibicion',
#   'centro',
#   'estetico',
#   'comite',
#   'asesor'],
#  ['creacion',
#   'programa',
#   'federal',
#   'prevencion',
#   'hpv',
#   'papiloma',
#   'virus',
#   'humano'],
#  ['instituto',
#   'profilaxis',
#   'enfermedad',
#   'venerea',
#   'ter',
#   'quater',
#   'examen',
#   'medico',
#   'prenupcial',
#   'ley'],
#  ['creacion',
#   'banco',
#   'leche',
#   'materno',
#   'humano',
#   'definicion',
#   'objetivo',
#   'donant',
#   'creacion',
#   'programa',
#   'nacional',
#   'concientizacion',
#   'fomentacion',
#   'importancia',
#   'lactancia',
#   'natural',
#   'materno'],
#  ['registro',
#   'nacional',
#   'beneficiario',
#   'programa',
#   'social',
#   'creacion',
#   'ambito',
#   'ejecutivo'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'higienico',
#   'territorio',
#   'nacion',
#   'argentino',
#   'combatir',
#   'enfermedad',
#   'viral',
#   'transmitido',
#   'mosquito',
#   'aedes',
#   'aegypti',
#   'producir',
#   'enfermedad',
#   'dengue'],
#  ['ejercicio',
#   'actividad',
#   'farmaceutico',
#   'prohibicion',
#   'farmacia',
#   'asistencial',
#   'institucional',
#   'programa',
#   'provision',
#   'medicamento',
#   'industrio',
#   'farmaceutico',
#   'drogueria',
#   'distribuidora',
#   'medicamento',
#   'elaboracion',
#   'venta',
#   'producto',
#   'homeopatico',
#   'herboristeria',
#   'industria',
#   'cosmetico',
#   'fabricacion',
#   'material',
#   'biomedico',
#   'esteril',
#   'fiscalizacion',
#   'control'],
#  ['tarjeta',
#   'social',
#   'gasto',
#   'alimentario',
#   'programa',
#   'nutricion',
#   'alimentacion',
#   'nacional',
#   'ley',
#   'exencion',
#   'impuesto',
#   'valor',
#   'agregado',
#   'iva'],
#  ['preferencia',
#   'adquisicion',
#   'medicamento',
#   'vacuna',
#   'producto',
#   'medico',
#   'produccion',
#   'publicar',
#   'nacional'],
#  ['regimen',
#   'transitorio',
#   'extension',
#   'cobertura',
#   'medico',
#   'trabajador',
#   'trabajadora',
#   'situacion',
#   'desempleo',
#   'distracto',
#   'suspension',
#   'financiacion',
#   'vigencio'],
#  ['vacuna',
#   'neumococico',
#   'heptavalente',
#   'incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporar',
#   'cobertura',
#   'prestacion',
#   'correspondiente',
#   'enfermedad',
#   'gaucher'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporar',
#   'cobertura',
#   'prestacion',
#   'correspondiente',
#   'enfermedad',
#   'fabry'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporar',
#   'cobertura',
#   'prestacion',
#   'correspondiente',
#   'enfermedad',
#   'pompe'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'diagnostico',
#   'tratamiento',
#   'enfermedad',
#   'celiaco',
#   'derogacion',
#   'ley'],
#  ['prevencion',
#   'lucha',
#   'enfermedad',
#   'chagas',
#   'mazza',
#   'examen',
#   'serologicos'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'diagnostico',
#   'tratamiento',
#   'enfermedad',
#   'celiaco',
#   'derogacion',
#   'ley'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'salud',
#   'social',
#   'procreacion',
#   'responsable'],
#  ['regimen', 'salud', 'mental'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'prevencion',
#   'tratamiento',
#   'inclusion',
#   'familiar',
#   'social',
#   'persona',
#   'afectado',
#   'alzheimer',
#   'demencia',
#   'trastorno',
#   'cognitivo'],
#  ['declaracion',
#   'vital',
#   'voluntad',
#   'paciente',
#   'terminal',
#   'muerte',
#   'inminente'],
#  ['creacion', 'programa', 'nacional', 'atencion', 'estr', 'postraumatico'],
#  ['control',
#   'tabaco',
#   'regulacion',
#   'consumo',
#   'comercializacion',
#   'publicidad',
#   'creacion',
#   'comite',
#   'asesor',
#   'interdisciplinario']]

# %%
# GUARDAR OBJETO PARA DETECTAR CAMBIOS SEMANTICOS
#with open(RESULTADOS_DIR + 'periodo_5anios_df.pkl', 'wb') as file: 
#    pickle.dump(PER5anios_df,file)

# %% [markdown]
# ## 3. Analizando frecuencias de palabras por período
# Se tiene en cuenta los períodos parlamentaríos

# %%
freqs_list = []
for anios5 in PER5anios_df['Periodo_5anios'].to_list():

    print(anios5)
    subdf = PER5anios_df.loc[(PER5anios_df['Periodo_5anios']==anios5),]
    subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")                                 
    
    freqs = Counter()
    subdf['Título normalizado'].apply(lambda x: freqs.update(x.split())) # cualquier espacio.
    total_number = sum(freqs.values())
    print('Número total de tokens:', total_number)

    freqs_df = pd.DataFrame.from_dict(freqs, orient='index',
                                      columns=['Frecuencia'])
    freqs_df = freqs_df.reset_index()

    freqs_df = freqs_df.rename(columns={'index': 'Palabra'})
    mask = (freqs_df['Palabra'].str.len() > 1)
    print(freqs_df.shape)
    freqs_df = freqs_df.loc[mask]
    print(freqs_df.shape)
    print('Entradas removidas de 1 carácter.')
    print('Cantidad de tokens únicos:', freqs_df.shape[0])

    freqs_df = freqs_df.sort_values('Frecuencia').reset_index(drop=True)

    freqs_df['Porcentaje'] = freqs_df['Frecuencia'] / total_number

    
    freqs_df.to_csv(RESULTADOS_DIR+'./archivos_out/frec_para_datos_limpios_por_desplaz_semantico_anios5_'+str(anios5)+'.csv', index=False)

    freqs_df['Período'] = str(anios5)
    
    freqs_list.append(freqs_df)
# Out:
# 2009
# Número total de tokens: 7854
# (1714, 2)
# (1714, 2)
# Entradas removidas de 1 carácter.
# Cantidad de tokens únicos: 1714
# 2014
# Número total de tokens: 9740
# (1969, 2)
# (1969, 2)
# Entradas removidas de 1 carácter.
# Cantidad de tokens únicos: 1969
# 2019
# Número total de tokens: 10222
# (1876, 2)
# (1876, 2)
# Entradas removidas de 1 carácter.
# Cantidad de tokens únicos: 1876
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3633415219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3633415219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3633415219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")

# %%
freqs_df = pd.concat(freqs_list) # Dataframe de frecuecias

# %%
freqs_df.head(2)
# Out:
#   Palabra  Frecuencia  Porcentaje Período
# 0    paro           1    0.000127    2009
# 1    ipod           1    0.000127    2009

# %% [markdown]
# ##### VOCABULARIO por período de 5 años

# %% [markdown]
# Analizando proyectos de IL de Salud:
# * [2009 - 2014)
#     * Número total de tokens: 7854
#     * Número de tokens únicos: 1713
# * [2014 - 2019)
#     * Número total de tokens: 9740
#     * Número de tokens únicos: 1969
# * [2019 - 2024)
#     * Número total de tokens: 10222
#     * Número de tokens únicos: 1876

# %% [markdown]
# ### Análisis general (Tres Periodos Combinados)

# %%
vocab_periodo = freqs_df['Período'].value_counts().reset_index() # vocabulario por períodos de 5 años
vocab_periodo
# Out:
#   Período  count
# 0    2014   1969
# 1    2019   1876
# 2    2009   1714

# %%
vocab_periodo.describe() # Estadística
# Out:
#              count
# count     3.000000
# mean   1853.000000
# std     129.046503
# min    1714.000000
# 25%    1795.000000
# 50%    1876.000000
# 75%    1922.500000
# max    1969.000000

# %%
# Calculo la media de cantidad de palabras del vocabulario
 
n = len(vocab_periodo['count'])
media_total = np.mean(vocab_periodo['count'])

# Calcula la desviación estándar de los promedios anuales
desviacion_estandar = np.std(vocab_periodo['count'], ddof=1) # ddof=1 para desviación estándar de la muestra

# Calcula el Error Estándar de la Media (SEM)
sem = desviacion_estandar / np.sqrt(n)
print('media de vocabulario por periodo (cantidad de palabras únicas)',media_total)
print('desviacion_estandar', desviacion_estandar)
coeficiente_variacion = (desviacion_estandar / media_total) * 100
print('coeficiente_variacion ',coeficiente_variacion)
print('sem',sem)

# Calcula el Intervalo de Confianza del 95%
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1
valor_critico_t = stats.t.ppf(1 - alpha / 2, grados_libertad)
intervalo_confianza = valor_critico_t * sem
print("intervalo de confianza: ",intervalo_confianza)
# Out:
# media de vocabulario por periodo (cantidad de palabras únicas) 1853.0
# desviacion_estandar 129.04650324592293
# coeficiente_variacion  6.964193375387098
# sem 74.50503338701353
# intervalo de confianza:  320.56928527873595

# %% [markdown]
# La desviación estándar es de 129 palabras, el Coeficiente de Variación de 7 (dispersión relativa), lo que indica que los vocabularios o las cantidades de palabras únicas por período están más dispersas, la media 1853 no es tan representativa para los tres periodos a procesar.

# %%
freqs_df = freqs_df.sort_values(by = 'Frecuencia', ascending =False)

# %%
freqs_df.to_csv(RESULTADOS_DIR+'/archivos_out/frec_para_datos_limpios_por_desplaz_semantico_anios5_all.csv', index=False)

# %%
# Suponiendo que tu DataFrame se llama 'df'
print("--- Análisis del Vocabulario para los Tres Periodos Combinados ---")

# 1. Tamaño total del vocabulario único
vocabulario_total = freqs_df['Palabra'].nunique()
print(f"Tamaño total del vocabulario único en los tres periodos: {vocabulario_total}")

# 2. Frecuencia total de todas las palabras
frecuencia_total = freqs_df['Frecuencia'].sum()
print(f"Frecuencia total de todas las palabras en los tres periodos: {frecuencia_total}")
# Out:
# --- Análisis del Vocabulario para los Tres Periodos Combinados ---
# Tamaño total del vocabulario único en los tres periodos: 3221
# Frecuencia total de todas las palabras en los tres periodos: 27816

# %%
# 3. Distribución de la frecuencia de las palabras
plt.figure(figsize=(10, 6))
sns.histplot(freqs_df['Frecuencia'], bins='auto', kde=True)
plt.title('Distribución de la Frecuencia de las Palabras (Tres Periodos)')
plt.xlabel('Frecuencia')
plt.ylabel('Número de Palabras')
plt.show()

# %%
sns.boxplot(x = 'Frecuencia', data=freqs_df)
# Out:
# <Axes: xlabel='Frecuencia'>

# %%
freqs_df.describe(include = 'all')
# Out:
#          Palabra   Frecuencia   Porcentaje Período
# count       5559  5559.000000  5559.000000    5559
# unique      3221          NaN          NaN       3
# top     nacional          NaN          NaN    2014
# freq           3          NaN          NaN    1969
# mean         NaN     5.003778     0.000540     NaN
# std          NaN    13.887580     0.001476     NaN
# min          NaN     1.000000     0.000098     NaN
# 25%          NaN     1.000000     0.000103     NaN
# 50%          NaN     2.000000     0.000196     NaN
# 75%          NaN     4.000000     0.000391     NaN
# max          NaN   361.000000     0.035316     NaN

# %%
rango = np.max(freqs_df['Frecuencia']) - np.min(freqs_df['Frecuencia'])
coeficiente_variacion = (desviacion_estandar / freqs_df['Frecuencia'].mean()) * 100
print('Rango ',rango)
print('Coeficiente_variacion ',coeficiente_variacion)
# Out:
# Rango  360
# Coeficiente_variacion  2578.9815629281193

# %% [markdown]
# * El frecuencia promedia de una palabra en período de 5 años es: 5
# * La frecuencia media de una palabra en período de 5 años es: 2
# * La desviación estandar de una palabra en período de 5 años es: 14
# * El rango de frecuencia de una palabra en período de 5 años es: 360
#
# Existe un alta variabilidad de frecuencia de palabra en período de 5 años (rango = 360 frecuencia). La mayorías de las palabras en período de 5 años tienen baja frecuencia de ocurrencia tal que se concentran alrededor de frecuencia=2. El 75% del total de palabras en los tres periodos presentan una frecuencia inferior a frecuencia = 4.

# %%
def eliminar_outliers_iqr(df, columna):
    """
    Separa los outliers y devuelve dos DataFrames:
    - df_limpio: sin outliers
    - df_outliers: con los valores atípicos detectados

    Parámetros:
    df (pd.DataFrame): DataFrame de pandas
    columna (str): Nombre de la columna a analizar

    Retorna:
    df_limpio (pd.DataFrame): DataFrame sin outliers
    df_outliers (pd.DataFrame): DataFrame solo con outliers
    """
    Q1 = df[columna].quantile(0.25)
    Q3 = df[columna].quantile(0.75)
    IQR = Q3 - Q1

    # Definir los límites
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    print("Q1:",Q1)
    print("Q3:",Q3)
    print('limite_inferior:', limite_inferior)
    print('limite_superior:', limite_superior)


    # Filtrar datos
    df_limpio = df[(df[columna] >= limite_inferior) & (df[columna] <= limite_superior)]
    df_outliers = df[(df[columna] < limite_inferior) | (df[columna] > limite_superior)]

    return df_limpio, df_outliers

# %%
# Detectar outliers
freqs_limpio_df , outliers_df = eliminar_outliers_iqr(freqs_df, 'Frecuencia')
display("Outliers detectados:\n", outliers_df)
# Out:
# Q1: 1.0
# Q3: 4.0
# limite_inferior: -3.5
# limite_superior: 8.5
# 'Outliers detectados:\n'
#              Palabra  Frecuencia  Porcentaje Período
# 1875        nacional         361    0.035316    2019
# 1968        nacional         267    0.027413    2014
# 1874        creacion         251    0.024555    2019
# 1967        creacion         220    0.022587    2014
# 1873        programa         211    0.020642    2019
# ...              ...         ...         ...     ...
# 1548        ganancia           9    0.001146    2009
# 1549           forma           9    0.001146    2009
# 1550           monto           9    0.001146    2009
# 1551  administracion           9    0.001146    2009
# 1552        hospital           9    0.001146    2009
#
# [622 rows x 4 columns]

# %% [markdown]
# Se considera que una palabra en periodo de 5 años con frecuencia superior 8 es una palabra de frecuencia extrema o especial.

# %%
print("Cantidad de palabras únicas por período que superan las 8 veces en alguno de los tres períodos  - OUTLIERS:", len(outliers_df.Palabra.unique()))
# Out:
# Cantidad de palabras únicas por período que superan las 8 veces en alguno de los tres períodos  - OUTLIERS: 318

# %% [markdown]
# * Existe un alta variabilidad de frecuencia de palabra en período de 5 años (rango = 360 frecuencia).
# * La mayoría de las palabras en período de 5 años tienen baja frecuencia de ocurrencia tal que se  concentran alrededor de frecuencia=2.
# * El 75% del total de palabras en los tres periodos presentan una frecuencia inferior a frecuencia = 4.
# * Se considera que una palabra en período de 5 años con frecuencia superior 8 es una palabra de frecuencia extrema o especial.
# * Hay 318 palabras únicas por período que superan las 8 veces en alguno de los tres períodos.
# * Total de palabras con frecuencia extrema en alguno de los tres periodo = 622

# %% [markdown]
# ### Análisis por Periodo:  Por período de 5 años

# %%
from scipy.stats import bootstrap


# Para una primera aproximación y visualización de la incertidumbre, el bootstrap de percentiles (o la salida por defecto de scipy.stats.bootstrap) es un buen comienzo.
def confidence_intervals(data):
    res = bootstrap((data,), np.mean, confidence_level=0.95, random_state=42) # Añadimos random_state para reproducibilidad
    return (res.confidence_interval.low, res.confidence_interval.high)

def confidence_intervals_bca(data):
    """
    Calcula el intervalo de confianza del 95% para la media utilizando el método BCa bootstrap.
    """
    res = bootstrap((data,), np.mean, confidence_level=0.95, method='BCa', random_state=42)
    return (res.confidence_interval.low, res.confidence_interval.high)

# %% [markdown]
# Bootstrap de Percentiles (Percentile Bootstrap):
#
# Cómo funciona: El intervalo de confianza se construye tomando los percentiles apropiados (por ejemplo, el 2.5% y el 97.5% para un intervalo del 95%) de la distribución de las estadísticas bootstrap.
# Ventajas: Conceptualmente simple y fácil de entender.
# Desventajas: Su precisión puede ser limitada, especialmente con muestras pequeñas o distribuciones sesgadas. No siempre es transformacionalmente invariante (el intervalo de confianza para una función del parámetro no siempre es la función de los límites del intervalo de confianza).

# %%
print("\n--- Análisis por Periodo ---")
for periodo in ['2009','2014','2019']:

    df_periodo = freqs_df[freqs_df['Período'] == periodo]
    print(f"\n--- Periodo: {periodo} ---")

    # 1. Tamaño del vocabulario único por periodo
    vocabulario_periodo = df_periodo['Palabra'].nunique()
    print(f"Tamaño del vocabulario único: {vocabulario_periodo}")

    # 2. Frecuencia total de palabras por periodo
    frecuencia_total_periodo = df_periodo['Frecuencia'].sum()
    print(f"Frecuencia total de palabras: {frecuencia_total_periodo}")

    # 3. Frecuencia media de las palabras por periodo con intervalos de confianza bootstrap
    frecuencias_periodo = df_periodo['Frecuencia'].values
    if len(frecuencias_periodo) > 0:
  
        media_frecuencia = np.mean(frecuencias_periodo)
        intervalo_confianza = confidence_intervals_bca(frecuencias_periodo)
        # Esto nos da una idea del rango plausible para la verdadera frecuencia media de las palabras en ese periodo.
        print(f"Frecuencia media de las palabras (BCa): {media_frecuencia:.2f} (IC 95%: {intervalo_confianza[0]:.2f}, {intervalo_confianza[1]:.2f})")

        temp = df_periodo.sort_values('Frecuencia', ascending=False)
        print(temp.head(10).Palabra.unique())
        display("Top 10 palabras",temp.head(10))

        
        # Visualización de la distribución de frecuencias por periodo
        plt.figure(figsize=(8, 5))
        sns.histplot(df_periodo['Frecuencia'], bins=30, kde=True)
        plt.title(f'Distribución de la Frecuencia de las Palabras (Periodo {periodo})')
        plt.xlabel('Frecuencia')
        plt.ylabel('Número de Palabras')
        plt.show()
    else:
        print("No hay palabras en este periodo.")
# Out:
# --- Análisis por Periodo ---
#
# --- Periodo: 2009 ---
# Tamaño del vocabulario único: 1714
# Frecuencia total de palabras: 7854
# Frecuencia media de las palabras (BCa): 4.58 (IC 95%: 4.12, 5.23)
# ['nacional' 'creacion' 'salud' 'programa' 'social' 'regimen' 'ley'
#  'obligatorio' 'medico' 'declarar']
# 'Top 10 palabras'
#           Palabra  Frecuencia  Porcentaje Período
# 1713     nacional         208    0.026483    2009
# 1712     creacion         157    0.019990    2009
# 1711        salud         133    0.016934    2009
# 1710     programa         112    0.014260    2009
# 1709       social         109    0.013878    2009
# 1708      regimen         106    0.013496    2009
# 1707          ley         102    0.012987    2009
# 1706  obligatorio          84    0.010695    2009
# 1705       medico          78    0.009931    2009
# 1704     declarar          77    0.009804    2009
# --- Periodo: 2014 ---
# Tamaño del vocabulario único: 1969
# Frecuencia total de palabras: 9740
# Frecuencia media de las palabras (BCa): 4.95 (IC 95%: 4.45, 5.66)
# ['nacional' 'creacion' 'regimen' 'programa' 'salud' 'medico' 'obligatorio'
#  'social' 'persona' 'tratamiento']
# 'Top 10 palabras'
#           Palabra  Frecuencia  Porcentaje Período
# 1968     nacional         267    0.027413    2014
# 1967     creacion         220    0.022587    2014
# 1966      regimen         202    0.020739    2014
# 1965     programa         165    0.016940    2014
# 1964        salud         155    0.015914    2014
# 1963       medico         121    0.012423    2014
# 1962  obligatorio          97    0.009959    2014
# 1961       social          93    0.009548    2014
# 1960      persona          90    0.009240    2014
# 1959  tratamiento          89    0.009138    2014
# --- Periodo: 2019 ---
# Tamaño del vocabulario único: 1876
# Frecuencia total de palabras: 10222
# Frecuencia media de las palabras (BCa): 5.45 (IC 95%: 4.85, 6.36)
# ['nacional' 'creacion' 'programa' 'salud' 'regimen' 'medico' 'persona'
#  'obligatorio' 'covid' 'integral']
# 'Top 10 palabras'
#           Palabra  Frecuencia  Porcentaje Período
# 1875     nacional         361    0.035316    2019
# 1874     creacion         251    0.024555    2019
# 1873     programa         211    0.020642    2019
# 1872        salud         195    0.019077    2019
# 1871      regimen         177    0.017316    2019
# 1870       medico         109    0.010663    2019
# 1869      persona         109    0.010663    2019
# 1868  obligatorio         106    0.010370    2019
# 1867        covid         104    0.010174    2019
# 1866     integral         103    0.010076    2019

# %% [markdown]
# * Frecuencia media con intervalos de confianza: el promedio de ocurrencias de una palabra en el periodo, es en general, un frecuencia de ocurrencia igual a 5.
# * El intervalo de confianza te proporciona un rango dentro del cual es probable que se encuentre la verdadera frecuencia media de las palabras en la población
# (todos los posibles títulos de ese periodo). Los intervalos de confianza para el promedio de ocurrencias de una palabra en el periodo para diferentes periodos en general
# se superponen lo que indicaría que no hay diferencia significativa en la frecuencia media de las palabras entre esos periodos.

# %%
def pares_primer_paso(lista_items):
    return [(lista_items[i],lista_items[i+1]) for i in range(len(lista_items)-1)]
pares_periodos = pares_primer_paso(['2009','2014','2019'])
pares_periodos
# Out:
# [('2009', '2014'), ('2014', '2019')]

# %%
print("\n--- Palabras en Común entre Pares de Periodos ---")
for par in pares_periodos:
    periodo1 = par[0]
    periodo2 = par[1]
    vocabulario1 = set(freqs_df[freqs_df['Período'] == periodo1]['Palabra'])
    vocabulario2 = set(freqs_df[freqs_df['Período'] == periodo2]['Palabra'])
    palabras_en_comun = vocabulario1.intersection(vocabulario2)
    total = len(vocabulario1) + len(vocabulario2)
    
    num_comunes = len(palabras_en_comun)
    print(f"\nPalabras en común entre {periodo1} y {periodo2}: {num_comunes}")
    print("%",round((num_comunes/total)*100,3))

    # Visualización del solapamiento (opcional, para una idea general)
    from matplotlib_venn import venn2
    plt.figure(figsize=(6, 6))
    venn2([vocabulario1, vocabulario2], set_labels=(str(periodo1), str(periodo2)))
    plt.title(f'Solapamiento de Vocabulario entre {periodo1} y {periodo2}')
    plt.show()

    print(list(palabras_en_comun)[1:10])
# Out:
# --- Palabras en Común entre Pares de Periodos ---
#
# Palabras en común entre 2009 y 2014: 1080
# % 29.324
# ['crecida', 'producido', 'calorico', 'implante', 'animal', 'caso', 'cuyo', 'odontologio', 'encontrar']
#
# Palabras en común entre 2014 y 2019: 1129
# % 29.363
# ['descanso', 'animal', 'implante', 'caso', 'cuyo', 'odontologio', 'encontrar', 'familia', 'situacion']

# %% [markdown]
# Palabras en común: El número de palabras en común y los diagramas de Venn muestran la superposición del vocabulario entre los diferentes periodos.
# En general, 29% del vocabulario total de pares de periodos a comparar es compartido, es decir  que solo el 29% de las palabras únicas que aparecen en la unión de los vocabularios de ambos periodos están presentes en ambos periodos. El 71% restante del vocabulario total aparece solo en uno de los dos periodos comparados.
#
#
# Influencia en Vocabularios Pequeños:
#
# En vocabularios pequeños, un solapamiento del 29% puede tener un impacto significativo en el análisis de cambio semántico:
#
# * Menos palabras para comparar: Cuanto menor sea el solapamiento, menor será el conjunto de palabras para las cuales puedes directamente intentar detectar un cambio semántico comparando su uso o representaciones a través del tiempo.
#
# * Mayor impacto de palabras nuevas y desaparecidas: Un porcentaje considerable del vocabulario siendo nuevo en un periodo o desapareciendo del otro puede indicar cambios temáticos o en el foco del discurso, lo cual podría estar relacionado con cambios semánticos en las palabras compartidas. Sin embargo, también dificulta el análisis directo del cambio semántico para las palabras no compartidas.
#
# * Potencial para inestabilidad en modelos: Si intentas entrenar modelos de embedding o de lenguaje en vocabularios pequeños con bajo solapamiento, la falta de datos compartidos puede llevar a representaciones inestables o poco confiables para las palabras.
# En resumen, un solapamiento del 29% en un vocabulario pequeño sugiere que hay una discontinuidad considerable en el léxico utilizado entre los periodos comparados, lo que puede dificultar la detección robusta de cambios semánticos utilizando métodos que se basan en la comparación directa de representaciones de palabras compartidas.

# %% [markdown]
# ##### Palabras emergentes
#
# * Objetivo: detectar palabras que aparecen o aumentan significativamente su uso en un período respecto a otro.
#
# Técnicas comunes:
#
# * Comparación de frecuencias relativas entre períodos : z-score, log-odds ratio con prior.
#
# * TF-IDF por período: resalta palabras distintivas en un segmento temporal.

# %%
Vocab_periodo_df =  pd.pivot_table(freqs_df, values=['Frecuencia'], columns=['Período'],
                      index=['Palabra']).reset_index()

Vocab_periodo_df.columns = [col[1] if col[1] else col[0] for col in Vocab_periodo_df.columns]
Vocab_periodo_df.fillna(0, inplace=True) # Rellenar valores faltantes con 0
Vocab_periodo_df
# Out:
#              Palabra  2009  2014  2019
# 0                1a1   0.0   2.0   0.0
# 1                1a2   0.0   2.0   0.0
# 2     abastecimiento   0.0   0.0   2.0
# 3          abdominal   0.0   1.0   0.0
# 4            abierto   0.0   2.0   4.0
# ...              ...   ...   ...   ...
# 3216           zonal   1.0   0.0   0.0
# 3217        zoonosis   0.0   3.0   1.0
# 3218       zoonotica   1.0   1.0   0.0
# 3219      zooterapia   1.0   0.0   0.0
# 3220          zoster   1.0   0.0   1.0
#
# [3221 rows x 4 columns]

# %% [markdown]
# **Calcular diferencias y Z-Score para identificar emergentes**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

def calcular_diferencia_zscore(df, periodo1, periodo2, min_frecuencia=5):
    """
    Calcula la diferencia de frecuencia normalizada (Z-Score de la diferencia)
    para identificar palabras emergentes entre dos periodos.

    Args:
        df (pd.DataFrame): DataFrame con columnas 'palabra', 'frecuencia', 'porcentaje', 'periodo'.
        periodo1 (int): Primer periodo para la comparación.
        periodo2 (int): Segundo periodo para la comparación.
        min_frecuencia (int): Frecuencia mínima en al menos uno de los periodos para considerar la palabra.

    Returns:
        pd.DataFrame: DataFrame con palabras compartidas, sus frecuencias en ambos periodos,
                      diferencia de frecuencia y Z-Score de la diferencia.
    """
    df1 = df[df['Período'] == periodo1].set_index('Palabra')[['Frecuencia', 'Porcentaje']].add_suffix(f'_{periodo1}')
    df2 = df[df['Período'] == periodo2].set_index('Palabra')[['Frecuencia', 'Porcentaje']].add_suffix(f'_{periodo2}')

    df_comparacion = pd.concat([df1, df2], axis=1, join='outer').fillna(0)

    # Filtrar palabras con baja frecuencia en ambos periodos
    df_comparacion = df_comparacion[
        (df_comparacion[f'Frecuencia_{periodo1}'] >= min_frecuencia) |
        (df_comparacion[f'Frecuencia_{periodo2}'] >= min_frecuencia)
    ]

    df_comparacion['Diferencia_frecuencia'] = df_comparacion[f'Frecuencia_{periodo2}'] - df_comparacion[f'Frecuencia_{periodo1}']
    df_comparacion['zscore_diferencia'] = zscore(df_comparacion['Diferencia_frecuencia'])

    return df_comparacion.sort_values(by='zscore_diferencia', ascending=False)

def visualizar_palabras_emergentes(df_resultados, top_n=20, title="Palabras Emergentes (Z-Score Diferencia)"):
    """
    Visualiza las N palabras con el Z-Score de diferencia más alto.

    Args:
        df_resultados (pd.DataFrame): DataFrame con la columna 'zscore_diferencia'.
        top_n (int): Número de palabras a mostrar.
        title (str): Título del gráfico.
    """
    top_emergentes = df_resultados.head(top_n).sort_values(by='zscore_diferencia', ascending=True)
    plt.figure(figsize=(10, 6))
    sns.barplot(x='zscore_diferencia', y=top_emergentes.index, data=top_emergentes, palette='viridis')
    plt.title(title)
    plt.xlabel("Z-Score de la Diferencia de Frecuencia")
    plt.ylabel("Palabra")
    plt.tight_layout()
    plt.show()

# %%
periodo_pares = [('2009', '2014'), ('2014', '2019'), ('2009', '2019')]

for p1, p2 in periodo_pares:
    print(f"\n--- Comparación entre {p1} y {p2} ---")
    resultados = calcular_diferencia_zscore(freqs_df.copy(), p1, p2, min_frecuencia=5)
    resultados.to_csv(RESULTADOS_DIR+'/archivos_out/zscore_'+p1+'_'+p2+'.csv')
    emergentes = resultados[resultados['zscore_diferencia']>1.5]
    print("Cantidad de palabras emergentes, Z > 1.5 :",len(emergentes))
    display(emergentes.head(10))  # Mostrar las 10 palabras más emergentes
    visualizar_palabras_emergentes(emergentes,10, title=f"Palabras Emergentes Top 10: {p2} vs {p1}")
# Out:
# --- Comparación entre 2009 y 2014 ---
# Cantidad de palabras emergentes, Z > 1.5 : 18
#              Frecuencia_2009  Porcentaje_2009  Frecuencia_2014  \
# Palabra
# regimen                106.0         0.013496            202.0
# creacion               157.0         0.019990            220.0
# nacional               208.0         0.026483            267.0
# programa               112.0         0.014260            165.0
# persona                 46.0         0.005857             90.0
# medico                  78.0         0.009931            121.0
# alimento                29.0         0.003692             63.0
# sistema                 26.0         0.003310             58.0
# pmo                     35.0         0.004456             66.0
# tratamiento             58.0         0.007385             89.0
#
#              Porcentaje_2014  Diferencia_frecuencia  zscore_diferencia
# Palabra
# regimen             0.020739                   96.0           8.661629
# creacion            0.022587                   63.0           5.599788
# nacional            0.027413                   59.0           5.228655
# programa            0.016940                   53.0           4.671957
# persona             0.009240                   44.0           3.836910
# medico              0.012423                   43.0           3.744126
# alimento            0.006468                   34.0           2.909079
# sistema             0.005955                   32.0           2.723513
# pmo                 0.006776                   31.0           2.630730
# tratamiento         0.009138                   31.0           2.630730
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3568983009.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='zscore_diferencia', y=top_emergentes.index, data=top_emergentes, palette='viridis')
# --- Comparación entre 2014 y 2019 ---
# Cantidad de palabras emergentes, Z > 1.5 : 25
#            Frecuencia_2014  Porcentaje_2014  Frecuencia_2019  Porcentaje_2019  \
# Palabra
# covid                  0.0         0.000000            104.0         0.010174
# nacional             267.0         0.027413            361.0         0.035316
# integral              48.0         0.004928            103.0         0.010076
# crear                  0.0         0.000000             53.0         0.005185
# pandemia               0.0         0.000000             47.0         0.004598
# programa             165.0         0.016940            211.0         0.020642
# salud                155.0         0.015914            195.0         0.019077
# sanitario             26.0         0.002669             64.0         0.006261
# creacion             220.0         0.022587            251.0         0.024555
# marco                 10.0         0.001027             40.0         0.003913
#
#            Diferencia_frecuencia  zscore_diferencia
# Palabra
# covid                      104.0           9.355287
# nacional                    94.0           8.445005
# integral                    55.0           4.894904
# crear                       53.0           4.712848
# pandemia                    47.0           4.166679
# programa                    46.0           4.075650
# salud                       40.0           3.529481
# sanitario                   38.0           3.347425
# creacion                    31.0           2.710227
# marco                       30.0           2.619199
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3568983009.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='zscore_diferencia', y=top_emergentes.index, data=top_emergentes, palette='viridis')
# --- Comparación entre 2009 y 2019 ---
# Cantidad de palabras emergentes, Z > 1.5 : 24
#           Frecuencia_2009  Porcentaje_2009  Frecuencia_2019  Porcentaje_2019  \
# Palabra
# nacional            208.0         0.026483            361.0         0.035316
# covid                 0.0         0.000000            104.0         0.010174
# programa            112.0         0.014260            211.0         0.020642
# creacion            157.0         0.019990            251.0         0.024555
# integral             26.0         0.003310            103.0         0.010076
# regimen             106.0         0.013496            177.0         0.017316
# persona              46.0         0.005857            109.0         0.010663
# salud               133.0         0.016934            195.0         0.019077
# crear                 0.0         0.000000             53.0         0.005185
# pandemia              3.0         0.000382             47.0         0.004598
#
#           Diferencia_frecuencia  zscore_diferencia
# Palabra
# nacional                  153.0           9.641675
# covid                     104.0           6.475901
# programa                   99.0           6.152863
# creacion                   94.0           5.829825
# integral                   77.0           4.731495
# regimen                    71.0           4.343849
# persona                    63.0           3.826988
# salud                      62.0           3.762380
# crear                      53.0           3.180911
# pandemia                   44.0           2.599442
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3568983009.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='zscore_diferencia', y=top_emergentes.index, data=top_emergentes, palette='viridis')

# %% [markdown]
# El Z-Score estandariza la diferencia, permitiendo comparar la magnitud del cambio relativa a la variabilidad de todas las diferencias. Un Z-Score positivo alto sugiere una mayor emergencia en el segundo periodo. Se consideraron emergentes aquellas palabras con un z-score superior a 1.5, es decir, cuyo crecimiento superó en al menos 1.5 desviaciones estándar el crecimiento promedio del conjunto. Este umbral permite detectar términos que se destacan significativamente sin restringir el análisis a casos extremos.
#
# * Se observan palabras de alta frecuencia con Z-Scores extremos, tal que están presentes en los tres períodos. Por ejemplo **"nacional" y "programa", "creacion" son palabras con alta frecuencia y Z-scores extremos entre los períodos comparados 2009 y 2019. Podriamos interpretar que sus usos se ha incrementado en el período (2019-2024] aún más en relación con el resto del vocabulario del periodo (2009-2014]. Al estar presentes en los tres periodos, las palabras pueden indicar continuidad de temática centrales sobre salud por ejemplo asociado al ambito o planificación.
#
# Podrían ser indicadores importantes de cambios lingüísticos ¿portadoras de significado?¿influir en los embeddings de otras palabras?. Su altas frecuencia podrían hacer que sus representaciones en el espacio de embedding estén más "anclada", dominen el proceso de aprendizaje.
#
# * La palabra "covid" presenta un Z-scores extremos entre los períodos comparados 2009 y 2019, y 2014 y 2019, esto es porque tiene solo aparición en el periodo para 2019. Lo cual tiene sentido porque entre esos años se dio la pandemia.
#
# Fortalezas y Debilidades del Enfoque en Palabras con Baja Frecuencia y Poco Vocabulario Compartido:
#
# Fortalezas:
#
# * Simple y directo: El cálculo de la diferencia de frecuencia y el Z-Score son relativamente sencillos de implementar y entender.
#
# * Identifica cambios relativos: El Z-Score ayuda a identificar palabras cuyo cambio de frecuencia es grande en comparación con la variabilidad general de los cambios de frecuencia en el vocabulario compartido.
#
# Debilidades:
#
# Problemas con palabras de baja frecuencia:
#
# Ruido: Las palabras que aparecen con muy poca frecuencia pueden tener grandes cambios relativos en su porcentaje o frecuencia debido a una sola aparición o desaparición. Estos cambios pueden generar Z-Scores altos pero no ser semánticamente significativos o robustos. El umbral min_frecuencia intenta mitigar esto, pero elegir el umbral adecuado puede ser difícil.
#
# Estimaciones inestables: Las estadísticas basadas en conteos bajos pueden ser inestables y sensibles a pequeñas fluctuaciones en los datos.
# Problemas con poco vocabulario compartido:
#
# Análisis limitado: El enfoque solo puede analizar las palabras que están presentes en ambos periodos comparados. Ignora las palabras que emergen completamente en un periodo o desaparecen del otro, las cuales podrían ser indicadores importantes de cambio semántico o temático.
#
# Sesgo en la comparación: Si el vocabulario compartido es pequeño y no representativo de los cambios lingüísticos generales, las conclusiones basadas en él podrían estar sesgadas.

# %% [markdown]
# ##### log-odds ratio (con o sin prior bayesiano)
# https://www.cambridge.org/core/journals/political-analysis/article/fightin-words-lexical-feature-selection-and-evaluation-for-identifying-the-content-of-political-conflict/81B3703230D21620B81EB6E2266C7A66
#
#
# El log-odds ratio compara la probabilidad de que una palabra aparezca en un corpus A (ej. 2019–2023) frente a un corpus B (ej. 2009–2013). Cuanto más alta (positiva) sea la puntuación, más característica o "emergente" es la palabra en A. Si es muy negativa, es distintiva de B.
# Fue propuesto y difundido por Monroe et al. (2008) en análisis político y por Eisenstein et al. (2014) para redes sociales.
#
# Corrige el ruido de palabras que aparecen muy poco. Es más confiable que mirar frecuencias absolutas o proporc crudas. Permite comparar muchos términos de forma estadísticamente sólida incluso en corpus pequeños.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calcular_log_odds_ratio_apriori(frecuencia_periodo1, total_tokens_periodo1,
                                    frecuencia_periodo2, total_tokens_periodo2,
                                    prior_apriori=0.5):
    """
    Calcula el log-odds ratio con un prior a priori (Bayesiano).
    (Misma función que antes)
    """
    n11 = frecuencia_periodo2
    n10 = total_tokens_periodo2 - frecuencia_periodo2
    n01 = frecuencia_periodo1
    n00 = total_tokens_periodo1 - frecuencia_periodo1

    odds_ratio = ((n11 + prior_apriori) * (n00 + prior_apriori)) / ((n10 + prior_apriori) * (n01 + prior_apriori))

    if odds_ratio == 0:
        return -np.inf
    elif np.isinf(odds_ratio):
        return np.inf
    else:
        return np.log(odds_ratio)

# %%
def identificar_palabras_emergentes_lor(df, periodo1, periodo2, prior=0.5, umbral_lor=1.0):
    """
    Identifica palabras emergentes entre dos periodos usando el log-odds ratio Bayesiano.

    Args:
        df (pd.DataFrame): DataFrame con columnas 'palabra', 'frecuencia', 'periodo'.
        periodo1 (int): Primer periodo para la comparación.
        periodo2 (int): Segundo periodo para la comparación (donde buscamos emergencia).
        prior (float): Valor del prior a priori.
        umbral_lor (float): Umbral para considerar una palabra como emergente (LOR positivo y mayor que el umbral).

    Returns:
        pd.DataFrame: DataFrame con las palabras compartidas entre los periodos, sus frecuencias,
                      el log-odds ratio y una columna booleana indicando si la palabra es emergente.
    """
    df1 = df[df['Período'] == periodo1].set_index('Palabra')['Frecuencia'].rename(f'Frecuencia_{periodo1}')
    df2 = df[df['Período'] == periodo2].set_index('Palabra')['Frecuencia'].rename(f'Frecuencia_{periodo2}')

    df_comparacion = pd.concat([df1, df2], axis=1, join='outer').fillna(0)


    total_tokens_p1 = df[df['Período'] == periodo1]['Frecuencia'].sum()
    total_tokens_p2 = df[df['Período'] == periodo2]['Frecuencia'].sum()

    df_comparacion['log_odds_ratio'] = df_comparacion.apply(
        lambda row: calcular_log_odds_ratio_apriori(
            row[f'Frecuencia_{periodo1}'], total_tokens_p1,
            row[f'Frecuencia_{periodo2}'], total_tokens_p2,
            prior
        ),
        axis=1
    )

    df_comparacion['es_emergente'] = (df_comparacion['log_odds_ratio'] > umbral_lor)

    return df_comparacion.sort_values(by='log_odds_ratio', ascending=False)

def visualizar_palabras_emergentes_lor(df_resultados, top_n=20, title="Palabras Emergentes (Log-Odds Ratio)"):
    """
    Visualiza las N palabras con el log-odds ratio más alto.

    Args:
        df_resultados (pd.DataFrame): DataFrame con la columna 'log_odds_ratio'.
        top_n (int): Número de palabras a mostrar.
        title (str): Título del gráfico.
    """
    top_emergentes = df_resultados.head(top_n).sort_values(by='log_odds_ratio', ascending=True)
    plt.figure(figsize=(10, 6))
    sns.barplot(x='log_odds_ratio', y=top_emergentes.index, data=top_emergentes, palette='viridis')
    plt.title(title)
    plt.xlabel("Log-Odds Ratio (Bayesiano)")
    plt.ylabel("Palabra")
    plt.tight_layout()
    plt.show()

# %%
def visualizar_top_odds_ratios(df, columna_lor, n=20, title="Top Palabras por Log-Odds Ratio"):
    """
    Visualiza las N palabras con los log-odds ratios más altos y más bajos.

    Args:
        df (pd.DataFrame): DataFrame con los resultados del análisis LOR.
        columna_lor (str): Nombre de la columna que contiene los valores de LOR.
        n (int): Número de palabras a mostrar en cada extremo.
        title (str): Título del gráfico.
    """
    top_n = df.sort_values(by=columna_lor, ascending=False).head(n)
    bottom_n = df.sort_values(by=columna_lor, ascending=True).head(n)
    combined = pd.concat([top_n, bottom_n]).sort_values(by=columna_lor, ascending=False)

    plt.figure(figsize=(10, 12))
    sns.barplot(x=columna_lor, y=combined.index, data=combined, palette="coolwarm")
    plt.title(title)
    plt.xlabel("Log-Odds Ratio")
    plt.ylabel("Palabra")
    plt.tight_layout()
    plt.show()

# %%
periodo_pares = [('2009', '2014'), ('2014', '2019'), ('2009', '2019')]

for p1, p2 in periodo_pares:
    print(f"\n--- Comparación entre {p1} y {p2} ---")
    periodo_emergente = p2
    periodo_referencia = p1

    resultados_emergentes = identificar_palabras_emergentes_lor(
        freqs_df.copy(), periodo_referencia, periodo_emergente, prior=0.5, umbral_lor=1
    )

    resultados_emergentes.to_csv(RESULTADOS_DIR+'/archivos_out/lor_'+p1+'_'+p2+'.csv')
    print("Cantidad de palabras emergentes :",len(resultados_emergentes[resultados_emergentes['es_emergente']==True]))

    print(f"\n--- Palabras emergentes en {periodo_emergente} comparado con {periodo_referencia} ---")
    display(resultados_emergentes.head(10))
    visualizar_palabras_emergentes_lor(resultados_emergentes, title=f"Palabras Emergentes: {periodo_emergente} vs {periodo_referencia}")
    visualizar_top_odds_ratios(resultados_emergentes, 'log_odds_ratio', n=15, title=f"Top 15 Palabras Distintivas : {periodo_emergente} vs {periodo_referencia}")
# Out:
# --- Comparación entre 2009 y 2014 ---
# Cantidad de palabras emergentes : 366
#
# --- Palabras emergentes en 2014 comparado con 2009 ---
#                  Frecuencia_2009  Frecuencia_2014  log_odds_ratio  \
# Palabra
# habito                       0.0              9.0        2.730158
# hiperactividad               0.0              9.0        2.730158
# declarese                    0.0              9.0        2.730158
# deficit                      0.0              8.0        2.618829
# endometriosis                0.0              7.0        2.493563
# trombofilia                  0.0              7.0        2.493563
# anti                         0.0              7.0        2.493563
# responsabilidad              0.0              7.0        2.493563
# docente                      0.0              6.0        2.350360
# tdah                         0.0              6.0        2.350360
#
#                  es_emergente
# Palabra
# habito                   True
# hiperactividad           True
# declarese                True
# deficit                  True
# endometriosis            True
# trombofilia              True
# anti                     True
# responsabilidad          True
# docente                  True
# tdah                     True
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\2372005113.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='log_odds_ratio', y=top_emergentes.index, data=top_emergentes, palette='viridis')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3871079248.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna_lor, y=combined.index, data=combined, palette="coolwarm")
# --- Comparación entre 2014 y 2019 ---
# Cantidad de palabras emergentes : 812
#
# --- Palabras emergentes en 2019 comparado con 2014 ---
#               Frecuencia_2014  Frecuencia_2019  log_odds_ratio  es_emergente
# Palabra
# covid                     0.0            104.0        5.304261          True
# crear                     0.0             53.0        4.629728          True
# pandemia                  0.0             47.0        4.510186          True
# coronavirus               0.0             24.0        3.845872          True
# plasma                    0.0             15.0        3.387157          True
# recuperado                0.0             11.0        3.088272          True
# comercial                 0.0             10.0        2.997202          True
# suicidio                  0.0              9.0        2.897021          True
# prorrogar                 0.0              8.0        2.785698          True
# garanticesir              0.0              7.0        2.660436          True
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\2372005113.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='log_odds_ratio', y=top_emergentes.index, data=top_emergentes, palette='viridis')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3871079248.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna_lor, y=combined.index, data=combined, palette="coolwarm")
# --- Comparación entre 2009 y 2019 ---
# Cantidad de palabras emergentes : 489
#
# --- Palabras emergentes en 2019 comparado con 2009 ---
#                 Frecuencia_2009  Frecuencia_2019  log_odds_ratio  es_emergente
# Palabra
# covid                       0.0            104.0        5.089055          True
# crear                       0.0             53.0        4.414522          True
# endometriosis               0.0             32.0        3.914018          True
# coronavirus                 0.0             24.0        3.630666          True
# acompanamiento              0.0             19.0        3.401917          True
# plasma                      0.0             15.0        3.171951          True
# declarese                   0.0             15.0        3.171951          True
# abordaje                    0.0             13.0        3.033605          True
# incorporese                 0.0             12.0        2.956546          True
# recuperado                  0.0             11.0        2.873066          True
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\2372005113.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='log_odds_ratio', y=top_emergentes.index, data=top_emergentes, palette='viridis')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3540\3871079248.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columna_lor, y=combined.index, data=combined, palette="coolwarm")

# %% [markdown]
# LOR > 0: Indica que la palabra tiene una mayor probabilidad de aparecer en el grupo 1 (generalmente el periodo de tiempo más reciente o el corpus de interés) en comparación con el grupo 2 (el periodo de referencia). Cuanto mayor sea el valor positivo, más fuerte es la evidencia de que la palabra está emergiendo o aumentando su uso en el grupo 1.
#
# LOR < 0: Indica que la palabra tiene una menor probabilidad de aparecer en el grupo 1 en comparación con el grupo 2. Un valor negativo grande sugiere que la palabra está disminuyendo su uso o era más común en el grupo de referencia.
#
#
# LOR ≈ 0: Indica que la probabilidad de la palabra es similar en ambos grupos. Estas palabras probablemente no son emergentes ni en declive significativo.

# %% [markdown]
# Se consider un prior pequeño y constante como 0.5. Esta es una práctica común. Habría que analizar otros.

# %% [markdown]
# * El análisis del log-odds ratio entre los períodos 2009–2013 y 2014–2018 revela la emergencia de nuevos términos asociados principalmente a la salud mental infantil (tdah, hiperactividad, déficit) y la salud reproductiva femenina (endometriosis, trombofilia) .
# * La comparación entre los períodos 2014–2018 y 2019–2023 muestra palabras que influyen en un cambio semántico abrupto, vinculado principalmente a la pandemia de COVID-19. Palabras como “covid”, “pandemia” y “coronavirus” emergen con log-odds elevados, reflejando la centralidad de la crisis sanitaria en la agenda legislativa.
# * La comparación entre los extremos del período (2009–2013 vs. 2019–2023) visibiliza la influencia de COVID-19 en cuanto a nuevos términos como “covid” y “coronavirus” y a una transformación en el lenguaje legislativo “crear”, “incorpórese”, “acompañamiento” e “abordaje". La existencia de palabra de “endometriosis” como palabra emergente podría relacionarse con salud reproductiva.

# %% [markdown]
# ##### TF-IDF por período

# %%
docs_por_periodo = pd.Series(PER5anios_df['Título normalizado'].values, index =PER5anios_df['Periodo_5anios'])
docs_por_periodo
# Out:
# Periodo_5anios
# 2009                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2014                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 2019    incluyar calendario nacional vacunacion caracter obligatorio gratuito vacuna virus dengue .incluir calendario nacional vacunacion caracter obligatorio gratuito vacuna virus dengue.fortalecimiento ingreso sector popular regimen.fomentese aplicacion programa compra iva sector vulnerable.control enfermedad prevenibl vacunacion  incorporacion vacuna dengue calendario nacional.prescripcion receta medica regimen.integrar calendario nacional vacunacion caracter gratuito obligatorio esquema completo inmunizacion virus dengue denv persona seropositiva contraer virus anterioridad.campana nacional difusion concientizacion promocion donacion voluntario sangre hemocomponent medula osea creacion.campana nacional prevencion incidente monoxido carbono creacion.declarar derecho humano fundamental acceso agua potable.garanticesir acceso integral procedimiento tecnica medico asistencial reproduccion medicamente asistido thro.enfermedad ocular recien nacido regimen deteccion precoz diagnostico posterior tratamiento.programa federal inclusion social mejora habitat construccion mejora vivienda creacion.gestacion sustitucion altruista regimen modificacion codigo civil comercial nacion.regimen regulacion ejercicio psicopedagogia.garanticesir acceso integral procedimiento tecnica medico asistencial reproduccion medicamente asistido thro.creacion programa nacional adecuado cesarea.declarar inter nacional abordaje integral persona afectado enfermedad parkinson instituir abril ano nacional parkinson.programa nacional capacitacion implementacion adulto huerta agroecologica proam huerta creacion.incorporar calendario nacional caracter gratuito obligatorio esquema completo vacunacion virus dengue persona ano.crear programa nacional deteccion enfermedad renal cronico nino nina adolescente ambito ministerio salud nacion.etiquetar inclusivo sistema escritura braille medicamento regimen .regimen promocion asociacion atencion servicio social.obra social ley medicina prepagar  persona poseer algun tipo discapacidad.concientizacion ciudadano importancia donacion medula oseo.deteccion recoleccion disposicion asbesto instalado.programa nacional prevencion discapacidad recien nacido  incorporar atrofia muscular espinal ame pesquisa neonatal.otorguese beneficio extraordinario caracter economico grupo familiar unico familia afectado incendio ocurrido agosto octubre provincia cordoba.instituir premio nacional medico ano doctor rene favaloro.sistema proteccion integral persona victima abuso psicopatico creacion.programa nacional argentino saludable creacion ambito ministerio salud nacion.derecho paciente relacion profesional institucion salud  asistencia paciente.declarar emergencia presupuestario nacional obra social universidad nacional aprobacion presupuesto.cobertura protector solar programa medico obligatorio.sistema integrado salud sis creacion.programa oficina gestion paciente ambito efector publico pais creacion.sistema integrado salud sis creacion.regulacion comercializacion sucedaneos leche humano proteccion lactancia.campana nacional difusion concientizacion donacion medula osea creacion.marco regulatorio medicina prepagar  equidad tratamiento medico.regulacion ejercicio profesion licenciado licenciado nutricion.afaquia pediatrica incorporacion programa medico obligatorio.capacitacion anual obligatorio realizacion maniobra heimlich personal establecimiento educativo recreacion gastronomicos circulacion concurrencia masivo.plan nacional alimentacion saludable infancia adolescencia prevencion sobrepeso obesidad nino nina adolescente plan creacion.reproduccion medicamente asistido  prevencion enfermedad genetica.registro nacional unico obligatorio profesional salud creacion.emergencia alimentario nacional  priorizar pago simplificar agilizar procedimiento administrativo reducir plazo licitacion publica compra alimento seco fresco comedor merendero inscripto registro nacional comunitario organizacion sociedad civil renacom.declarar emergencia alimentario n ...
# dtype: object

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer


# Aplicamos TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(docs_por_periodo)

# Creamos un DataFrame con los resultados
tfidf_df = pd.DataFrame(tfidf_matrix.T.toarray(), 
                        index=vectorizer.get_feature_names_out(), 
                        columns=docs_por_periodo.index)

# Mostrar las top palabras distintivas por período
for periodo in tfidf_df.columns:
    print(f"\n Palabras más distintivas en {periodo}")
    display(tfidf_df[periodo].sort_values(ascending=False).head(10))
# Out:
#  Palabras más distintivas en 2009
# nacional       0.402536
# creacion       0.303838
# salud          0.257391
# programa       0.216750
# social         0.210945
# regimen        0.205139
# ley            0.197398
# obligatorio    0.162563
# medico         0.150951
# declarar       0.149016
# Name: 2009, dtype: float64
#  Palabras más distintivas en 2014
# nacional       0.414676
# creacion       0.341681
# regimen        0.313725
# programa       0.256261
# salud          0.240730
# medico         0.187924
# obligatorio    0.150650
# social         0.144438
# persona        0.139778
# tratamiento    0.138225
# Name: 2014, dtype: float64
#  Palabras más distintivas en 2019
# nacional       0.475763
# creacion       0.330793
# programa       0.278077
# salud          0.256991
# regimen        0.233269
# covid          0.232066
# medico         0.143651
# persona        0.143651
# obligatorio    0.139698
# integral       0.135744
# Name: 2019, dtype: float64

# %% [markdown]
# Se aplicó la métrica TF-IDF sobre los textos agrupados por períodos de 5 años, considerando cada período como un “documento agregado”. Esta estrategia permitió identificar términos con alta relevancia local, palabras distintivas que caracterizan el discurso legislativo sobre salud en cada período analizado.

# %%
def mostrar_ejemplos_contextuales_titulos(df, palabra, periodo, n=5):
    """
    Muestra ejemplos de títulos que contienen una palabra específica en un periodo.

    Args:
        df (pd.DataFrame): DataFrame con columnas 'titulo' (o la columna de títulos) y 'periodo'.
        palabra (str): La palabra para buscar en los títulos (insensible a mayúsculas/minúsculas).
        periodo (int): El periodo de interés.
        n (int): Número de ejemplos a mostrar.
    """
    df_periodo = df[df['Periodo_5anios'] == periodo]
    titulos_con_palabra = df_periodo[df_periodo['Título normalizado'].str.lower().str.contains(palabra.lower(), na=False)]

    if not titulos_con_palabra.empty:
        print(f"\nEjemplos de títulos conteniendo '{palabra}' en el periodo {periodo}:")
        display(titulos_con_palabra[['Título','Título normalizado']].head(n))
    
    else:
        print(f"No se encontraron títulos conteniendo '{palabra}' en el periodo {periodo}.")

# %% [markdown]
# ### Para Análisis Cualitativo y Lingüístico

# %%
basetexto_df.columns
# Out:
# Index(['Proyecto.ID', 'Título', 'Título procesado', 'Título normalizado',
#        'Cant_token', 'Cant_token_normalizado',
#        'Proyecto_girado_a_comisiones_SALUD', 'Proyecto_SALUD', 'Resultado',
#        'Max_Orden', 'Tiene_antecedente_por_titulo_proy', 'Periodo', 'Año',
#        'Tokens', 'Periodo_5anios'],
#       dtype='object')

# %%
# Ejemplo de cómo usar la función para ver el contexto
palabra_ejemplo = 'nacional'
for periodo in [2009,2014,2019]:
    mostrar_ejemplos_contextuales_titulos(basetexto_df.copy(), palabra_ejemplo, periodo, n=3)
# Out:
# Ejemplos de títulos conteniendo 'nacional' en el periodo 2009:
#                                                                                                                                                                                                                Título  \
# 25671                                                                                                            CREACION EN EL AMBITO DEL MINISTERIO DE SALUD DE LA NACION EL REGISTRO UNIVERSAL SANITARIO NACIONAL.
# 25674                                                                              INCORPORACION AL CALENDARIO NACIONAL DE VACUNACION, LAS DOSIS DE VACUNAS CONTRA LA VARICELA, SIENDO ESTAS DE CARACTER OBLIGATORIO.
# 25708  ATENCION MEDICA, INVESTIGACION CLINICA Y EPIDEMIOLOGICA, CAPACITACION PROFESIONAL EN LA DETECCION TEMPRANA, DIAGNOSTICO DIFUSION Y TRATAMIENTO DE LAS ALERGIAS ALIMENTARIAS. DECLARACION DE INTERES NACIONAL.
#
#                                                                                                                                                             Título normalizado
# 25671                                                                                            creacion ambito ministerio salud nacion registro universal sanitario nacional
# 25674                                                                                  incorporacion calendario nacional vacunacion dosis vacuna varicela caracter obligatorio
# 25708  atencion medica investigacion clinico epidemiologico capacitacion profesional deteccion diagnostico difusion tratamiento alergia alimentario declaracion inter nacional
# Ejemplos de títulos conteniendo 'nacional' en el periodo 2014:
#                                                                         Título  \
# 12817       PROGRAMA NACIONAL DE ATENCION MEDICA SEXUAL AMBULATORIA. CREACION.
# 12823                      DECLARESE AL MANI ARGENTINO COMO ALIMENTO NACIONAL.
# 12867  LEY NACIONAL DEL REGISTRO MEDICO ELECTRONICO DE SALUD -REMES-. CREACION
#
#                                                   Título normalizado
# 12817  programa nacional atencion medica sexual ambulatorio creacion
# 12823                     declarese mani argentino alimento nacional
# 12867  ley nacional registro medico electronico salud remes creacion
# Ejemplos de títulos conteniendo 'nacional' en el periodo 2019:
#                                                                                                                                                                Título  \
# 2061        INCLUYASE EN EL CALENDARIO NACIONAL DE VACUNACION CON CARACTER OBLIGATORIO Y GRATUITO LA VACUNA CONTRA EL VIRUS DEL DENGUE. MODIFICACION DE LA LEY 27491.
# 2067                                        INCLUIR EN EL CALENDARIO NACIONAL DE VACUNACION CON CARACTER OBLIGATORIO Y GRATUITO LA VACUNA CONTRA EL VIRUS DEL DENGUE.
# 2100  CONTROL DE ENFERMEDADES PREVENIBLES POR VACUNACION - LEY 27491-. MODIFICACIONES SOBRE LA INCORPORACION DE LA VACUNA CONTRA EL DENGUE EN EL CALENDARIO NACIONAL.
#
#                                                                               Título normalizado
# 2061  incluyar calendario nacional vacunacion caracter obligatorio gratuito vacuna virus dengue
# 2067    incluir calendario nacional vacunacion caracter obligatorio gratuito vacuna virus dengue
# 2100    control enfermedad prevenibl vacunacion  incorporacion vacuna dengue calendario nacional

# %% [markdown]
# INICIATIVA LEGISLATIVA
# * Iniciativas total : 35179
# * Vocabulario : 12865
# * Top 4 palabras con mayores frecuencias:
# nacional (10119), creacion (6033), regimen(5828), ley(5262). No se las eliminaron aún.
#
# INICIATIVA LEGISLATIVA DE SALUD
# * Iniciativas total : 2848 (8% del total)
# * Vocabulario: 3221 (25% del total)
# * Top 5 palabras con mayores frecuencias:
# nacional (836), creacion (628), programa (488), regimen	(485), salud (483).
# * N-gramas más frecuentes top 6 (mas diferencia con el resto). Se observa n-gramas de n entre 2 a 5 con mínima frecuencia 1:
# 	* programa nacional  (2-grama)     208 veces
# 	* medico obligatorio (2-grama)     187 veces
# 	* programa medico obligatorio (3-grama)         153 veces
# 	* programa medico         153 veces
# 	* obligatorio pmo         150 veces
# 	* medico obligatorio pmo  150 veces
#
#
# CORPUS POR PERIODO DE 5 AÑOS
# * Desde 2009 a 2024, 16 años : promedio de cantidad palabras por título normalizado es 9. La media de 9 es una estimación del promedio anual de tokens para el periodo de 16 años.
# La mayoría de los promedios anuales de tokens se encuentran relativamente cerca de la media de 9.
#
# Análisis general (Tres Periodos Combinados)
#
#
# * Existe un alta variabilidad de frecuencia de palabra en período de 5 años (rango = 360 frecuencia).
# * La mayoría de las palabras en período de 5 años tienen baja frecuencia de ocurrencia tal que se  concentran alrededor de frecuencia=2.
# * El 75% del total de palabras en los tres periodos presentan una frecuencia inferior a frecuencia = 4.
# * Se considera que una palabra en período de 5 años con frecuencia superior 8 es una palabra de frecuencia extrema o especial.
# * Hay 318 palabras únicas por período que superan las 8 veces en alguno de los tres períodos.
# * Total de palabras con frecuencia extrema en alguno de los tres periodo = 622
#
# Análisis por Periodo:  Por período de 5 años
# Los vocabularios o las cantidades de palabras únicas por período están dispersos.
# La media 1853 no es tan representativa para los tres periodos a procesar, pero aún así no indica la existencia de
# vocabularios relativamente pequeños (menor diversidad léxica?)para entrenar embeddings de palabras robustos y para analizar la detección de cambios semánticos de manera confiable con las técnicas estándar.
#
# --- Periodo: 2009 ---
# Tamaño del vocabulario único: 1714
# Frecuencia total de palabras: 7854
# Frecuencia media de las palabras (BCa): 4.58 (IC 95%: 4.12, 5.23)
# ['nacional' 'creacion' 'salud' 'programa' 'social' 'regimen' 'ley'
#  'obligatorio' 'medico' 'declarar']
#
# --- Periodo: 2014 ---
# Tamaño del vocabulario único: 1969
# Frecuencia total de palabras: 9740
# Frecuencia media de las palabras (BCa): 4.95 (IC 95%: 4.45, 5.66)
# ['nacional' 'creacion' 'regimen' 'programa' 'salud' 'medico' 'obligatorio'
#  'social' 'persona' 'tratamiento']
#
#
# --- Periodo: 2019 ---
# Tamaño del vocabulario único: 1876
# Frecuencia total de palabras: 10222
# Frecuencia media de las palabras (BCa): 5.45 (IC 95%: 4.85, 6.36)
# ['nacional' 'creacion' 'programa' 'salud' 'regimen' 'medico' 'persona'
#  'obligatorio' 'covid' 'integral']
#
#
# Distribución de la frecuencia: Los histogramas muestran cómo se distribuyen las palabras según su frecuencia.
# Se mantiene la distribución con muchas palabras de baja frecuencia y pocas palabras de alta frecuencia (Ley de Zipf).
#
# Frecuencia media con intervalos de confianza: el promedio de ocurrencias de una palabra en el periodo, es en general, un frecuencia de ocurrencia igual a 5.
#
# El intervalo de confianza te proporciona un rango dentro del cual es probable que se encuentre la verdadera frecuencia media de las palabras en la población
# (todos los posibles títulos de ese periodo). Los intervalos de confianza para el promedio de ocurrencias de una palabra en el periodo para diferentes periodos en general se superponen lo que indicaría que no hay diferencia significativa en la frecuencia media de las palabras entre esos periodos.
#
#
# En general, 29% del vocabulario total de pares de periodos a comparar es compartido, es decir  que solo el 29% de las palabras únicas que aparecen en la unión de los vocabularios de ambos periodos están presentes en ambos periodos. El 71% restante del vocabulario total aparece solo en uno de los dos periodos comparados.
#
# En vocabularios pequeños, un solapamiento del 29% puede tener un impacto en el análisis de cambio semántico:
#
# * Menos palabras para comparar
# * Mayor impacto de palabras nuevas y desaparecidas
# * La falta de datos compartidos puede llevar a representaciones inestables o poco confiables para las palabras en embedding.
#
# Palabras emergente
#
# * Se observan palabras de alta frecuencia con Z-Scores extremos, tal que están presentes en los tres períodos. Por ejemplo **"nacional" y "programa", "creacion" son palabras con alta frecuencia y Z-scores extremos entre los períodos comparados 2009 y 2019. Podriamos interpretar que sus usos se ha incrementado en el período (2019-2024] aún más en relación con el resto del vocabulario del periodo (2009-2014]. Al estar presentes en los tres periodos, las palabras pueden indicar continuidad de temática centrales sobre salud por ejemplo asociado al ambito o planificación.
# * log-odds ratio al corregir el ruido de palabras que aparecen muy poco, identifica palabras emergentes que no están necesariamente en los tres períodos.
# Palabras como “covid”, “pandemia” y “coronavirus” emergen con log-odds elevados, reflejando la centralidad de la crisis sanitaria en la agenda legislativa.
