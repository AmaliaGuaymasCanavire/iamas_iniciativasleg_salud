# %% [markdown]
# # Contexto de cambios semanticos en iniciativas legislativas en SALUD

# %% [markdown]
# ## Consideraciones previas
# Se realizaron 50 ejecuciones independientes del enfoque Procrustes, cada una con una semilla aleatoria distinta. En cada iteración, se seleccionaron las 300 palabras con mayor cambio semántico entre los pares de períodos comparados, considerando únicamente aquellas con al menos 5 ocurrencias en alguno de los dos períodos de cinco años.
#
# Posteriormente, se calculó la similaridad semantica promedio (medida de estabilidad del modelo) para cada palabra identificada en cada par de periodos comparados. Este valor fue estimado junto con sus respectivos intervalos de confianza del 95%, utilizando el método bootstrap.
#
#
# **Umbrales cables**
# * umbral_top = 0 # antes 5 se eliminan las palabras nacional (836), creacion (628), programa (488), regimen	(485), salud (483).
# * umbral_frec_menos = 2 # < antes 5 mediana de frecuencia de ocurrencia de palabra en titulos
# * umbral_frec_menos_full  = 5 # antes 9 < amedia de ocurrencia de palabra en periodo de 5 años
# * topn_vecinos = 100
#
# **Config modelo**
#
# https://radimrehurek.com/gensim/models/word2vec.html
#
# * tam_vector = 100 # Dimensionalidad de los vectores de palabras.
# * ventana = 8 # ventana ( int , opcional ): distancia máxima entre la palabra actual y la palabra prevista dentro de una oración.
# * min_frec = 2 #  Ignora todas las palabras con una frecuencia total menor que esta.
# * w = 1  # utilice estos muchos subprocesos de trabajo para entrenar el modelo (=entrenamiento más rápido con máquinas de múltiples núcleos).
# * s = 1 # Algoritmo de entrenamiento: 1 para skip-gram; de lo contrario, CBOW.
# * e = 100 # Número de iteraciones (épocas) en el corpus. (Anteriormente: iter )
# * semilla = 1 # seed ( int , opcional ): Semilla para el generador de números aleatorios.
# * iteracion = 50
#
# **Terminología**
# * periodo 2009 : [2009, 2014)
# * periodo 2014 : [2014, 2019)
# * periodo 2019 : [2019, 2024)
# * Par de periodos (2009, 2014) : Esto indica los pares de periodos comparados [2009, 2014) vs  [2014, 2019)
# * Par de periodos (2014, 2019) : Esto indica los pares de periodos comparados [2014, 2019) vs [2019, 2024)
#
# En este trabajo se analiza pares de periodos, al analizar las palabras con fuerte y moderado cambio semantico entre los periodos comparados.

# %%
# Importar librería
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import pickle
import os
import re
import random as rn
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import bootstrap
import matplotlib.pyplot as plt
import itertools

from gensim.models import Word2Vec
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
tqdm.pandas()

from ast import literal_eval

# %%
# Configurar
load_dotenv() # Cargar las variables de entorno del archivo .env
BASE_DIR =  os.getenv("DIR_BASE")
RESULTADOS_DIR = os.getenv("DIR_DATOS_PROCESADOS") # Acceder a las variables de entorno
modelo_dir =  RESULTADOS_DIR+ '/archivos_out/modelos_swmwosge_1008211100'
pd.set_option('display.max_colwidth', None)

# %%
# Abrir OBJETO
with open(modelo_dir+'/top300_periodos_procrustes_df.pkl', 'rb') as file: 
    topn_periodo = pickle.load(file) ## Diccionario

# %%
pares_periodo = [ (2009, 2014),(2014, 2019)]
topk = 10
for par_periodo in pares_periodo:

    df = topn_periodo[par_periodo].sort_values('similaridad_semantica_mean', ascending=True)
    print("*************************")
    print(par_periodo)
    print("*************************")
    print(df.shape)
    #display(df.head(topk))
    display(df.describe(include='all'))
# Out:
# *************************
# (2009, 2014)
# *************************
# (341, 6)
#          par_periodo palabra  similaridad_semantica_mean  \
# count            341     341                  341.000000
# unique             1     341                         NaN
# top     (2009, 2014)   legal                         NaN
# freq             341       1                         NaN
# mean             NaN     NaN                    0.628807
# std              NaN     NaN                    0.097842
# min              NaN     NaN                    0.226934
# 25%              NaN     NaN                    0.572572
# 50%              NaN     NaN                    0.659745
# 75%              NaN     NaN                    0.705454
# max              NaN     NaN                    0.742527
#
#         similaridad_semantica_confidence_intervals  \
# count                                          341
# unique                                         341
# top     (0.22002384660263957, 0.23402394056119352)
# freq                                             1
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                               vt1_top10  \
# count                               341
# unique                              340
# top     {tgd, generalizado, integrante}
# freq                                  2
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#                                         vt2_top10
# count                                         341
# unique                                        341
# top     {droga, monodroga, embarazo, misoprostol}
# freq                                            1
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
# *************************
# (2014, 2019)
# *************************
# (333, 6)
#          par_periodo      palabra  similaridad_semantica_mean  \
# count            333          333                  333.000000
# unique             1          333                         NaN
# top     (2014, 2019)  dispositivo                         NaN
# freq             333            1                         NaN
# mean             NaN          NaN                    0.627456
# std              NaN          NaN                    0.102706
# min              NaN          NaN                    0.219099
# 25%              NaN          NaN                    0.566346
# 50%              NaN          NaN                    0.647331
# 75%              NaN          NaN                    0.709830
# max              NaN          NaN                    0.755610
#
#        similaridad_semantica_confidence_intervals  \
# count                                         333
# unique                                        333
# top      (0.2116572594670913, 0.2265566385301449)
# freq                                            1
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#                                               vt1_top10  \
# count                                               333
# unique                                              333
# top     {nocivo, electronico, dato, necesario, similar}
# freq                                                  1
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#                                                                                       vt2_top10
# count                                                                                       333
# unique                                                                                      333
# top     {tecnologico, desfibrilador, subitar, oftalmologico, concurrencia, instalacion, minimo}
# freq                                                                                          1
# mean                                                                                        NaN
# std                                                                                         NaN
# min                                                                                         NaN
# 25%                                                                                         NaN
# 50%                                                                                         NaN
# 75%                                                                                         NaN
# max                                                                                         NaN

# %% [markdown]
# * Cambio de 2009 y 2014
#     * 341 palabras
#     * similaridad_semantica_mean
#         * media: 0.628807
#         * mediana: 0.659745
#
# * Cambio de 2014 y 2019
#     * 333 palabras
#     * similaridad_semantica_mean
#         * media: 0.627456
#         * mediana: 0.6473315
#
#
# En general, teniendo en cuenta la similaridad semántica media, no se observan cambios semántico en las palabras comparadas entre pares de períodos, es decir entre 2009 y 2014,  y 2014  y 2019.

# %% [markdown]
# ### Distribución entre períodos

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Convertir datos en DataFrame para visualización
def plot_heatmap(cambios_df, title, top = 10):
    #words, values = zip(*changed_words[:top])  # Tomamos el top 10
    #df = pd.DataFrame({"Palabra": words, "Cambio Semántico": values})
    df = cambios_df.copy()
    plt.figure(figsize=(8, 5))
    sns.heatmap(df.set_index("palabra").T, cmap="Reds", annot=True, fmt=".2f", linewidths=0.5)
    plt.title(title + " Top "+str(top))
    plt.show()

def diferencia(par):
    return par[1] - par[0]

# %%
topk = 10
for par_periodo in pares_periodo:

    print("dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos)")
    periodo_df = topn_periodo[par_periodo]
    umbral_fuerte1 = 0.3
    periodo_df1 =  periodo_df[periodo_df['similaridad_semantica_mean']<=umbral_fuerte1].sort_values('similaridad_semantica_mean', ascending=True).head(topk)
    periodo_df1["dispersion"] = periodo_df1['similaridad_semantica_confidence_intervals'].apply(diferencia)
    periodo_df1 =  periodo_df1.sort_values('dispersion', ascending=True)

    # Graficar Heatmaps
    plot_heatmap(periodo_df1[['palabra','similaridad_semantica_mean']], "Cambio semántico  (["+str(par_periodo[0])+"-"+str(par_periodo[1])+") → ["+str(par_periodo[1])+"-"+str(par_periodo[1]+5)+")", top=topk)
    print("TOP 10 Palabras:", periodo_df1['palabra'].unique())
    display(periodo_df1) 
    print("dist ~ 0.5 (sc ~ 0.5)  Cambio moderado")

    umbral_fuerte2 = 0.5
    periodo_df1 =  periodo_df[(periodo_df['similaridad_semantica_mean']<=umbral_fuerte2) & (periodo_df['similaridad_semantica_mean']>umbral_fuerte1)].sort_values('similaridad_semantica_mean', ascending=True).head(topk)
    periodo_df1["dispersion"] = periodo_df1['similaridad_semantica_confidence_intervals'].apply(diferencia)
    periodo_df1 =  periodo_df1.sort_values('dispersion', ascending=True)

    # Graficar Heatmaps
    plot_heatmap(periodo_df1[['palabra','similaridad_semantica_mean']], "Cambio semántico  (["+str(par_periodo[0])+"-"+str(par_periodo[1])+") → ["+str(par_periodo[1])+"-"+str(par_periodo[1]+5)+")", top=topk)
    print("TOP 10 Palabras:", periodo_df1['palabra'].unique())
    display(periodo_df1)
# Out:
# dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos)
# TOP 10 Palabras: ['legal' 'materia' 'declaracion']
#       par_periodo      palabra  similaridad_semantica_mean  \
# 185  (2009, 2014)        legal                    0.226934
# 196  (2009, 2014)      materia                    0.284821
# 81   (2009, 2014)  declaracion                    0.240741
#
#      similaridad_semantica_confidence_intervals  \
# 185  (0.22002384660263957, 0.23402394056119352)
# 196   (0.27599544304365015, 0.2939124981934813)
# 81   (0.23132365204190666, 0.25030950875089053)
#
#                                                                                    vt1_top10  \
# 185                      {colaborador, norma, odontologia, loteria, auxiliar, musicoterapia}
# 196  {postraumatico, estr, presupuesto, delito, basica, adopcion, fortalecimiento, primaria}
# 81                               {natural, rioja, jujuy, chaco, valle, accion, departamento}
#
#                                                        vt2_top10  dispersion
# 185                    {droga, monodroga, embarazo, misoprostol}    0.014000
# 196  {politica, vacunacion, laboratorio, cumplimiento, congreso}    0.017917
# 81                          {prepagar, suspension, marco, valor}    0.018986
# dist ~ 0.5 (sc ~ 0.5)  Cambio moderado
# TOP 10 Palabras: ['dengue' 'acompanante' 'el' 'recurso' 'patologia' 'tipo' 'ingreso'
#  'empleo' 'comunitario' 'territorio']
#       par_periodo      palabra  similaridad_semantica_mean  \
# 84   (2009, 2014)       dengue                    0.393630
# 4    (2009, 2014)  acompanante                    0.385151
# 111  (2009, 2014)           el                    0.402771
# 281  (2009, 2014)      recurso                    0.403233
# 237  (2009, 2014)    patologia                    0.411419
# 324  (2009, 2014)         tipo                    0.353474
# 174  (2009, 2014)      ingreso                    0.374986
# 118  (2009, 2014)       empleo                    0.324193
# 65   (2009, 2014)  comunitario                    0.402430
# 323  (2009, 2014)   territorio                    0.382965
#
#      similaridad_semantica_confidence_intervals  \
# 84    (0.38788975113805113, 0.3991380240805996)
# 4    (0.37867500185855757, 0.39201489404050754)
# 111     (0.3962024900010215, 0.409767874662569)
# 281  (0.39645288196405276, 0.41031146638253785)
# 237   (0.40385431147510736, 0.4189179418427644)
# 324    (0.3457579396706319, 0.3610847644949076)
# 174    (0.3668127609121415, 0.3828470467135649)
# 118   (0.3157658079543117, 0.33340039425717294)
# 65     (0.3924988968362833, 0.4114690451141395)
# 323  (0.37243684312347564, 0.39260252943863166)
#
#                                                                                              vt1_top10  \
# 84                          {aparicion, epidemia, territorio, tropical, chaco, emergente, seguimiento}
# 4                               {nacimiento, gratuidad, parto, embarazo, proceso, permanencia, recien}
# 111      {rioja, febrero, regional, identificar, juvenil, infeccion, septiembre, infanto, hidrogenado}
# 281        {tecnologico, tecnico, verificacion, trazabilidad, superior, pandemia, aptitud, enfermeria}
# 237  {nocivo, puerperio, radiacion, mamario, producido, reconstruccion, mamaria, mastectomia, cirugia}
# 324                              {gripe, aparicion, h1n1, papiloma, avance, influenza, virus, causado}
# 174                                           {anses, geriatrico, fincini, ciudadano, ninez, ganancia}
# 118                                            {jefe, equivalente, familia, comunitario, nivel, hogar}
# 65                            {voluntario, radicacion, direccion, revestir, sanitaria, hogar, militar}
# 323                                    {corriente, tintoreria, lavanderia, percloroetileno, reconocer}
#
#                                                                                   vt2_top10  \
# 84                                                             {comprendido, fiebre, virus}
# 4    {cosmiatrio, piercing, recurso, equinoterapia, terapeutico, cosmetologia, obstetricia}
# 111                                   {clinico, premio, consentimiento, doctor, septiembre}
# 281      {acompanante, cerebrovascular, terapeutico, equinoterapia, acvo, acv, obstetricia}
# 237                                                                {recien, nacido, visual}
# 324                                          {fabricacion, ensenanza, cualquiera, mercurio}
# 174                                               {maquina, categoria, virus, ninez, solar}
# 118         {asignacion, subsistema, elemento, sustancia, formacion, ftalato, contributivo}
# 65                                                     {marzo, accion, familia, financiero}
# 323                                          {natural, tecnologico, restaurante, republica}
#
#      dispersion
# 84     0.011248
# 4      0.013340
# 111    0.013565
# 281    0.013859
# 237    0.015064
# 324    0.015327
# 174    0.016034
# 118    0.017635
# 65     0.018970
# 323    0.020166
# dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos)
# TOP 10 Palabras: ['dispositivo' 'adecuado' 'comunitario' 'accesibilidad']
#       par_periodo        palabra  similaridad_semantica_mean  \
# 101  (2014, 2019)    dispositivo                    0.219099
# 5    (2014, 2019)       adecuado                    0.286341
# 67   (2014, 2019)    comunitario                    0.281564
# 0    (2014, 2019)  accesibilidad                    0.298858
#
#     similaridad_semantica_confidence_intervals  \
# 101   (0.2116572594670913, 0.2265566385301449)
# 5    (0.27825804628988354, 0.2936208116061226)
# 67    (0.27165948468648776, 0.290427646180417)
# 0       (0.28724259050712, 0.3092740195772763)
#
#                                                  vt1_top10  \
# 101        {nocivo, electronico, dato, necesario, similar}
# 5            {camara, medicinal, especialidad, rotulacion}
# 67                    {marzo, accion, familia, financiero}
# 0    {discapacitada, consentimiento, movilidad, extension}
#
#                                                                                              vt2_top10  \
# 101            {tecnologico, desfibrilador, subitar, oftalmologico, concurrencia, instalacion, minimo}
# 5                                               {geriatrico, manejo, tumor, hijo, paliativo, congreso}
# 67   {organizacion, agente, presupuesto, objeto, reconocimiento, trabajador, fortalecimiento, escolar}
# 0                                                            {digno, gestion, elemento, trabajo, dato}
#
#      dispersion
# 101    0.014899
# 5      0.015363
# 67     0.018768
# 0      0.022031
# dist ~ 0.5 (sc ~ 0.5)  Cambio moderado
# TOP 10 Palabras: ['ingreso' 'pais' 'obligacion' 'materia' 'necesario' 'domiciliario'
#  'suplemento' 'forma' 'tipo' 'gratuidad']
#       par_periodo       palabra  similaridad_semantica_mean  \
# 177  (2014, 2019)       ingreso                    0.411782
# 244  (2014, 2019)          pais                    0.399096
# 231  (2014, 2019)    obligacion                    0.373731
# 201  (2014, 2019)       materia                    0.386777
# 224  (2014, 2019)     necesario                    0.374349
# 105  (2014, 2019)  domiciliario                    0.347000
# 308  (2014, 2019)    suplemento                    0.391603
# 148  (2014, 2019)         forma                    0.319486
# 316  (2014, 2019)          tipo                    0.321460
# 157  (2014, 2019)     gratuidad                    0.331567
#
#      similaridad_semantica_confidence_intervals  \
# 177    (0.4046775318559608, 0.4183423182018816)
# 244      (0.39177295813979, 0.4064403711758043)
# 231   (0.3656400425561812, 0.38094089837290473)
# 201    (0.3779044172997835, 0.3945494875000104)
# 224  (0.36594618141845137, 0.38315810094567526)
# 105  (0.33851897545910237, 0.35594063820341443)
# 308    (0.38194121911522616, 0.399852712331035)
# 148   (0.3096475531507553, 0.32785450295506097)
# 316  (0.31196973834101954, 0.33083859218558054)
# 157   (0.3218824423680031, 0.34121944977961777)
#
#                                                                          vt1_top10  \
# 177                                      {maquina, categoria, virus, ninez, solar}
# 244                               {deber, desfibrilador, comercialicir, acreditar}
# 231      {afiliado, especialidad, profesion, farmaceutico, cumplimiento, congreso}
# 201                    {politica, vacunacion, laboratorio, cumplimiento, congreso}
# 224  {desfibrilador, dispositivo, subitar, precio, existir, concurrencia, externo}
# 105                                    {inssjp, vencido, recoleccion, medicamento}
# 308                                 {monohidratado, dietario, habilitado, creatin}
# 148                               {proteina, transmision, complemento, cualquiera}
# 316                                 {fabricacion, ensenanza, cualquiera, mercurio}
# 157                                  {comprendido, calendario, vacuna, vacunacion}
#
#                                                                                                vt2_top10  \
# 177  {beneficiario, jubilado, afiliado, entidad, fortalecimiento, primario, indice, otorgar, pensionado}
# 244         {clinico, desfibrilador, consejo, ciudadano, ambiental, ejecutivo, instalacion, fabricacion}
# 231                                                      {judicial, donante, alcoholica, animal, sangre}
# 201                                      {periodo, prorrogable, chaco, sexual, infeccion, adiccion, vih}
# 224                                                                          {manejo, precio, principio}
# 105                                                    {organizacion, ter, educacion, forma, financiero}
# 308                                                                    {leche, fumar, etiquetado, libre}
# 148                                 {organizacion, domiciliario, actualizacion, modelo, correspondiente}
# 316                                         {judicial, droga, braille, diabetes, identificacion, visual}
# 157                                                   {presupuesto, afiliado, agua, potable, pensionado}
#
#      dispersion
# 177    0.013665
# 244    0.014667
# 231    0.015301
# 201    0.016645
# 224    0.017212
# 105    0.017422
# 308    0.017911
# 148    0.018207
# 316    0.018869
# 157    0.019337

# %% [markdown]
# #### Cambio de 2009 a 2014
# * dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos
# TOP 10 Palabras: ['legal' 'declaracion' 'materia']
# * dist ~ 0.5 (sc ~ 0.5)  Cambio moderado
# TOP 10 Palabras: ['empleo' 'tipo' 'ingreso' 'territorio' 'acompanante' 'dengue'  'comunitario' 'el' 'recurso' 'patologia']
# donde la palabra 'dengue' es la más estable en su valor similaridad_semantica_mean en las 50 corridas (0.011566) y 'territorio'
# el menos (0.020365) .
#
#
# #### Cambio de 2014 a 2019
# * dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos
# TOP 10 Palabras: ['dispositivo' 'comunitario' 'adecuado' 'accesibilidad']
# * dist ~ 0.5 (sc ~ 0.5)  Cambio moderado
# TOP 10 Palabras: TOP 10 Palabras: ['forma' 'tipo' 'gratuidad' 'domiciliario' 'obligacion' 'necesario'
#  'materia' 'suplemento' 'pais' 'ingreso'] donde la palabra 'ingreso' es la más estable en su valor similaridad_semantica_mean en las 50 corridas (0.013878) y 'gratuidad' el menos (0.019419) .
#
#
# #### Muerte súbita
#  * Palabra : Emergencia
#      * 2009-2014: 0.704497
#      * 2014-2019: 0.728426
#  * El término 'dispositivo' con cambio semántico fuerte , en el periodo [2019,2024) esta asociados a palabras que vinculamos con muerte subita como "desfibrilador" y "subitar".
#  *  El término 'pais' y 'necesario' con cambios semánticos moderado ,  en el periodo [2014,2019) y [2019,2024) están asociados a palabras que vinculamos con muerte subita como "desfibrilador".

# %% [markdown]
# ##### Palabras comunes en entre todos los períodos

# %%
palabra_comun = set(topn_periodo[(2009, 2014)]['palabra'].unique()) & set(topn_periodo[(2014, 2019)]['palabra'].unique())
print("Cantidad de palabras en común:",len(palabra_comun))
# Out:
# Cantidad de palabras en común: 269

# %%
# Período (2009, 2014)
df = topn_periodo[(2009, 2014)]
df = df[df['palabra'].isin(palabra_comun)]
df = df[['palabra','similaridad_semantica_mean','similaridad_semantica_confidence_intervals','vt1_top10','vt2_top10']]
df.columns = ['palabra','ss_mean_2009_2014','ss_ci_2009_2014','vt1_top10_2009_2014','vt2_top10_2009_2014']

# Período (2014, 2019)
df2 = topn_periodo[(2014, 2019)]
df2 = df2[df2['palabra'].isin(palabra_comun)]
df2 = df2[['palabra','similaridad_semantica_mean','similaridad_semantica_confidence_intervals','vt1_top10','vt2_top10']]
df2.columns = ['palabra','ss_mean_2014_2019','ss_ci_2014_2019','vt1_top10_2014_2019','vt2_top10_2014_2019']

# Unión
df = df.merge(df2, how='inner', on='palabra')
df = df[['palabra', 'ss_mean_2009_2014', 'ss_mean_2014_2019', 'ss_ci_2009_2014','ss_ci_2014_2019','vt1_top10_2009_2014','vt2_top10_2009_2014', 'vt1_top10_2014_2019','vt2_top10_2014_2019']]
df['peso'] = (df['ss_mean_2009_2014'] + df['ss_mean_2014_2019'] )/2
df['diferencia'] = abs(df['ss_mean_2009_2014'] - df['ss_mean_2014_2019'] )

print("Top 10 de palabras comunes con fuerte cambio semántco entre Período [2009, 2014) - > [2014, 2019)  ")
print("Palabras:",df[df['peso']<=0.3].sort_values('peso').head(10)['palabra'].unique() )
display(df[df['peso']<=0.3].sort_values('peso').head(10))
print("Top 10 de palabras comunes con moderado cambio semántco entre Período [2009, 2014) - > [2014, 2019)  ")
print("Palabras:",df[(df['peso']>0.3) & (df['peso']<=0.5)].sort_values('peso').head(10)['palabra'].unique() )
display(df[(df['peso']>0.3) & (df['peso']<=0.5)].sort_values(['peso','diferencia']).head(10))
# Out:
# Top 10 de palabras comunes con fuerte cambio semántco entre Período [2009, 2014) - > [2014, 2019)
# Palabras: []
# Empty DataFrame
# Columns: [palabra, ss_mean_2009_2014, ss_mean_2014_2019, ss_ci_2009_2014, ss_ci_2014_2019, vt1_top10_2009_2014, vt2_top10_2009_2014, vt1_top10_2014_2019, vt2_top10_2014_2019, peso, diferencia]
# Index: []
# Top 10 de palabras comunes con moderado cambio semántco entre Período [2009, 2014) - > [2014, 2019)
# Palabras: ['materia' 'tipo' 'comunitario' 'legal' 'ingreso' 'gratuidad'
#  'domiciliario' 'necesario' 'argentina' 'obligacion']
#           palabra  ss_mean_2009_2014  ss_mean_2014_2019  \
# 163       materia           0.284821           0.386777
# 254          tipo           0.353474           0.321460
# 53    comunitario           0.402430           0.281564
# 153         legal           0.226934           0.543984
# 144       ingreso           0.374986           0.411782
# 126     gratuidad           0.530001           0.331567
# 84   domiciliario           0.524213           0.347000
# 180     necesario           0.514073           0.374349
# 23      argentina           0.449219           0.444398
# 186    obligacion           0.521945           0.373731
#
#                                 ss_ci_2009_2014  \
# 163   (0.27599544304365015, 0.2939124981934813)
# 254    (0.3457579396706319, 0.3610847644949076)
# 53     (0.3924988968362833, 0.4114690451141395)
# 153  (0.22002384660263957, 0.23402394056119352)
# 144    (0.3668127609121415, 0.3828470467135649)
# 126    (0.5215224657247469, 0.5362155310817255)
# 84     (0.5168327490635526, 0.5313936901079658)
# 180    (0.5046100003397483, 0.5234496252933362)
# 23     (0.4412629631395372, 0.4568344693132116)
# 186     (0.511019733045155, 0.5328740465464675)
#
#                                 ss_ci_2014_2019  \
# 163    (0.3779044172997835, 0.3945494875000104)
# 254  (0.31196973834101954, 0.33083859218558054)
# 53     (0.27165948468648776, 0.290427646180417)
# 153    (0.5352329596648002, 0.5522952713932889)
# 144    (0.4046775318559608, 0.4183423182018816)
# 126   (0.3218824423680031, 0.34121944977961777)
# 84   (0.33851897545910237, 0.35594063820341443)
# 180  (0.36594618141845137, 0.38315810094567526)
# 23     (0.4343261884368739, 0.4541177447759303)
# 186   (0.3656400425561812, 0.38094089837290473)
#
#                                                                                     vt1_top10_2009_2014  \
# 163             {postraumatico, estr, presupuesto, delito, basica, adopcion, fortalecimiento, primaria}
# 254                               {gripe, aparicion, h1n1, papiloma, avance, influenza, virus, causado}
# 53                             {voluntario, radicacion, direccion, revestir, sanitaria, hogar, militar}
# 153                                 {colaborador, norma, odontologia, loteria, auxiliar, musicoterapia}
# 144                                            {anses, geriatrico, fincini, ciudadano, ninez, ganancia}
# 126                        {prohibir, acompanante, proceso, rotavirus, permanencia, indirecto, directo}
# 84                {recoleccion, instrumento, partos, civil, capacidad, odontologico, vencido, mercurio}
# 180                                         {presupuesto, ostomizada, incluyendolo, olivia, medicacion}
# 23   {republica, riesgo, tabaco, limitacion, comercializado, chagas, prioritario, bioetica, cigarrillo}
# 186                                  {cromosomatico, spw, existir, willi, posibilidad, omision, prader}
#
#                                                                vt2_top10_2009_2014  \
# 163                    {politica, vacunacion, laboratorio, cumplimiento, congreso}
# 254                                 {fabricacion, ensenanza, cualquiera, mercurio}
# 53                                            {marzo, accion, familia, financiero}
# 153                                      {droga, monodroga, embarazo, misoprostol}
# 144                                      {maquina, categoria, virus, ninez, solar}
# 126                                  {comprendido, calendario, vacuna, vacunacion}
# 84                                     {inssjp, vencido, recoleccion, medicamento}
# 180  {desfibrilador, dispositivo, subitar, precio, existir, concurrencia, externo}
# 23                           {natural, comision, republica, tecnologico, erupcion}
# 186      {afiliado, especialidad, profesion, farmaceutico, cumplimiento, congreso}
#
#                                                                vt1_top10_2014_2019  \
# 163                    {politica, vacunacion, laboratorio, cumplimiento, congreso}
# 254                                 {fabricacion, ensenanza, cualquiera, mercurio}
# 53                                            {marzo, accion, familia, financiero}
# 153                                      {droga, monodroga, embarazo, misoprostol}
# 144                                      {maquina, categoria, virus, ninez, solar}
# 126                                  {comprendido, calendario, vacuna, vacunacion}
# 84                                     {inssjp, vencido, recoleccion, medicamento}
# 180  {desfibrilador, dispositivo, subitar, precio, existir, concurrencia, externo}
# 23                           {natural, comision, republica, tecnologico, erupcion}
# 186      {afiliado, especialidad, profesion, farmaceutico, cumplimiento, congreso}
#
#                                                                                      vt2_top10_2014_2019  \
# 163                                      {periodo, prorrogable, chaco, sexual, infeccion, adiccion, vih}
# 254                                         {judicial, droga, braille, diabetes, identificacion, visual}
# 53     {organizacion, agente, presupuesto, objeto, reconocimiento, trabajador, fortalecimiento, escolar}
# 153                                                    {beneficiario, ingreso, misoprostol, obstetricia}
# 144  {beneficiario, jubilado, afiliado, entidad, fortalecimiento, primario, indice, otorgar, pensionado}
# 126                                                   {presupuesto, afiliado, agua, potable, pensionado}
# 84                                                     {organizacion, ter, educacion, forma, financiero}
# 180                                                                          {manejo, precio, principio}
# 23                     {republica, evaluacion, desfibrilador, pobreza, prevenibl, exigencia, tecnologia}
# 186                                                      {judicial, donante, alcoholica, animal, sangre}
#
#          peso  diferencia
# 163  0.335799    0.101956
# 254  0.337467    0.032015
# 53   0.341997    0.120865
# 153  0.385459    0.317049
# 144  0.393384    0.036796
# 126  0.430784    0.198435
# 84   0.435606    0.177213
# 180  0.444211    0.139724
# 23   0.446809    0.004821
# 186  0.447838    0.148214

# %% [markdown]
# * Cantidad de palabras en común: 269
# * Top 10 de palabras comunes con moderado cambio semántico por peso = promedio de similaridad semántica de pares de periodos.
# Palabras: ['materia' 'tipo' 'comunitario' 'legal' 'ingreso' 'gratuidad'
#  'domiciliario' 'necesario' 'argentina' 'obligacion']
#
#     * No aparece 'declaracion', pero aparecen ['legal' 'materia'] de las palabras de fuerte cambio semántico en (2009-2014). En relación a cambio semántico de las palabras identificadas con cambio moderado, solo aparecen en palabras en comunes 'tipo' e 'ingreso'. No aparecen ['empleo'  'territorio' 'acompanante' 'dengue'  'comunitario' 'el' 'recurso' 'patologia'].
#     * No aparecen ['dispositivo', 'adecuado', 'accesibilidad'], pero aparece 'comunitario' de las palabras de fuerte cambio semantico en (2014-2019).En relación a cambio semántico de las palabras identificadas con cambio moderado, solo aparecen en palabras en comunes 'tipo', 'gratuidad', 'domiciliario', 'obligacion' , 'necesario' , 'ingreso' y  'materia'. No aparecen ['forma''suplemento' 'pais' ].
#     * La palabra 'argentina' aparece entre las palabas de cambio moderado, cuando antes no estaban en top 10.
#     * Las palabras 'legal' y "materia" pasaron de un cambio fuerte en primer par de periodos a moderado en segundo par de periodos. Mientras que  comunitario paso de cambio moderado en primer par de periodos a fuerte en segundo par de periodos

# %% [markdown]
# ### Análisis de temporalidad

# %% [markdown]
# ¿Cuándo se usan más estas palabras en los títulos?

# %%
# Abrir
with open(os.getenv("DIR_DATOS_PROCESADOS") + 'base_texto_df_ley_0924.pkl', 'rb') as file: 
    basetexto_df = pickle.load(file)

basetexto_df.describe(include='all').T
# Out:
#                                       count unique  \
# Proyecto.ID                           35179  35179
# Título                                35179  33168
# Título procesado                      35179  29558
# Título normalizado                    35179  28761
# Cant_token                          35179.0    NaN
# Cant_token_normalizado              35179.0    NaN
# Proyecto_girado_a_comisiones_SALUD  35179.0    NaN
# Proyecto_SALUD                      35179.0    NaN
# Resultado                             35179      6
# Max_Orden                           35179.0    NaN
# Tiene_antecedente_por_titulo_proy     35179      2
# Periodo                             33097.0    NaN
# Año                                 35179.0    NaN
# Tokens                                35179  26519
#
#                                                                                                                            top  \
# Proyecto.ID                                                                                                         HCDN246858
# Título                                                                                           JUICIO POR JURADOS. CREACION.
# Título procesado                    contrato de trabajo ley numero modificacion del articulo numero sobre licencias especiales
# Título normalizado                                                                                           licencia especial
# Cant_token                                                                                                                 NaN
# Cant_token_normalizado                                                                                                     NaN
# Proyecto_girado_a_comisiones_SALUD                                                                                         NaN
# Proyecto_SALUD                                                                                                             NaN
# Resultado                                                                            NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# Max_Orden                                                                                                                  NaN
# Tiene_antecedente_por_titulo_proy                                                                                        False
# Periodo                                                                                                                    NaN
# Año                                                                                                                        NaN
# Tokens                                                                                                    [licencia, especial]
#
#                                      freq         mean       std     min  \
# Proyecto.ID                             1          NaN       NaN     NaN
# Título                                 18          NaN       NaN     NaN
# Título procesado                       36          NaN       NaN     NaN
# Título normalizado                     39          NaN       NaN     NaN
# Cant_token                            NaN    21.123682  10.69187     2.0
# Cant_token_normalizado                NaN      9.76341  5.051387     0.0
# Proyecto_girado_a_comisiones_SALUD    NaN      0.12786  0.333939     0.0
# Proyecto_SALUD                        NaN     0.085761  0.280015     0.0
# Resultado                           34268          NaN       NaN     NaN
# Max_Orden                             NaN     2.253504  0.822105     1.0
# Tiene_antecedente_por_titulo_proy   33198          NaN       NaN     NaN
# Periodo                               NaN   134.111944  4.075721   127.0
# Año                                   NaN  2016.586913  4.376397  2009.0
# Tokens                                 42          NaN       NaN     NaN
#
#                                        25%     50%     75%     max
# Proyecto.ID                            NaN     NaN     NaN     NaN
# Título                                 NaN     NaN     NaN     NaN
# Título procesado                       NaN     NaN     NaN     NaN
# Título normalizado                     NaN     NaN     NaN     NaN
# Cant_token                            14.0    19.0    27.0   125.0
# Cant_token_normalizado                 6.0     9.0    12.0    57.0
# Proyecto_girado_a_comisiones_SALUD     0.0     0.0     0.0     1.0
# Proyecto_SALUD                         0.0     0.0     0.0     1.0
# Resultado                              NaN     NaN     NaN     NaN
# Max_Orden                              2.0     2.0     3.0     8.0
# Tiene_antecedente_por_titulo_proy      NaN     NaN     NaN     NaN
# Periodo                              131.0   134.0   137.0   141.0
# Año                                 2013.0  2017.0  2020.0  2024.0
# Tokens                                 NaN     NaN     NaN     NaN

# %%
# Seleccionando IL de Salud
basetexto_df = basetexto_df[basetexto_df['Proyecto_SALUD']==1]
print("Conj. de datos de proyecto_SALUD con Nan en Período:",basetexto_df.shape)
basetexto_df = basetexto_df[~basetexto_df['Periodo'].isna()]
print("Conj. de datos de proyecto_SALUD sin Nan en Período:",basetexto_df.shape)
# Out:
# Conj. de datos de proyecto_SALUD con Nan en Período: (3017, 14)
# Conj. de datos de proyecto_SALUD sin Nan en Período: (2848, 14)

# %%
basetexto_df.head(1)
# Out:
#      Proyecto.ID  \
# 2061  HCDN272685
#
#                                                                                                                                                          Título  \
# 2061  INCLUYASE EN EL CALENDARIO NACIONAL DE VACUNACION CON CARACTER OBLIGATORIO Y GRATUITO LA VACUNA CONTRA EL VIRUS DEL DENGUE. MODIFICACION DE LA LEY 27491.
#
#                                                                                                                                               Título procesado  \
# 2061  incluyase en el calendario nacional de vacunacion con caracter obligatorio y gratuito la vacuna contra el virus del dengue modificacion de la ley numero
#
#                                                                               Título normalizado  \
# 2061  incluyar calendario nacional vacunacion caracter obligatorio gratuito vacuna virus dengue
#
#       Cant_token  Cant_token_normalizado  Proyecto_girado_a_comisiones_SALUD  \
# 2061          24                      10                                 1.0
#
#       Proyecto_SALUD                                  Resultado  Max_Orden  \
# 2061             1.0  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          3
#
#       Tiene_antecedente_por_titulo_proy  Periodo   Año  \
# 2061                              False    141.0  2024
#
#                                                                                                     Tokens
# 2061  [incluyar, calendario, nacional, vacunacion, caracter, obligatorio, gratuito, vacuna, virus, dengue]

# %%
basetexto_df.columns
# Out:
# Index(['Proyecto.ID', 'Título', 'Título procesado', 'Título normalizado',
#        'Cant_token', 'Cant_token_normalizado',
#        'Proyecto_girado_a_comisiones_SALUD', 'Proyecto_SALUD', 'Resultado',
#        'Max_Orden', 'Tiene_antecedente_por_titulo_proy', 'Periodo', 'Año',
#        'Tokens'],
#       dtype='object')

# %%
## Para analizar
palabras_comunes =  ['materia', 'tipo' ,'comunitario', 'legal', 'ingreso', 'gratuidad',
 'domiciliario' ,'necesario' ,'argentina' ,'obligacion']
palabras_emergentes = ['declaracion','empleo' , 'territorio' ,'acompanante', 'dengue' , 'comunitario' ,'recurso', 'patologia','dispositivo', 'adecuado', 'accesibilidad','forma','suplemento', 'pais']

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
for palabras_objetivo in [palabras_comunes,palabras_emergentes]:
    
    # Inicializar un diccionario de conteo por año
    frecuencia_por_anio = {palabra: {} for palabra in palabras_objetivo}
    
    # Iterar por año
    for año, grupo in basetexto_df.groupby('Año'):
        textos = " ".join(grupo['Título procesado'].tolist())
        conteo = Counter(textos.split())
    
        for palabra in palabras_objetivo:
            frecuencia_por_anio[palabra][año] = conteo.get(palabra, 0)
    
    # Convertir a DataFrame
    frecuencia_df = pd.DataFrame(frecuencia_por_anio).fillna(0).astype(int).sort_index()
    frecuencia_df = frecuencia_df.T
    frecuencia_df['total'] = frecuencia_df.sum(axis=1)
    frecuencia_df = frecuencia_df.sort_values('total', ascending=True).drop(columns='total')
    
    frecuencia_df.plot(kind='barh',
                       stacked=True,
                       figsize=(12, 8),
                       colormap='viridis',  
                       edgecolor='black')
    
    plt.title('Evolución de uso de palabras con cambio semántico en títulos legislativos de ley sobre salud')
    plt.xlabel('Frecuencia')
    plt.ylabel('Palabras con cambio semántico')
    plt.legend(title='Año', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.show()
    
    
    # Cantidad de proyectos por año (para normalizar)
    total_proyectos_por_anio = basetexto_df.groupby('Año').size()
    # frecuencia_df tiene palabras como índice y años como columnas (frecuencia absoluta)
    frecuencia_relativa_df = frecuencia_df.div(total_proyectos_por_anio, axis=1) * 100  # multiplicamos por 100 para %
    # Ordenar por promedio total para ordenar mejor las barras
    frecuencia_relativa_df['Promedio'] = frecuencia_relativa_df.mean(axis=1)
    frecuencia_relativa_df = frecuencia_relativa_df.sort_values('Promedio', ascending=True).drop(columns='Promedio')
    frecuencia_relativa_df.plot(kind='barh',
                                stacked=True,
                                figsize=(12, 8),
                                colormap='viridis',
                                edgecolor='black')
    
    plt.title('Porcentaje de legislativos de ley sobre salud por año que usan cada palabra con cambio semántico')
    plt.xlabel('% de proyectos por año')
    plt.ylabel('Palabras con cambio semántico')
    plt.legend(title='Año', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.show()

# %% [markdown]
# ### Análisis de actividad legislativa

# %%
basetexto_df.columns
# Out:
# Index(['Proyecto.ID', 'Título', 'Título procesado', 'Título normalizado',
#        'Cant_token', 'Cant_token_normalizado',
#        'Proyecto_girado_a_comisiones_SALUD', 'Proyecto_SALUD', 'Resultado',
#        'Max_Orden', 'Tiene_antecedente_por_titulo_proy', 'Periodo', 'Año',
#        'Tokens'],
#       dtype='object')

# %%
# Convertimos a minúscula y verificamos si la palabra aparece en el título
for palabras_clave in [palabras_comunes,  palabras_emergentes]:
     
    for palabra in palabras_clave:
        basetexto_df[f'contiene_{palabra}'] = basetexto_df['Título normalizado'].str.contains(rf'\b{palabra}\b', case=False)
    
    for palabra in palabras_clave:
        grupo = basetexto_df[basetexto_df[f'contiene_{palabra}']]
        print(f'\nAnálisis para la palabra "{palabra}":')
        print('Cantidad de proyectos:', len(grupo))
        print('Promedio de Max orden:', grupo['Max_Orden'].mean())
        print('Moda Resultado:', grupo['Resultado'].mode()[0])
# Out:
# Análisis para la palabra "materia":
# Cantidad de proyectos: 12
# Promedio de Max orden: 2.9166666666666665
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "tipo":
# Cantidad de proyectos: 17
# Promedio de Max orden: 2.176470588235294
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "comunitario":
# Cantidad de proyectos: 16
# Promedio de Max orden: 2.375
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "legal":
# Cantidad de proyectos: 14
# Promedio de Max orden: 2.642857142857143
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "ingreso":
# Cantidad de proyectos: 15
# Promedio de Max orden: 2.466666666666667
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "gratuidad":
# Cantidad de proyectos: 12
# Promedio de Max orden: 2.75
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "domiciliario":
# Cantidad de proyectos: 15
# Promedio de Max orden: 2.6
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "necesario":
# Cantidad de proyectos: 20
# Promedio de Max orden: 2.1
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "argentina":
# Cantidad de proyectos: 16
# Promedio de Max orden: 2.875
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "obligacion":
# Cantidad de proyectos: 20
# Promedio de Max orden: 2.2
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "declaracion":
# Cantidad de proyectos: 12
# Promedio de Max orden: 2.25
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "empleo":
# Cantidad de proyectos: 10
# Promedio de Max orden: 2.5
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "territorio":
# Cantidad de proyectos: 57
# Promedio de Max orden: 2.526315789473684
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "acompanante":
# Cantidad de proyectos: 12
# Promedio de Max orden: 3.0833333333333335
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "dengue":
# Cantidad de proyectos: 29
# Promedio de Max orden: 2.1379310344827585
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "comunitario":
# Cantidad de proyectos: 16
# Promedio de Max orden: 2.375
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "recurso":
# Cantidad de proyectos: 13
# Promedio de Max orden: 2.6153846153846154
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "patologia":
# Cantidad de proyectos: 14
# Promedio de Max orden: 2.4285714285714284
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "dispositivo":
# Cantidad de proyectos: 12
# Promedio de Max orden: 2.5
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "adecuado":
# Cantidad de proyectos: 10
# Promedio de Max orden: 2.3
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "accesibilidad":
# Cantidad de proyectos: 11
# Promedio de Max orden: 2.6363636363636362
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "forma":
# Cantidad de proyectos: 16
# Promedio de Max orden: 2.3125
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "suplemento":
# Cantidad de proyectos: 13
# Promedio de Max orden: 2.076923076923077
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
#
# Análisis para la palabra "pais":
# Cantidad de proyectos: 19
# Promedio de Max orden: 2.210526315789474
# Moda Resultado: NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN

# %% [markdown]
# ### Análisis por comisiones dominantes

# %%
# Leemos objeto para mapeear con giro de comisiones
with open(os.getenv("DIR_DATOS_PROCESADOS") +'BD_girocom_df_20250118.pkl', 'rb') as file:
    BD_girocom_df = pickle.load(file)

# %%
# BD giro comisión
BD_girocom_df.head(4)
# Out:
#            comision_nombre archivo_fuente comision_nombre_normalizada
# 0             SOBRE TABLAS  giro comision                sobre tablas
# 1          OBRAS PUBLICAS   giro comision              obras publicas
# 2  PRESUPUESTO Y HACIENDA   giro comision      presupuesto y hacienda
# 3                 TURISMO   giro comision                     turismo

# %%
FUENTE_DIR = os.getenv("DIR_FUENTE_DATOS") # Acceder a las variables de entorno
girocom_df = pd.read_csv(FUENTE_DIR+'diputados/giroacomisiones2.0.csv')
print('Tamaño de dataset de Giro a comisiones:',girocom_df.shape)
display(girocom_df.head(2))
display(girocom_df.describe(include='all').T)
# Out:
# Tamaño de dataset de Giro a comisiones: (404653, 3)
#   Proyecto.ID         Comisión  Orden
# 0  HCDN000000     SOBRE TABLAS      1
# 1  HCDN001090  OBRAS PUBLICAS       1
#                 count  unique                     top   freq      mean  \
# Proyecto.ID    404653  267339              HCDN061700     13       NaN
# Comisión       404653     196  PRESUPUESTO Y HACIENDA  47738       NaN
# Orden        404653.0     NaN                     NaN    NaN  1.481912
#
#                   std  min  25%  50%  75%   max
# Proyecto.ID       NaN  NaN  NaN  NaN  NaN   NaN
# Comisión          NaN  NaN  NaN  NaN  NaN   NaN
# Orden        0.802812  1.0  1.0  1.0  2.0  13.0

# %%
# Leemos BD de comisiones normalizadas
with open(os.getenv("DIR_DATOS_PROCESADOS") +'BD_normalizada_df_20250118.pkl', 'rb') as file:
    BD_normalizada_df = pickle.load(file)

# %%
BD_normalizada_df.head(3)
# Out:
#      comision_nombre_normalizada                     archivo_fuente  \
# 0               a la presidencia                      giro comision
# 1             a sus antecedentes                      giro comision
# 2  accion social y salud publica  giro comision, dictamen, comision
#
#   comision_nombre_normalizada_Levenshtein
# 0                        a la presidencia
# 1                      a sus antecedentes
# 2           accion social y salud publica

# %%
# BD_girocom_df para integrar con proyecto
llave = 'comision_nombre_normalizada'
temp_df = pd.merge(BD_girocom_df, BD_normalizada_df, how ='inner', left_on = llave, right_on = llave)[['comision_nombre','comision_nombre_normalizada_Levenshtein']]
display(temp_df.head(4))
display(temp_df.shape)
# Out:
#            comision_nombre comision_nombre_normalizada_Levenshtein
# 0             SOBRE TABLAS                            sobre tablas
# 1          OBRAS PUBLICAS                           obras publicas
# 2  PRESUPUESTO Y HACIENDA                   presupuesto y hacienda
# 3                 TURISMO                                  turismo
# (196, 2)

# %%
del BD_normalizada_df
del BD_girocom_df

# %%
# Mapeo proyecto - comisiones
girocom_df[['Proyecto.ID','Comisión']].drop_duplicates().sort_values('Proyecto.ID')
# Out:
#        Proyecto.ID                       Comisión
# 0       HCDN000000                   SOBRE TABLAS
# 1       HCDN001090                OBRAS PUBLICAS
# 2       HCDN001090        PRESUPUESTO Y HACIENDA
# 3       HCDN001091                       TURISMO
# 4       HCDN001092      ASUNTOS CONSTITUCIONALES
# ...            ...                            ...
# 404647  HCDN280535   FAMILIAS, NIÑEZ Y JUVENTUDES
# 404649  HCDN280536                      EDUCACION
# 404651  HCDN280537          LIBERTAD DE EXPRESION
# 404650  HCDN280537       ASUNTOS CONSTITUCIONALES
# 404652  HCDN280537  RELACIONES EXTERIORES Y CULTO
#
# [400721 rows x 2 columns]

# %%
temp2_df = pd.merge(girocom_df[['Proyecto.ID','Comisión']].drop_duplicates(),temp_df, how ='inner', left_on = 'Comisión', right_on = 'comision_nombre')[['Proyecto.ID','comision_nombre_normalizada_Levenshtein']].drop_duplicates()
temp2_df.head(3)
# Out:
#   Proyecto.ID comision_nombre_normalizada_Levenshtein
# 0  HCDN000000                            sobre tablas
# 1  HCDN001090                          obras publicas
# 2  HCDN001090                  presupuesto y hacienda

# %%
basetexto_com_df = pd.merge(basetexto_df,temp2_df, how ='inner', left_on = 'Proyecto.ID', right_on = 'Proyecto.ID')
basetexto_com_df.shape
# Out:
# (6936, 38)

# %%
# Comisiones 
basetexto_com_df['comision_nombre_normalizada_Levenshtein'].value_counts( normalize=True )
# Out:
# comision_nombre_normalizada_Levenshtein
# accion social y salud publica                                             0.410611
# presupuesto y hacienda                                                    0.271338
# legislacion general                                                       0.054066
# familia mujer ninez y adolescencia                                        0.031142
# educacion                                                                 0.023789
# comercio                                                                  0.022059
# legislacion del trabajo                                                   0.020473
# industria                                                                 0.020185
# discapacidad                                                              0.017589
# prevencion de adicciones y control del narcotrafico                       0.015138
# comunicaciones e informatica                                              0.013985
# familias ninez y juventudes                                               0.011534
# legislacion penal                                                         0.008218
# mujeres y diversidad                                                      0.008074
# salud                                                                     0.007641
# defensa del consumidor del usuario y de la competencia                    0.006200
# transportes                                                               0.004902
# de las personas mayores                                                   0.004037
# peticiones poderes y reglamento                                           0.003893
# salud y deporte                                                           0.003893
# justicia                                                                  0.003749
# deportes                                                                  0.003460
# derechos humanos y garantias                                              0.003460
# agricultura y ganaderia                                                   0.003028
# recursos naturales y conservacion del ambiente humano                     0.002884
# poblacion y desarrollo humano                                             0.002595
# prevision y seguridad social                                              0.002451
# finanzas                                                                  0.001874
# obras publicas                                                            0.001730
# ciencia tecnologia e innovacion productiva                                0.001586
# justicia y asuntos penales                                                0.001586
# seguridad interior                                                        0.001298
# asuntos constitucionales                                                  0.001153
# ciencia y tecnologia                                                      0.001009
# trabajo y prevision social                                                0.001009
# relaciones exteriores y culto                                             0.000865
# defensa nacional                                                          0.000721
# economias y desarrollo regional                                           0.000721
# educacion y cultura                                                       0.000721
# intereses maritimos fluviales pesqueros y portuarios                      0.000577
# economia                                                                  0.000433
# infraestructura vivienda y transporte                                     0.000433
# energia y combustibles                                                    0.000433
# asuntos cooperativos mutuales y de orgno gubernamentales                  0.000433
# asuntos municipales                                                       0.000433
# vivienda y ordenamiento urbano                                            0.000433
# turismo                                                                   0.000288
# banca de la mujer                                                         0.000288
# agricultura ganaderia y pesca                                             0.000288
# ambiente y desarrollo sustentable                                         0.000144
# mineria                                                                   0.000144
# bicameral de los derechos de las ninas ninos y adolescentes ley numero    0.000144
# cultura                                                                   0.000144
# seguridad interior y narcotrafico                                         0.000144
# industria y comercio                                                      0.000144
# derechos y garantias                                                      0.000144
# tercera edad                                                              0.000144
# asuntos administrativos y municipales                                     0.000144
# Name: proportion, dtype: float64

# %%
# Convertimos a minúscula y verificamos si la palabra aparece en el título
for palabras_clave in [palabras_comunes,  palabras_emergentes]:
       
    for palabra in palabras_clave:
        grupo = basetexto_com_df[basetexto_com_df[f'contiene_{palabra}']]
        com_df = grupo['comision_nombre_normalizada_Levenshtein'].value_counts( normalize=True)
        print(f'\nAnálisis para la palabra "{palabra}":')
        print('Cantidad de comisiones:', len(com_df))
        print('Detalle de comisiones:', com_df)
# Out:
# Análisis para la palabra "materia":
# Cantidad de comisiones: 12
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                          0.352941
# presupuesto y hacienda                                 0.235294
# prevencion de adicciones y control del narcotrafico    0.088235
# educacion                                              0.058824
# familia mujer ninez y adolescencia                     0.058824
# comunicaciones e informatica                           0.029412
# legislacion del trabajo                                0.029412
# justicia                                               0.029412
# poblacion y desarrollo humano                          0.029412
# peticiones poderes y reglamento                        0.029412
# salud y deporte                                        0.029412
# deportes                                               0.029412
# Name: proportion, dtype: float64
#
# Análisis para la palabra "tipo":
# Cantidad de comisiones: 10
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica         0.459459
# presupuesto y hacienda                0.243243
# familia mujer ninez y adolescencia    0.081081
# deportes                              0.054054
# discapacidad                          0.027027
# legislacion del trabajo               0.027027
# industria                             0.027027
# comunicaciones e informatica          0.027027
# comercio                              0.027027
# legislacion general                   0.027027
# Name: proportion, dtype: float64
#
# Análisis para la palabra "comunitario":
# Cantidad de comisiones: 5
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica    0.421053
# presupuesto y hacienda           0.394737
# legislacion general              0.078947
# defensa nacional                 0.078947
# legislacion del trabajo          0.026316
# Name: proportion, dtype: float64
#
# Análisis para la palabra "legal":
# Cantidad de comisiones: 9
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                          0.378378
# presupuesto y hacienda                                 0.270270
# familia mujer ninez y adolescencia                     0.162162
# legislacion general                                    0.054054
# prevencion de adicciones y control del narcotrafico    0.027027
# mujeres y diversidad                                   0.027027
# comunicaciones e informatica                           0.027027
# legislacion del trabajo                                0.027027
# asuntos constitucionales                               0.027027
# Name: proportion, dtype: float64
#
# Análisis para la palabra "ingreso":
# Cantidad de comisiones: 8
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica         0.405405
# presupuesto y hacienda                0.351351
# familia mujer ninez y adolescencia    0.081081
# legislacion del trabajo               0.054054
# prevision y seguridad social          0.027027
# finanzas                              0.027027
# de las personas mayores               0.027027
# discapacidad                          0.027027
# Name: proportion, dtype: float64
#
# Análisis para la palabra "gratuidad":
# Cantidad de comisiones: 6
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# presupuesto y hacienda                0.363636
# accion social y salud publica         0.363636
# transportes                           0.121212
# familia mujer ninez y adolescencia    0.090909
# derechos humanos y garantias          0.030303
# de las personas mayores               0.030303
# Name: proportion, dtype: float64
#
# Análisis para la palabra "domiciliario":
# Cantidad de comisiones: 8
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                            0.394737
# presupuesto y hacienda                                   0.263158
# legislacion general                                      0.131579
# recursos naturales y conservacion del ambiente humano    0.105263
# discapacidad                                             0.026316
# legislacion penal                                        0.026316
# legislacion del trabajo                                  0.026316
# comercio                                                 0.026316
# Name: proportion, dtype: float64
#
# Análisis para la palabra "necesario":
# Cantidad de comisiones: 8
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                             0.476190
# presupuesto y hacienda                                    0.357143
# comercio                                                  0.047619
# prevencion de adicciones y control del narcotrafico       0.023810
# comunicaciones e informatica                              0.023810
# deportes                                                  0.023810
# obras publicas                                            0.023810
# defensa del consumidor del usuario y de la competencia    0.023810
# Name: proportion, dtype: float64
#
# Análisis para la palabra "argentina":
# Cantidad de comisiones: 13
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                          0.355556
# presupuesto y hacienda                                 0.311111
# legislacion penal                                      0.044444
# educacion                                              0.044444
# legislacion general                                    0.044444
# comunicaciones e informatica                           0.044444
# familia mujer ninez y adolescencia                     0.022222
# peticiones poderes y reglamento                        0.022222
# agricultura y ganaderia                                0.022222
# legislacion del trabajo                                0.022222
# salud                                                  0.022222
# salud y deporte                                        0.022222
# prevencion de adicciones y control del narcotrafico    0.022222
# Name: proportion, dtype: float64
#
# Análisis para la palabra "obligacion":
# Cantidad de comisiones: 12
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                             0.454545
# presupuesto y hacienda                                    0.181818
# defensa del consumidor del usuario y de la competencia    0.090909
# discapacidad                                              0.045455
# legislacion general                                       0.045455
# legislacion penal                                         0.045455
# mujeres y diversidad                                      0.022727
# industria                                                 0.022727
# peticiones poderes y reglamento                           0.022727
# salud y deporte                                           0.022727
# transportes                                               0.022727
# justicia                                                  0.022727
# Name: proportion, dtype: float64
#
# Análisis para la palabra "declaracion":
# Cantidad de comisiones: 7
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica      0.444444
# presupuesto y hacienda             0.333333
# legislacion general                0.074074
# obras publicas                     0.037037
# peticiones poderes y reglamento    0.037037
# comercio                           0.037037
# educacion                          0.037037
# Name: proportion, dtype: float64
#
# Análisis para la palabra "empleo":
# Cantidad de comisiones: 5
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica         0.40
# presupuesto y hacienda                0.24
# legislacion del trabajo               0.16
# familia mujer ninez y adolescencia    0.12
# educacion                             0.08
# Name: proportion, dtype: float64
#
# Análisis para la palabra "territorio":
# Cantidad de comisiones: 19
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                            0.395833
# presupuesto y hacienda                                   0.243056
# prevencion de adicciones y control del narcotrafico      0.062500
# mujeres y diversidad                                     0.034722
# comercio                                                 0.034722
# familias ninez y juventudes                              0.027778
# educacion                                                0.027778
# comunicaciones e informatica                             0.027778
# legislacion general                                      0.020833
# discapacidad                                             0.020833
# industria                                                0.020833
# familia mujer ninez y adolescencia                       0.013889
# legislacion penal                                        0.013889
# recursos naturales y conservacion del ambiente humano    0.013889
# de las personas mayores                                  0.013889
# legislacion del trabajo                                  0.006944
# ciencia tecnologia e innovacion productiva               0.006944
# relaciones exteriores y culto                            0.006944
# energia y combustibles                                   0.006944
# Name: proportion, dtype: float64
#
# Análisis para la palabra "acompanante":
# Cantidad de comisiones: 6
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica         0.324324
# presupuesto y hacienda                0.243243
# educacion                             0.189189
# legislacion del trabajo               0.108108
# familia mujer ninez y adolescencia    0.081081
# legislacion general                   0.054054
# Name: proportion, dtype: float64
#
# Análisis para la palabra "dengue":
# Cantidad de comisiones: 6
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica    0.467742
# presupuesto y hacienda           0.467742
# comunicaciones e informatica     0.016129
# educacion                        0.016129
# poblacion y desarrollo humano    0.016129
# legislacion general              0.016129
# Name: proportion, dtype: float64
#
# Análisis para la palabra "comunitario":
# Cantidad de comisiones: 5
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica    0.421053
# presupuesto y hacienda           0.394737
# legislacion general              0.078947
# defensa nacional                 0.078947
# legislacion del trabajo          0.026316
# Name: proportion, dtype: float64
#
# Análisis para la palabra "recurso":
# Cantidad de comisiones: 7
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica    0.382353
# presupuesto y hacienda           0.323529
# educacion                        0.117647
# turismo                          0.058824
# industria                        0.058824
# ciencia y tecnologia             0.029412
# justicia y asuntos penales       0.029412
# Name: proportion, dtype: float64
#
# Análisis para la palabra "patologia":
# Cantidad de comisiones: 8
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica         0.411765
# presupuesto y hacienda                0.352941
# familia mujer ninez y adolescencia    0.088235
# educacion                             0.029412
# mujeres y diversidad                  0.029412
# salud                                 0.029412
# de las personas mayores               0.029412
# comercio                              0.029412
# Name: proportion, dtype: float64
#
# Análisis para la palabra "dispositivo":
# Cantidad de comisiones: 10
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                          0.400000
# presupuesto y hacienda                                 0.266667
# comunicaciones e informatica                           0.066667
# comercio                                               0.066667
# energia y combustibles                                 0.033333
# familias ninez y juventudes                            0.033333
# educacion                                              0.033333
# deportes                                               0.033333
# familia mujer ninez y adolescencia                     0.033333
# prevencion de adicciones y control del narcotrafico    0.033333
# Name: proportion, dtype: float64
#
# Análisis para la palabra "adecuado":
# Cantidad de comisiones: 5
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica    0.434783
# presupuesto y hacienda           0.347826
# mujeres y diversidad             0.086957
# industria                        0.086957
# legislacion del trabajo          0.043478
# Name: proportion, dtype: float64
#
# Análisis para la palabra "accesibilidad":
# Cantidad de comisiones: 8
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                             0.379310
# presupuesto y hacienda                                    0.206897
# mujeres y diversidad                                      0.103448
# discapacidad                                              0.103448
# familias ninez y juventudes                               0.068966
# defensa del consumidor del usuario y de la competencia    0.068966
# familia mujer ninez y adolescencia                        0.034483
# legislacion general                                       0.034483
# Name: proportion, dtype: float64
#
# Análisis para la palabra "forma":
# Cantidad de comisiones: 12
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica                          0.432432
# presupuesto y hacienda                                 0.297297
# prevencion de adicciones y control del narcotrafico    0.027027
# industria                                              0.027027
# educacion                                              0.027027
# legislacion general                                    0.027027
# salud y deporte                                        0.027027
# trabajo y prevision social                             0.027027
# familia mujer ninez y adolescencia                     0.027027
# discapacidad                                           0.027027
# comercio                                               0.027027
# comunicaciones e informatica                           0.027027
# Name: proportion, dtype: float64
#
# Análisis para la palabra "suplemento":
# Cantidad de comisiones: 6
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica         0.481481
# comercio                              0.259259
# presupuesto y hacienda                0.111111
# familia mujer ninez y adolescencia    0.074074
# comunicaciones e informatica          0.037037
# industria                             0.037037
# Name: proportion, dtype: float64
#
# Análisis para la palabra "pais":
# Cantidad de comisiones: 9
# Detalle de comisiones: comision_nombre_normalizada_Levenshtein
# accion social y salud publica    0.452381
# presupuesto y hacienda           0.285714
# comercio                         0.095238
# deportes                         0.047619
# transportes                      0.023810
# legislacion general              0.023810
# educacion                        0.023810
# industria                        0.023810
# legislacion del trabajo          0.023810
# Name: proportion, dtype: float64
