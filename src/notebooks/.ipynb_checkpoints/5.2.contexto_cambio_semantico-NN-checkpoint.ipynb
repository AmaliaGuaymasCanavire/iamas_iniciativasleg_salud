# %% [markdown]
# # Contexto de cambios semánticos de palabras en proyecto de ley de salud

# %% [markdown]
# **Objetivo**
#
# Se analizan los títulos de proyectos de ley de salud presentados entre 2009 y 2024 correspondientes a los períodos de sesiones 127 a 141 en la Cámara de Diputados de la Nación Argentina. Para más información [sesiones](https://www.hcdn.gob.ar/sesiones/index.html) .
#
# Un proyecto es de ley sobre salud, si tiene indicado el tipo de proyecto como "LEY" y el primer giro a comisión (comisión cabecera) es a una comisión vinculada a salud ('accion social y salud publica', 'asistencia social y salud publica', 'salud' o 'salud y deporte').
#
# **Método**
#
# Se identificaron 2848 proyectos de ley sobre salud. Se limpiaron los textos de los títulos de los proyectos. Se generaron corpus (colección cuidadosamente seleccionada y organizada de textos) para períodos quinquenales (2009,2014 y2019).
#
#     Período 2009: Periodos parlamentarios 127-131 (03/2009 - 02/2014)
#     Período 2014: Periodos parlamentarios 132-136 (03/2014 - 02/2019)
#     Período 2019: Periodos parlamentarios 137-141 (03/2019 - 02/2024)
#
# Se construyeron modelos de word embedding por períodos a comparar. Word embedding es un método utilizado en el procesamiento del lenguaje natural para representar palabras o documentos como vectores numéricos. La selección de parámetros para un modelo word embedding en corpus pequeños se baso en la evaluación sobre una muestra de palabras en los distintos períodos. Determinada la combinación de parámetros para los corpus pequeños, se continuo con la identificación de enfoque estable para la deteccion de cambios semánticos de palabras entre periodos quinquenales consecutivos, es decir cambios de palabras entre 2009 vs 2014 y 2014 vs 2019.
# Se exploraron dos enfoques, Procrustes y NN. Para analizar la estabilidad de enfoque se evaluó cuantitativa y cualitativamente ambos enfoques y comparó.
#
# Aplicamos la comparación a la tarea de detección de cambios en el uso de palabras por par de período comparado y enfoque.
# Utilizamos la intersección @k, propuesta por Gonen et al., que mide el porcentaje de palabras compartidas en las k palabras más cambiadas durante varios reinicios, cambiando cada vez la semilla aleatoria.
#
# Calculamos las palabras comunes cambiadas en las repeticiones. Específicamente, ejecutamos cada enfoque de cambio de uso y recopilamos las k palabras más cambiadas, donde k ∈ k = [10, 25, 50, 75, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600,650,700,750,800] . Luego, para cada uno de los (50 2 )= Combinaciones de 50 elementos tomados de 2 en 2 = 1225 pares de ejecuciones diferentes y para cada uno de los valores de k, medimos el porcentaje de palabras compartidas en las predicciones de palabras con mayor cambio de cada enfoque. **Un valor de cero entre un par de ejecuciones significa que no hay palabras compartidas en sus predicciones, lo que indica alta variabilidad, mientras que un valor de uno indica alta estabilidad.**
#
# Intersección @k: mide el porcentaje de palabras compartidas en las predicciones de k palabras con mayor cambio por par de ejecuciones.
# * Valor cercano a 1.0 : alta estabilidad, resultados consistentes.
# * Valor cercano a 0.0 : alta variabilidad, resultados sensibles a la semilla.
#
# Se determino que el enfoque de Procruste para k=250 palabras es el modelo que permite analizar el cambio semántico de palabras entre pares de períodos quinquenales. Para cada palabra, se calcula el promedio de similaridad coseno (medida de estabilidad del modelo) Este valor es estimado junto con los respectivos intervalos de confianza del 95%, utilizando el método bootstrap.
#
#
# **Config modelo word embedding**
#
# https://radimrehurek.com/gensim/models/word2vec.html
#
# * tam_vector = 50  # Dimensionalidad de los vectores de palabras.
# * ventana = 5 # ventana ( int , opcional ): distancia máxima entre la palabra actual y la palabra prevista dentro de una oración.
# * min_frec = 2 #  Ignora todas las palabras con una frecuencia total menor que esta.
# * w = 1  # utilice estos muchos subprocesos de trabajo para entrenar el modelo (=entrenamiento más rápido con máquinas de múltiples núcleos).
# * s = 1 # Algoritmo de entrenamiento: 1 para skip-gram; de lo contrario, CBOW.
# * e = 100 # Número de iteraciones (épocas) en el corpus. (Anteriormente: iter )
# * semilla = 1 # seed ( int , opcional ): Semilla para el generador de números aleatorios.
# * iteracion = 50
#
#
# * Par de periodos (2009, 2014) : Esto indica los pares de periodos comparados [2009, 2014) vs  [2014, 2019)
# * Par de periodos (2014, 2019) : Esto indica los pares de periodos comparados [2014, 2019) vs [2019, 2024)

# %%
# Importar librería
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import pickle
import os
import re
import random as rn
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import bootstrap
import matplotlib.pyplot as plt
import itertools
from scipy.spatial.distance import cosine
from scipy import stats

from ast import literal_eval
from gensim.models import Word2Vec
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
tqdm.pandas()

# %%
# Configurar
load_dotenv() # Cargar las variables de entorno del archivo .env
BASE_DIR =  os.getenv("DIR_BASE")
RESULTADOS_DIR = os.getenv("DIR_DATOS_PROCESADOS") # Acceder a las variables de entorno
modelo_dir =  RESULTADOS_DIR+ '/archivos_out/modelos_swmwosge_5051100'
pd.set_option('display.max_colwidth', None)

# %%
RESULTADOS_DIR
# Out:
# 'C:/Users/Usuario/iamas_iniciativasleg_salud/src/data/'

# %%
# Abrir OBJETO
with open(modelo_dir+'/top250_periodos_procrustes_df.pkl', 'rb') as file: 
    topn_periodo = pickle.load(file) ## Diccionario

# %%
pares_periodo = [ (2009, 2014),(2014, 2019)]
similitud = []
topk = 20
plt.figure(figsize=(8, 5))
for par_periodo in pares_periodo:

    df = topn_periodo[par_periodo].sort_values('similaridad_semantica_mean', ascending=True)
    df.to_csv(RESULTADOS_DIR+'procruste_top20_'+str(par_periodo[0])+'.csv', index=False)
    print("*************************")
    print(par_periodo)
    print("*************************")
    print(df.shape)
    display(df.head(topk))
    display(df.describe())
    similitud.append(df)
    #ax= sns.histplot(data=df, x='similaridad_semantica_mean', label=str(par_periodo), common_norm=False, bins=30, alpha=0.5)
    #ax.set(xlabel='similaridad coseno promedio', ylabel='Frecuencias')
#plt.title("Distribución de similaridad coseno promedio por par de períodos comparados")
#plt.legend(title='Par de períodos')
# Out:
# *************************
# (2009, 2014)
# *************************
# (345, 8)
#       par_periodo          palabra  similaridad_semantica_mean  \
# 186  (2009, 2014)            legal                    0.230416
# 83   (2009, 2014)      declaracion                    0.241996
# 294  (2009, 2014)  respectivamente                    0.326138
# 120  (2009, 2014)           empleo                    0.329805
# 197  (2009, 2014)          materia                    0.347583
# 113  (2009, 2014)               el                    0.367072
# 327  (2009, 2014)             tipo                    0.369607
# 176  (2009, 2014)          ingreso                    0.371601
# 238  (2009, 2014)        patologia                    0.373533
# 326  (2009, 2014)       territorio                    0.379232
# 251  (2009, 2014)              pre                    0.386240
# 4    (2009, 2014)      acompanante                    0.390003
# 87   (2009, 2014)           dengue                    0.403819
# 333  (2009, 2014)      utilizacion                    0.406112
# 282  (2009, 2014)          recurso                    0.407642
# 29   (2009, 2014)        argentina                    0.408254
# 8    (2009, 2014)         adiccion                    0.414245
# 167  (2009, 2014)           inciso                    0.421997
# 215  (2009, 2014)            movil                    0.426802
# 102  (2009, 2014)     discapacidad                    0.428907
#
#      similaridad_semantica_confidence_intervals  \
# 186  (0.21918460401466147, 0.24316196816925545)
# 83   (0.22538144276768002, 0.25874248028772795)
# 294  (0.31000066329099835, 0.34259649436498296)
# 120    (0.3152243284074939, 0.3442162811836018)
# 197    (0.3322674175455796, 0.3619563159131458)
# 113    (0.3482723704426346, 0.3824650847704803)
# 327   (0.35189076832918387, 0.3869733164046924)
# 176   (0.35578361207707604, 0.3872754203331894)
# 238  (0.36118246445317465, 0.38710499376822405)
# 326   (0.36277050566657804, 0.3951777759489354)
# 251  (0.37198404208842567, 0.40063318683714794)
# 4      (0.3785201351911447, 0.4004796646310691)
# 87    (0.39325848977919625, 0.4148078983326197)
# 333   (0.3875579394358465, 0.42577690140763114)
# 282  (0.39634042414055104, 0.41926356302184936)
# 29     (0.3958283777904521, 0.4203712582242761)
# 8    (0.40200058145252426, 0.42637821898975614)
# 167    (0.4038519649410325, 0.4385463325661508)
# 215   (0.4128569853822095, 0.44086530894513515)
# 102    (0.4101301652406918, 0.4467943588146668)
#
#                                                                                                vt1_top10  \
# 186          {musicoterapia, obstetricia, ejercicio, norma, colaborador, auxiliar, odontologia, loteria}
# 83                                                                 {natural, valle, rioja, chaco, jujuy}
# 294                                                        {potable, gravis, semana, gasificado, ajuste}
# 120                                             {hogar, observatorio, comunitario, monto, familia, jefe}
# 197                      {presupuesto, adopcion, fortalecimiento, postraumatico, estr, primaria, basica}
# 113                                                           {identificar, septiembre, regional, rioja}
# 327                                        {virus, gripe, causado, aparicion, h1n1, influenza, papiloma}
# 176                                            {fincini, ciudadano, ninez, ganancia, geriatrico, basico}
# 238                        {mamario, mastectomia, nocivo, radiacion, mamaria, reconstruccion, puerperio}
# 326                               {percloroetileno, lavanderia, reconocer, aparicion, chaco, tintoreria}
# 251                                                                           {sol, rio, lent, recetado}
# 4                                         {embarazo, nacimiento, gratuidad, permanencia, proceso, parto}
# 87                                                     {aparicion, emergente, epidemia, chaco, tropical}
# 333                                                                                           {mercurio}
# 282  {pandemia, verificacion, gripe, enfermeria, trazabilidad, periodico, tecnologico, aptitud, tecnico}
# 29                    {cigarrillo, comercializado, prioritario, chagas, republica, limitacion, bioetica}
# 8                                              {mental, voluntario, militar, ostomizado, rehabilitacion}
# 167                                                           {continuidad, agregar, sustitucion, texto}
# 215                                  {modificar, audicion, perdido, dispositivo, salario, musica, vital}
# 102                                                                    {visceral, hereditario, percibir}
#
#                                                                                   vt2_top10  \
# 186                                                                      {droga, monodroga}
# 83                                                       {valor, prepagar, marco, medicina}
# 294                                                                 {autoridad, gasificado}
# 120        {monodroga, sustancia, ftalato, subsistema, contributivo, instrumento, elemento}
# 197                                  {cumplimiento, politica, muerte, congreso, vacunacion}
# 113                                                            {premio, doctor, septiembre}
# 327                                                                 {ensenanza, cualquiera}
# 176                                                                      {ninez, categoria}
# 238                                                                {nacido, recien, visual}
# 326                                                                                      {}
# 251                                               {prenatal, sol, lent, recetado, prohibir}
# 4    {obstetricia, cosmiatrio, equinoterapia, cosmetologia, recurso, piercing, terapeutico}
# 87                                                   {alzheimer, virus, fiebre, nosocomial}
# 333                                                                  {tecnica, sustitucion}
# 282                                         {acompanante, acvo, terapeutico, equinoterapia}
# 29                                                           {natural, comision, republica}
# 8                                             {mental, licenciado, red, hospital, primaria}
# 167                                   {articulo, fumar, tabaco, grupo, primario, lactancia}
# 215                                                   {trabajador, vital, salario, afectar}
# 102                                       {ensenanza, judicial, prioritario, equinoterapia}
#
#                                                                                                                                                                                                                                                                                                                                                   vt1_top10_union  \
# 186                                                                                    {cosmetologo, ejercicio, fitoterapicos, juegos, norma, medicina, capitulo, colaborador, cosmetologia, gravamen, loteria, obstetricia, eliminacion, complementario, parrafo, odontologico, musicoterapia, apuesta, ocupacional, expendio, auxiliar, odontologia, terapeuta}
# 83                                                                                                          {plazo, mendoza, rioja, pedro, chaco, rio, epidemiologico, tecnico, valle, declarar, ceniza, ochenta, corriente, accion, enfermeria, desastre, espinal, natural, atrofia, dengue, volcanica, muerte, vital, departamento, jujuy, emergencia, alergia}
# 294                                                                                                                                                                  {potable, bis, equivalente, gratuito, ayuda, escala, monto, gasificado, ajuste, mastectomia, remuneracion, anual, rango, osteoporosis, acceder, miastenia, agua, gravis, semana, top, chaga}
# 120                                                                                                                                          {nivel, equivalente, pacto, hogar, autorizar, rural, ceniza, observatorio, comunitario, erupcion, monto, fuerza, remuneracion, rango, revestir, republica, jefe, consejo, volcanica, familia, aprobacion, formacion}
# 197                                                                                                                                                                                         {cerebrovascular, basica, fortalecer, prostata, presupuesto, objetivo, adopcion, fortalecimiento, hipoacusia, delito, estr, red, financiero, primaria, postraumatico}
# 113                                                                                                                             {mundial, infeccion, comercializado, rioja, ciudad, autorizar, infanto, autonoma, quistico, endemico, prioritario, febrero, ambulancia, argentina, juvenil, fibromialgia, regional, identificar, hidrogenado, septiembre, aceite}
# 327                                                                                                                                                              {incremento, hepatitis, virus, cobro, creasar, hpv, varicela, causado, neumococo, avance, pandemia, aparicion, h1n1, papiloma, vacunacion, asistencial, gripe, reconocer, territorio, influenza}
# 176  {trabajador, conexa, desocupado, pension, fondo, fincini, sexo, adiccion, geriatrico, dieciseis, medicacion, distribucion, consultoria, anses, mental, certificado, revestir, jubilacion, prohibicion, basico, prenupcial, monodroga, asistencial, ciudadano, diabetes, fisico, ninez, militar, reconocimiento, ordenado, ganancia, correspondiente, ciento}
# 238                                                                                                                                                                                                                     {mamario, partos, infantil, mastectomia, cirugia, infancia, nocivo, radiacion, maternidad, producido, mamaria, reconstruccion, puerperio}
# 326                                                                                                                                                                                                           {isla, corriente, dengue, lavanderia, reconocer, percloroetileno, causado, aparicion, prioritario, represa, chaco, tintoreria, acupuntura, ochenta}
# 251                                                                                             {monohidratado, negro, pila, bateria, mercurio, habilitado, elemento, rio, epidemiologico, relevamiento, ambiente, exclusivo, trazabilidad, lent, recetado, importacion, prohibir, neuquen, chubut, creatin, madr, monodroga, poblacion, sol, peligroso, general}
# 4                                                                                                                                     {suspension, nacimiento, percibir, reconstruccion, embarazo, prenatal, inciso, situacion, proceso, mujer, violencia, puerperio, marco, consultoria, maternidad, embarazado, partos, gratuidad, privado, permanencia, parto}
# 87                                                                                                                                                         {transmision, sanitario, fibromialgia, aparicion, prioritario, comite, territorio, emergente, congreso, epidemia, demencia, seguimiento, chaco, tropical, afectado, medioambiental, bioetica, ochenta}
# 333                                                                                                          {derivado, muerte_subita, televisivo, presupuesto, pila, bateria, mercurio, elemento, lugar, preferencia, lent, recetado, prohibir, adquisicion, advertencia, consumar, escena, basico, laboratorio, sol, cinematografica, peligroso, comercialicir}
# 282                                                                                                                     {periodico, aptitud, beneficiario, seguro, ceniza, causado, trazabilidad, afiliado, tecnologico, declaracion, humano, pandemia, enfermeria, implementacion, sustitucion, categoria, verificacion, gripe, procreacion, volcanica, tecnico}
# 29                                                                                                              {octubre, comercializado, comision, volcan, limitacion, peyehue, riesgo, emergente, avance, tabaco, bioetica, cigarrillo, prioritario, epidemia, republica, osteoporosis, chagas, combatir, identificar, hidrogenado, control, influenza, aceite}
# 8                                                                                                                                                                                            {cerebrovascular, basica, acv, reumatoidea, san, mental, comunitario, voluntario, artriti, militar, revestir, ostomizado, geriatrico, acvo, brindar, rehabilitacion}
# 167                                                                                                                                                                     {acompanante, continuidad, agregar, responsable, ter, articulo, anses, fincini, procreacion, permanencia, texto, eliminacion, ordenado, requisito, sustitucion, dato, parrafo, categoria}
# 215                                                                                                                                                                                                                                         {modificar, enero, reproduccion, audicion, censo, perdido, dispositivo, salario, musica, contado, advertencia, vital}
# 102                                                                                                                 {profe, hereditario, hemoglobina, percibir, adolescente, prenatal, ayuda, subsistema, contributivo, percepcion, movilidad, visceral, certificado, otorgar, rango, trasplantado, equinoterapia, terapeutico, discapacitada, ninez, asignacion}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           vt2_top10_union
# 186                                                             {efecto, realizacion, fitoterapicos, mercurio, vencido, aptitud, exigencia, vegetal, elemento, embarazo, formulacion, recoleccion, menor, domiciliario, estudio, implante, empleo, ftalato, medicamentosa, fabricacion, produccion, medicamento, oftalmologico, caso, tipo, alergena, fetal, calendario, misoprostol, cirugia, vacuna, droga, sufrir, garantizar, planta, monodroga, sol, procreacion, fisico, laser, comprendido, proteina, instrumento}
# 83                                                                                                                                                                                                                                                                                         {suspension, publicar, listado, lectivo, comision, transcurso, exigencia, receta, prepagar, pami, medicina, trabajo, afiliado, requisito, tecnologico, judicial, entidad, valor, marco, impuesto, maternidad, inssjp, familia}
# 294                                                                                                                                                                                          {potable, autoridad, monohidratado, suspension, nutricion, composicion, pensionado, regulacion, exencion, habilitado, relacion, pension, sexo, el, monto, requisito, gasificado, judicial, valor, mayo, discapacidad, consentimiento, jubilacion, donante, premio, informado, subsidio, obligacion, congreso, apto, tecnico}
# 282                                                                                                                                                                                                                                                                                                                 {cerebrovascular, acompanante, acv, obstetricia, reumatoidea, perforacion, tatuaj, promover, cosmiatrio, artriti, terapeutico, vascular, equinoterapia, cosmetologia, acvo, piercing, rehabilitacion}
# 29                                                                                                                                                                                                                                                                 {suspension, intrahospitalaria, comision, cartel, ambiental, licenciado, volcan, objeto, erupcion, tecnologico, profesion, digno, neuquen, chubut, republica, basico, natural, paliativo, cumplimiento, territorio, nosocomial, odontologia, primaria}
# 8                                                                                                                                                                                                                                                                                  {articulo, enfermo, fortalecimiento, licenciado, chaco, red, objeto, psicologico, comunitario, proceso, hospital, estatal, accion, implementacion, mental, asiento, modificatoria, cumplimiento, marzo, victima, financiero, primaria}
# 167                                                                                                                                                                                                                                                                                                {articulo, fumar, fitoterapicos, grupo, primario, vegetal, obra, subsistema, contributivo, monto, fabricacion, elaborado, tabaco, materno, lactancia, accion, monodroga, tabaquismo, familiar, numerir, actualizacion}
# 215                                                                                                                                                                                                                                {bullos, trabajador, ambiental, equivalente, primario, volcan, pami, ceniza, medicamentosa, leche, leyenda, alergena, inssjp, afectado, minimo, personal, venerea, resolucion, leches, profilaxis, gratuidad, tabaquismo, afectar, salario, vital, laser, actualizacion, modificacion}
# 102                                                                                                                                                                                                                                                                  {etiqueta, nacimiento, codigo, rehabilitacion, pension, region, capacidad, proceso, integrante, judicial, farmaceutico, prioritario, otorgar, jubilacion, subsidio, equinoterapia, terapeutico, visual, congreso, ensenanza, principio, utilizacion}
#        similaridad_semantica_mean
# count                  345.000000
# mean                     0.596458
# std                      0.082912
# min                      0.230416
# 25%                      0.555834
# 50%                      0.627690
# 75%                      0.658410
# max                      0.696240
# *************************
# (2014, 2019)
# *************************
# (335, 8)
#       par_periodo        palabra  similaridad_semantica_mean  \
# 96   (2014, 2019)    dispositivo                    0.222339
# 5    (2014, 2019)       adecuado                    0.241482
# 0    (2014, 2019)  accesibilidad                    0.246599
# 143  (2014, 2019)          forma                    0.302599
# 317  (2014, 2019)           tipo                    0.316068
# 100  (2014, 2019)   domiciliario                    0.333025
# 62   (2014, 2019)    comunitario                    0.339957
# 221  (2014, 2019)      necesario                    0.347956
# 106  (2014, 2019)      educacion                    0.362112
# 241  (2014, 2019)           pais                    0.363814
# 192  (2014, 2019)         manejo                    0.368741
# 228  (2014, 2019)     obligacion                    0.369161
# 310  (2014, 2019)      sustancia                    0.373314
# 225  (2014, 2019)          norma                    0.373908
# 10   (2014, 2019)       afectado                    0.380547
# 27   (2014, 2019)      argentina                    0.382985
# 152  (2014, 2019)      gratuidad                    0.383025
# 85   (2014, 2019)       derivado                    0.390248
# 331  (2014, 2019)      violencia                    0.396161
# 171  (2014, 2019)        ingreso                    0.397244
#
#      similaridad_semantica_confidence_intervals  \
# 96    (0.20586610863791263, 0.2391247419353876)
# 5     (0.22572215140184967, 0.2558761352809253)
# 0    (0.22763808713904068, 0.26636443663705994)
# 143     (0.2882390375204928, 0.316838888095242)
# 317    (0.2983191971361545, 0.3331165147781076)
# 100    (0.317037690697097, 0.35246236927276287)
# 62    (0.32505722278001153, 0.3541252435676746)
# 221   (0.32752307127265573, 0.3694650541698644)
# 106  (0.34007437653483163, 0.38310500701484407)
# 241  (0.35057463923012755, 0.37747087892753695)
# 192    (0.3523312395419264, 0.3830732703936053)
# 228    (0.3551305571824204, 0.3850117959915039)
# 310  (0.35612755699351456, 0.38861854732727286)
# 225  (0.35637597422047257, 0.39391153620758296)
# 10    (0.3615774766033914, 0.39878783931293443)
# 27   (0.36590119343130795, 0.39967891989958326)
# 152    (0.3643398146053257, 0.4026412260381601)
# 85    (0.37203290551394896, 0.4056632749626365)
# 331    (0.3836513932414806, 0.4098573553306984)
# 171    (0.3841834612507075, 0.4099497013901893)
#
#                                                                      vt1_top10  \
# 96                                        {electronico, similar, nocivo, dato}
# 5                                                                 {rotulacion}
# 0                                   {movilidad, consentimiento, discapacitada}
# 143                                                    {proteina, transmision}
# 317                                                    {ensenanza, cualquiera}
# 100                                                     {recoleccion, vencido}
# 62                                                             {accion, marzo}
# 221                                               {dispositivo, desfibrilador}
# 106                                                                   {semana}
# 241                                                     {comercialicir, deber}
# 192                                       {explotacion, azar, activo, sancion}
# 228  {cumplimiento, congreso, afiliado, especialidad, profesion, farmaceutico}
# 310                {alergena, empleo, ftalato, leyendo, instrumento, elemento}
# 225           {farmacopea, capitulo, rotulacion, tecnologia, anmat, autorizar}
# 10                           {negro, neuquen, chubut, ceniza, artriti, volcan}
# 27                                              {natural, comision, republica}
# 152                                          {calendario, vacunacion, estatal}
# 85                                     {geneticamente, modificado, exposicion}
# 331                                               {junio, financiero, victima}
# 171                                                         {ninez, categoria}
#
#                                                                     vt2_top10  \
# 96                        {muerte_subita, oftalmologico, minimo, tecnologico}
# 5                                                 {tumor, geriatrico, manejo}
# 0                                                         {gestion, elemento}
# 143                            {correspondiente, organizacion, actualizacion}
# 317                                                {braille, droga, diabetes}
# 100                                              {educacion, financiero, ter}
# 62                                            {escolar, organizacion, agente}
# 221                                                       {precio, principio}
# 106                            {domiciliario, semana, septiembre, enfermeria}
# 241                                     {ejecutivo, fabricacion, instalacion}
# 192                                                   {adecuado, relacionado}
# 228                                                 {donante, sangre, animal}
# 310                                                     {materia, etiquetado}
# 225            {trabajador, complementario, materno, lactancia, consecuencia}
# 10                 {mision, corriente, zona, desastre, abril, familia, chaco}
# 27     {evaluacion, pobreza, tecnologia, republica, exigencia, desfibrilador}
# 152                                              {potable, agua, presupuesto}
# 85                                             {organismo, medicinal, planta}
# 331            {cerebrovascular, observatorio, psicologico, cirugia, victima}
# 171  {beneficiario, pensionado, otorgar, fortalecimiento, jubilado, primario}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                
# 310                                                                                                                                                                                       {periodo, efecto, centro, derivado, rotulo, consumo, autorizar, alcohol, rehabilitacion, padecer, secundario, norma, comercializacion, adiccion, necesario, materia, geriatrico, perjudicial, encontrar, importacion, prorrogable, alimenticio, complementario, legal, sodio, etiquetado, grasa, suplemento, apto}
# 225  {periodo, publicar, efecto, banco, trabajador, adquirido, dato, autorizar, alcohol, manejo, pension, sanitario, situacion, adiccion, relacionado, comunitario, fabricacion, produccion, decreto, donacion, materno, hijo, lactancia, geriatrico, consecuencia, perjudicial, diverso, evaluacion, establecido, administracion, sustancia, misoprostol, genetico, alimenticio, complementario, denominado, sangre, modificatoria, laboratorio, consejo, complejidad, etiquetado, procreacion, emergencia}
# 10                                                                                                                                                                                                                                                                                                             {octubre, cordoba, economico, chaco, rio, abril, inter, mision, corriente, mayo, zona, desastre, santa, politica, instituir, dengue, gratuidad, departamento, familia, financiero, provincia}
# 27                                                                                                                                                                                                                                 {fortalecimiento, exigencia, instalacion, accidente, beneficiario, braille, observatorio, objeto, digital, fabricacion, prevenibl, organismo, evaluacion, administracion, tecnologia, externo, cancer, mama, republica, automatico, tumor, pobreza, unico, desfibrilador}
# 152                                                                                                                                                                                           {potable, ter, pensionado, trabajador, nutricional, presupuesto, dependencia, actividad, elaboracion, medida, especial, afiliado, jubilado, cuyo, alcoholica, publico, establecimiento, minimo, afectado, restaurante, animal, agua, privado, concurrencia, fisico, instituto, departamento, financiero, apto}
# 85                                                                                                                                                                                                                   {cualquiera, rotulo, cordoba, exhibicion, presupuesto, primario, medica, autorizar, rio, comercializacion, inciso, autonoma, produccion, medicinal, alcoholica, organismo, corriente, distribucion, zona, droga, traves, aires, planta, agua, sodio, expendio, similar, identificacion}
# 331                                                                                                                                                                                        {acv, cronico, nacion, malformacion, dato, adolescente, accidente, quimico, observatorio, psicologico, estetico, mujer, reproduccion, cirugia, externo, embarazado, mama, especialidad, categoria, nina, cerebrovascular, tumor, pmo, pobreza, victima, artriti, correspondiente, ministerio, plazo, utilizacion}
# 171                                                                                                                                                                                                                                                                       {ter, beneficio, pensionado, bis, exhibicion, presupuesto, fortalecimiento, grupo, primario, economico, pension, beneficiario, obra, jubilado, entidad, organismo, valor, otorgar, minimo, basico, indice, familiar, departamento}
#        similaridad_semantica_mean
# count                  335.000000
# mean                     0.581268
# std                      0.085868
# min                      0.222339
# 25%                      0.547514
# 50%                      0.603131
# 75%                      0.646472
# max                      0.677858

# %% [markdown]
# * Par de períodos (2009, 2014)
#     * 345 palabras
#     * Similaridad coseno promedio
#         * media: 0.596458 std 0.082912 rango 0.46
#         * mediana: 0.627690
#
# * Par de períodos (2014, 2019)
#     * 335 palabras
#     * Similaridad coseno promedio
#         * media: 0.581268 	std 0.085868 rango 0.45
#         * mediana: 0.603131

# %%
# Crear DataFrame
df_coseno = pd.concat(similitud, axis=0)
df_coseno = df_coseno[['similaridad_semantica_mean','par_periodo']]
# Calcular estadísticas
coseno_2009_2014 = df_coseno[df_coseno['par_periodo']==(2009, 2014)]['similaridad_semantica_mean']
coseno_2014_2019 = df_coseno[df_coseno['par_periodo']==(2014, 2019)]['similaridad_semantica_mean']
# Test estadístico para diferencia de distribuciones
t_stat, p_value = stats.ttest_ind(coseno_2009_2014, coseno_2014_2019)

print("ANÁLISIS ESTADÍSTICO DE SIMILITUD COSENO")
print(f"2009 vs 2014: Media = {coseno_2009_2014.mean():.3f} ± {coseno_2009_2014.std():.3f}")
print(f"2014 vs 2019: Media = {coseno_2014_2019.mean():.3f} ± {coseno_2014_2019.std():.3f}")
print(f"Diferencia: {coseno_2009_2014.mean() - coseno_2014_2019.mean():.3f}")
print(f"Test t: t = {t_stat:.3f}, p-value = {p_value:.3f}")
print(f"Significativo (p < 0.05): {'SÍ' if p_value < 0.05 else 'NO'}")
# Out:
# ANÁLISIS ESTADÍSTICO DE SIMILITUD COSENO
# 2009 vs 2014: Media = 0.596 ± 0.083
# 2014 vs 2019: Media = 0.581 ± 0.086
# Diferencia: 0.015
# Test t: t = 2.347, p-value = 0.019
# Significativo (p < 0.05): SÍ

# %% [markdown]
# **Los resultados generales indican que, para cada par de períodos analizados, la media de la similaridad coseno promedio entre vectores de palabras es superior a 0.5, lo cual sugiere una relativa estabilidad semántica en el uso del lenguaje legislativo vinculado a la salud**. Se observa que hay diferencia significativa entre las medias por par de período a comparar.

# %%
# Leyenda unificada y clara
from matplotlib.patches import Patch

# Paleta optimizada para similitud coseno
PALETA_COSENO = {
    (2009, 2014): '#5DA5DA',  # Azul - tu color de proyectos de salud
    (2014, 2019): '#DE8F05'   # Naranja - tu color de tokens
}


plt.figure(figsize=(14, 10))
# Gráfico principal
sns.histplot(data=df_coseno, x='similaridad_semantica_mean', hue='par_periodo', 
             palette=PALETA_COSENO,
             alpha=0.5, 
             bins=25,
             kde=True,
             element='step',
             stat='density')

plt.xlabel('Promedio de similitud coseno', fontsize=12, fontweight='bold')
plt.ylabel('Densidad', fontsize=12, fontweight='bold')
plt.title('Distribución de densidad de promedio de similitud coseno', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)

# Calcular medias
media_2009_2014 = coseno_2009_2014.mean()
media_2014_2019 = coseno_2014_2019.mean()
diferencia_medias = abs(media_2009_2014 - media_2014_2019)

# Elementos visuales clave
plt.axvline(media_2009_2014, color=PALETA_COSENO[(2009, 2014)], linestyle='--', linewidth=2, alpha=0.8)
plt.axvline(media_2014_2019, color=PALETA_COSENO[(2014, 2019)], linestyle='--', linewidth=2, alpha=0.8)
plt.axvspan(min(media_2009_2014, media_2014_2019), max(media_2009_2014, media_2014_2019), 
            alpha=0.2, color='gray')


legend_elements = [
    Patch(facecolor=PALETA_COSENO[(2009, 2014)], alpha=0.5, label='2009 vs 2014'),
    Patch(facecolor=PALETA_COSENO[(2014, 2019)], alpha=0.5, label='2014 vs 2019'),
    plt.Line2D([0], [0], color=PALETA_COSENO[(2009, 2014)], linestyle='--', linewidth=2, 
               label=f'Media 09-14: {media_2009_2014:.3f}'),
    plt.Line2D([0], [0], color=PALETA_COSENO[(2014, 2019)], linestyle='--', linewidth=2, 
               label=f'Media 14-19: {media_2014_2019:.3f}'),
    Patch(facecolor='gray', alpha=0.2, label=f'Δ = {diferencia_medias:.3f}')
]

plt.legend(handles=legend_elements, loc='best', title='Leyenda', frameon=True, shadow=True)

plt.tight_layout(pad=3)
plt.savefig(BASE_DIR+'imagenes/promedio_similitud_coseno.png', 
            dpi=300, bbox_inches='tight', facecolor='white')
plt.show()

# %% [markdown]
# ### Distribución entre períodos

# %% [markdown]
# Para determinar que una palabra tiene cambio semántico entre los pares de periodos comparados (período 2009 vs período 2014 y período 2014 vs período 2019) se debe garantizar que :
# * Se identifica la palabra como palabra consistentemente cambiantes en alguno de los pares de períodos comparados.
# * El promedio de similaridad coseno asociado a la palabra es menor a 0.5 tal que:
#     * Cambio fuerte: promedio de similaridad coseno  < 0.3
#     * Cambio moderado: promedio de similaridad coseno entre 0.3 y 0.5

# %%
# Convertir datos en DataFrame para visualización
def plot_heatmap(cambios_df, title, top = 10):
    #words, values = zip(*changed_words[:top])  # Tomamos el top 10
    #df = pd.DataFrame({"Palabra": words, "Cambio Semántico": values})
    df = cambios_df.copy()
    plt.figure(figsize=(14, 10))
    sns.heatmap(df.set_index("palabra").T, cmap="Reds_r", annot=True, fmt=".2f", linewidths=0.5)
    plt.title(title)
    plt.show()

def diferencia(par):
    return par[1] - par[0]

# %%
topk = 10
for par_periodo in pares_periodo:

    print(" Promedio de similaridad coseno  <= 0.3 , Cambio fuerte (usos muy distintos)")
    periodo_df = topn_periodo[par_periodo]
    umbral_fuerte1 = 0.3
    periodo_df1 =  periodo_df[periodo_df['similaridad_semantica_mean']<=umbral_fuerte1].sort_values('similaridad_semantica_mean', ascending=True).head(topk)
    periodo_df1["dispersion"] = periodo_df1['similaridad_semantica_confidence_intervals'].apply(diferencia)
    #periodo_df1 =  periodo_df1.sort_values('dispersion', ascending=True) # ordenado por dispersion

    # Graficar Heatmaps
    plot_heatmap(periodo_df1[['palabra','similaridad_semantica_mean']], "Top 10 palabras con cambio semántico entre período "+str(par_periodo[0])+ " → "+str(par_periodo[1]), top=topk)
    print("TOP 10 Palabras:", periodo_df1['palabra'].unique())
    display(periodo_df1) 
    print("Promedio de similaridad coseno  <= 0.5  Cambio moderado")

    umbral_fuerte2 = 0.5
    periodo_df1 =  periodo_df[(periodo_df['similaridad_semantica_mean']<=umbral_fuerte2) & (periodo_df['similaridad_semantica_mean']>umbral_fuerte1)].sort_values('similaridad_semantica_mean', ascending=True).head(topk)
    periodo_df1["dispersion"] = periodo_df1['similaridad_semantica_confidence_intervals'].apply(diferencia)
    #periodo_df1 =  periodo_df1.sort_values('dispersion', ascending=True)

    # Graficar Heatmaps
    plot_heatmap(periodo_df1[['palabra','similaridad_semantica_mean']], "Top 10 palabras con cambio semántico entre período "+str(par_periodo[0])+ " → "+str(par_periodo[1]), top=topk)
    print("TOP 10 Palabras:", periodo_df1['palabra'].unique())
    display(periodo_df1[['par_periodo', 	'palabra', 	'similaridad_semantica_mean' 	,'vt1_top10' 	,'vt2_top10', 	'vt1_top10_union' 	,'vt2_top10_union', 	'dispersion','similaridad_semantica_confidence_intervals' 	]])
# Out:
#  Promedio de similaridad coseno  <= 0.3 , Cambio fuerte (usos muy distintos)
# TOP 10 Palabras: ['legal' 'declaracion']
#       par_periodo      palabra  similaridad_semantica_mean  \
# 186  (2009, 2014)        legal                    0.230416
# 83   (2009, 2014)  declaracion                    0.241996
#
#      similaridad_semantica_confidence_intervals  \
# 186  (0.21918460401466147, 0.24316196816925545)
# 83   (0.22538144276768002, 0.25874248028772795)
#
#                                                                                        vt1_top10  \
# 186  {musicoterapia, obstetricia, ejercicio, norma, colaborador, auxiliar, odontologia, loteria}
# 83                                                         {natural, valle, rioja, chaco, jujuy}
#
#                               vt2_top10  \
# 186                  {droga, monodroga}
# 83   {valor, prepagar, marco, medicina}
#
#                                                                                                                                                                                                                                                                 vt1_top10_union  \
# 186  {cosmetologo, ejercicio, fitoterapicos, juegos, norma, medicina, capitulo, colaborador, cosmetologia, gravamen, loteria, obstetricia, eliminacion, complementario, parrafo, odontologico, musicoterapia, apuesta, ocupacional, expendio, auxiliar, odontologia, terapeuta}
# 83                        {plazo, mendoza, rioja, pedro, chaco, rio, epidemiologico, tecnico, valle, declarar, ceniza, ochenta, corriente, accion, enfermeria, desastre, espinal, natural, atrofia, dengue, volcanica, muerte, vital, departamento, jujuy, emergencia, alergia}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                vt2_top10_union  \
# 186  {efecto, realizacion, fitoterapicos, mercurio, vencido, aptitud, exigencia, vegetal, elemento, embarazo, formulacion, recoleccion, menor, domiciliario, estudio, implante, empleo, ftalato, medicamentosa, fabricacion, produccion, medicamento, oftalmologico, caso, tipo, alergena, fetal, calendario, misoprostol, cirugia, vacuna, droga, sufrir, garantizar, planta, monodroga, sol, procreacion, fisico, laser, comprendido, proteina, instrumento}
# 83                                                                                                                                                                                                                              {suspension, publicar, listado, lectivo, comision, transcurso, exigencia, receta, prepagar, pami, medicina, trabajo, afiliado, requisito, tecnologico, judicial, entidad, valor, marco, impuesto, maternidad, inssjp, familia}
#
#      dispersion
# 186    0.023977
# 83     0.033361
# Promedio de similaridad coseno  <= 0.5  Cambio moderado
# TOP 10 Palabras: ['respectivamente' 'empleo' 'materia' 'el' 'tipo' 'ingreso' 'patologia'
#  'territorio' 'pre' 'acompanante']
#       par_periodo          palabra  similaridad_semantica_mean  \
# 294  (2009, 2014)  respectivamente                    0.326138
# 120  (2009, 2014)           empleo                    0.329805
# 197  (2009, 2014)          materia                    0.347583
# 113  (2009, 2014)               el                    0.367072
# 327  (2009, 2014)             tipo                    0.369607
# 176  (2009, 2014)          ingreso                    0.371601
# 238  (2009, 2014)        patologia                    0.373533
# 326  (2009, 2014)       territorio                    0.379232
# 251  (2009, 2014)              pre                    0.386240
# 4    (2009, 2014)      acompanante                    0.390003
#
#                                                                            vt1_top10  \
# 294                                    {potable, gravis, semana, gasificado, ajuste}
# 120                         {hogar, observatorio, comunitario, monto, familia, jefe}
# 197  {presupuesto, adopcion, fortalecimiento, postraumatico, estr, primaria, basica}
# 113                                       {identificar, septiembre, regional, rioja}
# 327                    {virus, gripe, causado, aparicion, h1n1, influenza, papiloma}
# 176                        {fincini, ciudadano, ninez, ganancia, geriatrico, basico}
# 238    {mamario, mastectomia, nocivo, radiacion, mamaria, reconstruccion, puerperio}
# 326           {percloroetileno, lavanderia, reconocer, aparicion, chaco, tintoreria}
# 251                                                       {sol, rio, lent, recetado}
# 4                     {embarazo, nacimiento, gratuidad, permanencia, proceso, parto}
#
#                                                                                   vt2_top10  \
# 294                                                                 {autoridad, gasificado}
# 120        {monodroga, sustancia, ftalato, subsistema, contributivo, instrumento, elemento}
# 197                                  {cumplimiento, politica, muerte, congreso, vacunacion}
# 113                                                            {premio, doctor, septiembre}
# 327                                                                 {ensenanza, cualquiera}
# 176                                                                      {ninez, categoria}
# 238                                                                {nacido, recien, visual}
# 326                                                                                      {}
# 251                                               {prenatal, sol, lent, recetado, prohibir}
# 4    {obstetricia, cosmiatrio, equinoterapia, cosmetologia, recurso, piercing, terapeutico}
#
#                                                                                                                                                                                                                                                                                                                                                   vt1_top10_union  \
# 294                                                                                                                                                                  {potable, bis, equivalente, gratuito, ayuda, escala, monto, gasificado, ajuste, mastectomia, remuneracion, anual, rango, osteoporosis, acceder, miastenia, agua, gravis, semana, top, chaga}
# 120                                                                                                                                          {nivel, equivalente, pacto, hogar, autorizar, rural, ceniza, observatorio, comunitario, erupcion, monto, fuerza, remuneracion, rango, revestir, republica, jefe, consejo, volcanica, familia, aprobacion, formacion}
# 197                                                                                                                                                                                         {cerebrovascular, basica, fortalecer, prostata, presupuesto, objetivo, adopcion, fortalecimiento, hipoacusia, delito, estr, red, financiero, primaria, postraumatico}
# 113                                                                                                                             {mundial, infeccion, comercializado, rioja, ciudad, autorizar, infanto, autonoma, quistico, endemico, prioritario, febrero, ambulancia, argentina, juvenil, fibromialgia, regional, identificar, hidrogenado, septiembre, aceite}
# 327                                                                                                                                                              {incremento, hepatitis, virus, cobro, creasar, hpv, varicela, causado, neumococo, avance, pandemia, aparicion, h1n1, papiloma, vacunacion, asistencial, gripe, reconocer, territorio, influenza}
# 176  {trabajador, conexa, desocupado, pension, fondo, fincini, sexo, adiccion, geriatrico, dieciseis, medicacion, distribucion, consultoria, anses, mental, certificado, revestir, jubilacion, prohibicion, basico, prenupcial, monodroga, asistencial, ciudadano, diabetes, fisico, ninez, militar, reconocimiento, ordenado, ganancia, correspondiente, ciento}
# 238                                                                                                                                                                                                                     {mamario, partos, infantil, mastectomia, cirugia, infancia, nocivo, radiacion, maternidad, producido, mamaria, reconstruccion, puerperio}
# 326                                                                                                                                                                                                           {isla, corriente, dengue, lavanderia, reconocer, percloroetileno, causado, aparicion, prioritario, represa, chaco, tintoreria, acupuntura, ochenta}
# 251                                                                                             {monohidratado, negro, pila, bateria, mercurio, habilitado, elemento, rio, epidemiologico, relevamiento, ambiente, exclusivo, trazabilidad, lent, recetado, importacion, prohibir, neuquen, chubut, creatin, madr, monodroga, poblacion, sol, peligroso, general}
# 4                                                                                                                                     {suspension, nacimiento, percibir, reconstruccion, embarazo, prenatal, inciso, situacion, proceso, mujer, violencia, puerperio, marco, consultoria, maternidad, embarazado, partos, gratuidad, privado, permanencia, parto}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 197    0.029689    (0.3322674175455796, 0.3619563159131458)
# 113    0.034193    (0.3482723704426346, 0.3824650847704803)
# 327    0.035083   (0.35189076832918387, 0.3869733164046924)
# 176    0.031492   (0.35578361207707604, 0.3872754203331894)
# 238    0.025923  (0.36118246445317465, 0.38710499376822405)
# 326    0.032407   (0.36277050566657804, 0.3951777759489354)
# 251    0.028649  (0.37198404208842567, 0.40063318683714794)
# 4      0.021960    (0.3785201351911447, 0.4004796646310691)
#  Promedio de similaridad coseno  <= 0.3 , Cambio fuerte (usos muy distintos)
# TOP 10 Palabras: ['dispositivo' 'adecuado' 'accesibilidad']
#      par_periodo        palabra  similaridad_semantica_mean  \
# 96  (2014, 2019)    dispositivo                    0.222339
# 5   (2014, 2019)       adecuado                    0.241482
# 0   (2014, 2019)  accesibilidad                    0.246599
#
#     similaridad_semantica_confidence_intervals  \
# 96   (0.20586610863791263, 0.2391247419353876)
# 5    (0.22572215140184967, 0.2558761352809253)
# 0   (0.22763808713904068, 0.26636443663705994)
#
#                                      vt1_top10  \
# 96        {electronico, similar, nocivo, dato}
# 5                                 {rotulacion}
# 0   {movilidad, consentimiento, discapacitada}
#
#                                               vt2_top10  \
# 96  {muerte_subita, oftalmologico, minimo, tecnologico}
# 5                           {tumor, geriatrico, manejo}
# 0                                   {gestion, elemento}
#
#                                                                                                                                                                                                                                                                                                                                                                     vt1_top10_union  \
# 96  {bullos, efecto, listado, rotulo, transcurso, dato, incorporar, medica, receta, infanto, secundario, capacidad, transgenico, digital, nocivo, medicamentosa, necesario, demas, electronico, requisito, geneticamente, organismo, administracion, implementacion, historia, cancer, osteoporosis, campana, leches, ciudadano, consumidor, similar, comprendido, correspondiente}
# 5                                                                          {potable, composicion, frio, cadena, alimentario, complemento, codigo, alcohol, braille, capitulo, elaborado, gasificado, medicinal, circuito, profesion, contenido, jugo, especialidad, cerrado, planta, informado, camara, porcentaje, modificatoria, seguridad, rotulacion, alimentacion, television}
# 0                       {presupuesto, dato, espacio, rehabilitacion, prepagar, fondo, cuyo, hijo, judicial, permanente, movilidad, area, politica, maternidad, consentimiento, hemocomponent, garantizar, trasplantado, automatico, informado, proteccion, equinoterapia, poblacion, seguridad, discapacitada, concurrencia, asistido, fertilizacion, actualizacion, desfibrilador}
#
#                                                                                                                                                                                                                                                                                                                                   vt2_top10_union  \
# 96                                                                 {potable, examen, muerte_subita, cronico, enfermo, cartel, adolescente, instalacion, calidad, gratuito, escolar, aplicacion, radiacion, lugar, tecnologico, educativo, oftalmologico, minimo, automatico, pobreza, privado, concurrencia, cuidado, comprendido, desfibrilador}
# 5                                                       {multiple, paciente, pais, dato, elemento, manejo, vida, domiciliario, situacion, mujer, alzheimer, hijo, geriatrico, mama, nomenclador, personal, agente, cerebrovascular, tumor, modificatoria, funcion, paliativo, ejecutivo, procreacion, diabetes, congreso, ministerio, financiero}
# 0   {etiqueta, examen, fumar, exhibicion, muscular, condicion, ambiental, ame, dato, incorporar, licenciado, habilitado, espacio, elemento, gratuito, gestion, producto, trabajo, congenita, tecnologico, elaborado, tabaco, oftalmologico, digno, calendario, gluten, celiaca, espinal, visual, poblacion, atrofia, paliativo, similar, numerir}
#
#     dispersion
# 96    0.033259
# 5     0.030154
# 0     0.038726
# Promedio de similaridad coseno  <= 0.5  Cambio moderado
# TOP 10 Palabras: ['forma' 'tipo' 'domiciliario' 'comunitario' 'necesario' 'educacion'
#  'pais' 'manejo' 'obligacion' 'sustancia']
#       par_periodo       palabra  similaridad_semantica_mean  \
# 143  (2014, 2019)         forma                    0.302599
# 317  (2014, 2019)          tipo                    0.316068
# 100  (2014, 2019)  domiciliario                    0.333025
# 62   (2014, 2019)   comunitario                    0.339957
# 221  (2014, 2019)     necesario                    0.347956
# 106  (2014, 2019)     educacion                    0.362112
# 241  (2014, 2019)          pais                    0.363814
# 192  (2014, 2019)        manejo                    0.368741
# 228  (2014, 2019)    obligacion                    0.369161
# 310  (2014, 2019)     sustancia                    0.373314
#
#                                                                      vt1_top10  \
# 143                                                    {proteina, transmision}
# 317                                                    {ensenanza, cualquiera}
# 100                                                     {recoleccion, vencido}
# 62                                                             {accion, marzo}
# 221                                               {dispositivo, desfibrilador}
# 106                                                                   {semana}
# 241                                                     {comercialicir, deber}
# 192                                       {explotacion, azar, activo, sancion}
# 228  {cumplimiento, congreso, afiliado, especialidad, profesion, farmaceutico}
# 310                {alergena, empleo, ftalato, leyendo, instrumento, elemento}
#
#                                           vt2_top10  \
# 143  {correspondiente, organizacion, actualizacion}
# 317                      {braille, droga, diabetes}
# 100                    {educacion, financiero, ter}
# 62                  {escolar, organizacion, agente}
# 221                             {precio, principio}
# 106  {domiciliario, semana, septiembre, enfermeria}
# 241           {ejecutivo, fabricacion, instalacion}
# 192                         {adecuado, relacionado}
# 228                       {donante, sangre, animal}
# 310                           {materia, etiquetado}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                  vt1_top10_union  \
# 143  {cualquiera, examen, derivado, bis, exhibicion, solar, nivel, fitoterapicos, cartel, oximetria, derogacion, complemento, gratuito, transmision, adiccion, relacionado, elaborado, humano, tecnica, prevenibl, educativo, anonimo, investigacion, leyenda, biomedico, reproduccion, almacenamiento, fertilizacion, consumar, celiaca, comida, vih, prenupcial, agua, tabaquismo, pulso, ensenanza, sal, proteina, apto, sexual, utilizacion}
# 317                                                                                                      {cualquiera, practica, instrumento, frio, organo, cadena, mercurio, incorporar, aptitud, perforacion, medicamentosa, fabricacion, integrante, deportivo, importacion, piercing, prohibir, distribucion, fetal, tatuaj, vacuna, droga, nomenclador, sufrir, planta, legal, odontologico, tabaquismo, ensenanza, aplv, proteina, recurso}
# 100                                                                        {pensionado, comision, fitoterapicos, frio, fortalecimiento, cadena, dato, vencido, autorizar, vegetal, recoleccion, pami, seguro, braille, materia, autonoma, tecnologico, jubilado, medicamento, anmat, medicinal, entidad, digno, tecnologia, droga, maternidad, inssjp, resolucion, planta, dengue, paliativo, consejo, comercialicir, muerte, deber, financiero}
# 62                                                         {octubre, listado, enfermo, nacion, comision, fortalecimiento, licenciado, mes, calidad, enero, prepagar, medicina, adiccion, desarrollo, afiliado, proceso, declaracion, julio, violencia, ambito, organismo, estatal, accion, prestacion, valor, mayo, digno, marco, mental, febrero, maternidad, cancer, natural, paliativo, marzo, victima, ninez, familia, financiero, primaria}
# 221  {acv, cronico, llamado, malformacion, grupo, fiebre, alcohol, manejo, recoleccion, terapia, comercializacion, norma, quimico, capacidad, relacionado, acceso, vino, produccion, publicitario, farmacia, mancha, mujer, provision, perjudicial, consecuencia, importacion, organismo, precio, accion, biomedico, reproduccion, sustancia, misoprostol, cirugia, tecnologia, espinal, maquina, dengue, oporto, forma, sodio, promover, aplv, correspondiente, proteina, principio, vascular}
# 106                                                                                                                                                                                              {acompanante, ter, articulo, pensionado, cordoba, licenciado, septiembre, especial, domiciliario, fondo, corporal, el, tecnologico, alzheimer, profesion, obstetricia, tipo, enfermeria, mayo, disponer, diabetes, fisico, semana, respectivamente, odontologia, trabajo, financiero, recurso}
# 241                                                                                                                                                                                                                                                                                 {desfibrilador, epidemiologico, recoleccion, virus, consejo, laboratorio, ejecutivo, ciudadano, concurrencia, externo, ambiental, fabricacion, clinico, investigacion, red, celula, instalacion, exigencia}
# 192                                                                                                                   {hepatitis, responsable, virus, practica, ambiental, organo, elemento, padecer, terapia, norma, relacionado, necesario, mujer, hijo, geriatrico, deportivo, biomedico, reproduccion, adecuado, obligatorio, denominado, nomenclador, automatico, personal, prenupcial, pmo, funcion, oporto, laboratorio, complejidad, procreacion, diabetes, correspondiente, principio}
# 228                                                                                                                                                                                                                                                    {etiqueta, periodo, banco, listado, solar, organo, rehabilitacion, prepagar, obra, medicina, estetico, lactancia, judicial, leyenda, alcoholica, cobertura, biomedico, valor, donante, sangre, animal, envase, afectar, respectivamente}
# 310                                                                                                                                                                          {periodo, efecto, centro, derivado, rotulo, consumo, autorizar, alcohol, rehabilitacion, padecer, secundario, norma, comercializacion, adiccion, necesario, materia, geriatrico, perjudicial, encontrar, importacion, prorrogable, alimenticio, complementario, legal, sodio, etiquetado, grasa, suplemento, apto}
#
#      dispersion  similaridad_semantica_confidence_intervals
# 143    0.028600     (0.2882390375204928, 0.316838888095242)
# 317    0.034797    (0.2983191971361545, 0.3331165147781076)
# 100    0.035425    (0.317037690697097, 0.35246236927276287)
# 62     0.029068   (0.32505722278001153, 0.3541252435676746)
# 221    0.041942   (0.32752307127265573, 0.3694650541698644)
# 106    0.043031  (0.34007437653483163, 0.38310500701484407)
# 241    0.026896  (0.35057463923012755, 0.37747087892753695)
# 192    0.030742    (0.3523312395419264, 0.3830732703936053)
# 228    0.029881    (0.3551305571824204, 0.3850117959915039)
# 310    0.032491  (0.35612755699351456, 0.38861854732727286)

# %% [markdown]
# #### Análisis técnico y contextual palabra por palabra, considerando:
#
# * El valor promedio de similaridad coseno (similaridad_semantica_mean): cuanto más bajo, mayor cambio semántico.
#
# * El contenido de las vecindades (vt1_top10, vt2_top10) por intersección de 50 iteraciones.
#
# * Las vecindades por unión (vt1_top10_union, vt2_top10_union) como panorama más amplio del contexto semántico.
#
# * La dispersión, que indica variabilidad en las 50 iteraciones.

# %% [markdown]
# #### 🔴Palabras con cambio semántico fuerte
# **Par de período (2009, 2014)**
# *  'legal' 'declaracion'
#
# **Par de período (2014, 2019)**
# * dispositivo' 'adecuado' 'accesibilidad'

# %% [markdown]
# #### 🟡Palabras con cambio semántico moderado
# **Par de período (2009, 2014)**
# * 'respectivamente' 'empleo' 'materia' 'el' 'tipo' 'ingreso' 'patologia'
#  'territorio' 'pre' 'acompanante'
#
#
# **Par de período (2014, 2019)**
# * 'forma' 'tipo' 'domiciliario' 'comunitario' 'necesario' 'educacion'
#  'pais' 'manejo' 'obligacion' 'sustancia'

# %% [markdown]
# *Para tener en cuenta*
#
# * ¿Detectar reorientaciones en las prioridades discursivas del Congreso?.
#
# * ¿Entender cómo ciertos términos como acompañante, recurso, territorio se adaptan a nuevos marcos legales o institucionales?.
#
# * ¿Servir de insumo para organizaciones que monitorean derechos y acceso a salud, alertando sobre cambios sutiles en el lenguaje parlamentario que pueden reflejar transformaciones más profundas?.

# %% [markdown]
# ##### Palabras comunes en entre todos los períodos

# %%
palabra_comun = set(topn_periodo[(2009, 2014)]['palabra'].unique()) & set(topn_periodo[(2014, 2019)]['palabra'].unique())
print("Cantidad de palabras en común:",len(palabra_comun))
# Out:
# Cantidad de palabras en común: 276

# %%
# Período (2009, 2014)
df = topn_periodo[(2009, 2014)]
df = df[df['palabra'].isin(palabra_comun)]
df = df[['palabra','similaridad_semantica_mean','similaridad_semantica_confidence_intervals','vt1_top10','vt2_top10']]
df.columns = ['palabra','ss_mean_2009_2014','ss_ci_2009_2014','vt1_top10_2009_2014','vt2_top10_2009_2014']
 
# Período (2014, 2019)
df2 = topn_periodo[(2014, 2019)]
df2 = df2[df2['palabra'].isin(palabra_comun)]
df2 = df2[['palabra','similaridad_semantica_mean','similaridad_semantica_confidence_intervals','vt1_top10','vt2_top10']]
df2.columns = ['palabra','ss_mean_2014_2019','ss_ci_2014_2019','vt1_top10_2014_2019','vt2_top10_2014_2019']

# Unión
df = df.merge(df2, how='inner', on='palabra')
df = df[['palabra', 'ss_mean_2009_2014', 'ss_mean_2014_2019', 'ss_ci_2009_2014','ss_ci_2014_2019','vt1_top10_2009_2014','vt2_top10_2009_2014', 'vt1_top10_2014_2019','vt2_top10_2014_2019']]
df['peso'] = (df['ss_mean_2009_2014'] + df['ss_mean_2014_2019'] )/2
df['diferencia'] = abs(df['ss_mean_2009_2014'] - df['ss_mean_2014_2019'] )

df.sort_values(['peso','diferencia']).to_csv(RESULTADOS_DIR+'procruste_top20_COM.csv', index=False)


print("Top 10 de palabras comunes con fuerte cambio semántico")
print("Palabras:",df[df['peso']<=0.3].sort_values('peso').head(10)['palabra'].unique() )
display(df[df['peso']<=0.3].sort_values('peso').head(10))
print("Top 10 de palabras comunes con moderado cambio semántico")
print("Palabras:",df[(df['peso']>0.3) & (df['peso']<=0.5)].sort_values('peso').head(10)['palabra'].unique() )
display(df[(df['peso']>0.3) & (df['peso']<=0.5)].sort_values(['peso','diferencia']).head(10))
# Out:
# Top 10 de palabras comunes con fuerte cambio semántico
# Palabras: []
# Empty DataFrame
# Columns: [palabra, ss_mean_2009_2014, ss_mean_2014_2019, ss_ci_2009_2014, ss_ci_2014_2019, vt1_top10_2009_2014, vt2_top10_2009_2014, vt1_top10_2014_2019, vt2_top10_2014_2019, peso, diferencia]
# Index: []
# Top 10 de palabras comunes con moderado cambio semántico
# Palabras: ['tipo' 'legal' 'ingreso' 'materia' 'forma' 'argentina' 'comunitario'
#  'respectivamente' 'domiciliario' 'derivado']
#              palabra  ss_mean_2009_2014  ss_mean_2014_2019  \
# 260             tipo           0.369607           0.316068
# 149            legal           0.230416           0.531215
# 141          ingreso           0.371601           0.397244
# 159          materia           0.347583           0.422933
# 120            forma           0.484979           0.302599
# 22         argentina           0.408254           0.382985
# 50       comunitario           0.460755           0.339957
# 236  respectivamente           0.326138           0.479367
# 82      domiciliario           0.495901           0.333025
# 71          derivado           0.459340           0.390248
#
#                                 ss_ci_2009_2014  \
# 260   (0.35189076832918387, 0.3869733164046924)
# 149  (0.21918460401466147, 0.24316196816925545)
# 141   (0.35578361207707604, 0.3872754203331894)
# 159    (0.3322674175455796, 0.3619563159131458)
# 120    (0.4665327142841819, 0.5009133483967529)
# 22     (0.3958283777904521, 0.4203712582242761)
# 50     (0.4459668303655224, 0.4748261881042146)
# 236  (0.31000066329099835, 0.34259649436498296)
# 82    (0.47952582331516275, 0.5109570484530604)
# 71     (0.44563523807165345, 0.471862724692613)
#
#                                 ss_ci_2014_2019  \
# 260    (0.2983191971361545, 0.3331165147781076)
# 149    (0.5117833939128683, 0.5447925434450439)
# 141    (0.3841834612507075, 0.4099497013901893)
# 159    (0.4094772437019852, 0.4364269540652596)
# 120     (0.2882390375204928, 0.316838888095242)
# 22   (0.36590119343130795, 0.39967891989958326)
# 50    (0.32505722278001153, 0.3541252435676746)
# 236   (0.4617260213965058, 0.49642280060125143)
# 82     (0.317037690697097, 0.35246236927276287)
# 71    (0.37203290551394896, 0.4056632749626365)
#
#                                                                              vt1_top10_2009_2014  \
# 260                                {virus, gripe, causado, aparicion, h1n1, influenza, papiloma}
# 149  {musicoterapia, obstetricia, ejercicio, norma, colaborador, auxiliar, odontologia, loteria}
# 141                                    {fincini, ciudadano, ninez, ganancia, geriatrico, basico}
# 159              {presupuesto, adopcion, fortalecimiento, postraumatico, estr, primaria, basica}
# 120                                       {indirecto, transmision, directo, realizacion, chagas}
# 22            {cigarrillo, comercializado, prioritario, chagas, republica, limitacion, bioetica}
# 50                      {direccion, radicacion, voluntario, sanitaria, militar, revestir, hogar}
# 236                                                {potable, gravis, semana, gasificado, ajuste}
# 82         {recoleccion, partos, capacidad, civil, vencido, mercurio, instrumento, odontologico}
# 71                                                     {geneticamente, gluten, alergena, envase}
#
#                                         vt2_top10_2009_2014  \
# 260                                 {ensenanza, cualquiera}
# 149                                      {droga, monodroga}
# 141                                      {ninez, categoria}
# 159  {cumplimiento, politica, muerte, congreso, vacunacion}
# 120                                 {proteina, transmision}
# 22                           {natural, comision, republica}
# 50                                          {accion, marzo}
# 236                                 {autoridad, gasificado}
# 82                                   {recoleccion, vencido}
# 71                  {geneticamente, modificado, exposicion}
#
#                                         vt1_top10_2014_2019  \
# 260                                 {ensenanza, cualquiera}
# 149                                      {droga, monodroga}
# 141                                      {ninez, categoria}
# 159  {cumplimiento, politica, muerte, congreso, vacunacion}
# 120                                 {proteina, transmision}
# 22                           {natural, comision, republica}
# 50                                          {accion, marzo}
# 236                                 {autoridad, gasificado}
# 82                                   {recoleccion, vencido}
# 71                  {geneticamente, modificado, exposicion}
#
#                                                           vt2_top10_2014_2019  \
# 260                                                {braille, droga, diabetes}
# 149                                                             {obstetricia}
# 141  {beneficiario, pensionado, otorgar, fortalecimiento, jubilado, primario}
# 159                             {infeccion, prorrogable, zona, desastre, vih}
# 120                            {correspondiente, organizacion, actualizacion}
# 22     {evaluacion, pobreza, tecnologia, republica, exigencia, desfibrilador}
# 50                                            {escolar, organizacion, agente}
# 236                                                      {publicidad, fisico}
# 82                                               {educacion, financiero, ter}
# 71                                             {organismo, medicinal, planta}
#
#          peso  diferencia
# 260  0.342838    0.053538
# 149  0.380816    0.300799
# 141  0.384422    0.025643
# 159  0.385258    0.075351
# 120  0.393789    0.182380
# 22   0.395619    0.025269
# 50   0.400356    0.120798
# 236  0.402753    0.153229
# 82   0.414463    0.162875
# 71   0.424794    0.069092

# %% [markdown]
# * Cantidad de palabras en común: 276
# * Las 10 palabras comunes entre pares de periodos comparados consecutivos con mayor peso de cambio semántico moderado son ['tipo' 'legal' 'ingreso' 'materia' 'forma' 'argentina' 'comunitario'
#  'respectivamente' 'domiciliario' 'derivado'] .El peso es el promedio de similaridad coseno promedio para los pares de períodos comparados.
#     * No aparece 'declaracion', pero aparecen ['legal'] de las palabras de fuerte cambio semántico en (2009-2014). En relación a cambio semántico de las palabras identificadas con cambio moderado, solo aparecen en palabras en comunes 'respectivamente' , ',materia', 'tipo', 'ingreso'.
#     * No aparecen ninguna de las palabras ['dispositivo', 'adecuado', 'accesibilidad'] de fuerte cambio semántico en (2014-2019).En relación a cambio semántico de las palabras identificadas con cambio moderado, solo aparecen en palabras en comunes 'forma', 'tipo', 'domiciliario', 'comunitario'..
#     * La palabra 'argentina' aparece entre las palabas de cambio moderado, cuando antes no estaba en top 10.

# %% [markdown]
# #### Identificar vecindades de palabras
#
# La vecindad de una palabra, son las N palabras más asociadas al período quinquinal observado. Por ejemplo: la palabra 'dispositivo' en el período 2014 estaba más asociado a las palabras {electronico, similar, dato, nocivo} tal para el período 2019 estaba más relacionado con {desfibrilador, instalacion, tecnologico, subitar, concurrencia}.
#
# Se busca las n palabras más similares (por similut coseno) a una palabra objetivo y así poder interpretar el posible cambio semantico. Para más información: https://tedboy.github.io/nlps/generated/generated/gensim.models.Word2Vec.most_similar.html

# %%
# Directorio con modelo de embedding alineados por procrustes correspondiente a i = 0
alin_dir = modelo_dir +'/estabilidad_procrustes/alineado/'
i = 0

# %%
# Inicializar estructura de vectores por palabra
from collections import defaultdict
vectores_por_palabra = {}
vectores_promedio = {}

def get_vector_modelo(vectores,periodo,i):
    modelo = Word2Vec.load(alin_dir+"alin_" + str(periodo)+'_'+str(i)+'.mdl')
    for palabra in modelo.wv.key_to_index:
        vectores[palabra].append(modelo.wv[palabra])
    return vectores
    
for periodo in [2009,2014,2019]:
    # Por período
    vectores_por_palabra[periodo] = defaultdict(list)
    for i in range(50):
        vectores_por_palabra[periodo] = get_vector_modelo(vectores_por_palabra[periodo],periodo,i)
    #Calcular vector medio solo para palabras con presencia en todas las iteraciones (opcional)
    vectores_promedio[periodo] = {pal: np.mean(vs, axis=0) for pal, vs in vectores_por_palabra[periodo].items() if len(vs) == 50}

# %%
## 2. Visualización del desplazamiento con t-SNE
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.manifold import TSNE
from scipy.spatial.distance import cosine


def compute_cosine_similarity(model1,model2,word):
    vector1 = model1.wv[word].reshape(1,-1)
    vector2 = model2.wv[word].reshape(1,-1)
    return(cosine_similarity(X=vector1, Y=vector2)[0][0])

def reducir_dimensionalidad( embeddings, n_components=2, perplexity=5, palabrasComun = []):
    if len(palabrasComun)>0:
        words = palabrasComun
    else:
        words = list(embeddings.keys())
    
    vectors = np.array([embeddings.wv.get_vector(word)  for word in words])
    #embeddings[word]  
    tsne = TSNE(n_components=n_components, perplexity=perplexity, random_state=42)
    reduced_vectors = tsne.fit_transform(vectors)
    
    return reduced_vectors



def plot_neighbors_tsne(word, embeddings_by_period, alineados=None, periods=None, top_k=10):

    all_vectors, all_labels, all_colors = [], [], []
    center_positions = {}

    # Paleta accesible para daltonismo
    color_palette = sns.color_palette("colorblind", len(periods))

    for i, period in enumerate(periods):
        if word not in embeddings_by_period[period]:
            print(f"'{word}' no está en el vocabulario del período {period}")
            continue

        vocab = embeddings_by_period[period]

        if alineados:
            vecinos = alineados[period].wv.most_similar(positive=[word], topn=top_k)
            print(period)
            print(vecinos)
            neighbors = [w for w, _ in vecinos] + [word]
        else:
            vecinos = sorted(
                vocab.items(),
                key=lambda kv: cosine(vocab[word], kv[1])
            )[1:top_k+1]
            neighbors = [w for w, _ in vecinos] + [word]

        for w in neighbors:
            all_vectors.append(vocab[w])
            all_labels.append(w)
            all_colors.append(color_palette[i])

    if all_vectors:
        tsne = TSNE(n_components=2, perplexity=5, random_state=0)
        X_2d = tsne.fit_transform(np.array(all_vectors))

        plt.figure(figsize=(16, 10))
        ax = plt.gca()
        ax.set_facecolor('white')  # Fondo blanco
        ax.spines['top'].set_visible(True)
        ax.spines['right'].set_visible(True)
        ax.spines['bottom'].set_visible(True)
        ax.spines['left'].set_visible(True)

        for i, (x, label) in enumerate(zip(X_2d, all_labels)):
            plt.scatter(x[0], x[1], color=all_colors[i], s=70, edgecolor='black', linewidth=0.6)
            fontsize = 14 if label == word else 11
            weight = 'bold' if label == word else 'normal'

            # Separación de etiquetas: se desplazará ligeramente del punto
            offset = 1 if label == word else 0.5
            plt.text(x[0] + offset, x[1] + offset, label, fontsize=fontsize,
                     fontweight=weight, color='black',
                     bbox=dict(facecolor='white', edgecolor='none', pad=0.2))

        # Identificar y trazar los centros
        index = 0
        for i, period in enumerate(periods):
            if word in embeddings_by_period[period]:
                center_positions[period] = X_2d[index + top_k]
                index += top_k + 1

        # Flechas de cambio semántico
        for i in range(len(periods) - 1):
            p1, p2 = periods[i], periods[i+1]
            if p1 in center_positions and p2 in center_positions:
                start, end = center_positions[p1], center_positions[p2]
                plt.arrow(start[0], start[1], end[0]-start[0], end[1]-start[1],
                          color='gray', linewidth=1.5, head_width=0.5, length_includes_head=True)

                mid_x = (start[0] + end[0]) / 2
                mid_y = (start[1] + end[1]) / 2
                plt.text(mid_x, mid_y, f'{p2}', fontsize=10, ha='center',
                         va='center', backgroundcolor='white')

        # Leyenda
        for i, period in enumerate(periods):
            plt.scatter([], [], color=color_palette[i], label=str(period))
        plt.legend(title='Período', loc='upper left', fontsize=11)

        plt.title(f"Evolución semántica de '{word}' por quinquenios", fontsize=16, weight='bold')
        plt.axis('off')  # Mostrar bordes del gráfico
        plt.grid(True, linestyle='--', alpha=0.3)
        plt.savefig(modelo_dir+'/estabilidad_procrustes/estabilidad_procrustes_'+word)
        plt.tight_layout()
        plt.show()
        plt.clf()       # Limpia el contenido actual de la figura
        plt.close()     # Cierra la figura actual

# %%
# Para graficar
i = 0
vectores_alineados = {}
modelos_alineados = {}
vocab = {}
for periodo in [2009,2014,2019]:
    modelo = Word2Vec.load(alin_dir+"alin_" + str(periodo)+'_'+str(i)+'.mdl')
    vocab = {word: modelo.wv.get_vector(word) for word in modelo.wv.key_to_index}  # NUEVO vocab cada vez
    vectores_alineados[periodo]=  vocab
    modelos_alineados[periodo] = modelo

# %% [markdown]
# **Enfoque de explorar la iteración 0**

# %%
top10pal_comunes_df = df.sort_values(['peso']).head(10)
top10pal = list(top10pal_comunes_df['palabra'].values)
top10pal
# Out:
# ['tipo',
#  'legal',
#  'ingreso',
#  'materia',
#  'forma',
#  'argentina',
#  'comunitario',
#  'respectivamente',
#  'domiciliario',
#  'derivado']

# %%
top10pal_comunes_df
# Out:
#              palabra  ss_mean_2009_2014  ss_mean_2014_2019  \
# 260             tipo           0.369607           0.316068
# 149            legal           0.230416           0.531215
# 141          ingreso           0.371601           0.397244
# 159          materia           0.347583           0.422933
# 120            forma           0.484979           0.302599
# 22         argentina           0.408254           0.382985
# 50       comunitario           0.460755           0.339957
# 236  respectivamente           0.326138           0.479367
# 82      domiciliario           0.495901           0.333025
# 71          derivado           0.459340           0.390248
#
#                                 ss_ci_2009_2014  \
# 260   (0.35189076832918387, 0.3869733164046924)
# 149  (0.21918460401466147, 0.24316196816925545)
# 141   (0.35578361207707604, 0.3872754203331894)
# 159    (0.3322674175455796, 0.3619563159131458)
# 120    (0.4665327142841819, 0.5009133483967529)
# 22     (0.3958283777904521, 0.4203712582242761)
# 50     (0.4459668303655224, 0.4748261881042146)
# 236  (0.31000066329099835, 0.34259649436498296)
# 82    (0.47952582331516275, 0.5109570484530604)
# 71     (0.44563523807165345, 0.471862724692613)
#
#                                 ss_ci_2014_2019  \
# 260    (0.2983191971361545, 0.3331165147781076)
# 149    (0.5117833939128683, 0.5447925434450439)
# 141    (0.3841834612507075, 0.4099497013901893)
# 159    (0.4094772437019852, 0.4364269540652596)
# 120     (0.2882390375204928, 0.316838888095242)
# 22   (0.36590119343130795, 0.39967891989958326)
# 50    (0.32505722278001153, 0.3541252435676746)
# 236   (0.4617260213965058, 0.49642280060125143)
# 82     (0.317037690697097, 0.35246236927276287)
# 71    (0.37203290551394896, 0.4056632749626365)
#
#                                                                              vt1_top10_2009_2014  \
# 260                                {virus, gripe, causado, aparicion, h1n1, influenza, papiloma}
# 149  {musicoterapia, obstetricia, ejercicio, norma, colaborador, auxiliar, odontologia, loteria}
# 141                                    {fincini, ciudadano, ninez, ganancia, geriatrico, basico}
# 159              {presupuesto, adopcion, fortalecimiento, postraumatico, estr, primaria, basica}
# 120                                       {indirecto, transmision, directo, realizacion, chagas}
# 22            {cigarrillo, comercializado, prioritario, chagas, republica, limitacion, bioetica}
# 50                      {direccion, radicacion, voluntario, sanitaria, militar, revestir, hogar}
# 236                                                {potable, gravis, semana, gasificado, ajuste}
# 82         {recoleccion, partos, capacidad, civil, vencido, mercurio, instrumento, odontologico}
# 71                                                     {geneticamente, gluten, alergena, envase}
#
#                                         vt2_top10_2009_2014  \
# 260                                 {ensenanza, cualquiera}
# 149                                      {droga, monodroga}
# 141                                      {ninez, categoria}
# 159  {cumplimiento, politica, muerte, congreso, vacunacion}
# 120                                 {proteina, transmision}
# 22                           {natural, comision, republica}
# 50                                          {accion, marzo}
# 236                                 {autoridad, gasificado}
# 82                                   {recoleccion, vencido}
# 71                  {geneticamente, modificado, exposicion}
#
#                                         vt1_top10_2014_2019  \
# 260                                 {ensenanza, cualquiera}
# 149                                      {droga, monodroga}
# 141                                      {ninez, categoria}
# 159  {cumplimiento, politica, muerte, congreso, vacunacion}
# 120                                 {proteina, transmision}
# 22                           {natural, comision, republica}
# 50                                          {accion, marzo}
# 236                                 {autoridad, gasificado}
# 82                                   {recoleccion, vencido}
# 71                  {geneticamente, modificado, exposicion}
#
#                                                           vt2_top10_2014_2019  \
# 260                                                {braille, droga, diabetes}
# 149                                                             {obstetricia}
# 141  {beneficiario, pensionado, otorgar, fortalecimiento, jubilado, primario}
# 159                             {infeccion, prorrogable, zona, desastre, vih}
# 120                            {correspondiente, organizacion, actualizacion}
# 22     {evaluacion, pobreza, tecnologia, republica, exigencia, desfibrilador}
# 50                                            {escolar, organizacion, agente}
# 236                                                      {publicidad, fisico}
# 82                                               {educacion, financiero, ter}
# 71                                             {organismo, medicinal, planta}
#
#          peso  diferencia
# 260  0.342838    0.053538
# 149  0.380816    0.300799
# 141  0.384422    0.025643
# 159  0.385258    0.075351
# 120  0.393789    0.182380
# 22   0.395619    0.025269
# 50   0.400356    0.120798
# 236  0.402753    0.153229
# 82   0.414463    0.162875
# 71   0.424794    0.069092

# %% [markdown]
# Las gráficas siguientes nos permiten visualizar cómo cambia el contexto semántico de una palabra específica a lo largo de periodos quinquenales, representando:
# * Sus vecinos más similares (por word embeddings alineados por enfoque Procustes) en cada período.
# * Su posición central (vector) en un espacio reducido a 2 dimensiones con t-SNE.
# * Las flechas indican el desplazamiento del significado entre períodos.
#
# **Para interpretar**
# * Colores y períodos
#     * Cada color representa un período (por ejemplo: 2009, 2014, 2019).
#     * Todos los puntos del mismo color corresponden a la palabra de interés y sus vecinos en ese período.
#     * Usá la leyenda para saber a qué período corresponde cada color.
#
# * Puntos o destacados
#     * El punto de la palabra clave (por ejemplo 'obligacion') suele estar con etiqueta en negrita.
#     * Los vecinos más similares están alrededor, mostrando con qué palabras compartía contexto en ese momento.
#
# * Flechas de cambio
#     * Las flechas conectan el centro de cada período.
#     * Muestran cómo se movió la palabra en el espacio semántico entre dos períodos consecutivos.
#     * Si la dirección cambia mucho, sugiere cambio semántico fuerte.
#
# * Distancia entre períodos
# * Una distancia grande entre las posiciones de la palabra en distintos períodos sugiere cambios de significado o de contexto de uso.
# * Una distancia corta indica estabilidad semántica.

# %%
for palabra in top10pal : 
    plot_neighbors_tsne(palabra, vectores_alineados,modelos_alineados, [2009,2014,2019], top_k=10)
# Out:
# 2009
# [('causado', 0.7312771081924438), ('aparicion', 0.7136205434799194), ('h1n1', 0.7093455791473389), ('gripe', 0.6830159425735474), ('papiloma', 0.6745467185974121), ('influenza', 0.6416090130805969), ('virus', 0.6255151629447937), ('avance', 0.5940244197845459), ('pandemia', 0.5770514011383057), ('hpv', 0.5768388509750366)]
# 2014
# [('ensenanza', 0.7124901413917542), ('cualquiera', 0.668062150478363), ('fabricacion', 0.6149323582649231), ('instrumento', 0.5768714547157288), ('fetal', 0.5758169293403625), ('mercurio', 0.5727382302284241), ('importacion', 0.5623658895492554), ('distribucion', 0.5600583553314209), ('piercing', 0.5594909191131592), ('practica', 0.5576760768890381)]
# 2019
# [('droga', 0.614311158657074), ('secundario', 0.6124213337898254), ('braille', 0.6088365316390991), ('diabetes', 0.5965186953544617), ('judicial', 0.5947089791297913), ('animal', 0.5739579796791077), ('trasplantado', 0.572794497013092), ('afectar', 0.5713313221931458), ('sustitucion', 0.5700321197509766), ('pensionado', 0.5647804141044617)]
# 2009
# [('loteria', 0.8574459552764893), ('ejercicio', 0.8088810443878174), ('auxiliar', 0.8013213872909546), ('odontologia', 0.7716036438941956), ('obstetricia', 0.771074652671814), ('musicoterapia', 0.7672595381736755), ('norma', 0.7359511852264404), ('colaborador', 0.7210851311683655), ('expendio', 0.6932270526885986), ('eliminacion', 0.6715078949928284)]
# 2014
# [('droga', 0.5959363579750061), ('monodroga', 0.5741350054740906), ('embarazo', 0.5692857503890991), ('misoprostol', 0.5685172080993652), ('fabricacion', 0.5253490209579468), ('planta', 0.5187300443649292), ('aptitud', 0.5131853222846985), ('formulacion', 0.5089772939682007), ('realizacion', 0.5050554275512695), ('vencido', 0.5047135353088379)]
# 2019
# [('obstetricia', 0.5278719663619995), ('edad', 0.5232183933258057), ('periodo', 0.5208038687705994), ('alcohol', 0.4833892583847046), ('estetico', 0.483220636844635), ('sustancia', 0.48309800028800964), ('menor', 0.47515901923179626), ('garantizar', 0.47197312116622925), ('especialidad', 0.4664487838745117), ('embarazo', 0.46510592103004456)]
# 2009
# [('ninez', 0.7989323139190674), ('fincini', 0.775601327419281), ('ciudadano', 0.7242684960365295), ('basico', 0.6931915879249573), ('geriatrico', 0.6679727435112), ('anses', 0.6195378303527832), ('ganancia', 0.6080860495567322), ('mental', 0.5825474858283997), ('ciento', 0.5716988444328308), ('fondo', 0.5593427419662476)]
# 2014
# [('vencido', 0.932624340057373), ('recoleccion', 0.9116963148117065), ('medicamento', 0.7195951342582703), ('muerte', 0.6606871485710144), ('resolucion', 0.6352334022521973), ('tecnologia', 0.6304008364677429), ('vegetal', 0.5993617177009583), ('fitoterapicos', 0.5829907059669495), ('planta', 0.5807668566703796), ('frio', 0.5741263031959534)]
# 2019
# [('trasplantado', 0.6590492725372314), ('financiero', 0.6507527232170105), ('educacion', 0.6392754912376404), ('organizacion', 0.6071751713752747), ('obstetricia', 0.5921343564987183), ('forma', 0.586733877658844), ('extension', 0.5744085311889648), ('ter', 0.5647851824760437), ('hijo', 0.5535404682159424), ('cuidado', 0.5530663132667542)]
# 2009
# [('envase', 0.8266571164131165), ('geneticamente', 0.8218485713005066), ('gluten', 0.8039276599884033), ('identificar', 0.7810763120651245), ('alergena', 0.7775430083274841), ('modificado', 0.7714470624923706), ('indicar', 0.7633350491523743), ('televisivo', 0.7611690163612366), ('identificacion', 0.7585259079933167), ('fumar', 0.7556285858154297)]
# 2014
# [('exposicion', 0.8068185448646545), ('modificado', 0.7587658166885376), ('geneticamente', 0.7340756058692932), ('radiacion', 0.6162437796592712), ('proteina', 0.5992203950881958), ('bis', 0.5980525612831116), ('solar', 0.584377646446228), ('masivo', 0.5783448815345764), ('cartel', 0.5610639452934265), ('riesgo', 0.5594556927680969)]
# 2019
# [('planta', 0.788296639919281), ('medicinal', 0.7662044763565063), ('organismo', 0.6096066236495972), ('comercializacion', 0.6001161336898804), ('expendio', 0.5914250016212463), ('droga', 0.5850197672843933), ('identificacion', 0.5731600522994995), ('cualquiera', 0.5671513080596924), ('autorizar', 0.5548104047775269), ('primario', 0.5467133522033691)]

# %% [markdown]
# En un gráfico t-SNE las palabras más similares deberían aparecer más cerca unas de otras. Pero en la práctica, hay varios factores que pueden distorsionar esta expectativa.

# %% [markdown]
# **Para tener en cuenta**
# ¿Cuáles vecinos persisten entre períodos? (mismo contexto).
# ¿Qué palabras nuevas aparecen en los vecinos más similares? (nuevos usos).
# ¿Cuáles se desvanecen o ya no son vecinos relevantes?
# ¿Qué tan cohesivo o disperso es el grupo de vecinos?

# %% [markdown]
# ## Análisis proyectos de ley asociados a términos con cambio fuerte y moderado

# %%
# Abrir
with open(os.getenv("DIR_DATOS_PROCESADOS") + 'base_texto_df_ley_0924.pkl', 'rb') as file: 
    basetexto_df = pickle.load(file)

basetexto_df.describe(include='all').T
# Out:
#                           count unique  \
# Proyecto.ID               33097  33097
# Título                    33097  31392
# Título procesado          33097  27969
# Título normalizado        33097  27247
# Cant_token              33097.0    NaN
# Cant_token_procesados   33097.0    NaN
# Cant_token_normalizado  33097.0    NaN
# Proyecto_SALUD          33097.0    NaN
# Resultado                 33097      6
# Periodo                 33097.0    NaN
# Año                     33097.0    NaN
# Tokens                    33097  25012
#
#                                                                                                                top  \
# Proyecto.ID                                                                                             HCDN152173
# Título                                                                               JUICIO POR JURADOS. CREACION.
# Título procesado        contrato de trabajo ley numero modificacion del articulo numero sobre licencias especiales
# Título normalizado                                                                               licencia especial
# Cant_token                                                                                                     NaN
# Cant_token_procesados                                                                                          NaN
# Cant_token_normalizado                                                                                         NaN
# Proyecto_SALUD                                                                                                 NaN
# Resultado                                                                NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# Periodo                                                                                                        NaN
# Año                                                                                                            NaN
# Tokens                                                                                        [licencia, especial]
#
#                          freq         mean        std     min     25%     50%  \
# Proyecto.ID                 1          NaN        NaN     NaN     NaN     NaN
# Título                     18          NaN        NaN     NaN     NaN     NaN
# Título procesado           33          NaN        NaN     NaN     NaN     NaN
# Título normalizado         36          NaN        NaN     NaN     NaN     NaN
# Cant_token                NaN    21.181225  10.774979     2.0    14.0    19.0
# Cant_token_procesados     NaN    20.947971  10.805237     2.0    13.0    19.0
# Cant_token_normalizado    NaN     9.782246   5.081133     0.0     6.0     9.0
# Proyecto_SALUD            NaN      0.08605   0.280442     0.0     0.0     0.0
# Resultado               32191          NaN        NaN     NaN     NaN     NaN
# Periodo                   NaN   134.111944   4.075721   127.0   131.0   134.0
# Año                       NaN  2016.132822   4.085628  2009.0  2013.0  2016.0
# Tokens                     39          NaN        NaN     NaN     NaN     NaN
#
#                            75%     max
# Proyecto.ID                NaN     NaN
# Título                     NaN     NaN
# Título procesado           NaN     NaN
# Título normalizado         NaN     NaN
# Cant_token                27.0   125.0
# Cant_token_procesados     27.0   128.0
# Cant_token_normalizado    12.0    57.0
# Proyecto_SALUD             0.0     1.0
# Resultado                  NaN     NaN
# Periodo                  137.0   141.0
# Año                     2020.0  2024.0
# Tokens                     NaN     NaN

# %%
# Seleccionando IL de Salud
# Supongamos que estos son tus 3 DataFrames ya filtrados
basetotaltexto_df = basetexto_df.copy()  # todas las iniciativas
basetexto_df = basetexto_df[basetexto_df['Proyecto_SALUD']==1]
print("Conj. de datos de proyecto_SALUD con Nan en Período:",basetexto_df.shape)
basetexto_df = basetexto_df[~basetexto_df['Periodo'].isna()]
print("Conj. de datos de proyecto_SALUD sin Nan en Período:",basetexto_df.shape)
# Out:
# Conj. de datos de proyecto_SALUD con Nan en Período: (2848, 12)
# Conj. de datos de proyecto_SALUD sin Nan en Período: (2848, 12)

# %%
#pal = set(['legal', 'declaracion']).union(set(['acompanante', 'dengue', 'recurso' ,'tipo' ,'patologia', 'comunitario','empleo', 'ingreso' ,'territorio']))
#pal = pal.union(set( ['comunitario', 'adecuado', 'dispositivo'])).union(set(['necesario', 'materia', 'suplemento', 'obligacion' ,'tipo', 'gratuidad','forma' ,'domiciliario' ,'pais' ,'accesibilidad']))
#pal = pal.union(set(top10pal))
pal = top10pal # list(pal)

# %%
# Convertimos a minúscula y verificamos si la palabra aparece en el título
for palabra in pal:
    basetexto_df[palabra] = basetexto_df['Título normalizado'].str.contains(rf'\b{palabra}\b', case=False)

# %%
proyectos_relevantes = basetexto_df[basetexto_df[pal].any(axis=1)]
print("Cantidad de proyectos asociados a las palabras con cambio semántico':" ,proyectos_relevantes.shape[0])
print("% :" , round((proyectos_relevantes.shape[0]/basetexto_df.shape[0]) * 100,2))
# Out:
# Cantidad de proyectos asociados a las palabras con cambio semántico': 167
# % : 5.86

# %%
frecuencias_df = basetexto_df[['Año']+top10pal].groupby(['Año']).sum().T#reset_index()
frecuencias_df['total'] = frecuencias_df.sum(axis=1) 
frecuencias_df = frecuencias_df.sort_values('total', ascending=True)
# Cantidad de proyectos por año (para normalizar)
#total_proyectos_por_anio = basetexto_df.groupby('Año').size()
# frecuencia_df tiene palabras como índice y años como columnas (frecuencia absoluta)
#frecuencia_relativa_df = frecuencias_df.div(total_proyectos_por_anio, axis=1) * 100  # multiplicamos por 100 para %
frecuencia_relativa_df = frecuencias_df.div(frecuencias_df['total'], axis=0) * 100  # multiplicamos por 100 para %
frecuencia_relativa_df = frecuencia_relativa_df.drop(columns='total')
# Ordenar por promedio total para ordenar mejor las barras
#frecuencia_relativa_df['Promedio'] = frecuencia_relativa_df.mean(axis=1)
#frecuencia_relativa_df = frecuencia_relativa_df.sort_values('Promedio', ascending=True).drop(columns='Promedio')

# %%
frecuencias_df
# Out:
# Año              2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# materia             0     0     1     0     1     1     3     0     1     1
# legal               1     0     1     0     0     0     2     0     2     2
# ingreso             1     2     0     1     1     3     1     0     0     1
# domiciliario        1     2     1     0     3     0     1     0     1     1
# forma               1     1     3     1     1     2     0     1     2     2
# argentina           1     0     1     1     0     0     1     2     0     3
# comunitario         3     0     2     0     1     0     2     0     0     1
# tipo                6     1     1     1     0     3     1     1     0     0
# derivado            1     1     0     0     1     1     1     3     2     2
# respectivamente     0     0     2     2     2     2     4     2     5     2
#
# Año              2019  2020  2021  2022  2023  2024  total
# materia             1     1     0     1     1     0     12
# legal               2     1     1     0     2     0     14
# ingreso             1     3     0     0     0     1     15
# domiciliario        1     2     1     1     0     0     15
# forma               0     2     0     0     0     0     16
# argentina           3     1     0     2     1     0     16
# comunitario         1     2     1     1     2     0     16
# tipo                0     0     0     1     2     0     17
# derivado            3     1     0     2     0     0     18
# respectivamente     2     3     2     6     1     0     35

# %%
plt.figure(figsize=(14, 10))
sns.set(font_scale=0.9)

# Crear una versión formateada como texto con % para anotar
annot_text = frecuencia_relativa_df.round(1).astype(str) + '%'

# Paleta perceptualmente uniforme, buena para datos proporcionales
sns.heatmap(
    frecuencia_relativa_df,
    cmap="YlOrRd",           # o usa "viridis", "cividis" para daltónicos
    linewidths=0.3,
    linecolor='gray',
    cbar_kws={'label': 'Frecuencia relativa (%)'},
    vmin=1,                  # valor mínimo en escala de color
    vmax=50,                 # valor máximo
    annot=annot_text,  # Mostrar los valores como texto
    fmt='',             # Ya están formateados como string
    annot_kws={"size": 8}  # Tamaño del texto en las celdas
)
plt.title('Presencia relativa de palabras con cambios moderado en proyectos de ley sobre salud (2009–2024)', fontsize=14)
plt.xlabel('Año')
plt.ylabel('Palabra clave')
plt.tight_layout()
plt.show()

# %%
def mostrar_ejemplos_contextuales_titulos(df, palabra, periodo, n=5):
    """
    Muestra ejemplos de títulos que contienen una palabra específica en un periodo.

    Args:
        df (pd.DataFrame): DataFrame con columnas 'titulo' (o la columna de títulos) y 'periodo'.
        palabra (str): La palabra para buscar en los títulos (insensible a mayúsculas/minúsculas).
        periodo (int): El periodo de interés.
        n (int): Número de ejemplos a mostrar.
    """
    df_periodo = df[df['Periodo_5anios'] == periodo]
    titulos_con_palabra = df_periodo[df_periodo['Título normalizado'].str.lower().str.contains(palabra.lower(), na=False)]

    if not titulos_con_palabra.empty:
        print(f"\nEjemplos de títulos conteniendo '{palabra}' en el periodo {periodo}:")
        display(titulos_con_palabra[['Título','Título normalizado']].head(n))
    
    else:
        print(f"No se encontraron títulos conteniendo '{palabra}' en el periodo {periodo}.")

# %% [markdown]
# **Comunitario**

# %%
proyectos_relevantes.loc[proyectos_relevantes['legal']==True,['Proyecto.ID','Año','Título','Resultado'],].sort_values(by='Año', ascending = False)
# Out:
#       Proyecto.ID   Año  \
# 1288   HCDN266397  2023
# 1409   HCDN266207  2023
# 4642   HCDN251920  2021
# 7637   HCDN239627  2020
# 9544   HCDN231356  2019
# 10319  HCDN228403  2019
# 11100  HCDN222415  2018
# 11373  HCDN220908  2018
# 13789  HCDN206872  2017
# 15036  HCDN196961  2017
# 19103  HCDN178824  2015
# 19219  HCDN177185  2015
# 29141  HCDN124011  2011
# 31847  HCDN108501  2009
#
#                                                                                                                                                                                                                                                 Título  \
# 1288                                                                                                             "PROGRAMA NACIONAL DE REDUCCION DE RIESGOS Y DAÑOS ASOCIADOS AL CONSUMO DE SUSTANCIAS PSICOACTIVAS LEGALES E ILEGALIZADAS". CREACION.
# 1409                                                                                                                                                                    REGIMEN LEGAL PARA EL EJERCICIO PROFESIONAL DE LA INSTRUMENTACION QUIRURGICA.
# 4642                                                                                                                                                                     REGIMEN LEGAL PARA EL EJERCICIO PROFESIONAL DE LA INSTRUMENTACION QUIRURGICA.
# 7637                                                                                              INCORPORESE COMO BENEFICIARIOS DEL "INGRESO FAMILIAR  DE EMERGENCIA - IFE -"  A TODOS LOS HABITANTES CON RESIDENCIA LEGAL EN LA REPUBLICA ARGENTINA.
# 9544                                                                                     INCLUSION DEL MISOPROSTOL EN EL PLAN MEDICO OBLIGATORIO PARA GARANTIZAR LA "INTERRUPCION LEGAL DEL EMBARAZO - ILE -" (REPRODUCCION DEL EXPEDIENTE 5853-D-17).
# 10319                                                                                                                                       OBLIGATORIEDAD DE PRACTICAR LA AUTOPSIA MEDICO LEGAL A TODA PERSONA FALLECIDA MENOR DE TRES AÑOS DE EDAD.
# 11100                                                                                                           DECLARAR DE INTERES NACIONAL LA INVESTIGACION Y PRODUCCION DE MEDICAMENTOS PARA LA REALIZACION DE INTERRUPCIONES LEGALES DE EMBARAZOS.
# 11373                                                                                                                                                  PRODUCCION PUBLICA DE MEDICAMENTOS ESENCIALES PARA LA INTERRUPCION LEGAL DE EMBARAZOS. REGIMEN.
# 13789                                                                                                                            INCLUSION DEL MISOPROSTOL EN EL PLAN MEDICO OBLIGATORIO PARA GARANTIZAR LA "INTERRUPCION LEGAL DEL EMBARAZO - ILE -".
# 15036                                                                                                                                          AUTOPSIA MEDICO LEGAL. OBLIGATORIEDAD DE PRACTICAR A TODA PERSONA FALLECIDA MENOR DE TRES AÑOS DE EDAD.
# 19103  AVISOS, PUBLICACIONES, PUBLICIDADES O CUALQUIER OTRO TIPO DE MENSAJES QUE PROMUEVAN LA COMPRA O CONSUMO DE MEDICAMENTOS, DROGAS LEGALES, COMPLEJOS VITAMINICOS, ENERGIZANTES Y TERAPIAS O TRATAMIENTOS MEDICOS DE DISTINTA INDOLE. PROHIBICION.
# 19219                                                                                                                                          AUTOPSIA MEDICO LEGAL. OBLIGATORIEDAD DE PRACTICAR A TODA PERSONA FALLECIDA MENOR DE TRES AÑOS DE EDAD.
# 29141                                                   REGIMEN LEGAL DEL EJERCICIO DE LA MEDICINA, ODONTOLOGIA Y ACTIVIDADES AUXILIARES - LEY 17132 -. MODIFICACIONES, SOBRE INCORPORACION DE LA ACTIVIDAD DE TRABAJADOR SOCIAL Y/O ASISTENTE SOCIAL.
# 31847                                                                                                       REGIMEN LEGAL DE LOTERIA NACIONAL (LEYES 18226 Y 25295) Y DECRETOS 598/90, 1688/94, 1155/03, 1851/07 Y NORMAS COMPLEMENTARIAS: DEROGACION.
#
#                                        Resultado
# 1288   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 1409   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 4642   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 7637   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 9544   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 10319  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 11100  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 11373  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 13789  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 15036  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 19103  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 19219  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 29141  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 31847  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN

# %% [markdown]
# **Tipo**

# %%
proyectos_relevantes.loc[proyectos_relevantes['tipo']==True,['Proyecto.ID','Año','Título','Resultado'],].sort_values(by='Año', ascending = False)
# Out:
#       Proyecto.ID   Año  \
# 231    HCDN271752  2023
# 1121   HCDN266755  2023
# 2759   HCDN258843  2022
# 18528  HCDN182750  2016
# 19103  HCDN178824  2015
# 21531  HCDN166795  2014
# 21705  HCDN166050  2014
# 22717  HCDN161139  2014
# 26496  HCDN136544  2012
# 28535  HCDN126852  2011
# 30069  HCDN116897  2010
# 32096  HCDN107297  2009
# 32101  HCDN107291  2009
# 32103  HCDN107124  2009
# 32104  HCDN107123  2009
# 32758  HCDN103933  2009
# 32814  HCDN103833  2009
#
#                                                                                                                                                                                                                                                                                                                             Título  \
# 231                                                                                                                                                                                              OBRA SOCIALES - LEY 23660 - Y MEDICINA PREPAGA - LEY 26682- MODIFICACIONES SOBRE PERSONAS QUE POSEEN ALGUN TIPO DE DISCAPACIDAD.
# 1121                                                                                                                     MEDICAMENTOS - LEY 16463 -. MODIFICACION DEL ARTICULO 5 SOBRE LAS CONDICIONES TECNICAS DE IDENTIFICACION DE LA FECHA DE VENCIMIENTO, TIPO DE MEDICAMENTO Y DROGA PARA PERSONAS CON DIFICULTADES VISUALES.
# 2759                                                                                                                                                                                                                                                                CREASE EL REGISTRO NACIONAL DE PERSONAS CON DIABETES TIPO 1.
# 18528  CERTIFICADO MEDICO - APTO FISICO. SE ESTABLECE LA OBLIGATORIEDAD A TODA PERSONA QUE REALICE ACTIVIDADES FISICAS O DEPORTIVAS EN INSTITUCIONES, ACADEMIAS, CENTROS DEPORTIVOS, GIMNASIOS Y TODO OTRO ESTABLECIMIENTO DEDICADO A LA ENSEÑANZA O PRACTICA DE ESTE TIPO DE ACTIVIDADES (REPRODUCCION DEL EXPEDIENTE 1957-D-14).
# 32758                                                                                               CALCETIN PARA CORRECCION DEL PIE EQUINO ACCIONADO COMO VENDAJE DE DOS TIROS, CON ZONAS DE COMPRESION REFORZADAS EN SUS PUNTOS DE ATAQUE, DEL TIPO "PHILIPP". INCORPORACION DE SU COBERTURA COMO PRESTACION MEDICA OBLIGATORIA.
# 32814   TRATAMIENTO DE LAS ENFERMEDADES DEL TIPO ANTICOAGULANTE, INCLUYENDO LA PREVENCION Y DETECCION TEMPRANA EN MUJERES EN EDAD REPRODUCTIVA: INCORPORACION AL PROGRAMA MEDICO OBLIGATORIO (PMO); LOS EMBARAZOS, PARTOS, CESAREAS, PUERPERIO DE MUJERES CON ESTA PATOLOGIA QUEDARAN CUBIERTOS EN EL PLAN MATERNO INFANTIL (PMI).
#
#                                        Resultado
# 231    NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 1121   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 2759   NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 18528  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 19103  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 21531  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 21705  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 22717  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 26496  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 28535  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 30069  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 32096  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 32101  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 32103  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 32104  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 32758  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN
# 32814  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN

# %% [markdown]
# **Comunitario**

# %%
proyectos_relevantes.loc[proyectos_relevantes['comunitario']==True,['Proyecto.ID','Año','Título','Resultado'],].sort_values(by='Año', ascending = False)
# Out:
#       Proyecto.ID   Año  \
# 481    HCDN270295  2023
# 736    HCDN268843  2023
# 1946   HCDN264031  2022
# 4120   HCDN254497  2021
# 6195   HCDN245350  2020
# 7339   HCDN241020  2020
# 8729   HCDN235425  2019
# 12985  HCDN212408  2018
# 18752  HCDN181316  2015
# 18887  HCDN180643  2015
# 25038  HCDN149292  2013
# 28254  HCDN128718  2011
# 28931  HCDN125057  2011
# 31572  HCDN110199  2009
# 31746  HCDN109040  2009
# 32362  HCDN105109  2009
#
#                                                                                                                                                                                                                                                                                                                                                                                                     Título  \
# 481    EMERGENCIA ALIMENTARIA NACIONAL - LEY 27519 - MODIFICACIONES DEL ARTICULO 6 SOBRE PRIORIZAR LOS PAGOS, SIMPLIFICAR Y AGILIZAR LOS PROCEDIMIENTOS ADMINISTRATIVOS Y REDUCIR LOS PLAZOS DE LAS LICITACIONES PUBLICAS DEL ESTADO DE COMPRAS DE ALIMENTOS SECOS Y FRESCOS, PARA COMEDORES Y MERENDEROS INSCRIPTOS EN EL REGISTRO NACIONAL COMUNITARIO DE ORGANIZACIONES DE LA SOCIEDAD CIVIL (RENACOM).
# 736                                                                                                                                                                                                                                                                                                                         REGULACION DEL EJERCICIO DEL PROMOTOR COMUNITARIO EN SALUD / AGENTE SANITARIO.
# 1946                                                                                                                                                                                                                                                                                                   CREASE LA FIGURA DE PROMOTOR/A COMUNITARIO/A DE SALUD Y AGENTE SANITARIO/A - LEY DANIEL CAPPONI -.
# 4120                                                                                                                                                                                                                                                                                                                                                        "PROMOTOR / A COMUNITARIA EN SALUD". CREACION.
# 6195                                                                                                                                                                                                                                                                                                                        CREASE EL PROGRAMA DE ACOMPAÑAMIENTO Y CAPACITACION A REFERENTES COMUNITARIOS.
# 7339                                                                                                                                                                             OTORGAR EL PAGO DE UNA ASIGNACION DE RECONOCIMIENTO NO REMUNERATIVA A TRABAJADORES DE MERENDEROS Y COMEDORES COMUNITARIOS, QUE DESARROLLEN TAREAS DURANTE LA EMERGENCIA SANITARIA EN VIRTUD DE LA PANDEMIA POR COVID-19.
