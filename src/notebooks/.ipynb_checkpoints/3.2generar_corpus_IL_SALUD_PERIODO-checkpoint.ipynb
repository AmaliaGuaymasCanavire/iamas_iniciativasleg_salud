# %% [markdown]
# # 3.2  Generar corpus IL SALUD PERIODO

# %% [markdown]
# Los títulos asociados a iniciativas legislativas de ley presentan en promedio 21 palabras, maximo 125 palabras y mínimo 2 palabras.

# %%
# Importar librerias

from dotenv import load_dotenv
import os
import pandas as pd
import numpy as np
import pickle
import sweetviz as sv
import sys

# Visualización
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.lines import Line2D
import matplotlib.colors as mcolors
from matplotlib import colormaps

from collections import Counter
from itertools import islice

from tqdm import tqdm
tqdm.pandas()

# %%
# Configurar path
load_dotenv() # Cargar las variables de entorno del archivo .env
BASE_DIR =  os.getenv("DIR_BASE")
RESULTADOS_DIR = os.getenv("DIR_DATOS_PROCESADOS") # Acceder a las variables de entorno
sys.path.append(BASE_DIR)
sys.path.append(RESULTADOS_DIR)

pd.set_option('display.max_colwidth', None)

# %%
# Abrir
with open(RESULTADOS_DIR + 'base_texto_df_ley_0924.pkl', 'rb') as file: 
    df = pickle.load(file)
df.head()
# Out:
#   Proyecto.ID  \
# 0  HCDN280534
# 1  HCDN280533
# 2  HCDN280532
# 3  HCDN280531
# 4  HCDN280530
#
#                                                                                                                  Título  \
# 0   ANULENSE LOS DECRETOS 1107/2024 Y 1112/2024, SOBRE MODIFICACIONES EN LAS FUNCIONES DE LAS FUERZAS ARMADAS - FFAA -.
# 1             DEFENSA DEL CONSUMIDOR - LEY 24240 -. MODIFICACION DEL ARTICULO 8 SOBRE IMAGENES HUMANAS EN PUBLICIDADES.
# 2         DEFENSA DEL CONSUMIDOR - LEY 24240 -. MODIFICACION DEL ARTICULO 8 BIS SOBRE TRATO DIGNO Y PRACTICAS ABUSIVAS.
# 3                     CODIGO CIVIL Y COMERCIAL DE LA NACION - LEY 26994 -. MODIFICACIONES SOBRE CONTRATOS DE LOCACION-.
# 4  CODIGO CIVIL Y COMERCIAL DE LA NACION - LEY 26994 -. MODIFICACION DEL ARTICULO 1098 SOBRE PROTECCION DEL CONSUMIDOR.
#
#                                                                                                         Título procesado  \
# 0  anulense los decretos numero numero y numero numero sobre modificaciones en las funciones de las fuerzas armadas ffaa
# 1              defensa del consumidor ley numero modificacion del articulo numero sobre imagenes humanas en publicidades
# 2          defensa del consumidor ley numero modificacion del articulo numero bis sobre trato digno y practicas abusivas
# 3                            codigo civil y comercial de la nacion ley numero modificaciones sobre contratos de locacion
# 4      codigo civil y comercial de la nacion ley numero modificacion del articulo numero sobre proteccion del consumidor
#
#                                          Título normalizado  Cant_token  \
# 0  anulense decreto modificacion funcion fuerza armado ffaa          18
# 1              defensa consumidor  imagen humano publicidad          16
# 2      defensa consumidor  bis trato digno practica abusivo          18
# 3          codigo civil comercial nacion  contrato locacion          16
# 4      codigo civil comercial nacion  proteccion consumidor          19
#
#    Cant_token_normalizado  Proyecto_girado_a_comisiones_SALUD  Proyecto_SALUD  \
# 0                       7                                 0.0             0.0
# 1                       5                                 0.0             0.0
# 2                       7                                 0.0             0.0
# 3                       6                                 0.0             0.0
# 4                       6                                 0.0             0.0
#
#                                    Resultado  Max_Orden  \
# 0  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          3
# 1  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          1
# 2  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          1
# 3  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          2
# 4  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          2
#
#    Tiene_antecedente_por_titulo_proy  Periodo   Año  \
# 0                              False      NaN  2024
# 1                              False      NaN  2024
# 2                              False      NaN  2024
# 3                              False      NaN  2024
# 4                              False      NaN  2024
#
#                                                              Tokens
# 0  [anulense, decreto, modificacion, funcion, fuerza, armado, ffaa]
# 1                 [defensa, consumidor, imagen, humano, publicidad]
# 2       [defensa, consumidor, bis, trato, digno, practica, abusivo]
# 3            [codigo, civil, comercial, nacion, contrato, locacion]
# 4        [codigo, civil, comercial, nacion, proteccion, consumidor]

# %%
df.describe()
# Out:
#          Cant_token  Cant_token_normalizado  \
# count  35179.000000            35179.000000
# mean      21.123682                9.763410
# std       10.691870                5.051387
# min        2.000000                0.000000
# 25%       14.000000                6.000000
# 50%       19.000000                9.000000
# 75%       27.000000               12.000000
# max      125.000000               57.000000
#
#        Proyecto_girado_a_comisiones_SALUD  Proyecto_SALUD     Max_Orden  \
# count                        35179.000000    35179.000000  35179.000000
# mean                             0.127860        0.085761      2.253504
# std                              0.333939        0.280015      0.822105
# min                              0.000000        0.000000      1.000000
# 25%                              0.000000        0.000000      2.000000
# 50%                              0.000000        0.000000      2.000000
# 75%                              0.000000        0.000000      3.000000
# max                              1.000000        1.000000      8.000000
#
#             Periodo           Año
# count  33097.000000  35179.000000
# mean     134.111944   2016.586913
# std        4.075721      4.376397
# min      127.000000   2009.000000
# 25%      131.000000   2013.000000
# 50%      134.000000   2017.000000
# 75%      137.000000   2020.000000
# max      141.000000   2024.000000

# %%
df[df["Cant_token"]==125]
# Out:
#       Proyecto.ID  \
# 32542  HCDN114854
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Título  \
# 32542  CREACION DEL FONDO PARA EL INGRESO CIUDADANO DE LA NIÑEZ (FINCINI), EL CUAL SERA ADMINISTRADO POR LA ANSES; DEROGACION DE LOS INCISOS H), K), W), E Y) DEL ARTICULO 20 DE LA LEY 20628 DE IMPUESTO A LAS GANANCIAS, TO DECRETO 649/97 Y MODIFICATORIAS; DEROGAR DE LA LEY 24714, SUS LEYES Y DECRETOS MODIFICATORIOS DE AQUELLOS BENEFICIOS RELACIONADOS DIRECTAMENTE CON LA NIÑEZ Y DISCAPACIDAD; MODIFICACION DE LOS ARTICULOS 1(REGIMEN DE ASIGNACION FAMILIAR), 5 (FINANCIAMIENTO), 6 (PRESTACIONES) DE LA LEY 24714 Y SUS MODIFICATORIAS; SUSTITUCION DE LOS ARTICULOS 23 (DEDUCCION DE GANANCIAS NETAS) Y 104 (PARTICIPACION DEL FINCINI EN LA DISTRIBUCION DE LO RECAUDADO POR EL IMPUESTO A LAS GANANCIAS) DE LA LEY 20628 DE LA LEY DE IMPUESTO A LAS GANANCIAS, TO POR DECRETO 649/97
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Título procesado  \
# 32542  creacion del fondo para el ingreso ciudadano de la ninez fincini el cual sera administrado por la anses derogacion de los incisos h k w e y del articulo numero de la ley numero de impuesto a las ganancias to decreto numero numero y modificatorias derogar de la ley numero sus leyes y decretos modificatorios de aquellos beneficios relacionados directamente con la ninez y discapacidad modificacion de los articulos numero regimen de asignacion familiar numero financiamiento numero prestaciones de la ley numero y sus modificatorias sustitucion de los articulos numero deduccion de ganancias netas y numero participacion del fincini en la distribucion de lo recaudado por el impuesto a las ganancias de la ley numero de la ley de impuesto a las ganancias to por decreto numero numero
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      Título normalizado  \
# 32542  creacion fondo ingreso ciudadano ninez fincini serar administrar anses derogacion inciso articulo ley impuesto ganancia decreto modificatoria derogar ley ley decreto modificatorio beneficio relacionado directamente ninez discapacidad  regimen asignacion familiar financiamiento prestacion ley modificatoria sustitucion articulo deduccion ganancia neto participacion fincini distribucion recaudado impuesto ganancia ley ley impuesto ganancia decreto
#
#        Cant_token  Cant_token_normalizado  Proyecto_girado_a_comisiones_SALUD  \
# 32542         125                      50                                 1.0
#
#        Proyecto_SALUD                                  Resultado  Max_Orden  \
# 32542             1.0  NO TUVO TRATAMIENTO POSTERIOR NI DICTAMEN          3
#
#        Tiene_antecedente_por_titulo_proy  Periodo   Año  \
# 32542                              False    128.0  2010
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Tokens
# 32542  [creacion, fondo, ingreso, ciudadano, ninez, fincini, serar, administrar, anses, derogacion, inciso, articulo, ley, impuesto, ganancia, decreto, modificatoria, derogar, ley, ley, decreto, modificatorio, beneficio, relacionado, directamente, ninez, discapacidad, regimen, asignacion, familiar, financiamiento, prestacion, ley, modificatoria, sustitucion, articulo, deduccion, ganancia, neto, participacion, fincini, distribucion, recaudado, impuesto, ganancia, ley, ley, impuesto, ganancia, decreto]

# %%
# Seleccionando IL de Salud
df = df[df['Proyecto_SALUD']==1]
print("Conj. de datos de proyecto_SALUD con Nan en Período:",df.shape)
df = df[~df['Periodo'].isna()]
print("Conj. de datos de proyecto_SALUD sin Nan en Período:",df.shape)
# Out:
# Conj. de datos de proyecto_SALUD con Nan en Período: (3017, 14)
# Conj. de datos de proyecto_SALUD sin Nan en Período: (2848, 14)

# %%
df = df[~(df['Título normalizado']==" ")]
print("Conj. de datos de proyecto_SALUD sin título vacio:",df.shape)
# Out:
# Conj. de datos de proyecto_SALUD sin título vacio: (2848, 14)

# %%
df.describe().T
# Out:
#                                      count         mean        std     min  \
# Cant_token                          2848.0    19.251053  10.004802     2.0
# Cant_token_normalizado              2848.0     9.766854   4.657696     1.0
# Proyecto_girado_a_comisiones_SALUD  2848.0     1.000000   0.000000     1.0
# Proyecto_SALUD                      2848.0     1.000000   0.000000     1.0
# Max_Orden                           2848.0     2.445225   0.742946     1.0
# Periodo                             2848.0   134.391152   4.093235   127.0
# Año                                 2848.0  2016.415028   4.105452  2009.0
#
#                                        25%     50%     75%     max
# Cant_token                            12.0    18.0    24.0   125.0
# Cant_token_normalizado                 6.0     9.0    12.0    50.0
# Proyecto_girado_a_comisiones_SALUD     1.0     1.0     1.0     1.0
# Proyecto_SALUD                         1.0     1.0     1.0     1.0
# Max_Orden                              2.0     2.0     3.0     7.0
# Periodo                              131.0   135.0   138.0   141.0
# Año                                 2013.0  2017.0  2020.0  2024.0

# %% [markdown]
# #### N-gramas

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Crear bigramas y trigramas
vectorizer = CountVectorizer(ngram_range=(2,5), min_df=1) # Para n-gramas raros , si consideramos min_df = 1, p90=4
X = vectorizer.fit_transform(df['Título normalizado'])
n_gramas = vectorizer.get_feature_names_out()
frecuencias = X.sum(axis=0).A1
df_ngrams = pd.DataFrame({'ngram': n_gramas, 'frecuencia': frecuencias})
df_ngrams = df_ngrams.sort_values(by='frecuencia', ascending=False)

# %%
df_ngrams.describe() # Se observa n-gramas de n entre 2 a 5 con mínima frecuencia 1
# Out:
#          frecuencia
# count  49548.000000
# mean       1.673165
# std        3.156590
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max      208.000000

# %%
# Mostrar top 50
print(df_ngrams.head(50))

# Visualizar
plt.figure(figsize=(12,6))
sns.barplot(data=df_ngrams.head(50), x='frecuencia', y='ngram', palette='viridis')
plt.title("Top 50 n-gramas más frecuentes")
plt.xlabel("Frecuencia")
plt.ylabel("n-grama")
plt.tight_layout()
plt.show()
# Out:
#                                          ngram  frecuencia
# 37695                        programa nacional         208
# 27461                       medico obligatorio         187
# 37653              programa medico obligatorio         153
# 37652                          programa medico         153
# 32011                          obligatorio pmo         150
# 27500                   medico obligatorio pmo         150
# 37673          programa medico obligatorio pmo         128
# 2417                         ambito ministerio         123
# 28193                         ministerio salud         123
# 2430                   ambito ministerio salud         113
# 43171                             salud nacion         105
# 28200                  ministerio salud nacion         102
# 9947                           creacion ambito         102
# 2433            ambito ministerio salud nacion          96
# 9958                creacion ambito ministerio          93
# 32174                              obra social          87
# 9967          creacion ambito ministerio salud          85
# 11295                           declarar inter          83
# 9969   creacion ambito ministerio salud nacion          75
# 24098                           inter nacional          74
# 11299                  declarar inter nacional          70
# 30105                      nacional prevencion          68
# 10225                        creacion programa          61
# 11453                            declarar zona          57
# 13214                  diagnostico tratamiento          55
# 15400                     emergencia sanitario          53
# 3798                       asignacion familiar          53
# 49434                            zona desastre          52
# 43072                             salud mental          49
# 14773                    ejercicio profesional          49
# 11454                   declarar zona desastre          47
# 11203                      declarar emergencia          44
# 27156                        medicina prepagar          43
# 38895                      proteccion integral          43
# 14322                         economico social          42
# 41391                        registro nacional          40
# 10261               creacion programa nacional          40
# 23532                       instituto nacional          39
# 31039                                nino nina          37
# 46823                      territorio nacional          37
# 12485                      desastre emergencia          36
# 49435                 zona desastre emergencia          36
# 40104                          publico privado          36
# 34053                     persona discapacidad          34
# 43284                           salud publicar          33
# 11455        declarar zona desastre emergencia          33
# 15246                     emergencia economico          33
# 5738                          campana nacional          33
# 40666                            recien nacido          33
# 23897                         integral persona          32
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16316\982629151.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_ngrams.head(50), x='frecuencia', y='ngram', palette='viridis')

# %%
from pprint import pprint
#from gensim import corpora
from collections import defaultdict
from collections import Counter
##################################PASOS DICCIONARIO########################
corpus_norm = list(df['Título normalizado'])
# Tokenizamos
documents_tok = [word.split() for word in corpus_norm]

# Creamos el diccionario (vocabulario)
frequency = defaultdict(int)
for doc in documents_tok:
    for token in doc:
        frequency[token] += 1

# Exploramos todas las palabras para limpiar mejor
#counter = Counter(frequency)
frecuencia_df = pd.DataFrame.from_records(list(frequency.items()), columns = ['token','frecuencia'])
display(frecuencia_df.describe())

fig, ax = plt.subplots(figsize=(5, 10))
frecuencia_df.sort_values('frecuencia', ascending=False).head(50).plot(kind='barh', x = 'token', ax=ax)
ax.set_title('Top 50 palabras más frecuentes')
# Out:
#         frecuencia
# count  3221.000000
# mean      8.635827
# std      31.123107
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       6.000000
# max     836.000000
# Text(0.5, 1.0, 'Top 50 palabras más frecuentes')

# %%
frecuencia_df.sort_values('frecuencia', ascending=False).head(50)
# Out:
#               token  frecuencia
# 2          nacional         836
# 48         creacion         628
# 18         programa         488
# 15          regimen         485
# 120           salud         483
# 64           medico         308
# 5       obligatorio         287
# 80           social         279
# 34          persona         245
# 131             ley         229
# 53         declarar         228
# 77      tratamiento         222
# 23       enfermedad         215
# 49       prevencion         204
# 61         integral         177
# 180      emergencia         175
# 118          ambito         168
# 104             ano         163
# 185       cobertura         160
# 92           nacion         156
# 309             pmo         150
# 25    incorporacion         146
# 128        atencion         141
# 119      ministerio         140
# 169      proteccion         129
# 126     medicamento         128
# 123         sistema         127
# 455  obligatoriedad         126
# 250       sanitario         125
# 237        alimento         123
# 41        promocion         119
# 193         publico         117
# 129        servicio         116
# 175        paciente         113
# 94        ejercicio         112
# 177     profesional         109
# 504      asignacion         108
# 834           covid         104
# 115            nino         102
# 73        deteccion         102
# 495        producto         100
# 173       argentino          94
# 163       provincia          94
# 54          derecho          93
# 75      diagnostico          93
# 227     alimentario          93
# 79        inclusion          92
# 98            inter          91
# 337       actividad          90
# 130            obra          88

# %% [markdown]
# La selección de períodos de cada 5 años se basa a los periodos de presidencia. Es importante tener en cuenta a la hora de comparar el año 2020, dado que fue el año de inicio de pandemía covid 19, en donde se priorizaron proyectos de salud más que en los otros años. Ver notebook de EDA
#
# * Periodo: 10 de diciembre de 2023 al presente
#   Presidente Javier Milei
# Ministro de Defensa
# Dr. Luis Alfonso Petri
#
# * Periodo: 10 de agosto de 2021 al 10 de diciembre de 2023
# Presidente Alberto Fernández
# Ministro de Defensa
# Lic. Jorge Enrique Taiana
#
# * Periodo: 10 de diciembre de 2019 al 10 de Agosto 2021
# Presidente Alberto Fernández
# Ministro de Defensa
# Ing. Agustín Oscar Rossi
#
# * Periodo: 10 de diciembre de 2015 al 10 de diciembre de 2019
# Presidente Mauricio Macri
# Ministro de Defensa
# Ing. Julio César Martínez – 2015-2017
# Dr. Oscar Raúl Aguad – 2017 al 2019
#
# * Periodo: 10 de diciembre de 2011 al 10 de diciembre de 2015
# Presidenta Cristina Fernández de Kirchner. Re-elección
# Ministro de Defensa
# Ing. Agustín Oscar Rossi – 2013 - 2015
# Arturo Puricelli – 2011 - 2013
#
# * Periodo: 10 de diciembre de 2007 al 10 de diciembre de 2011
# Presidenta Cristina Fernández de Kirchner
# Ministro de Defensa
# Arturo Puricelli – 2010 - 2011
# Nilda Garré – 2007 - 2010

# %% [markdown]
# ## Cargar Corpus para los tres períodos

# %%
df['Periodo_5anios'] = 2009
df.loc[(df['Año']>=2014) & (df['Año']<2019), 'Periodo_5anios'] =  2014
df.loc[(df['Año']>=2019), 'Periodo_5anios'] =  2019

# %%
df[['Periodo', 'Año','Periodo_5anios']].describe(include='all')
# Out:
#            Periodo          Año  Periodo_5anios
# count  2848.000000  2848.000000     2848.000000
# mean    134.391152  2016.415028     2014.509129
# std       4.093235     4.105452        3.987237
# min     127.000000  2009.000000     2009.000000
# 25%     131.000000  2013.000000     2009.000000
# 50%     135.000000  2017.000000     2014.000000
# 75%     138.000000  2020.000000     2019.000000
# max     141.000000  2024.000000     2019.000000

# %%
df['Periodo_5anios'].value_counts() # frecuencia absoluto
# Out:
# Periodo_5anios
# 2019    1065
# 2014    1008
# 2009     775
# Name: count, dtype: int64

# %%
import matplotlib.ticker as ticker
sns.color_palette("pastel")

f, ax = plt.subplots(1, 1, figsize=(10, 5))
df['Periodo_5anios'].value_counts().plot.bar(ax=ax)
ax.set_title('Cantidad de IL de ley sobre salud por período')
ax.set_xlabel("Períodos de 5 años")
plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True, nbins=15))
plt.savefig(BASE_DIR+"imagenes/evolucion_IL_periodo.png")
plt.show()

# %%
#concatenando titulos IL
PER5anios_df = df.groupby('Periodo_5anios')['Título normalizado'].progress_apply('.'.join).reset_index() 
PER5anios_df['corpus']= PER5anios_df['Título normalizado'].progress_apply(lambda x: [sent.split() for sent in x.split('.')])
PER5anios_df['corpus'] = PER5anios_df['corpus'].progress_apply(lambda x: [token.remove(' ') if ' ' in token else token  for token in x ])
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 654.24it/s]
# 100%|██████████| 3/3 [00:00<00:00, 389.37it/s]
# 100%|██████████| 3/3 [00:00<00:00, 1623.39it/s]

# %%
print(len(PER5anios_df['corpus'].values[0]))
PER5anios_df['corpus'].values[0]
# Out:
# 775
# [['paro',
#   'cardiorrespiratorio',
#   'espectaculo',
#   'publico',
#   'futbol',
#   'regimen',
#   'presupuesto',
#   'minimo',
#   'necesario',
#   'materia',
#   'prevencion',
#   'atencion',
#   'primaria',
#   'basica'],
#  ['creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion',
#   'registro',
#   'universal',
#   'sanitario',
#   'nacional'],
#  ['incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion',
#   'dosis',
#   'vacuna',
#   'varicela',
#   'caracter',
#   'obligatorio'],
#  ['atencion',
#   'medica',
#   'investigacion',
#   'clinico',
#   'epidemiologico',
#   'capacitacion',
#   'profesional',
#   'deteccion',
#   'diagnostico',
#   'difusion',
#   'tratamiento',
#   'alergia',
#   'alimentario',
#   'declaracion',
#   'inter',
#   'nacional'],
#  ['ley', 'tabaco', 'paquete', 'envase', 'producto', 'elaborado', 'tabaco'],
#  ['pesquisa',
#   'neonatal',
#   'incorporacion',
#   'diverso',
#   'estudio',
#   'recien',
#   'nacido'],
#  ['control',
#   'sanitario',
#   'personal',
#   'embarcacion',
#   'amarrir',
#   'suelo',
#   'argentino',
#   'proveniente',
#   'puerto',
#   'extranjero',
#   'regimen'],
#  ['cobertura',
#   'obra',
#   'social',
#   'entidad',
#   'medicina',
#   'prepagar',
#   'tira',
#   'reactiva',
#   'glucos',
#   'sangre'],
#  ['vacuna',
#   'rotavirus',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['vacuna',
#   'varicela',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['implementacion',
#   'estudio',
#   'oximetria',
#   'pulso',
#   'nino',
#   'recien',
#   'nacido'],
#  ['derecho',
#   'alimentacion',
#   'adecuado',
#   'seguridad',
#   'soberania',
#   'alimentario'],
#  ['establecer',
#   'funcionario',
#   'designado',
#   'director',
#   'subdirector',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'administracion',
#   'nacional',
#   'seguridad',
#   'social',
#   'ans',
#   'gozar',
#   'remuneracion',
#   'equivalente',
#   'nivel',
#   'escalafonario',
#   'grado',
#   'sistema',
#   'nacional',
#   'empleo',
#   'publico'],
#  ['ley',
#   'proteccion',
#   'embarazo',
#   'recien',
#   'nacido',
#   'modificacion',
#   'inciso',
#   'articulo',
#   'gratuidad',
#   'permanencia',
#   'acompanante',
#   'mujer',
#   'situacion',
#   'parto'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regulacion',
#   'kiosco',
#   'escolar'],
#  ['alimento',
#   'bebida',
#   'saludable',
#   'incorporacion',
#   'venta',
#   'maquina',
#   'automatica',
#   'expendedora'],
#  ['garantizar',
#   'disponibilidad',
#   'desfibrilador',
#   'externo',
#   'automatico',
#   'dea',
#   'institucion',
#   'deportivo',
#   'pais',
#   'comprendido',
#   'ley',
#   'ley',
#   'deporte'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'atencion',
#   'tratamiento',
#   'integral',
#   'paciente',
#   'ostomizado'],
#  ['perdido',
#   'audicion',
#   'advertencia',
#   'dispositivo',
#   'movil',
#   'reproduccion',
#   'musica'],
#  ['responsable', 'pila', 'bateria'],
#  ['lucha', 'sedentarismo', 'promocion', 'salud', 'actividad', 'fisico'],
#  ['prevencion', 'contralor', 'radiacion', 'perjudicial', 'salud', 'regimen'],
#  ['ejercicio', 'profesion', 'acompanant', 'terapeutico', 'regimen'],
#  ['campana',
#   'nacional',
#   'prevencion',
#   'concientizacion',
#   'efecto',
#   'nocivo',
#   'abusivo',
#   'videojuego',
#   'creacion'],
#  ['servicio',
#   'nacional',
#   'lucha',
#   'diabetes',
#   'cobertura',
#   'medico',
#   'asistencial',
#   'caracter',
#   'obligatorio'],
#  ['rotavirus', 'incorporar', 'calendario', 'nacional', 'vacunacion'],
#  ['nino',
#   'nacido',
#   'partos',
#   'domiciliario',
#   'regimen',
#   'inscripcion',
#   'registro',
#   'civil',
#   'capacidad',
#   'persona'],
#  ['ley',
#   'servicio',
#   'nacional',
#   'lucha',
#   'diabetes',
#   'modificacion',
#   'actualizacion',
#   'programa',
#   'nacional',
#   'ampliacion',
#   'nivel',
#   'cobertura',
#   'tratamiento',
#   'provision',
#   'integral',
#   'medicamento',
#   'insumo',
#   'reactivo',
#   'diagnostico'],
#  ['incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion',
#   'obligatoriedad',
#   'aplicacion',
#   'vacuna',
#   'rotavirus',
#   'nino',
#   'nina',
#   'edad',
#   'mes'],
#  ['programa', 'federal', 'salud', 'educacion', 'republica'],
#  ['ley', 'servicio', 'nacional', 'lucha', 'diabetes', 'modificacion'],
#  ['establecimiento',
#   'sistema',
#   'prestacion',
#   'basica',
#   'deteccion',
#   'prevencion',
#   'asistencia',
#   'dislexia'],
#  ['proteccion',
#   'integral',
#   'derecho',
#   'maternidad',
#   'paternidad',
#   'situacion',
#   'vulnerabilidad'],
#  ['testeado',
#   'animal',
#   'incluir',
#   'leyenda',
#   'identificatorio',
#   'producto',
#   'comercializado',
#   'pais'],
#  ['sistema',
#   'proteccion',
#   'salud',
#   'estudiante',
#   'terciario',
#   'universitario',
#   'regimen'],
#  ['ejercicio', 'profesional', 'cosmetologia', 'cosmiatrio', 'regimen'],
#  ['encuesta',
#   'nacional',
#   'nutricion',
#   'salud',
#   'discapacidad',
#   'ennsdi',
#   'regimen'],
#  ['observatorio', 'social', 'republica', 'argentino'],
#  ['prevencion',
#   'control',
#   'forma',
#   'transmision',
#   'enfermedad',
#   'chagas',
#   'considerar',
#   'prioritario',
#   'caracter',
#   'urgente',
#   'avance',
#   'concrecion',
#   'vacuna'],
#  ['medicamento',
#   'obligatoriedad',
#   'incluir',
#   'prospecto',
#   'leyenda',
#   'indicar',
#   'cantidad',
#   'contenido',
#   'gluten'],
#  ['proteccion', 'embrion', 'implantado'],
#  ['regulacion', 'parto', 'domiciliario'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'quater',
#   'asignacion',
#   'embarazo',
#   'proteccion',
#   'social'],
#  ['acordado',
#   'resolucion',
#   'direccion',
#   'ejecutivo',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'disponer',
#   'publicacion',
#   'boletin',
#   'oficial'],
#  ['incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'integral',
#   'leche',
#   'medicamentos',
#   'consumo',
#   'padecer',
#   'alergia',
#   'proteina',
#   'leche',
#   'vacuna',
#   'aplv'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'medioambiental',
#   'provincia',
#   'cordoba',
#   'prorrogable',
#   'consecuencia',
#   'incendio',
#   'desatado',
#   'setiembre'],
#  ['acceso',
#   'gratuito',
#   'curso',
#   'ensenanza',
#   'auxilio',
#   'reanimacion',
#   'cardiopulmonar'],
#  ['servicio',
#   'nacional',
#   'lucha',
#   'diabetes',
#   'cobertura',
#   'ciento',
#   'medicamento',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'pauta',
#   'antidiscriminatoria',
#   'ingreso',
#   'laboral'],
#  ['habitante',
#   'acreditar',
#   'padecimiento',
#   'fibromialgia',
#   'fibromiositi',
#   'fibrositi',
#   'sindrome',
#   'fatiga',
#   'cronico',
#   'sensibilidad',
#   'quimico',
#   'multiple',
#   'extension',
#   'beneficio',
#   'ley',
#   'sistema',
#   'proteccion',
#   'integral',
#   'persona',
#   'discapacitada',
#   'accesibilidad',
#   'persona',
#   'movilidad',
#   'reducido',
#   'fondo',
#   'permanente',
#   'recompensa'],
#  ['protesis',
#   'mamaria',
#   'estetico',
#   'permitir',
#   'implante',
#   'persona',
#   'capaz',
#   'anos',
#   'cirugia',
#   'reparadora'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'nina',
#   'nino',
#   'adolescente',
#   'regulacion'],
#  ['prohibicion',
#   'exhibicion',
#   'difusion',
#   'promocion',
#   'anuncio',
#   'publicitario',
#   'cualquiera',
#   'formato',
#   'juego',
#   'azar'],
#  ['declarar',
#   'zona',
#   'emergencia',
#   'catastrofir',
#   'localidad',
#   'caleta',
#   'olivia',
#   'provincia',
#   'santa',
#   'cruz',
#   'obra',
#   'necesario',
#   'normalizar',
#   'servicio',
#   'agua',
#   'potable'],
#  ['juego', 'azar', 'regulacion', 'publicidad', 'promocion', 'consumo'],
#  ['creacion',
#   'unidad',
#   'contencion',
#   'duelo',
#   'ucod',
#   'ambito',
#   'efector',
#   'publico',
#   'privado'],
#  ['declarar', 'inter', 'nacional', 'prevencion', 'control', 'fibromialgia'],
#  ['rotulo',
#   'leyendo',
#   'alimento',
#   'exceso',
#   'grasa',
#   'grasa',
#   'saturada',
#   'azucar',
#   'sodio',
#   'nutrient',
#   'identificacion',
#   'envase'],
#  ['declarar',
#   'zona',
#   'emergencia',
#   'desastre',
#   'plazo',
#   'prorrogable',
#   'territorio',
#   'comprendido',
#   'isla',
#   'apipe',
#   'provincia',
#   'corriente',
#   'consecuencia',
#   'apertura',
#   'compuerta',
#   'represa',
#   'yacyreta'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'modificacion',
#   'institucion',
#   'caracter',
#   'nacional',
#   'obligatorio',
#   'universal',
#   'financiamiento',
#   'monto',
#   'prestacion'],
#  ['creacion', 'programa', 'humanitario', 'nacional', 'salud', 'phunad'],
#  ['incentivo',
#   'economico',
#   'suceptibl',
#   'valoracion',
#   'pecuniario',
#   'producto',
#   'medico',
#   'biologico',
#   'farmaceutico',
#   'otorgado',
#   'profesional',
#   'medico',
#   'disponer',
#   'informar',
#   'situacion',
#   'autoridad',
#   'sanitario',
#   'nacional'],
#  ['derecho', 'salud', 'persona', 'problema', 'adiccion'],
#  ['creacion', 'plan', 'nacional', 'lucha', 'enfermedad', 'alzheimer'],
#  ['instituir',
#   'junio',
#   'ano',
#   'nacional',
#   'lucha',
#   'indebido',
#   'trafico',
#   'ilicito',
#   'droga'],
#  ['ley',
#   'identificacion',
#   'rotulo',
#   'medicamento',
#   'efecto',
#   'secundario',
#   'adverso',
#   'disminuir',
#   'capacidad',
#   'conduccion',
#   'vehiculo',
#   'automotor'],
#  ['bebida',
#   'azucarado',
#   'obligatoriedad',
#   'incluir',
#   'envase',
#   'leyenda',
#   'beber',
#   'bebida',
#   'azucarado',
#   'perjudicial',
#   'salud'],
#  ['regimen', 'promocion', 'desarrollo', 'economia', 'social', 'solidario'],
#  ['individualizacion', 'medicamento', 'sistema', 'braille'],
#  ['declarar',
#   'zona',
#   'emergencia',
#   'litoral',
#   'paranaense',
#   'provincia',
#   'mision',
#   'corriente',
#   'chaco',
#   'santa',
#   'rio',
#   'plazo',
#   'noventa',
#   'prorrogable'],
#  ['obligatoriedad',
#   'comunicar',
#   'ministerio',
#   'salud',
#   'nacion',
#   'oficio',
#   'sentencia',
#   'resolucion',
#   'interlocutoria',
#   'dictado',
#   'proceso',
#   'amparo',
#   'medida',
#   'cautelar',
#   'garantizar',
#   'derecho',
#   'salud'],
#  ['obligatoriedad',
#   'implementar',
#   'medida',
#   'seguridad',
#   'jardin',
#   'maternal',
#   'guarderia',
#   'instalacion',
#   'camara',
#   'circuito',
#   'cerrado',
#   'television',
#   'cctv'],
#  ['prevencion',
#   'suicidio',
#   'regimen',
#   'declarar',
#   'inter',
#   'nacional',
#   'atencion',
#   'medica'],
#  ['ley',
#   'programa',
#   'nutricion',
#   'alimentacion',
#   'nacional',
#   'correccion',
#   'retroactivo',
#   'evolucion',
#   'acumulado',
#   'salario',
#   'minimo',
#   'vital',
#   'movil',
#   'normalizacion',
#   'instituto',
#   'nacional',
#   'estadistica',
#   'censo',
#   'indec'],
#  ['instituir',
#   'marzo',
#   'nacional',
#   'medico',
#   'argentino',
#   'conmemoracion',
#   'nacimiento',
#   'profesor',
#   'doctor',
#   'ramon',
#   'carrillo'],
#  ['rotavirus',
#   'incluir',
#   'aplicacion',
#   'calendario',
#   'nacional',
#   'vacunacion'],
#  ['elaboracionir',
#   'plan',
#   'nacional',
#   'contingencia',
#   'caida',
#   'ceniza',
#   'volcanica'],
#  ['instalacion',
#   'videocamara',
#   'circuito',
#   'cerrado',
#   'jardin',
#   'infante',
#   'jardin',
#   'maternal',
#   'guarderia',
#   'geriatrico',
#   'regimen'],
#  ['reparacion',
#   'integral',
#   'igualitario',
#   'familiar',
#   'victima',
#   'fatal',
#   'victima',
#   'sobrevivient',
#   'masacre',
#   'cromanon'],
#  ['ley', 'nacional', 'salud'],
#  ['prevencion',
#   'lavado',
#   'activo',
#   'actividad',
#   'juegos',
#   'azar',
#   'regimen',
#   'modificacion'],
#  ['creacion',
#   'registro',
#   'unico',
#   'dador',
#   'voluntario',
#   'sangre',
#   'hemocomponent',
#   'nacion'],
#  ['regimen', 'proteccion', 'integral', 'persona', 'trasplantado'],
#  ['establecimiento', 'geriatrico', 'regimen'],
#  ['establecer',
#   'obligatoriedad',
#   'exhibir',
#   'listado',
#   'actualizado',
#   'centro',
#   'salud',
#   'farmacia',
#   'turno',
#   'correspondiente',
#   'localidad',
#   'encontrar',
#   'efector',
#   'salud'],
#  ['codigo',
#   'alimentario',
#   'argentino',
#   'porcentaje',
#   'jugo',
#   'bebida',
#   'alcohol'],
#  ['trastorno',
#   'generalizado',
#   'desarrollo',
#   'tgd',
#   'incorporar',
#   'cobertura',
#   'diagnostico',
#   'tratamiento',
#   'demas',
#   'prestacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['enfermedad',
#   'zoonotica',
#   'declarar',
#   'inter',
#   'nacional',
#   'prevencion',
#   'lucha',
#   'creasar',
#   'linea',
#   'gratuito',
#   'recepcion',
#   'denuncia'],
#  ['provision',
#   'agua',
#   'consumo',
#   'personal',
#   'centro',
#   'deportivo',
#   'club',
#   'gimnasio',
#   'publico',
#   'privado'],
#  ['obligatoriedad',
#   'identificacion',
#   'alimento',
#   'contengan',
#   'organismo',
#   'geneticamente',
#   'modificado',
#   'ogm',
#   'derivado'],
#  ['servicio', 'nacional', 'lucha', 'diabetes', 'cobertura', 'obra', 'social'],
#  ['adopcion', 'regimen', 'concientizacion', 'asistencia'],
#  ['consejo', 'nacional', 'evaluacion', 'programa', 'social', 'creacion'],
#  ['ley',
#   'trastorno',
#   'alimentario',
#   'inclusion',
#   'descripcion',
#   'contenido',
#   'calorico',
#   'alimento',
#   'preparado',
#   'envasar',
#   'vista',
#   'consumidor'],
#  ['exigencia',
#   'instalacion',
#   'camara',
#   'circuito',
#   'cerrado',
#   'television',
#   'jardin',
#   'maternal',
#   'guarderia',
#   'geriatrico'],
#  ['ley',
#   'salud',
#   'publicar',
#   'sancion',
#   'omision',
#   'notificacion',
#   'obligatorio',
#   'caso',
#   'enfermedad',
#   'infeccioso'],
#  ['trasplante', 'organo', 'material', 'anatomico', 'gasto', 'donante'],
#  ['obra',
#   'social',
#   'empresa',
#   'medicina',
#   'prepagar',
#   'ampliacion',
#   'cobertura',
#   'leche',
#   'maternizado',
#   'medicamentos'],
#  ['derecho',
#   'paciente',
#   'relacion',
#   'profesional',
#   'institucion',
#   'salud',
#   'ley',
#   'sustitucion',
#   'articulo',
#   'asiento',
#   'historia',
#   'clinico'],
#  ['codigo',
#   'alimentario',
#   'nacional',
#   'agua',
#   'potable',
#   'agua',
#   'gasificado',
#   'respectivamente'],
#  ['obligatoriedad',
#   'identificar',
#   'rotulado',
#   'claramente',
#   'visible',
#   'empaque',
#   'producto',
#   'geneticamente',
#   'modificado',
#   'origen',
#   'transgenico'],
#  ['refugio', 'digno', 'regimen'],
#  ['informacion',
#   'consumidor',
#   'etiquetado',
#   'alimento',
#   'bebida',
#   'transgenico',
#   'contener',
#   'organismo',
#   'geneticamente',
#   'modificado'],
#  ['informacion',
#   'consumidor',
#   'etiquetado',
#   'bebida',
#   'contenido',
#   'calorico',
#   'etiquetado',
#   'bebida',
#   'alcoholica'],
#  ['incorporacion',
#   'calendario',
#   'control',
#   'oftalmologico',
#   'examen',
#   'visual',
#   'plan',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'vigente'],
#  ['programa',
#   'nacional',
#   'prevencion',
#   'tratamiento',
#   'rehabilitacion',
#   'seguimiento',
#   'accidente',
#   'cerebrovascular',
#   'acv',
#   'acvo',
#   'creacion'],
#  ['creacion',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'derogacion',
#   'ley',
#   'modificatoria',
#   'decreto'],
#  ['programa',
#   'probienestar',
#   'sustituir',
#   'complemento',
#   'alimentario',
#   'otorgado',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'suma',
#   'dinero',
#   'equivalente'],
#  ['plan', 'nacional', 'lucha', 'enfermedad', 'alzheimer', 'creacion'],
#  ['instalacion',
#   'desfibrilador',
#   'externo',
#   'automatico',
#   'espacio',
#   'publico',
#   'privado'],
#  ['inundacion',
#   'ocurrido',
#   'abril',
#   'declarar',
#   'zona',
#   'desastre',
#   'prorrogable',
#   'diverso',
#   'barrio',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'diverso',
#   'localidad',
#   'provincia',
#   'aires'],
#  ['respuesta', 'solidario', 'inundacion', 'abril'],
#  ['declarar',
#   'emergencia',
#   'social',
#   'economio',
#   'habitacional',
#   'causa',
#   'inundacion',
#   'ocurrido',
#   'abril',
#   'afectar',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'provincia',
#   'aires',
#   'ciudad',
#   'plata',
#   'localidad',
#   'conurbano',
#   'bonaerense'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'establecimiento',
#   'regimen',
#   'reparacion',
#   'asistencia',
#   'favor',
#   'damnificado',
#   'inundacion',
#   'acaecido',
#   'abril',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'diverso',
#   'partido',
#   'provincia',
#   'aires'],
#  ['creacion', 'plan', 'nacional', 'enfermedad', 'alzheimer', 'demencia'],
#  ['asignacion', 'familiar', 'asignacion', 'ayuda', 'escolar'],
#  ['comercializacion', 'especialidad', 'medicinal', 'regulacion'],
#  ['instituto',
#   'nacional',
#   'promocion',
#   'salud',
#   'calidad',
#   'vida',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'termino',
#   'ciento',
#   'ochenta',
#   'prorrogable',
#   'distrito',
#   'plata',
#   'berisso',
#   'ensenada',
#   'provincia',
#   'ari'],
#  ['creacion', 'fondo', 'integral', 'reparacion', 'victima', 'inundacion'],
#  ['creacion',
#   'plan',
#   'nacional',
#   'solucion',
#   'integral',
#   'persona',
#   'afectado',
#   'inundacion'],
#  ['subsidio',
#   'especial',
#   'reparacion',
#   'victima',
#   'inundacion',
#   'ocurrido',
#   'abril',
#   'creacion'],
#  ['diverso',
#   'zona',
#   'provincia',
#   'aires',
#   'barrio',
#   'ciudad',
#   'autonoma',
#   'aires',
#   'declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social'],
#  ['incremento',
#   'asignacion',
#   'familiar',
#   'modificacion',
#   'parrafo',
#   'articulo',
#   'ley'],
#  ['obra',
#   'social',
#   'mutual',
#   'cooperativo',
#   'asociacion',
#   'entidad',
#   'cuidado',
#   'salud',
#   'recupero',
#   'costo',
#   'prestacion',
#   'caso',
#   'afiliado',
#   'doble',
#   'cobertura'],
#  ['creacion',
#   'asignacion',
#   'universal',
#   'ayuda',
#   'escolar',
#   'ley',
#   'asignacion',
#   'familiar',
#   'derogacion',
#   'inciso',
#   'articulo',
#   'articulo',
#   'inciso',
#   'articulo',
#   'articulo'],
#  ['regulacion',
#   'publicidad',
#   'promocion',
#   'consumo',
#   'producto',
#   'elaborado',
#   'tabaco',
#   'ley',
#   'numerir',
#   'modificacion',
#   'composicion',
#   'producto'],
#  ['creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion',
#   'registro',
#   'unico',
#   'tumor',
#   'maligno'],
#  ['incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'leches',
#   'medicamentosa',
#   'consumido',
#   'sufrir',
#   'alergia',
#   'proteina',
#   'leche',
#   'vacuna',
#   'aplv',
#   'sufrir',
#   'padecer',
#   'desorden',
#   'enfermedad',
#   'trastorno',
#   'gastrointestinal',
#   'eosinofilico'],
#  ['promover',
#   'difusion',
#   'concientizacion',
#   'relevancia',
#   'lavado',
#   'mano',
#   'accion',
#   'eficaz',
#   'prevenir',
#   'enfermedad',
#   'transmisibl',
#   'contacto'],
#  ['edificacion',
#   'centro',
#   'integral',
#   'rehabilitacion',
#   'persona',
#   'enfermedad',
#   'adiccion',
#   'atencion',
#   'salud',
#   'mental',
#   'denominado',
#   'san',
#   'expedito',
#   'municipio',
#   'mojon',
#   'provincia',
#   'mision'],
#  ['programa', 'nacional', 'prevencion', 'cancer', 'prostata', 'creacion'],
#  ['obligacion',
#   'indicar',
#   'etiqueta',
#   'producto',
#   'alimenticio',
#   'sustancia',
#   'alimenticio',
#   'bebida',
#   'cuyo',
#   'caracteristica',
#   'adaptar',
#   'consumo',
#   'persona',
#   'diabetica',
#   'leyenda',
#   'apto',
#   'diabetico'],
#  ['atencion',
#   'victima',
#   'delito',
#   'sexual',
#   'prevencion',
#   'enfermedad',
#   'regimen'],
#  ['jubilacion',
#   'pension',
#   'servicio',
#   'medico',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'persona',
#   'ano',
#   'edad',
#   'sexo',
#   'femenino',
#   'ano',
#   'edad',
#   'persona',
#   'sexo',
#   'masculino',
#   'acreditar',
#   'domicilio',
#   'pais',
#   'lapso',
#   'inferior',
#   'anos'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'ley', 'regulacion'],
#  ['ejercicio',
#   'profesion',
#   'terapeuta',
#   'ocupacional',
#   'terapista',
#   'ocupacional',
#   'licenciado',
#   'terapia',
#   'ocupacional',
#   'regimen'],
#  ['creacion',
#   'servicio',
#   'obligatorio',
#   'social',
#   'ciudadano',
#   'argentino',
#   'servicio',
#   'nacional',
#   'revestir',
#   'servicio',
#   'comunitario',
#   'servicio',
#   'militar',
#   'voluntario',
#   'tratamiento',
#   'rehabilitacion',
#   'adiccion'],
#  ['regimen', 'soberania', 'alimentario'],
#  ['obligatoriedad',
#   'rotulacion',
#   'adecuado',
#   'informar',
#   'fecha',
#   'vencimiento',
#   'producto',
#   'especialidad',
#   'medicinal'],
#  ['presupuesto',
#   'minimo',
#   'prevencion',
#   'accidente',
#   'grave',
#   'intervengar',
#   'sustancia',
#   'peligroso'],
#  ['modificacion',
#   'escala',
#   'prestacion',
#   'asignacion',
#   'hijo',
#   'asignacion',
#   'ayuda',
#   'escolar',
#   'anual',
#   'regimen',
#   'asignacion',
#   'familiar',
#   'ley'],
#  ['asistencia',
#   'alimentario',
#   'especial',
#   'paciente',
#   'diabetico',
#   'situacion',
#   'vulnerabilidad',
#   'inclusion',
#   'programa',
#   'asistencia',
#   'alimentario'],
#  ['programa',
#   'federal',
#   'desarrollo',
#   'tratamiento',
#   'efectivo',
#   'alzheimer',
#   'enfermedad',
#   'neurodegenerativo',
#   'relacionado',
#   'creacion'],
#  ['nacional',
#   'instituto',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'pami',
#   'instituir',
#   'mayo',
#   'ano'],
#  ['suplemento',
#   'dietario',
#   'creatin',
#   'monohidratado',
#   'comercializacion',
#   'exclusivo',
#   'farmacia',
#   'habilitado',
#   'prohibicion'],
#  ['hepatitis',
#   'incorporar',
#   'integrante',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'diagnostico',
#   'tratamiento'],
#  ['planta',
#   'medicinal',
#   'droga',
#   'vegetal',
#   'medicamento',
#   'fitoterapicos',
#   'promocion',
#   'distribucion',
#   'expendio',
#   'regimen',
#   'derogacion',
#   'articulo',
#   'ejercicio',
#   'actividad',
#   'farmaceutico'],
#  ['medicamento', 'braille', 'regimen'],
#  ['cuidado',
#   'paliativo',
#   'promover',
#   'muerte',
#   'natural',
#   'digno',
#   'creacion',
#   'comision',
#   'nacional',
#   'cuidado',
#   'paliativo',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['examen', 'medico', 'prenupcial'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'recoleccion',
#   'medicamento',
#   'vencido',
#   'domiciliario'],
#  ['celula',
#   'madr',
#   'cordon',
#   'umbilical',
#   'capacitacion',
#   'almacenamiento',
#   'investigacion',
#   'aplicacion',
#   'donacion',
#   'obligatorio',
#   'anonimo',
#   'gratuito'],
#  ['pediculosis',
#   'implementar',
#   'campana',
#   'lucha',
#   'transcurso',
#   'ano',
#   'lectivo'],
#  ['enfermedad',
#   'cronico',
#   'psoriasis',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'inclusion',
#   'resolucion',
#   'cobertura',
#   'medicamento'],
#  ['plan',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'inclusion',
#   'tratamiento',
#   'laser',
#   'malformacion',
#   'vascular',
#   'congenita',
#   'adquirido',
#   'llamado',
#   'mancha',
#   'vino',
#   'oporto'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'ciento',
#   'ochenta',
#   'prorrogable',
#   'diverso',
#   'municipio',
#   'valle',
#   'rio',
#   'negro'],
#  ['jardin',
#   'maternal',
#   'guarderia',
#   'geriatrico',
#   'centro',
#   'similar',
#   'caracteristica',
#   'instalacion',
#   'equipo',
#   'herramienta',
#   'tecnologica',
#   'permitir',
#   'monitoreo',
#   'permanente',
#   'dependencia',
#   'utilizar',
#   'prestar',
#   'servicio',
#   'albergue',
#   'atencion',
#   'cuidado'],
#  ['considerese',
#   'psoriasis',
#   'enfermedad',
#   'cronico',
#   'incluyendolo',
#   'resolucion',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['regular',
#   'acceso',
#   'gratuito',
#   'agua',
#   'beber',
#   'lugar',
#   'acceso',
#   'publico'],
#  ['creacion', 'region', 'sanitario', 'aires'],
#  ['sistema',
#   'integral',
#   'proteccion',
#   'persona',
#   'discapacitada',
#   'ley',
#   'efecto',
#   'articulo',
#   'considerar',
#   'persona',
#   'discapacidad',
#   'visceral',
#   'afectado',
#   'trastorno',
#   'hereditario',
#   'hemoglobina',
#   'requerir',
#   'tratamiento',
#   'permanente',
#   'sobrevivir',
#   'incorporacion',
#   'prestacion',
#   'obligatorio',
#   'obra',
#   'social',
#   'agente',
#   'salud'],
#  ['asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ley',
#   'decreto',
#   'actualizacion',
#   'periodico',
#   'automatico',
#   'modificar',
#   'salario',
#   'minimo',
#   'vital',
#   'movil'],
#  ['soberania', 'alimentario', 'regimen'],
#  ['programa',
#   'federal',
#   'equinoterapia',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['protector', 'solar', 'obligatoriedad', 'cobertura', 'obra', 'social'],
#  ['registro',
#   'nacional',
#   'infeccion',
#   'intrahospitalaria',
#   'nosocomial',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['maquina',
#   'tragamonedas',
#   'creasar',
#   'impuesto',
#   'emergencia',
#   'explotacion',
#   'mejorar',
#   'jubilacion',
#   'pension',
#   'minima',
#   'subsidio',
#   'persona',
#   'discapacidad'],
#  ['asignacion',
#   'familiar',
#   'ajuste',
#   'ayuda',
#   'escolar',
#   'anual',
#   'coeficiente',
#   'zonal',
#   'respectivamente'],
#  ['persona',
#   'enferma',
#   'miastenia',
#   'gravis',
#   'semana',
#   'lucha',
#   'miastenia',
#   'gravis',
#   'instituyase',
#   'junio',
#   'ano',
#   'semana',
#   'mes',
#   'comprender',
#   'respectivamente'],
#  ['creacion',
#   'regimen',
#   'represion',
#   'penal',
#   'juego',
#   'azar',
#   'apuesta',
#   'mutuo',
#   'actividad',
#   'conexa',
#   'caracter',
#   'clandestino'],
#  ['programa',
#   'nacional',
#   'universal',
#   'obligatorio',
#   'nutricion',
#   'infantil',
#   'estimulacion',
#   'pronin',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['regimen',
#   'especial',
#   'donacion',
#   'alimento',
#   'creacion',
#   'registro',
#   'nacional',
#   'entidad',
#   'receptor',
#   'donacion',
#   'alimenticio'],
#  ['ejercicio', 'enfermeria', 'resguardo', 'salud', 'fisico', 'psiquico'],
#  ['persona',
#   'nacido',
#   'fertilizacion',
#   'asistido',
#   'acceso',
#   'informacion',
#   'referente',
#   'identidad',
#   'genetico'],
#  ['calendario',
#   'nacional',
#   'vacunacion',
#   'incorporacion',
#   'obligatoriedad',
#   'gratuidad',
#   'administracion',
#   'vacuna',
#   'rotavirus',
#   'nino',
#   'mes'],
#  ['regimen', 'asignacion', 'familiar', 'actualizacion', 'beneficio'],
#  ['ley',
#   'celiaquia',
#   'ley',
#   'reduccion',
#   'alicuota',
#   'impuesto',
#   'valor',
#   'agregado',
#   'iva',
#   'producto',
#   'libre',
#   'gluten',
#   'destinado',
#   'persona',
#   'celiaca'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporacion',
#   'cobertura',
#   'tratamiento',
#   'psoriasis'],
#  ['responsable',
#   'pila',
#   'bateria',
#   'indicacion',
#   'advertencia',
#   'contaminacion',
#   'ambiental',
#   'envase',
#   'producto',
#   'requeir',
#   'utilizacion'],
#  ['regimen',
#   'asistencia',
#   'proteccion',
#   'integral',
#   'persona',
#   'trasplantado'],
#  ['regulacion',
#   'implementacion',
#   'politica',
#   'publicar',
#   'control',
#   'enfermedad',
#   'prevenibl',
#   'vacunacion'],
#  ['instituto',
#   'nacional',
#   'enfermedad',
#   'visual',
#   'inevi',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['obligatoriedad',
#   'contar',
#   'asiento',
#   'especial',
#   'obeso',
#   'reparticion',
#   'estatal',
#   'local',
#   'privado',
#   'atencion',
#   'publico'],
#  ['nacional', 'fibrosis', 'quistico', 'instituir', 'septiembre', 'ano'],
#  ['soberania',
#   'alimentario',
#   'instituir',
#   'octubre',
#   'ano',
#   'inclusion',
#   'calendario',
#   'escolar'],
#  ['epidermis',
#   'bulos',
#   'creacion',
#   'sistema',
#   'proteccion',
#   'integral',
#   'persona',
#   'padecer',
#   'enfermedad'],
#  ['accidente',
#   'cerebrovascular',
#   'acv',
#   'acvo',
#   'regimen',
#   'promover',
#   'prevencion',
#   'tratamiento',
#   'rehabilitacion',
#   'seguimiento',
#   'paciente'],
#  ['hotel',
#   'restaurante',
#   'confiteria',
#   'caf',
#   'obligatoriedad',
#   'incluir',
#   'menu',
#   'apto',
#   'diabetico'],
#  ['fortalecimiento',
#   'financiero',
#   'red',
#   'publicar',
#   'estatal',
#   'servicio',
#   'salud',
#   'regimen'],
#  ['lealtad', 'actividad', 'solidario', 'regimen'],
#  ['ejercicio', 'enfermeria', 'regimen', 'reforma', 'ley'],
#  ['registro',
#   'unico',
#   'voluntario',
#   'donante',
#   'sangre',
#   'hemocomponent',
#   'persona',
#   'cuyo',
#   'grupo',
#   'sanguineo',
#   'grupo',
#   'factor',
#   'cero',
#   'negativo',
#   'universal',
#   'creacion'],
#  ['programa',
#   'nacional',
#   'enfermedad',
#   'neurologica',
#   'cronica',
#   'pnenc',
#   'creacion'],
#  ['persona',
#   'ostomizada',
#   'incluir',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'tratamiento'],
#  ['fondo', 'ingreso', 'ciudadano', 'ninez', 'fincini', 'creacion'],
#  ['perdido',
#   'audicion',
#   'advertencia',
#   'dispositivo',
#   'movil',
#   'reproduccion',
#   'musica'],
#  ['comit', 'salud', 'condicion', 'ambiente', 'trabajo', 'creacion'],
#  ['desfibrilador',
#   'externo',
#   'automatico',
#   'establecer',
#   'instalacion',
#   'espacio',
#   'publico',
#   'cardioprotegido',
#   'cardioseguro'],
#  ['programa',
#   'nacional',
#   'nutricion',
#   'alimentacion',
#   'promocion',
#   'compra',
#   'alimento',
#   'producido',
#   'agricultor',
#   'inscripto',
#   'registro',
#   'nacional',
#   'agricultura',
#   'familiar',
#   'renaf'],
#  ['recurso',
#   'humano',
#   'anestesiologio',
#   'declaracion',
#   'emergencia',
#   'nacional',
#   'creacion',
#   'plan',
#   'nacional',
#   'desarrollo',
#   'anestesiologia'],
#  ['declarar',
#   'aceite',
#   'oliva',
#   'alimento',
#   'nacional',
#   'implementacion',
#   'programa',
#   'federal',
#   'promocion'],
#  ['investigacion', 'biomedico', 'humano', 'regulacion'],
#  ['alimento',
#   'golosina',
#   'apto',
#   'celiaco',
#   'obligatoriedad',
#   'comercializacion',
#   'establecimiento',
#   'educativo'],
#  ['inclusion',
#   'tratamiento',
#   'enfermedad',
#   'linfedema',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['creacion', 'consejo', 'nacional', 'bioetica'],
#  ['regimen',
#   'trazabilidad',
#   'verificacion',
#   'aptitud',
#   'tecnico',
#   'recurso',
#   'tecnologico',
#   'salud'],
#  ['necropsio',
#   'obligatoriedad',
#   'practica',
#   'muerte',
#   'extrainstitucional',
#   'nino',
#   'menor',
#   'ano',
#   'mediacion',
#   'intervencion',
#   'judicial'],
#  ['programa',
#   'federal',
#   'salud',
#   'profe',
#   'disponer',
#   'transferencia',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp'],
#  ['declarar',
#   'inter',
#   'camaro',
#   'xii',
#   'congreso',
#   'argentino',
#   'congreso',
#   'internacional',
#   'epidemiologia',
#   'control',
#   'infeccion',
#   'seguridad',
#   'paciente',
#   'realizar',
#   'el',
#   'septiembre',
#   'ciudad',
#   'autonoma',
#   'aires'],
#  ['creacion',
#   'marco',
#   'anses',
#   'registro',
#   'unico',
#   'beneficiario',
#   'plan',
#   'social',
#   'ministerio',
#   'desarrollo',
#   'social',
#   'nacion'],
#  ['garantiar',
#   'nacional',
#   'dignidad',
#   'integridad',
#   'confidencialidad',
#   'identidad',
#   'profesional',
#   'investigacion',
#   'salud'],
#  ['incorporacion', 'alimento', 'bebida', 'saludable', 'maquina', 'expendedor'],
#  ['institucion', 'paciente', 'junio', 'ano'],
#  ['ley',
#   'lucha',
#   'sida',
#   'universalizacion',
#   'realizacion',
#   'test',
#   'vih',
#   'mujer',
#   'embarazado'],
#  ['establecimiento',
#   'productivo',
#   'capacitacion',
#   'rehabilitacion',
#   'salud',
#   'mental',
#   'creacion'],
#  ['garantizar',
#   'cobertura',
#   'basico',
#   'menor',
#   'edad',
#   'sufrir',
#   'intolerancia',
#   'lactos'],
#  ['estudio',
#   'oximetria',
#   'pulso',
#   'nino',
#   'recien',
#   'nacido',
#   'implementacion',
#   'ley'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regulacion',
#   'kiosco',
#   'escolar'],
#  ['fondo',
#   'nacional',
#   'especial',
#   'atencion',
#   'enfermedad',
#   'catastrofica',
#   'creacion'],
#  ['promocion',
#   'alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regulacion',
#   'kiosco',
#   'escolar'],
#  ['ley',
#   'presupuesto',
#   'minimo',
#   'gestion',
#   'ambiental',
#   'agua',
#   'elaboracion',
#   'relevamiento',
#   'consumo'],
#  ['comite',
#   'especialista',
#   'analisis',
#   'estudio',
#   'investigacion',
#   'prevencion',
#   'morbimortalidad',
#   'materno',
#   'traves',
#   'comit',
#   'hospitalarios',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['comida',
#   'hipercalorico',
#   'declarar',
#   'inter',
#   'nacional',
#   'lucha',
#   'proteccion',
#   'salud',
#   'nino',
#   'adolescente'],
#  ['obra', 'social', 'administracion', 'obra', 'social'],
#  ['percloroetileno',
#   'prohibicion',
#   'tintoreria',
#   'lavanderia',
#   'radicado',
#   'territorio',
#   'nacional'],
#  ['ejercicio', 'profesional', 'musicoterapia', 'regimen'],
#  ['sistema', 'historia', 'clinico', 'digital', 'creacion'],
#  ['sodio', 'regimen', 'promover', 'reduccion', 'consumo', 'poblacion'],
#  ['ejercicio',
#   'profesional',
#   'partero',
#   'licenciado',
#   'obstetrico',
#   'regulacion'],
#  ['declarar',
#   'nacional',
#   'argentina',
#   'chagas',
#   'viernes',
#   'mes',
#   'agosto',
#   'ano'],
#  ['prevencion',
#   'control',
#   'forma',
#   'transmision',
#   'enfermedad',
#   'chagas',
#   'realizacion',
#   'examen',
#   'forma',
#   'gratuito',
#   'establecimiento',
#   'sanitario',
#   'oficial',
#   'creacion',
#   'hospital',
#   'publico',
#   'consultorio',
#   'chaga',
#   'respectivamente'],
#  ['alimento',
#   'bebida',
#   'saludable',
#   'incorporacion',
#   'venta',
#   'maquina',
#   'automatica',
#   'expendedora'],
#  ['asignacion',
#   'familiar',
#   'top',
#   'salarial',
#   'acceder',
#   'beneficio',
#   'ajuste',
#   'automatico'],
#  ['declarar', 'abril', 'ano', 'cardiologia', 'argentino'],
#  ['salud',
#   'publicar',
#   'derecho',
#   'paciente',
#   'relacion',
#   'profesional',
#   'institucion',
#   'salud',
#   'ley',
#   'incorporacion',
#   'inciso',
#   'articulo',
#   'excepcion',
#   'consentimiento',
#   'informado',
#   'caso',
#   'vacunacion',
#   'obligatorio'],
#  ['daltonismo',
#   'declarar',
#   'inter',
#   'nacional',
#   'actividad',
#   'destinado',
#   'mitigar',
#   'contrarrestar',
#   'consecuencia'],
#  ['asignacion',
#   'familiar',
#   'ley',
#   'derogacion',
#   'articulo',
#   'exclusion',
#   'prestacion',
#   'eliminacion',
#   'top',
#   'maximo',
#   'remuneracion',
#   'establecido',
#   'articulo'],
#  ['amparo', 'alimentario', 'regimen'],
#  ['medicina', 'prepagar', 'sancion', 'incumplimiento'],
#  ['impuesto',
#   'emergencia',
#   'complementario',
#   'actividad',
#   'explotacion',
#   'privado',
#   'juego',
#   'azar',
#   'concesionada',
#   'loteria',
#   'nacional',
#   'sociedad',
#   'creacion'],
#  ['alimentacion',
#   'saludable',
#   'seguro',
#   'nino',
#   'nina',
#   'adolescente',
#   'edad',
#   'escolar',
#   'regimen',
#   'promocion',
#   'prevencion'],
#  ['muerte',
#   'subitar',
#   'regimen',
#   'prevencion',
#   'espacio',
#   'publico',
#   'privado',
#   'acceso',
#   'publico'],
#  ['reproduccion', 'humano', 'asistido', 'regimen'],
#  ['ley',
#   'enfermedad',
#   'celiaco',
#   'inclusion',
#   'menu',
#   'gastronomico',
#   'alimento',
#   'leyenda',
#   'libre',
#   'gluten'],
#  ['fertilizacion', 'humano', 'asistido'],
#  ['obra',
#   'social',
#   'inciso',
#   'articulo',
#   'continuidad',
#   'categoria',
#   'beneficiario',
#   'periodo',
#   'mes',
#   'contado',
#   'extincion'],
#  ['hipermercado',
#   'supermercado',
#   'cadena',
#   'comercio',
#   'alimento',
#   'bebida',
#   'obligatoriedad',
#   'incluir',
#   'gondola',
#   'alimento',
#   'bebida',
#   'apto',
#   'diabetico'],
#  ['nacional', 'medico', 'argentino', 'instituir', 'julio', 'ano'],
#  ['diverso',
#   'localidad',
#   'provincia',
#   'aires',
#   'declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'hidrico',
#   'economico',
#   'social',
#   'agropecuario',
#   'termino',
#   'prorrogable'],
#  ['declarar',
#   'emergencia',
#   'nacional',
#   'recurso',
#   'humano',
#   'enfermeria',
#   'promover',
#   'inclusion',
#   'articulo',
#   'ley',
#   'educacion',
#   'superior'],
#  ['creacion',
#   'fondo',
#   'promocion',
#   'difusion',
#   'educacion',
#   'salud',
#   'prevencion',
#   'enfermedad'],
#  ['diverso',
#   'departamento',
#   'provincia',
#   'rioja',
#   'declaracion',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'prorrogable',
#   'consecuencia',
#   'crecida',
#   'rio',
#   'tormenta',
#   'ocurrido',
#   'mes',
#   'enero',
#   'febrero'],
#  ['fertilizacion',
#   'asistido',
#   'inclusion',
#   'tratamiento',
#   'plan',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['sangre', 'informacion', 'relacionado', 'salud', 'donante', 'receptor'],
#  ['vacuna',
#   'virus',
#   'papiloma',
#   'humano',
#   'tipo',
#   'incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion',
#   'caracter',
#   'gratuito',
#   'obligatorio',
#   'mujer',
#   'anos',
#   'edad'],
#  ['obligatoriedad',
#   'examen',
#   'oftalmologico',
#   'caracter',
#   'anual',
#   'neonato',
#   'recien',
#   'nacido',
#   'nino',
#   'comprendido',
#   'etapa',
#   'infancia',
#   'anos',
#   'edad'],
#  ['declarar',
#   'inter',
#   'prioritario',
#   'sanitario',
#   'territorio',
#   'republica',
#   'argentino',
#   'enfermedad',
#   'alzheimer',
#   'demencia',
#   'senil'],
#  ['lent',
#   'pre',
#   'graduado',
#   'sol',
#   'autorizado',
#   'recetado',
#   'prohibir',
#   'importacion',
#   'distribucion',
#   'comercializacion',
#   'venta'],
#  ['producto', 'elaborado', 'tabaco', 'reduccion', 'consumo'],
#  ['sodio', 'regulacion', 'contenido', 'industria', 'alimentacion'],
#  ['regimen', 'fertilizacion', 'humano', 'asistido'],
#  ['creacion', 'plan', 'federal', 'formacion', 'empleo', 'enfermero'],
#  ['vacuna',
#   'rotavirus',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['nacional',
#   'reivindicacion',
#   'derecho',
#   'social',
#   'instituir',
#   'mayo',
#   'ano',
#   'conmemoracion',
#   'natalicio',
#   'maria',
#   'eva',
#   'duartar'],
#  ['declarar',
#   'nacional',
#   'tecnico',
#   'hemoterapia',
#   'inmunohematologia',
#   'noviembre',
#   'ano'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regimen'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'modificacion',
#   'top',
#   'rango',
#   'beneficio'],
#  ['programa',
#   'nacional',
#   'prevencion',
#   'tratamiento',
#   'seguimiento',
#   'enfermedad',
#   'denominado',
#   'retinoblastoma'],
#  ['obra',
#   'social',
#   'asociacion',
#   'obra',
#   'social',
#   'entidad',
#   'medicina',
#   'prepagar',
#   'obligatoriedad',
#   'aplicar',
#   'tecnica',
#   'deteccion',
#   'acido',
#   'nucleico',
#   'metodo',
#   'analisi',
#   'sanguineo',
#   'transfusion'],
#  ['asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ley',
#   'sustitucion',
#   'inciso',
#   'articulo',
#   'ter',
#   'control',
#   'sanitario',
#   'plan',
#   'vacunacion',
#   'acreditacion',
#   'concurrencia',
#   'establecimiento',
#   'educativo',
#   'publico',
#   'publico',
#   'gestion',
#   'privado'],
#  ['emergencia',
#   'hospitalario',
#   'sanitario',
#   'declarar',
#   'provincia',
#   'santa',
#   'cruz'],
#  ['vacuna',
#   'varicela',
#   'incorporar',
#   'calendario',
#   'anual',
#   'vacunacion',
#   'obligatorio',
#   'gratuito'],
#  ['ley',
#   'ejercicio',
#   'medicina',
#   'odontologio',
#   'actividad',
#   'colaboracion',
#   'sustitucion',
#   'inciso',
#   'articulo',
#   'impresion',
#   'receta',
#   'dato',
#   'profesional'],
#  ['asignacion',
#   'familiar',
#   'derogacion',
#   'articulo',
#   'exclusion',
#   'prestacion',
#   'sustitucion',
#   'articulo',
#   'monto',
#   'prestacion',
#   'otorgar'],
#  ['prohibicion',
#   'comercializacion',
#   'aplicacion',
#   'herbicida',
#   'contener',
#   'glifosato'],
#  ['programa',
#   'nacional',
#   'deteccion',
#   'atencion',
#   'hipoacusia',
#   'financiamiento'],
#  ['prohibicion',
#   'emplear',
#   'cualquiera',
#   'elemento',
#   'medico',
#   'contenido',
#   'ftalato'],
#  ['asistencia',
#   'psicologico',
#   'psiquiatrico',
#   'cargo',
#   'persona',
#   'sufrir',
#   'algun',
#   'dano',
#   'consecuencia',
#   'accidente',
#   'catastrof'],
#  ['evaluacion',
#   'obligatorio',
#   'programa',
#   'social',
#   'creacion',
#   'agencia',
#   'nacional',
#   'evaluacion'],
#  ['obra', 'social', 'beneficiario'],
#  ['sindrome',
#   'prader',
#   'willi',
#   'spw',
#   'obligacion',
#   'estudio',
#   'cromosomatico',
#   'existir',
#   'posibilidad',
#   'anomalia',
#   'genetico',
#   'presentar',
#   'antecedente',
#   'cobertura',
#   'obra',
#   'social'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regimen'],
#  ['fondo',
#   'especial',
#   'fortalecimiento',
#   'atencion',
#   'primaria',
#   'salud',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['asignacion',
#   'familiar',
#   'bis',
#   'asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social'],
#  ['prevencion',
#   'sancion',
#   'manejo',
#   'espurio',
#   'fondo',
#   'publico',
#   'destinado',
#   'politica',
#   'social'],
#  ['trasplante',
#   'organo',
#   'material',
#   'anatomico',
#   'otorgamiento',
#   'empresa',
#   'transporte',
#   'aereo',
#   'plaza',
#   'incucai',
#   'solicitar',
#   'traslado',
#   'paciente',
#   'organo',
#   'asignado'],
#  ['ejercicio', 'profesional', 'obstetricia', 'regimen'],
#  ['declarar',
#   'zona',
#   'desastre',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'ciento',
#   'ochenta',
#   'prorrogable',
#   'diverso',
#   'localidad',
#   'provincia',
#   'rio',
#   'negro'],
#  ['cuidado', 'paliativo', 'regimen'],
#  ['prevencion', 'tratamiento', 'infertilidad', 'regimen'],
#  ['cartel',
#   'leyenda',
#   'consumo',
#   'excesivo',
#   'sal',
#   'perjudicial',
#   'salud',
#   'exhibicion',
#   'lugar',
#   'acceso',
#   'publico',
#   'comercialicir',
#   'consumar',
#   'comida',
#   'bebida'],
#  ['regulacion',
#   'cadena',
#   'frio',
#   'medicamento',
#   'testigo',
#   'temperatura',
#   'sancion'],
#  ['asignacion', 'familiar', 'movilidad', 'topes', 'rango', 'remuneratorio'],
#  ['reconocimiento',
#   'medico',
#   'obligatorio',
#   'ciudadano',
#   'sexo',
#   'cumplir',
#   'edad',
#   'dieciseis',
#   'ano',
#   'establecimiento'],
#  ['clausula',
#   'actualizacion',
#   'asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ano',
#   'incorporacion',
#   'parrafo',
#   'articulo',
#   'ley',
#   'asignacion',
#   'familiar'],
#  ['aprobacion', 'pacto', 'federal', 'legislativo', 'salud'],
#  ['cobertura',
#   'obra',
#   'social',
#   'entidad',
#   'medicina',
#   'prepagar',
#   'tira',
#   'reactiva',
#   'glucos',
#   'sangre'],
#  ['investigacion',
#   'desarrollo',
#   'formulacion',
#   'produccion',
#   'acceso',
#   'medicamento',
#   'medida',
#   'nino',
#   'regimen'],
#  ['regimen', 'regulacion', 'practica', 'piercing', 'tatuaj', 'perforacion'],
#  ['instituir', 'octubre', 'ano', 'nacional', 'osteoporosis'],
#  ['instalacion',
#   'quiosco',
#   'saludable',
#   'colegio',
#   'ensenanza',
#   'primario',
#   'secundario',
#   'publicar',
#   'privado',
#   'regimen'],
#  ['regimen', 'ejercicio', 'profesional', 'musicoterapia'],
#  ['psoriasis',
#   'inclusion',
#   'cobertura',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'terapia',
#   'biologica',
#   'tratamiento'],
#  ['instalacion',
#   'desfibrilador',
#   'externo',
#   'automatico',
#   'espacio',
#   'publico',
#   'privado'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'investigacion',
#   'tratamiento',
#   'atrofia',
#   'muscular',
#   'espinal',
#   'ame'],
#  ['monodroga',
#   'denominado',
#   'misoprostol',
#   'prohibicion',
#   'produccion',
#   'distribucion',
#   'comercializacion',
#   'venta'],
#  ['codigo',
#   'alimentario',
#   'argentino',
#   'capitulo',
#   'norma',
#   'rotulacion',
#   'alimento',
#   'incorporacion',
#   'punto',
#   'rotulo',
#   'sistema',
#   'braille'],
#  ['ley', 'sangre', 'dato', 'salud', 'donante'],
#  ['tabaquismo',
#   'ley',
#   'exhibicion',
#   'leyenda',
#   'fumar',
#   'perjudicial',
#   'salud',
#   'escena',
#   'televisivo',
#   'cinematografica',
#   'consumar',
#   'producto',
#   'elaborado',
#   'tabaco'],
#  ['ley', 'sangre', 'exigencia', 'deber', 'cumplir', 'donante', 'cuestionario'],
#  ['consultoria',
#   'ciudadano',
#   'vida',
#   'situacion',
#   'mistanasica',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['codigo',
#   'alimentario',
#   'nacional',
#   'agua',
#   'potable',
#   'agua',
#   'gasificado'],
#  ['educacion', 'alimentario', 'nutricional', 'regimen'],
#  ['prohibicion',
#   'publicitar',
#   'modelo',
#   'cuyo',
#   'indice',
#   'masa',
#   'muscular',
#   'encontrar',
#   'parametro',
#   'saludable',
#   'establecido',
#   'organizacion',
#   'mundial',
#   'salud'],
#  ['derecho',
#   'establecimiento',
#   'salud',
#   'publicar',
#   'privado',
#   'proceso',
#   'nacimiento',
#   'gratuidad',
#   'permanencia',
#   'acompanante',
#   'mujer',
#   'situacion',
#   'parto'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regulacion'],
#  ['atencion',
#   'victima',
#   'delito',
#   'sexual',
#   'prevencion',
#   'enfermedad',
#   'regimen'],
#  ['departamento',
#   'san',
#   'pedro',
#   'ledesmo',
#   'provincia',
#   'jujuy',
#   'declarar',
#   'zona',
#   'emergencia',
#   'economico',
#   'social',
#   'plazo',
#   'prorrogable'],
#  ['quebrado',
#   'humahuaca',
#   'departamento',
#   'valle',
#   'provincia',
#   'jujuy',
#   'declaracion',
#   'zona',
#   'desastre',
#   'natural',
#   'plazo',
#   'prorrogable'],
#  ['tecnica', 'reproduccion', 'humano', 'asistido', 'regimen'],
#  ['asignacion', 'familiar', 'asignacion', 'ayuda', 'escolar'],
#  ['prevencion',
#   'lavado',
#   'activo',
#   'actividad',
#   'juegos',
#   'azar',
#   'regimen',
#   'modificacion'],
#  ['creacion',
#   'instituto',
#   'nacional',
#   'promocion',
#   'salud',
#   'calidad',
#   'vida',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['sala',
#   'maternal',
#   'creacion',
#   'establecimiento',
#   'publico',
#   'privado',
#   'prestir',
#   'servicio',
#   'minimo',
#   'doscientos',
#   'trabajador',
#   'impuesto',
#   'ganancia',
#   'texto',
#   'ordenado',
#   'ganancia',
#   'minimo',
#   'presunto'],
#  ['plan', 'nacional', 'lucha', 'enfermedad', 'alzheimer', 'creacion'],
#  ['plan', 'aprovechamiento', 'economico', 'ceniza', 'volcanica', 'creacion'],
#  ['diagnostico', 'tratamiento', 'enfermedad', 'celiaca', 'cobertura'],
#  ['discontinuidad', 'produccion', 'comercializacion', 'medicamento'],
#  ['registro', 'nacional', 'poblacion', 'riesgo', 'sanitario', 'creacion'],
#  ['bebida',
#   'alcoholica',
#   'inclusion',
#   'informacion',
#   'consumidor',
#   'contenido',
#   'calorico',
#   'etiquetado'],
#  ['programa',
#   'federal',
#   'equinoterapia',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['programa',
#   'nacional',
#   'concientizacion',
#   'asistencia',
#   'materia',
#   'adopcion',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'desarrollo',
#   'social',
#   'nacion'],
#  ['programa',
#   'federal',
#   'desarrollo',
#   'tratamiento',
#   'efectivo',
#   'alzheimer',
#   'enfermedad',
#   'neurodegenerativo',
#   'relacionado',
#   'creacion'],
#  ['erupcion',
#   'volcan',
#   'puyehue',
#   'otorguese',
#   'jefe',
#   'jefa',
#   'familia',
#   'rural',
#   'dedicado',
#   'crianza',
#   'ovino',
#   'caprino',
#   'calidad',
#   'minifundista',
#   'area',
#   'rural',
#   'provincia',
#   'chubut',
#   'asignacion',
#   'mensual',
#   'equivalente',
#   'salario',
#   'minimo',
#   'vital',
#   'movil',
#   'plazo',
#   'ano',
#   'contado',
#   'enero',
#   'diciembre'],
#  ['nacional', 'voz', 'instituir', 'abril', 'ano'],
#  ['vacuna',
#   'varicela',
#   'zoster',
#   'incluir',
#   'aplicacion',
#   'calendario',
#   'nacional',
#   'inmunizacion',
#   'obligatorio',
#   'gratuito'],
#  ['enfermedad',
#   'parkinson',
#   'incorporacion',
#   'tratamiento',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cuestion',
#   'conexa'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'incorporacion',
#   'cobertura',
#   'dispositivo',
#   'necesario',
#   'persona',
#   'ostomizada'],
#  ['derecho',
#   'paciente',
#   'historia',
#   'clinico',
#   'consentimiento',
#   'informado',
#   'muerte',
#   'digno',
#   'cuidado',
#   'paliativo',
#   'integral'],
#  ['comision',
#   'nacional',
#   'asesora',
#   'lactancia',
#   'materno',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['fondo', 'especial', 'paciente', 'alto', 'complejidad', 'creacion'],
#  ['creacion',
#   'fondo',
#   'nacional',
#   'investigacion',
#   'desarrollo',
#   'produccion',
#   'vacuna',
#   'farmaco',
#   'metodo',
#   'diagnostico',
#   'masivo',
#   'estudio',
#   'epidemiologico',
#   'enfermedad',
#   'chaga'],
#  ['codigo',
#   'alimentario',
#   'nacional',
#   'agua',
#   'potable',
#   'agua',
#   'mineral',
#   'agua',
#   'gasificado',
#   'respectivamente'],
#  ['deteccion',
#   'diagnostico',
#   'tratamiento',
#   'enfermedad',
#   'celiaca',
#   'relacionado',
#   'implementacion',
#   'campana',
#   'anual',
#   'deteccion',
#   'realizacion',
#   'estudio',
#   'forma',
#   'gratuito'],
#  ['derecho',
#   'paciente',
#   'historia',
#   'clinico',
#   'consentimiento',
#   'informado',
#   'muerte',
#   'digno',
#   'cuidado',
#   'paliativo',
#   'integral'],
#  ['regulacion',
#   'publicidad',
#   'promocion',
#   'consumo',
#   'producto',
#   'elaborado',
#   'tabaco',
#   'ley',
#   'numerir',
#   'modificacion',
#   'composicion',
#   'producto'],
#  ['codigo',
#   'alimentario',
#   'argentino',
#   'porcentaje',
#   'jugo',
#   'bebida',
#   'alcohol'],
#  ['creacion',
#   'comision',
#   'nacional',
#   'vih',
#   'sida',
#   'conasido',
#   'ambito',
#   'jefatura',
#   'gabinete',
#   'ministros',
#   'derogacion',
#   'decreto'],
#  ['asignacion', 'familiar', 'monto', 'beneficio'],
#  ['animal',
#   'destinado',
#   'docencia',
#   'investigacion',
#   'control',
#   'calidad',
#   'prueba',
#   'laboratorio',
#   'cientifico',
#   'regimen',
#   'basico',
#   'utilizacion'],
#  ['asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social',
#   'ley',
#   'decreto',
#   'actualizacion',
#   'periodico',
#   'automatico',
#   'modificar',
#   'salario',
#   'minimo',
#   'vital',
#   'movil'],
#  ['sistema',
#   'nacional',
#   'vigilancia',
#   'mortalidad',
#   'materno',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['asignacion',
#   'familiar',
#   'bis',
#   'incorporacion',
#   'boleto',
#   'estudiantil',
#   'gratuito'],
#  ['incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'leches',
#   'medicamentosa',
#   'consumido',
#   'sufrir',
#   'alergia',
#   'proteina',
#   'leche',
#   'vacuna',
#   'aplv',
#   'sufrir',
#   'padecer',
#   'desorden',
#   'enfermedad',
#   'trastorno',
#   'gastrointestinal',
#   'eosinofilico'],
#  ['ley',
#   'asignacion',
#   'familiar',
#   'creacion',
#   'subsistema',
#   'contributivo',
#   'asignacion',
#   'universal',
#   'hijo',
#   'proteccion',
#   'social'],
#  ['ablacion',
#   'mamario',
#   'mastectomia',
# ...
#   'seguridad',
#   'social'],
#  ['planta',
#   'medicinal',
#   'droga',
#   'vegetal',
#   'medicamento',
#   'fitoterapicos',
#   'promocion',
#   'distribucion',
#   'expendio',
#   'regimen',
#   'derogacion',
#   'articulo',
#   'ejercicio',
#   'actividad',
#   'farmaceutico'],
#  ['emergencia',
#   'sanitario',
#   'declarar',
#   'prorrogable',
#   'consecuencia',
#   'propagacion',
#   'virus',
#   'influenza'],
#  ['ley',
#   'nacional',
#   'salud',
#   'valor',
#   'principio',
#   'derecho',
#   'obligacion',
#   'organizacion',
#   'federal',
#   'salud',
#   'gestion',
#   'publicar',
#   'nacional',
#   'modelo',
#   'prestador',
#   'estrategio',
#   'atencion',
#   'primaria',
#   'salud',
#   'red',
#   'servicio',
#   'hospital',
#   'publico',
#   'derogacion',
#   'decreto',
#   'ley'],
#  ['obligacion',
#   'fabricante',
#   'medicamento',
#   'proporcionar',
#   'consumidor',
#   'informacion',
#   'necesario',
#   'utilizacion'],
#  ['gripe',
#   'causado',
#   'virus',
#   'influenza',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'aparicion',
#   'enfermedad'],
#  ['gripe',
#   'tipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'aparicion',
#   'enfermedad'],
#  ['medicamento',
#   'producto',
#   'destinado',
#   'combatir',
#   'virus',
#   'influenza',
#   'h1n1',
#   'exceptuan',
#   'tributar',
#   'arancel',
#   'importacion',
#   'impuesto',
#   'interno',
#   'periodo',
#   'pandemia',
#   'enfermedad',
#   'declarado',
#   'organizacion',
#   'mundial',
#   'salud',
#   'oms'],
#  ['gripe',
#   'tipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'enfermedad',
#   'creacion',
#   'fondo',
#   'especial',
#   'lucha'],
#  ['declarar',
#   'emergencia',
#   'nacional',
#   'salud',
#   'termino',
#   'sesenta',
#   'creacion',
#   'comite',
#   'nacional',
#   'crisis',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['gripe',
#   'tipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional'],
#  ['gripe',
#   'causado',
#   'virus',
#   'influenza',
#   'tipo',
#   'subtipo',
#   'h1n1',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'pandemia',
#   'enfermedad'],
#  ['incorporacion',
#   'vacuna',
#   'antigripal',
#   'programa',
#   'ampliado',
#   'inmunizacion',
#   'aplicacion',
#   'gratuito',
#   'obligatorio',
#   'anos',
#   'embarazado',
#   'semana',
#   'gestacion'],
#  ['infertilidad',
#   'tecnica',
#   'fertilizacion',
#   'asistido',
#   'inclusion',
#   'tratamiento',
#   'diagnostico',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['administracion',
#   'nacional',
#   'laboratorio',
#   'instituto',
#   'salud',
#   'anlis',
#   'doctor',
#   'carlos',
#   'malbrar',
#   'ampliase',
#   'partida',
#   'presupuestario',
#   'asignado'],
#  ['plan',
#   'asistencia',
#   'integral',
#   'persona',
#   'enfermedad',
#   'frecuente',
#   'epf',
#   'creacion'],
#  ['psicologo', 'social', 'instituir', 'junio', 'ano'],
#  ['certificado',
#   'medico',
#   'aptitud',
#   'fisico',
#   'realizacion',
#   'actividad',
#   'fisica',
#   'deportivo',
#   'regimen'],
#  ['esclerosis',
#   'multiple',
#   'incluir',
#   'paciente',
#   'beneficiario',
#   'instituto',
#   'nacional',
#   'servicio',
#   'social',
#   'jubilado',
#   'pensionado',
#   'inssjp',
#   'pami'],
#  ['ley',
#   'general',
#   'salud',
#   'poblacion',
#   'caracteristica',
#   'poblacional',
#   'servicio',
#   'poblacion',
#   'comportamiento',
#   'individual',
#   'colectivo',
#   'habitat',
#   'caracteristica',
#   'ambiental',
#   'servicio',
#   'ambiente',
#   'ordenamiento',
#   'territorial',
#   'sistema',
#   'salud',
#   'servicio',
#   'salud',
#   'fuerza',
#   'trabajo',
#   'financiamiento',
#   'salud',
#   'publicar',
#   'poblacion',
#   'caracteristica',
#   'poblacional'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'lucha',
#   'hidroarsenicismo',
#   'cronico',
#   'regional',
#   'endemico',
#   'hacre',
#   'creacion',
#   'programa',
#   'federal'],
#  ['instituto',
#   'medicina',
#   'tropical',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'recoleccion',
#   'medicamento',
#   'vencido',
#   'domiciliario'],
#  ['plan',
#   'federal',
#   'inclusion',
#   'familiar',
#   'denominado',
#   'plan',
#   'incluir',
#   'creacion',
#   'ambito',
#   'presidencia',
#   'nacion'],
#  ['creacion',
#   'programa',
#   'contencion',
#   'social',
#   'pcs',
#   'mision',
#   'combatir',
#   'situacion',
#   'pobreza',
#   'hogar',
#   'republica',
#   'argentino',
#   'promover',
#   'certificar',
#   'insercion',
#   'reinsercion',
#   'fuente',
#   'genuina',
#   'empleo',
#   'formal',
#   'jefe',
#   'jefas',
#   'hogar',
#   'pobre'],
#  ['creacion', 'region', 'sanitario', 'aires'],
#  ['creacion',
#   'programa',
#   'apoyo',
#   'enfermo',
#   'celiaco',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['regulacion', 'cadena', 'frio', 'medicamento', 'ter', 'sancion'],
#  ['ley',
#   'acupuntura',
#   'autoridad',
#   'aplicacion',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['obligatoriedad',
#   'venta',
#   'medicamento',
#   'contener',
#   'sustancia',
#   'activo',
#   'denominado',
#   'oseltamivir',
#   'rimantadin',
#   'zanamivir',
#   'efectuar',
#   'unicamente',
#   'exhibicion',
#   'receta',
#   'medico'],
#  ['glifosato', 'suspension', 'aplicacion'],
#  ['gripe',
#   'porcinar',
#   'declarar',
#   'prevencion',
#   'emergencia',
#   'sanitario',
#   'creacion',
#   'comite',
#   'hospital',
#   'aeropuerto'],
#  ['enfermedad',
#   'celiaco',
#   'rotulacion',
#   'contener',
#   'gluten',
#   'contener',
#   'gluten',
#   'envase'],
#  ['tabaco',
#   'regimen',
#   'limitacion',
#   'control',
#   'riesgo',
#   'control',
#   'producto',
#   'cigarrillo',
#   'comercializado',
#   'fabricado',
#   'argentina'],
#  ['plan',
#   'nacional',
#   'radicacion',
#   'profesional',
#   'salud',
#   'creacion',
#   'direccion',
#   'nacional',
#   'prestacion',
#   'sanitaria',
#   'comunitario',
#   'ambito',
#   'ministerio',
#   'salud'],
#  ['hepatitis',
#   'incorporar',
#   'integrante',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'cobertura',
#   'diagnostico',
#   'tratamiento'],
#  ['creacion',
#   'programa',
#   'lucha',
#   'fiebre',
#   'hemorragico',
#   'argentino',
#   'fha'],
#  ['pediculosis',
#   'incorporacion',
#   'cobertura',
#   'prestacion',
#   'medica',
#   'obligatorio'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'emergencia',
#   'pmoe',
#   'incorporacion',
#   'cobertura',
#   'diagnostico',
#   'tratamiento',
#   'hepatitis'],
#  ['dengue',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'nacional',
#   'creacion',
#   'comision',
#   'nacional',
#   'seguimiento',
#   'epidemia'],
#  ['dengue',
#   'declaracion',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional',
#   'afectado'],
#  ['programa',
#   'nacional',
#   'prevencion',
#   'control',
#   'proteccion',
#   'integral',
#   'dengue',
#   'epidemia',
#   'enfermedad',
#   'emergente',
#   'reemergent',
#   'creacion'],
#  ['celula',
#   'madr',
#   'disponer',
#   'conservacion',
#   'envio',
#   'almacenamiento',
#   'banco',
#   'nacional',
#   'publico',
#   'celula',
#   'progenitora',
#   'hematopoyetica',
#   'funcionar',
#   'hospital',
#   'garrahaber'],
#  ['prohibicion',
#   'ingreso',
#   'persona',
#   'geriatrico',
#   'centro',
#   'salud',
#   'mental',
#   'rehabilitacion',
#   'fisico',
#   'mental',
#   'consentimiento',
#   'informado',
#   'orden',
#   'judicial',
#   'relevamiento'],
#  ['prohibir',
#   'consumo',
#   'directo',
#   'soja',
#   'transgenico',
#   'autoridad',
#   'aplicacion',
#   'ministerio',
#   'salud',
#   'secuestro',
#   'decomiso',
#   'incumplimiento'],
#  ['dengue', 'declarar', 'emergencia', 'sanitario'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'pais',
#   'brote',
#   'epidemico',
#   'dengue'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'control',
#   'dengue',
#   'creacion',
#   'programa',
#   'nacional',
#   'permanente',
#   'prevencion',
#   'control',
#   'dengue',
#   'enfermedad',
#   'tropical'],
#  ['enfermedad',
#   'dengue',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional',
#   'ciento',
#   'ochenta'],
#  ['enfermedad',
#   'dengue',
#   'declarar',
#   'emergencia',
#   'sanitario',
#   'territorio',
#   'nacional'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'odontologia',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['sodio', 'regulacion', 'contenido', 'industria', 'alimentacion'],
#  ['declaracion',
#   'interes',
#   'nacional',
#   'accion',
#   'dirigido',
#   'prevencion',
#   'atencion',
#   'salud',
#   'publicar',
#   'ratificacion',
#   'decreto',
#   'creacion',
#   'administracion',
#   'nacional',
#   'medicamento',
#   'alimento',
#   'tecnologia',
#   'medica',
#   'anmat'],
#  ['prohibicion',
#   'publicidad',
#   'promocion',
#   'distribucion',
#   'venta',
#   'entrega',
#   'regalo',
#   'producto',
#   'subproducto',
#   'tabaco',
#   'menor',
#   'edad'],
#  ['creacion',
#   'instituto',
#   'nacional',
#   'cancer',
#   'ambito',
#   'ministerio',
#   'salud',
#   'nacion'],
#  ['enfermedad',
#   'celiaco',
#   'obligatoriedad',
#   'obra',
#   'social',
#   'empresa',
#   'medicina',
#   'prepagar',
#   'brindar',
#   'atencion',
#   'medica',
#   'cobertura',
#   'integral',
#   'persona',
#   'padezcar',
#   'exencion',
#   'impositivo',
#   'producto',
#   'contener',
#   'gluten',
#   'derivado'],
#  ['dengue', 'declarar', 'emergencia', 'sanitario', 'territorio', 'nacional'],
#  ['alimento',
#   'envasado',
#   'inclusion',
#   'leyenda',
#   'aclarar',
#   'contener',
#   'gluten'],
#  ['servicio', 'nacional', 'lucha', 'diabetes', 'cobertura', 'obra', 'social'],
#  ['tatuaj', 'piercing', 'prevencion', 'regulacion'],
#  ['elemento',
#   'medico',
#   'mercurio',
#   'prohibir',
#   'utilizacion',
#   'establecimiento',
#   'salud',
#   'publico',
#   'privado'],
#  ['ecocardiografia',
#   'fetal',
#   'incorporacion',
#   'caracter',
#   'obligatorio',
#   'practica',
#   'rutinario',
#   'control'],
#  ['reconocimiento', 'oficial', 'acupuntura', 'acto', 'medico'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'provincia',
#   'chaco',
#   'afectado',
#   'dengue'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'asistencia',
#   'donante',
#   'vivo',
#   'organo',
#   'beneficio',
#   'recursos'],
#  ['prohibicion',
#   'importacion',
#   'fabricacion',
#   'expendio',
#   'indumentaria',
#   'contener',
#   'dimetilfumarato'],
#  ['calcetin',
#   'correccion',
#   'pie',
#   'equino',
#   'accionado',
#   'vendaje',
#   'tiro',
#   'zona',
#   'compresion',
#   'reforzado',
#   'punto',
#   'ataque',
#   'tipo',
#   'philipp',
#   'incorporacion',
#   'cobertura',
#   'prestacion',
#   'medica',
#   'obligatorio'],
#  ['creacion',
#   'programa',
#   'federal',
#   'salud',
#   'educacion',
#   'republica',
#   'ambito',
#   'consejo',
#   'nacional',
#   'coordinacion',
#   'politica',
#   'social'],
#  ['programa',
#   'nacional',
#   'investigacion',
#   'desarrollo',
#   'produccion',
#   'vacuna',
#   'demas',
#   'insumo',
#   'medico',
#   'creacion',
#   'ambito',
#   'ministerio',
#   'ciencia',
#   'tecnologio',
#   'innovacion',
#   'productivo'],
#  ['farmacopea',
#   'ley',
#   'incorporacion',
#   'anexo',
#   'identificacion',
#   'color',
#   'droga',
#   'anestesiologico'],
#  ['sistema',
#   'integral',
#   'proteccion',
#   'persona',
#   'discapacitada',
#   'ley',
#   'efecto',
#   'articulo',
#   'considerar',
#   'persona',
#   'discapacidad',
#   'visceral',
#   'afectado',
#   'trastorno',
#   'hereditario',
#   'hemoglobina',
#   'requerir',
#   'tratamiento',
#   'permanente',
#   'sobrevivir',
#   'obra',
#   'social',
#   'agente',
#   'salud',
#   'incorporarar',
#   'prestacion',
#   'obligatorio'],
#  ['tratamiento',
#   'enfermedad',
#   'tipo',
#   'anticoagulante',
#   'incluir',
#   'prevencion',
#   'deteccion',
#   'mujer',
#   'edad',
#   'reproductivo',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'embarazo',
#   'partos',
#   'cesarea',
#   'puerperio',
#   'mujer',
#   'patologia',
#   'quedar',
#   'cubierto',
#   'plan',
#   'materno',
#   'infantil',
#   'pmi'],
#  ['nacional', 'medico', 'argentino', 'instituir', 'marzo', 'ano'],
#  ['acceso',
#   'reproduccion',
#   'humano',
#   'asistido',
#   'salud',
#   'sexual',
#   'procreacion',
#   'responsable',
#   'inciso',
#   'articulo',
#   'garantizar',
#   'acceso',
#   'poblacion',
#   'agregar',
#   'inciso',
#   'articulo',
#   'articulo',
#   'agregar',
#   'tercer',
#   'parrafo',
#   'articulo'],
#  ['proteccion',
#   'promocion',
#   'concientizacion',
#   'publicar',
#   'lactancia',
#   'materno',
#   'practica',
#   'optima',
#   'nutricion',
#   'seguro',
#   'lactant',
#   'nino',
#   'pequeno',
#   'anos',
#   'alcanz'],
#  ['pediculosis',
#   'implementar',
#   'campana',
#   'lucha',
#   'transcurso',
#   'ano',
#   'lectivo'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'zona',
#   'afectado',
#   'dengue',
#   'creacion',
#   'comite',
#   'emergencia',
#   'sanitario',
#   'dengue'],
#  ['enfermedad',
#   'cronico',
#   'psoriasis',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'inclusion',
#   'resolucion',
#   'cobertura',
#   'medicamento'],
#  ['enfermedad',
#   'hunter',
#   'incorporacion',
#   'programa',
#   'medico',
#   'obligatorio',
#   'pmo'],
#  ['creacion',
#   'observatorio',
#   'parlamentario',
#   'exclusion',
#   'social',
#   'ambito',
#   'congreso'],
#  ['cosmetologia',
#   'cosmiatrio',
#   'estetico',
#   'corporal',
#   'regulacion',
#   'profesion',
#   'naturaleza',
#   'finalidad',
#   'cosmetologo',
#   'cosmiatra',
#   'esteticista',
#   'corporal',
#   'principio',
#   'ejercicio',
#   'profesion',
#   'centro',
#   'formacion',
#   'prohibicion',
#   'centro',
#   'estetico',
#   'comite',
#   'asesor'],
#  ['creacion',
#   'programa',
#   'federal',
#   'prevencion',
#   'hpv',
#   'papiloma',
#   'virus',
#   'humano'],
#  ['instituto',
#   'profilaxis',
#   'enfermedad',
#   'venerea',
#   'ter',
#   'quater',
#   'examen',
#   'medico',
#   'prenupcial',
#   'ley'],
#  ['creacion',
#   'banco',
#   'leche',
#   'materno',
#   'humano',
#   'definicion',
#   'objetivo',
#   'donant',
#   'creacion',
#   'programa',
#   'nacional',
#   'concientizacion',
#   'fomentacion',
#   'importancia',
#   'lactancia',
#   'natural',
#   'materno'],
#  ['registro',
#   'nacional',
#   'beneficiario',
#   'programa',
#   'social',
#   'creacion',
#   'ambito',
#   'ejecutivo'],
#  ['declarar',
#   'emergencia',
#   'sanitario',
#   'higienico',
#   'territorio',
#   'nacion',
#   'argentino',
#   'combatir',
#   'enfermedad',
#   'viral',
#   'transmitido',
#   'mosquito',
#   'aedes',
#   'aegypti',
#   'producir',
#   'enfermedad',
#   'dengue'],
#  ['ejercicio',
#   'actividad',
#   'farmaceutico',
#   'prohibicion',
#   'farmacia',
#   'asistencial',
#   'institucional',
#   'programa',
#   'provision',
#   'medicamento',
#   'industrio',
#   'farmaceutico',
#   'drogueria',
#   'distribuidora',
#   'medicamento',
#   'elaboracion',
#   'venta',
#   'producto',
#   'homeopatico',
#   'herboristeria',
#   'industria',
#   'cosmetico',
#   'fabricacion',
#   'material',
#   'biomedico',
#   'esteril',
#   'fiscalizacion',
#   'control'],
#  ['tarjeta',
#   'social',
#   'gasto',
#   'alimentario',
#   'programa',
#   'nutricion',
#   'alimentacion',
#   'nacional',
#   'ley',
#   'exencion',
#   'impuesto',
#   'valor',
#   'agregado',
#   'iva'],
#  ['preferencia',
#   'adquisicion',
#   'medicamento',
#   'vacuna',
#   'producto',
#   'medico',
#   'produccion',
#   'publicar',
#   'nacional'],
#  ['regimen',
#   'transitorio',
#   'extension',
#   'cobertura',
#   'medico',
#   'trabajador',
#   'trabajadora',
#   'situacion',
#   'desempleo',
#   'distracto',
#   'suspension',
#   'financiacion',
#   'vigencio'],
#  ['vacuna',
#   'neumococico',
#   'heptavalente',
#   'incorporacion',
#   'calendario',
#   'nacional',
#   'vacunacion'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporar',
#   'cobertura',
#   'prestacion',
#   'correspondiente',
#   'enfermedad',
#   'gaucher'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporar',
#   'cobertura',
#   'prestacion',
#   'correspondiente',
#   'enfermedad',
#   'fabry'],
#  ['programa',
#   'medico',
#   'obligatorio',
#   'pmo',
#   'incorporar',
#   'cobertura',
#   'prestacion',
#   'correspondiente',
#   'enfermedad',
#   'pompe'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'diagnostico',
#   'tratamiento',
#   'enfermedad',
#   'celiaco',
#   'derogacion',
#   'ley'],
#  ['prevencion',
#   'lucha',
#   'enfermedad',
#   'chagas',
#   'mazza',
#   'examen',
#   'serologicos'],
#  ['declarar',
#   'inter',
#   'nacional',
#   'diagnostico',
#   'tratamiento',
#   'enfermedad',
#   'celiaco',
#   'derogacion',
#   'ley'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'salud',
#   'social',
#   'procreacion',
#   'responsable'],
#  ['regimen', 'salud', 'mental'],
#  ['creacion',
#   'programa',
#   'nacional',
#   'prevencion',
#   'tratamiento',
#   'inclusion',
#   'familiar',
#   'social',
#   'persona',
#   'afectado',
#   'alzheimer',
#   'demencia',
#   'trastorno',
#   'cognitivo'],
#  ['declaracion',
#   'vital',
#   'voluntad',
#   'paciente',
#   'terminal',
#   'muerte',
#   'inminente'],
#  ['creacion', 'programa', 'nacional', 'atencion', 'estr', 'postraumatico'],
#  ['control',
#   'tabaco',
#   'regulacion',
#   'consumo',
#   'comercializacion',
#   'publicidad',
#   'creacion',
#   'comite',
#   'asesor',
#   'interdisciplinario']]

# %%
# GUARDAR OBJETO PARA DETECTAR CAMBIOS SEMANTICOS
with open(RESULTADOS_DIR + 'periodo_5anios_df.pkl', 'wb') as file: 
    pickle.dump(PER5anios_df,file)

# %% [markdown]
# ## Analizando frecuencias de palabras por período
# Se tiene en cuenta los períodos parlamentaríos

# %%
freqs_list = []
for anios5 in PER5anios_df['Periodo_5anios'].to_list():

    print(anios5)
    subdf = PER5anios_df.loc[(PER5anios_df['Periodo_5anios']==anios5),]
    subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")                                 
    
    freqs = Counter()
    subdf['Título normalizado'].apply(lambda x: freqs.update(x.split())) # cualquier espacio.
    total_number = sum(freqs.values())
    print('Número total de tokens:', total_number)

    freqs_df = pd.DataFrame.from_dict(freqs, orient='index',
                                      columns=['Frecuencia'])
    freqs_df = freqs_df.reset_index()

    freqs_df = freqs_df.rename(columns={'index': 'Palabra'})
    mask = (freqs_df['Palabra'].str.len() > 1)
    print(freqs_df.shape)
    freqs_df = freqs_df.loc[mask]
    print(freqs_df.shape)
    print('Entradas removidas de 1 carácter.')
    print('Cantidad de tokens únicos:', freqs_df.shape[0])

    freqs_df = freqs_df.sort_values('Frecuencia').reset_index(drop=True)

    freqs_df['Porcentaje'] = freqs_df['Frecuencia'] / total_number

    
    freqs_df.to_csv(RESULTADOS_DIR+'/archivos_out/frec_para_datos_limpios_por_desplaz_semantico_anios5_'+str(anios5)+'.csv', index=False)

    freqs_df['Período'] = str(anios5)
    
    freqs_list.append(freqs_df)
# Out:
# 2009
# Número total de tokens: 7854
# (1714, 2)
# (1714, 2)
# Entradas removidas de 1 carácter.
# Cantidad de tokens únicos: 1714
# 2014
# Número total de tokens: 9740
# (1969, 2)
# (1969, 2)
# Entradas removidas de 1 carácter.
# Cantidad de tokens únicos: 1969
# 2019
# Número total de tokens: 10222
# (1876, 2)
# (1876, 2)
# Entradas removidas de 1 carácter.
# Cantidad de tokens únicos: 1876
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16316\3633415219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16316\3633415219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16316\3633415219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subdf['Título normalizado'] = subdf['Título normalizado'].str.replace("."," ")

# %%
freqs_df = pd.concat(freqs_list) # Dataframe de frecuecias

# %%
freqs_df.head(2)
# Out:
#   Palabra  Frecuencia  Porcentaje Período
# 0    paro           1    0.000127    2009
# 1    ipod           1    0.000127    2009

# %%
freqs_df = freqs_df.sort_values(by = 'Frecuencia', ascending =False)

# %% [markdown]
# ##### Top 10 frecuencia de palabra por período de 5 años

# %%
freqs_df.head(10).Palabra.unique() # Palabras
# Out:
# array(['nacional', 'creacion', 'programa', 'regimen', 'salud'],
#       dtype=object)

# %%
freqs_df.head(10)
# Out:
#        Palabra  Frecuencia  Porcentaje Período
# 1875  nacional         361    0.035316    2019
# 1968  nacional         267    0.027413    2014
# 1874  creacion         251    0.024555    2019
# 1967  creacion         220    0.022587    2014
# 1873  programa         211    0.020642    2019
# 1713  nacional         208    0.026483    2009
# 1966   regimen         202    0.020739    2014
# 1872     salud         195    0.019077    2019
# 1871   regimen         177    0.017316    2019
# 1965  programa         165    0.016940    2014

# %% [markdown]
# ##### Las menos 10 frecuencia de palabra por período de 5 años

# %%
freqs_df.tail(10).Palabra.unique()
# Out:
# array(['adio', 'querido', 'compania', 'municipal', 'pedro', 'gobierno',
#        'optativo', 'surgido', 'estatal', 'paro'], dtype=object)

# %%
freqs_df.tail(10)
# Out:
#       Palabra  Frecuencia  Porcentaje Período
# 63       adio           1    0.000098    2019
# 64    querido           1    0.000098    2019
# 65   compania           1    0.000098    2019
# 66  municipal           1    0.000098    2019
# 67      pedro           1    0.000098    2019
# 68   gobierno           1    0.000098    2019
# 69   optativo           1    0.000098    2019
# 70    surgido           1    0.000098    2019
# 71    estatal           1    0.000098    2019
# 0        paro           1    0.000127    2009

# %%
freqs_df.describe(include = 'all')
# Out:
#          Palabra   Frecuencia   Porcentaje Período
# count       5559  5559.000000  5559.000000    5559
# unique      3221          NaN          NaN       3
# top     nacional          NaN          NaN    2014
# freq           3          NaN          NaN    1969
# mean         NaN     5.003778     0.000540     NaN
# std          NaN    13.887580     0.001476     NaN
# min          NaN     1.000000     0.000098     NaN
# 25%          NaN     1.000000     0.000103     NaN
# 50%          NaN     2.000000     0.000196     NaN
# 75%          NaN     4.000000     0.000391     NaN
# max          NaN   361.000000     0.035316     NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(x = 'Frecuencia', data=freqs_df, bins='auto') # hue='Período'
# Out:
# <Axes: xlabel='Frecuencia', ylabel='Count'>

# %%
sns.boxplot(x = 'Frecuencia', data=freqs_df)
# Out:
# <Axes: xlabel='Frecuencia'>

# %%
def eliminar_outliers_iqr(df, columna):
    """
    Separa los outliers y devuelve dos DataFrames:
    - df_limpio: sin outliers
    - df_outliers: con los valores atípicos detectados

    Parámetros:
    df (pd.DataFrame): DataFrame de pandas
    columna (str): Nombre de la columna a analizar

    Retorna:
    df_limpio (pd.DataFrame): DataFrame sin outliers
    df_outliers (pd.DataFrame): DataFrame solo con outliers
    """
    Q1 = df[columna].quantile(0.25)
    Q3 = df[columna].quantile(0.75)
    IQR = Q3 - Q1

    # Definir los límites
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    print("Q1:",Q1)
    print("Q3:",Q3)
    print('limite_inferior:', limite_inferior)
    print('limite_superior:', limite_superior)


    # Filtrar datos
    df_limpio = df[(df[columna] >= limite_inferior) & (df[columna] <= limite_superior)]
    df_outliers = df[(df[columna] < limite_inferior) | (df[columna] > limite_superior)]

    return df_limpio, df_outliers

# %%
# Detectar outliers
freqs_limpio_df , outliers_df = eliminar_outliers_iqr(freqs_df, 'Frecuencia')
display("Outliers detectados:\n", outliers_df)
# Out:
# Q1: 1.0
# Q3: 4.0
# limite_inferior: -3.5
# limite_superior: 8.5
# 'Outliers detectados:\n'
#              Palabra  Frecuencia  Porcentaje Período
# 1875        nacional         361    0.035316    2019
# 1968        nacional         267    0.027413    2014
# 1874        creacion         251    0.024555    2019
# 1967        creacion         220    0.022587    2014
# 1873        programa         211    0.020642    2019
# ...              ...         ...         ...     ...
# 1548        ganancia           9    0.001146    2009
# 1549           forma           9    0.001146    2009
# 1550           monto           9    0.001146    2009
# 1551  administracion           9    0.001146    2009
# 1552        hospital           9    0.001146    2009
#
# [622 rows x 4 columns]

# %%
print("Cantidad de palabras por período que superan las 8 veces - OUTLIERS:", len(outliers_df.Palabra.unique()))
# Out:
# Cantidad de palabras por período que superan las 8 veces - OUTLIERS: 318

# %%
outliers_df.describe(include='all')
# Out:
#          Palabra  Frecuencia  Porcentaje Período
# count        622  622.000000  622.000000     622
# unique       318         NaN         NaN       3
# top     nacional         NaN         NaN    2019
# freq           3         NaN         NaN     224
# mean         NaN   27.339228    0.002939     NaN
# std          NaN   33.784231    0.003570     NaN
# min          NaN    9.000000    0.000880     NaN
# 25%          NaN   11.000000    0.001174     NaN
# 50%          NaN   16.000000    0.001704     NaN
# 75%          NaN   29.750000    0.003183     NaN
# max          NaN  361.000000    0.035316     NaN

# %%
p99 = freqs_df['Frecuencia'].quantile(0.99)
print('Perceptil 99% de Frecuencia:', p99)
display(outliers_df[outliers_df['Frecuencia']> p99].sort_values('Porcentaje', ascending=False))
# Out:
# Perceptil 99% de Frecuencia: 56.42000000000007
#             Palabra  Frecuencia  Porcentaje Período
# 1875       nacional         361    0.035316    2019
# 1968       nacional         267    0.027413    2014
# 1713       nacional         208    0.026483    2009
# 1874       creacion         251    0.024555    2019
# 1967       creacion         220    0.022587    2014
# 1966        regimen         202    0.020739    2014
# 1873       programa         211    0.020642    2019
# 1712       creacion         157    0.019990    2009
# 1872          salud         195    0.019077    2019
# 1871        regimen         177    0.017316    2019
# 1965       programa         165    0.016940    2014
# 1711          salud         133    0.016934    2009
# 1964          salud         155    0.015914    2014
# 1710       programa         112    0.014260    2009
# 1709         social         109    0.013878    2009
# 1708        regimen         106    0.013496    2009
# 1707            ley         102    0.012987    2009
# 1963         medico         121    0.012423    2014
# 1706    obligatorio          84    0.010695    2009
# 1869        persona         109    0.010663    2019
# 1870         medico         109    0.010663    2019
# 1868    obligatorio         106    0.010370    2019
# 1867          covid         104    0.010174    2019
# 1866       integral         103    0.010076    2019
# 1962    obligatorio          97    0.009959    2014
# 1705         medico          78    0.009931    2009
# 1702     enfermedad          77    0.009804    2009
# 1704       declarar          77    0.009804    2009
# 1703     asignacion          77    0.009804    2009
# 1961         social          93    0.009548    2014
# 1960        persona          90    0.009240    2014
# 1959    tratamiento          89    0.009138    2014
# 1958       declarar          85    0.008727    2014
# 1865     prevencion          86    0.008413    2019
# 1701     emergencia          61    0.007767    2009
# 1864         social          77    0.007533    2019
# 1957            ano          72    0.007392    2014
# 1700    tratamiento          58    0.007385    2009
# 1863     enfermedad          75    0.007337    2019
# 1862    tratamiento          75    0.007337    2019
# 1699  incorporacion          57    0.007257    2009
# 1956            pmo          66    0.006776    2014
# 1861         nacion          69    0.006750    2019
# 1955     prevencion          64    0.006571    2014
# 1860            ley          67    0.006554    2019
# 1954     enfermedad          63    0.006468    2014
# 1953       alimento          63    0.006468    2014
# 1858       declarar          66    0.006457    2019
# 1859     emergencia          66    0.006457    2019
# 1857      sanitario          64    0.006261    2019
# 1952            ley          60    0.006160    2014
# 1856         ambito          62    0.006065    2019
# 1950        sistema          58    0.005955    2014
# 1951      cobertura          58    0.005955    2014
# 1949         ambito          57    0.005852    2014
# 1855       atencion          58    0.005674    2019

# %%
# Miramos distribución sin outliers
sns.boxplot(x = 'Frecuencia', data=freqs_limpio_df)
# Out:
# <Axes: xlabel='Frecuencia'>

# %%
sns.histplot(x = 'Frecuencia', data=freqs_limpio_df,  hue='Período')
# Out:
# <Axes: xlabel='Frecuencia', ylabel='Count'>

# %% [markdown]
# Analizando proyectos de IL de Salud:
# * [2009 - 2014)
#     * Número total de tokens: 7654
#     * Número de tokens únicos: 1714
# * [2014 - 2019)
#     * Número total de tokens: 9740
#     * Número de tokens únicos: 1969
# * [2019 - 2024)
#     * Número total de tokens: 10222
#     * Número de tokens únicos: 1876
#
# **Corpus IL:**
# * Las palabras aparecen pocas veces. Esto afectará el aprender del modelo. Embeddings inestables, esto afecta la detección de cambios semánticos.
# * Esto afecta tareas posteriores
#     * Analizando las frecuencia de token por período:
#         * 2 veces es la mediana de veces por periodo en que aparece un token.
#         * 5 veces es el promedio de veces por periodo en que aparece un token.
#         * Limite superior (método IQR) = 8.5  veces
#             * 318 palabras
