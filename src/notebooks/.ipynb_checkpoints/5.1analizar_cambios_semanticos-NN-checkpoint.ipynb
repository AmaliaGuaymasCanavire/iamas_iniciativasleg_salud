# %% [markdown]
# # Análisis de cambio semánticos (generar datos para análisis)

# %%
# Importar librería
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import pickle
import os
import re
import random as rn
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import bootstrap
import matplotlib.pyplot as plt
import itertools

from gensim.models import Word2Vec
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
tqdm.pandas()

from ast import literal_eval

# %%
# Configurar
load_dotenv() # Cargar las variables de entorno del archivo .env
BASE_DIR =  os.getenv("DIR_BASE")
RESULTADOS_DIR = os.getenv("DIR_DATOS_PROCESADOS") # Acceder a las variables de entorno modelos_swmwosge_1008211100
modelo_dir =  RESULTADOS_DIR+ '/archivos_out/modelos_swmwosge_5051100'
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Se selecciona para analizar el modelo de procrustes

# %%
basename = 'procrustes'
iteracion = 50
tam_vector = 50

# %%
# estabilidad_procrustes_iter10_tam50
selected_topics_df = pd.read_csv(
    modelo_dir+'/estabilidad_procrustes/estabilidad_'+basename+'_iter'+str(iteracion)+'_tam'+str(tam_vector)+'.csv',
    converters={'par_periodo': literal_eval})

selected_topics_df.head(5)
# Out:
#    iteracion   par_periodo      palabra  similaridad_semantica  \
# 0          6  (2014, 2019)       accion               0.026791
# 1         40  (2014, 2019)  dispositivo               0.067824
# 2         35  (2009, 2014)       basico               0.071167
# 3         44  (2009, 2014)       basico               0.080370
# 4         33  (2014, 2019)     adecuado               0.090077
#
#    cantidad_palabras_comun  \
# 0                      461
# 1                      461
# 2                      632
# 3                      632
# 4                      461
#
#                                                                                                                                                                                                                                                                                                                                        top10_vecindad_t1  \
# 0    [('judicial', 0.6770266890525818), ('comunitario', 0.6661193370819092), ('julio', 0.6481040120124817), ('mental', 0.6264558434486389), ('nacimiento', 0.6204757690429688), ('valor', 0.5921574831008911), ('primario', 0.579254150390625), ('desarrollo', 0.5711088180541992), ('premio', 0.5692583322525024), ('psicologico', 0.5626101493835449)]
# 1    [('nocivo', 0.7619382739067078), ('similar', 0.6900781989097595), ('electronico', 0.6778493523597717), ('dato', 0.6534647941589355), ('digital', 0.6030073761940002), ('efecto', 0.5861523151397705), ('necesario', 0.585832417011261), ('medicamentosa', 0.5726563930511475), ('transgenico', 0.5610784292221069), ('leches', 0.5532217621803284)]
# 2      [('laboratorio', 0.6807141900062561), ('menor', 0.6475790143013), ('fincini', 0.6377453804016113), ('ninez', 0.631625235080719), ('ganancia', 0.6304410696029663), ('ingreso', 0.6263360977172852), ('utilizacion', 0.6157370805740356), ('calidad', 0.6059296727180481), ('distribucion', 0.6013383269309998), ('padezcar', 0.5793224573135376)]
# 3  [('laboratorio', 0.6913539171218872), ('ninez', 0.6830536127090454), ('ingreso', 0.6494584679603577), ('ganancia', 0.6301590204238892), ('fincini', 0.6233099699020386), ('tabaco', 0.617645263671875), ('utilizacion', 0.6065181493759155), ('menor', 0.5954523682594299), ('distribucion', 0.5937909483909607), ('limitacion', 0.5896505117416382)]
# 4      [('rotulacion', 0.7852411866188049), ('especialidad', 0.6834930181503296), ('porcentaje', 0.6528801321983337), ('camara', 0.6461610198020935), ('gasificado', 0.6428849101066589), ('frio', 0.6421188712120056), ('jugo', 0.6405826807022095), ('cadena', 0.640575647354126), ('alcohol', 0.6377267241477966), ('medicinal', 0.6370911598205566)]
#
#                                                                                                                                                                                                                                                                                                                                                      top10_vecindad_t2
# 0                [('epidemiologico', 0.6849518418312073), ('promover', 0.6302334666252136), ('inter', 0.6208462119102478), ('organo', 0.6154682040214539), ('celula', 0.6115739941596985), ('tratamiento', 0.6076741218566895), ('nivel', 0.5620438456535339), ('donacion', 0.5555312633514404), ('padecer', 0.554180383682251), ('investigacion', 0.538840115070343)]
# 1  [('tecnologico', 0.6621898412704468), ('muerte_subita', 0.6154015064239502), ('minimo', 0.5942965149879456), ('desfibrilador', 0.5798337459564209), ('oftalmologico', 0.565621018409729), ('concurrencia', 0.5628604888916016), ('comprendido', 0.5361419320106506), ('lugar', 0.5149423480033875), ('calidad', 0.513451099395752), ('examen', 0.5114758014678955)]
# 2                          [('reduccion', 0.7038561701774597), ('objeto', 0.7004052400588989), ('precio', 0.6229988932609558), ('nacido', 0.6214845776557922), ('recien', 0.6185654401779175), ('equipo', 0.6037498712539673), ('primaria', 0.5589615702629089), ('situacion', 0.5472093224525452), ('celiaco', 0.538116455078125), ('argentina', 0.5338548421859741)]
# 3                                [('reduccion', 0.6890735030174255), ('objeto', 0.679164707660675), ('precio', 0.652248203754425), ('recien', 0.652148425579071), ('nacido', 0.6508929133415222), ('equipo', 0.6109211444854736), ('primaria', 0.5782000422477722), ('bis', 0.5420730710029602), ('situacion', 0.522652804851532), ('geriatrico', 0.5151534080505371)]
# 4                 [('manejo', 0.6844812631607056), ('geriatrico', 0.6576078534126282), ('tumor', 0.6037538051605225), ('hijo', 0.5944344997406006), ('agente', 0.5880053043365479), ('situacion', 0.5502997636795044), ('procreacion', 0.5487896800041199), ('paliativo', 0.5447098016738892), ('modificatoria', 0.5377705693244934), ('funcion', 0.5327803492546082)]

# %%
selected_topics_df.describe() # Estadística
# Out:
#           iteracion  similaridad_semantica  cantidad_palabras_comun
# count  54650.000000           54650.000000             54650.000000
# mean      24.500000               0.640435               559.876487
# std       14.431002               0.139921                84.447914
# min        0.000000               0.026791               461.000000
# 25%       12.000000               0.551986               461.000000
# 50%       24.500000               0.651548               632.000000
# 75%       37.000000               0.740335               632.000000
# max       49.000000               0.945866               632.000000

# %% [markdown]
# Se realizaron 50 ejecuciones independientes del enfoque Procrustes, cada una con una semilla aleatoria distinta. En cada iteración, se seleccionaron las 250 palabras con mayor cambio semántico entre los pares de períodos comparados, considerando únicamente aquellas con al menos 5 ocurrencias en alguno de los dos períodos de cinco años.
#
# Posteriormente, se calculó la similaridad semantica promedio (medida de estabilidad del modelo) para cada palabra identificada en cada par de periodos comparados. Este valor fue estimado junto con sus respectivos intervalos de confianza del 95%, utilizando el método bootstrap.

# %%
n = 250
at_least_in_any_decade = 5
pares_periodo = [ (2009, 2014),(2014, 2019)]
topn_periodo = {}

for par_periodo in pares_periodo:
    df =  selected_topics_df[
        selected_topics_df['par_periodo'] == par_periodo
    ].copy()
    
    
    frecPer1 = pd.read_csv(RESULTADOS_DIR+'/archivos_out/frec_para_datos_limpios_por_desplaz_semantico_anios5_'+str(par_periodo[0])+'.csv')
    frecPer2 = pd.read_csv(RESULTADOS_DIR+'/archivos_out/frec_para_datos_limpios_por_desplaz_semantico_anios5_'+str(par_periodo[1])+'.csv')
    frecPer1.columns = ['palabra', 'frec1', 'porc1']
    frecPer2.columns = ['palabra', 'frec2', 'porc2']
    #print(frecPer2.shape)
    topn_all_df = []

    for iter in range(iteracion):
        #print(iter)
        df_topn = df[(df.iteracion==iter)]
        #controlar frec
        #display(df_topn)
        df_topn = df_topn.merge(frecPer1, how='left', on='palabra')
        df_topn = df_topn.merge(frecPer2, how='left', on='palabra')
        df_topn['max_freq_of_any_decade'] = df_topn[['frec1', 'frec2']].max(axis=1)
        df_topn.drop(['frec1', 'frec2', 'porc1', 'porc2'], axis=1, inplace=True) 
        df_topn = df_topn.loc[df_topn.max_freq_of_any_decade>= at_least_in_any_decade].head(n)
        df_topn = df_topn.sort_values('similaridad_semantica', ascending=True).head(n)
        #display(df_topn)
        topn_all_df.append(df_topn)
    
    topn_periodo[par_periodo] = pd.concat(topn_all_df, ignore_index=True)

# %% [markdown]
# #### Intersección promedio
# Por el enfoque Procruste para cada par de periodos de 5 años:
# ¿Cuál es la similaridad semantica promedio (medida de estabilidad del modelo) de los top 250 palabras de las 50 ejecuciones para cada par de periodos comparados con intervalos de confianza del 95% calculados mediante el método bootstrap?

# %%
def confidence_intervals(data):
    res = bootstrap((data,), np.mean, confidence_level=0.95)
    return (res.confidence_interval.low, res.confidence_interval.high)

# %%
topn_periodo_all = topn_periodo.copy() # copiar

# %%
#df = topn_periodo[(2009, 2014)].copy()
#data = df['palabra'].value_counts().reset_index()
#data = data[data['count']<2]
#pal_lista = list(data['palabra'].unique())
#pal_lista
# (2009, 2014) = ['tratamiento',  'provincia',  'desastre',  'celula', 'pmo', 'ministerio', 'zona', 'ambito']
#(2014, 2019) = ['nina', 'persona', 'medicina', 'potable', 'ley']

# %%
for par_periodo in pares_periodo: 
    display(topn_periodo[par_periodo].shape)
    df = topn_periodo[par_periodo].copy()
    data = df['palabra'].value_counts().reset_index()
    data = data[data['count']>=2]
    pal_lista = list(data['palabra'].unique())
    df = df[df['palabra'].isin(pal_lista)]
    df['vt1'] = df['top10_vecindad_t1'].apply(lambda x: [ peso[0] for peso in eval(x) ])
    df['vt2'] = df['top10_vecindad_t2'].apply(lambda x: [ peso[0] for peso in eval(x) ])
    df['vt1_union'] = df['vt1'].copy()
    df['vt2_union'] = df['vt2'].copy()
    
    #df = df[['par_periodo', 'palabra', 'similaridad_semantica']].groupby(['par_periodo', 'palabra']).agg(['mean', confidence_intervals]).reset_index()
    df = df[['par_periodo', 'palabra', 'similaridad_semantica','vt1','vt2','vt1_union','vt2_union']].groupby(['par_periodo', 'palabra']).agg({
        'similaridad_semantica': ['mean',confidence_intervals],
        'vt1': [ lambda listas: set.intersection(*map(set, listas))],
        'vt2': [ lambda listas: set.intersection(*map(set, listas))],
        'vt1_union': [ lambda listas: set.union(*map(set, listas))],
        'vt2_union': [ lambda listas: set.union(*map(set, listas))]
    }).reset_index()

    #df.sort_values(by='par_periodo', inplace=True)
    df.columns = [
    '_'.join(filter(None, x))
    for x in df.columns.to_flat_index() 
    ]
     	
    df.rename(columns={'vt1_<lambda>': 'vt1_top10', 'vt2_<lambda>': 'vt2_top10','vt1_union_<lambda>': 'vt1_top10_union', 'vt2_union_<lambda>': 'vt2_top10_union'}, inplace=True)
    topn_periodo[par_periodo] = df
# Out:
# (12500, 8)
# (12500, 8)

# %%
topn_periodo[par_periodo].head(3)
# Out:
#     par_periodo        palabra  similaridad_semantica_mean  \
# 0  (2014, 2019)  accesibilidad                    0.246599
# 1  (2014, 2019)         acceso                    0.575210
# 2  (2014, 2019)      accidente                    0.581097
#
#    similaridad_semantica_confidence_intervals  \
# 0  (0.22763808713904068, 0.26636443663705994)
# 1       (0.559738913411164, 0.59046617305113)
# 2     (0.5673349171300808, 0.593610727792091)
#
#                                                 vt1_top10  \
# 0              {discapacitada, movilidad, consentimiento}
# 1  {potable, formulacion, solar, comercialicir, consumar}
# 2                  {acv, cerebrovascular, vascular, acvo}
#
#                                               vt2_top10  \
# 0                                   {elemento, gestion}
# 1                                       {agua, potable}
# 2  {alergia, cerebrovascular, proteina, alzheimer, acv}
#
#                                                                                                                                                                                                                                                                                                                                                vt1_top10_union  \
# 0  {politica, consentimiento, trasplantado, area, maternidad, dato, fertilizacion, presupuesto, informado, permanente, poblacion, concurrencia, desfibrilador, fondo, hijo, seguridad, proteccion, cuyo, actualizacion, garantizar, espacio, judicial, rehabilitacion, asistido, hemocomponent, prepagar, discapacitada, equinoterapia, movilidad, automatico}
# 1                                          {biomedico, gasificado, area, exhibicion, consumar, publico, sal, medida, concurrencia, vacunacion, radiacion, garantizar, agua, potable, produccion, lugar, espacio, piercing, asistido, deber, comercialicir, padecer, epidemiologico, relacionado, regulacion, formulacion, solar, investigacion, muerte_subita}
# 2                                                                                          {seguimiento, minimo, vino, vascular, caso, vida, cerebrovascular, transcurso, rehabilitacion, adquirido, presupuesto, acvo, llamado, digno, artriti, mancha, reumatoidea, sustancia, oporto, sida, natural, recurso, juegos, exposicion, acv, promover, radiacion}
#
#                                                                                                                                                                                                                                                                                                                                                                       vt2_top10_union
# 0                                       {paliativo, visual, dato, tecnologico, congenita, exhibicion, elaborado, elemento, oftalmologico, etiqueta, poblacion, producto, atrofia, muscular, gluten, gratuito, ambiental, numerir, celiaca, espacio, incorporar, similar, examen, digno, calendario, ame, habilitado, condicion, licenciado, gestion, fumar, tabaco, trabajo, espinal}
# 1                                                                                     {provision, punto, dependencia, leche, aplv, presupuesto, farmacia, reproduccion, necesario, medicamento, prioritario, proteina, acv, declarar, calidad, proteccion, edad, privado, cuyo, garantizar, agua, minimo, potable, departamento, apto, padecer, fiebre, vacuna, gratuidad, universal}
# 2  {politica, publicitario, leche, alergia, deteccion, aplv, llamado, enfermo, regional, malformacion, artriti, mancha, psicologico, oporto, quimico, cirugia, atrofia, proteina, cumplimiento, acv, anual, radiacion, vino, vascular, campana, cerebrovascular, alzheimer, hepatitis, fiebre, calendario, leyenda, exigencia, violencia, prevencion, espinal, evaluacion, prevenibl}

# %% [markdown]
# ### Cambios semánticos
#
# #### Identificar las palabras con cambio semántico importante y moderado
#
# Identificar las palabras que aparecen consistentemente como cambiantes con similitud coseno promedio inferior a 0.5
# tal que:
#
# * Cambio fuerte  (usos muy distintos) : similitud coseno promedio <= 0.3 (umbral 1)
# * Cambio moderado: similitud coseno promedio entre 0.3 y 0.5 (umbral 2)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Convertir datos en DataFrame para visualización
def plot_heatmap(cambios_df, title, top = 10):
    #words, values = zip(*changed_words[:top])  # Tomamos el top 10
    #df = pd.DataFrame({"Palabra": words, "Cambio Semántico": values})
    df = cambios_df.copy()
    plt.figure(figsize=(8, 5))
    sns.heatmap(df.set_index("palabra").T, cmap="Reds", annot=True, fmt=".2f", linewidths=0.5)
    plt.title(title + " Top "+str(top))
    plt.show()

# %%
topk = 10
for par_periodo in pares_periodo:

    print("dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos)")
    periodo_df = topn_periodo[par_periodo]
    umbral_fuerte1 = 0.3
    periodo_df1 =  periodo_df[periodo_df['similaridad_semantica_mean']<=umbral_fuerte1].sort_values('similaridad_semantica_mean', ascending=True).head(topk)
    # Graficar Heatmaps
    #display(periodo_df1)
    #plot_heatmap(periodo_df1[['palabra','similaridad_semantica_mean']], "Cambio semántico  (["+str(par_periodo[0])+"-"+str(par_periodo[1])+") → ["+str(par_periodo[1])+"-"+str(par_periodo[1]+5)+")", top=topk)
    print("TOP 10 Palabras:", periodo_df1['palabra'].unique())
    display(periodo_df1) 
    print("dist ~ 0.5 (sc ~ 0.5)  Cambio moderado")

    umbral_fuerte2 = 0.5
    periodo_df1 =  periodo_df[(periodo_df['similaridad_semantica_mean']<=umbral_fuerte2) & (periodo_df['similaridad_semantica_mean']>umbral_fuerte1)].sort_values('similaridad_semantica_mean', ascending=True).head(topk)
    # Graficar Heatmaps
    #plot_heatmap(periodo_df1[['palabra','similaridad_semantica_mean']], "Cambio semántico  (["+str(par_periodo[0])+"-"+str(par_periodo[1])+") → ["+str(par_periodo[1])+"-"+str(par_periodo[1]+5)+")", top=topk)
    print("TOP 10 Palabras:", periodo_df1['palabra'].unique())
    display(periodo_df1)
# Out:
# dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos)
# TOP 10 Palabras: ['legal' 'declaracion']
#       par_periodo      palabra  similaridad_semantica_mean  \
# 186  (2009, 2014)        legal                    0.230416
# 83   (2009, 2014)  declaracion                    0.241996
#
#      similaridad_semantica_confidence_intervals  \
# 186  (0.21918460401466147, 0.24316196816925545)
# 83   (0.22538144276768002, 0.25874248028772795)
#
#                                                                                        vt1_top10  \
# 186  {odontologia, obstetricia, auxiliar, colaborador, loteria, norma, ejercicio, musicoterapia}
# 83                                                         {chaco, rioja, valle, natural, jujuy}
#
#                               vt2_top10  \
# 186                  {monodroga, droga}
# 83   {medicina, prepagar, marco, valor}
#
#                                                                                                                                                                                                                                                                 vt1_top10_union  \
# 186  {expendio, obstetricia, medicina, fitoterapicos, norma, parrafo, odontologia, capitulo, gravamen, auxiliar, colaborador, cosmetologo, terapeuta, cosmetologia, loteria, juegos, ocupacional, complementario, odontologico, ejercicio, eliminacion, musicoterapia, apuesta}
# 83                        {ochenta, rioja, emergencia, valle, alergia, departamento, mendoza, jujuy, epidemiologico, enfermeria, muerte, chaco, rio, accion, natural, vital, atrofia, dengue, pedro, volcanica, corriente, desastre, declarar, tecnico, plazo, espinal, ceniza}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                vt2_top10_union
# 186  {vegetal, mercurio, fetal, fitoterapicos, fisico, empleo, tipo, domiciliario, recoleccion, realizacion, comprendido, elemento, medicamento, oftalmologico, sufrir, cirugia, fabricacion, estudio, proteina, misoprostol, garantizar, embarazo, produccion, caso, planta, instrumento, sol, monodroga, efecto, vencido, laser, calendario, ftalato, vacuna, procreacion, aptitud, alergena, formulacion, exigencia, droga, menor, implante, medicamentosa}
# 83                                                                                                                                                                                                                              {inssjp, medicina, comision, judicial, transcurso, impuesto, maternidad, tecnologico, listado, afiliado, receta, familia, prepagar, pami, lectivo, requisito, marco, exigencia, suspension, trabajo, entidad, publicar, valor}
# dist ~ 0.5 (sc ~ 0.5)  Cambio moderado
# TOP 10 Palabras: ['respectivamente' 'empleo' 'materia' 'el' 'tipo' 'ingreso' 'patologia'
#  'territorio' 'pre' 'acompanante']
#       par_periodo          palabra  similaridad_semantica_mean  \
# 294  (2009, 2014)  respectivamente                    0.326138
# 120  (2009, 2014)           empleo                    0.329805
# 197  (2009, 2014)          materia                    0.347583
# 113  (2009, 2014)               el                    0.367072
# 327  (2009, 2014)             tipo                    0.369607
# 176  (2009, 2014)          ingreso                    0.371601
# 238  (2009, 2014)        patologia                    0.373533
# 326  (2009, 2014)       territorio                    0.379232
# 251  (2009, 2014)              pre                    0.386240
# 4    (2009, 2014)      acompanante                    0.390003
#
#      similaridad_semantica_confidence_intervals  \
# 294  (0.31000066329099835, 0.34259649436498296)
# 120    (0.3152243284074939, 0.3442162811836018)
# 197    (0.3322674175455796, 0.3619563159131458)
# 113    (0.3482723704426346, 0.3824650847704803)
# 327   (0.35189076832918387, 0.3869733164046924)
# 176   (0.35578361207707604, 0.3872754203331894)
# 238  (0.36118246445317465, 0.38710499376822405)
# 326   (0.36277050566657804, 0.3951777759489354)
# 251  (0.37198404208842567, 0.40063318683714794)
# 4      (0.3785201351911447, 0.4004796646310691)
#
#                                                                            vt1_top10  \
# 294                                    {potable, semana, gasificado, ajuste, gravis}
# 120                         {observatorio, comunitario, jefe, hogar, monto, familia}
# 197  {primaria, adopcion, basica, fortalecimiento, estr, presupuesto, postraumatico}
# 113                                       {rioja, regional, septiembre, identificar}
# 327                    {h1n1, virus, gripe, causado, papiloma, influenza, aparicion}
# 176                        {basico, ninez, fincini, ciudadano, geriatrico, ganancia}
# 238    {reconstruccion, mastectomia, puerperio, nocivo, mamaria, mamario, radiacion}
# 326           {chaco, lavanderia, reconocer, percloroetileno, aparicion, tintoreria}
# 251                                                       {sol, recetado, rio, lent}
# 4                     {parto, embarazo, gratuidad, permanencia, nacimiento, proceso}
#
#                                                                                   vt2_top10  \
# 294                                                                 {autoridad, gasificado}
# 120        {ftalato, sustancia, elemento, subsistema, instrumento, monodroga, contributivo}
# 197                                  {politica, vacunacion, congreso, cumplimiento, muerte}
# 113                                                            {premio, septiembre, doctor}
# 327                                                                 {ensenanza, cualquiera}
# 176                                                                      {ninez, categoria}
# 238                                                                {visual, nacido, recien}
# 326                                                                                      {}
# 251                                               {prenatal, sol, recetado, prohibir, lent}
# 4    {obstetricia, cosmetologia, piercing, terapeutico, recurso, equinoterapia, cosmiatrio}
#
#                                                                                                                                                                                                                                                                                                                                                   vt1_top10_union  \
# 294                                                                                                                                                                  {ayuda, agua, remuneracion, equivalente, potable, semana, gasificado, top, bis, acceder, rango, miastenia, mastectomia, osteoporosis, escala, chaga, anual, ajuste, gravis, monto, gratuito}
# 120                                                                                                                                          {equivalente, nivel, remuneracion, consejo, rural, erupcion, pacto, hogar, familia, rango, observatorio, fuerza, comunitario, aprobacion, autorizar, jefe, revestir, republica, volcanica, monto, ceniza, formacion}
# 197                                                                                                                                                                                         {prostata, objetivo, primaria, adopcion, cerebrovascular, red, presupuesto, postraumatico, delito, financiero, hipoacusia, basica, fortalecer, fortalecimiento, estr}
# 113                                                                                                                             {argentina, rioja, comercializado, mundial, ambulancia, infeccion, infanto, autonoma, febrero, identificar, regional, hidrogenado, endemico, septiembre, fibromialgia, aceite, quistico, autorizar, prioritario, juvenil, ciudad}
# 327                                                                                                                                                              {varicela, creasar, gripe, asistencial, causado, papiloma, neumococo, cobro, aparicion, hepatitis, hpv, avance, pandemia, territorio, h1n1, incremento, reconocer, vacunacion, virus, influenza}
# 176  {basico, trabajador, fisico, fincini, conexa, certificado, prenupcial, distribucion, sexo, geriatrico, ninez, correspondiente, revestir, pension, militar, fondo, jubilacion, ganancia, diabetes, medicacion, ciento, anses, asistencial, reconocimiento, monodroga, mental, ciudadano, adiccion, desocupado, ordenado, dieciseis, consultoria, prohibicion}
# 238                                                                                                                                                                                                                     {reconstruccion, partos, producido, maternidad, mamaria, infancia, infantil, mastectomia, puerperio, cirugia, nocivo, mamario, radiacion}
# 326                                                                                                                                                                                                           {ochenta, lavanderia, causado, represa, aparicion, isla, acupuntura, chaco, reconocer, percloroetileno, prioritario, dengue, corriente, tintoreria}
# 251                                                                                             {mercurio, madr, sol, ambiente, monodroga, pila, bateria, relevamiento, epidemiologico, importacion, lent, neuquen, creatin, elemento, peligroso, rio, habilitado, poblacion, trazabilidad, negro, monohidratado, exclusivo, prohibir, recetado, chubut, general}
# 4                                                                                                                                     {reconstruccion, partos, embarazo, embarazado, percibir, mujer, prenatal, maternidad, inciso, permanencia, nacimiento, proceso, parto, puerperio, gratuidad, situacion, marco, violencia, suspension, consultoria, privado}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                    vt2_top10_union
# 294                                                                                                                                                   {consentimiento, subsidio, gasificado, discapacidad, sexo, autoridad, informado, nutricion, composicion, pension, monohidratado, tecnico, monto, jubilacion, potable, judicial, obligacion, el, apto, congreso, mayo, premio, exencion, pensionado, habilitado, requisito, regulacion, donante, suspension, relacion, valor}
# 120                                                                                                                                                                                                                                                                                                                                {mercurio, subsistema, instrumento, asignacion, monodroga, laser, contributivo, ftalato, sustancia, elemento, alergena, misoprostol, formacion}
# 197                                                                                                                                                                                                           {garantizar, politica, produccion, consentimiento, agropecuario, area, obligacion, congreso, trabajo, laboratorio, vencido, domiciliario, glifosato, recoleccion, muerte, fiebre, formulacion, vacunacion, cumplimiento, violencia, economico, seguridad, prevenibl}
# 113                                                                                                                                     {respectivamente, mercurio, consentimiento, inter, distribucion, nacimiento, informado, institucion, julio, creatin, lectivo, septiembre, doctor, monohidratado, fabricacion, control, clinico, edad, expendio, octubre, produccion, monodroga, premio, acreditar, glifosato, importacion, formulacion, prohibir, recetado, lavado, menor}
# 327                                                                                                                                        {mercurio, fetal, integrante, legal, aplv, organo, distribucion, frio, cadena, tabaquismo, sufrir, fabricacion, recurso, proteina, practica, cualquiera, planta, piercing, instrumento, incorporar, ensenanza, nomenclador, importacion, vacuna, deportivo, aptitud, perforacion, prohibir, tatuaj, droga, odontologico, medicamentosa}
# 176                                                                                                                                                                                                                                                                       {politica, explotacion, manejo, area, conexa, sancion, deber, azar, federal, categoria, pobreza, ciudadano, administracion, ninez, fiebre, lactancia, loteria, dengue, virus, maquina, solar, prevenibl}
# 238  {basico, comercializacion, biomedico, visual, inter, deteccion, nino, aplv, nacido, infanto, recoleccion, psoriasis, precio, comprendido, gastrointestinal, codigo, eosinofilico, oftalmologico, etiqueta, nina, situacion, atrofia, trastorno, atencion, juvenil, eliminacion, recien, neonatal, braille, examen, sexual, epidemiologico, diverso, desorden, calendario, pulso, ame, reumatoidea, oximetria, transmision, adolescente, prohibir, recetado, estudio, espinal}
# 326                                                                                                                                                                     {jugo, porcentaje, comision, gasificado, tecnologico, argentino, restaurante, codigo, etiqueta, natural, pension, maquina, educativo, jubilacion, argentina, explotacion, caracter, similar, alcohol, afiliado, menu, organismo, venta, observatorio, nutricional, ocurrido, republica, cartel, capacidad}
# 251                                                                                                                  {nivel, provision, fetal, paliativo, periodo, ambiente, llamado, intrahospitalaria, malformacion, mancha, realizacion, precio, nosocomial, registro, oporto, radiacion, cuidado, gluten, vino, libre, receptor, celiaca, prenatal, sol, asistencial, laser, digno, importacion, lent, comite, tumor, habilitado, solar, prohibir, recetado, materno, estudio}
# 4                                                                                                                                                                                                                                                                                                                                                  {obstetricia, piercing, cosmiatrio, cosmetologia, perforacion, terapeutico, recurso, equinoterapia, tatuaj, tecnico, ejercicio}
# dist > 0.7 (sc <= 0.3) Cambio fuerte (usos muy distintos)
# TOP 10 Palabras: ['dispositivo' 'adecuado' 'accesibilidad']
#      par_periodo        palabra  similaridad_semantica_mean  \
# 96  (2014, 2019)    dispositivo                    0.222339
# 5   (2014, 2019)       adecuado                    0.241482
# 0   (2014, 2019)  accesibilidad                    0.246599
#
#     similaridad_semantica_confidence_intervals  \
# 96   (0.20586610863791263, 0.2391247419353876)
# 5    (0.22572215140184967, 0.2558761352809253)
# 0   (0.22763808713904068, 0.26636443663705994)
#
#                                      vt1_top10  \
# 96        {dato, electronico, similar, nocivo}
# 5                                 {rotulacion}
# 0   {discapacitada, movilidad, consentimiento}
#
#                                               vt2_top10  \
# 96  {tecnologico, minimo, muerte_subita, oftalmologico}
# 5                           {manejo, geriatrico, tumor}
# 0                                   {elemento, gestion}
#
#                                                                                                                                                                                                                                                                                                                                                                     vt1_top10_union  \
# 96  {capacidad, transcurso, dato, cancer, rotulo, infanto, demas, necesario, electronico, administracion, comprendido, correspondiente, bullos, geneticamente, secundario, medica, campana, incorporar, efecto, transgenico, similar, digital, listado, receta, ciudadano, organismo, historia, requisito, leches, implementacion, nocivo, consumidor, osteoporosis, medicamentosa}
# 5                                                                          {jugo, porcentaje, gasificado, frio, informado, cadena, codigo, elaborado, medicinal, composicion, contenido, television, seguridad, camara, profesion, potable, cerrado, planta, braille, rotulacion, alcohol, alimentacion, capitulo, modificatoria, complemento, especialidad, alimentario, circuito}
# 0                       {politica, consentimiento, trasplantado, area, maternidad, dato, fertilizacion, presupuesto, informado, permanente, poblacion, concurrencia, desfibrilador, fondo, hijo, seguridad, proteccion, cuyo, actualizacion, garantizar, espacio, judicial, rehabilitacion, asistido, hemocomponent, prepagar, discapacitada, equinoterapia, movilidad, automatico}
#
#                                                                                                                                                                                                                                                                                                                                   vt2_top10_union
# 96                                                                 {radiacion, minimo, automatico, potable, lugar, escolar, tecnologico, cuidado, pobreza, examen, enfermo, muerte_subita, instalacion, cronico, comprendido, oftalmologico, concurrencia, desfibrilador, adolescente, aplicacion, cartel, educativo, calidad, gratuito, privado}
# 5                                                       {paliativo, manejo, vida, mujer, dato, domiciliario, geriatrico, elemento, financiero, personal, ejecutivo, situacion, hijo, mama, diabetes, cerebrovascular, congreso, ministerio, alzheimer, nomenclador, paciente, agente, modificatoria, tumor, funcion, procreacion, pais, multiple}
# 0   {paliativo, visual, dato, tecnologico, congenita, exhibicion, elaborado, elemento, oftalmologico, etiqueta, poblacion, producto, atrofia, muscular, gluten, gratuito, ambiental, numerir, celiaca, espacio, incorporar, similar, examen, digno, calendario, ame, habilitado, condicion, licenciado, gestion, fumar, tabaco, trabajo, espinal}
# dist ~ 0.5 (sc ~ 0.5)  Cambio moderado
# TOP 10 Palabras: ['forma' 'tipo' 'domiciliario' 'comunitario' 'necesario' 'educacion'
#  'pais' 'manejo' 'obligacion' 'sustancia']
#       par_periodo       palabra  similaridad_semantica_mean  \
# 143  (2014, 2019)         forma                    0.302599
# 317  (2014, 2019)          tipo                    0.316068
# 100  (2014, 2019)  domiciliario                    0.333025
# 62   (2014, 2019)   comunitario                    0.339957
# 221  (2014, 2019)     necesario                    0.347956
# 106  (2014, 2019)     educacion                    0.362112
# 241  (2014, 2019)          pais                    0.363814
# 192  (2014, 2019)        manejo                    0.368741
# 228  (2014, 2019)    obligacion                    0.369161
# 310  (2014, 2019)     sustancia                    0.373314
#
#      similaridad_semantica_confidence_intervals  \
# 143     (0.2882390375204928, 0.316838888095242)
# 317    (0.2983191971361545, 0.3331165147781076)
# 100    (0.317037690697097, 0.35246236927276287)
# 62    (0.32505722278001153, 0.3541252435676746)
# 221   (0.32752307127265573, 0.3694650541698644)
# 106  (0.34007437653483163, 0.38310500701484407)
# 241  (0.35057463923012755, 0.37747087892753695)
# 192    (0.3523312395419264, 0.3830732703936053)
# 228    (0.3551305571824204, 0.3850117959915039)
# 310  (0.35612755699351456, 0.38861854732727286)
#
#                                                                      vt1_top10  \
# 143                                                    {transmision, proteina}
# 317                                                    {ensenanza, cualquiera}
# 100                                                     {recoleccion, vencido}
# 62                                                             {accion, marzo}
# 221                                               {dispositivo, desfibrilador}
# 106                                                                   {semana}
# 241                                                     {deber, comercialicir}
# 192                                       {activo, azar, explotacion, sancion}
# 228  {especialidad, farmaceutico, congreso, cumplimiento, afiliado, profesion}
# 310                {ftalato, elemento, leyendo, alergena, instrumento, empleo}
#
#                                           vt2_top10  \
# 143  {actualizacion, organizacion, correspondiente}
# 317                      {braille, droga, diabetes}
# 100                    {educacion, ter, financiero}
# 62                  {agente, organizacion, escolar}
# 221                             {precio, principio}
# 106  {enfermeria, septiembre, domiciliario, semana}
# 241           {instalacion, ejecutivo, fabricacion}
# 192                         {relacionado, adecuado}
# 228                       {animal, donante, sangre}
# 310                           {materia, etiquetado}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                  vt1_top10_union  \
# 143  {nivel, biomedico, fitoterapicos, tecnica, fertilizacion, prenupcial, almacenamiento, exhibicion, consumar, anonimo, reproduccion, elaborado, humano, tabaquismo, sal, utilizacion, proteina, comida, educativo, cualquiera, gratuito, agua, celiaca, bis, apto, derivado, ensenanza, examen, sexual, adiccion, leyenda, pulso, derogacion, complemento, relacionado, transmision, oximetria, vih, solar, cartel, investigacion, prevenibl}
# 317                                                                                                      {mercurio, fetal, integrante, legal, aplv, organo, distribucion, frio, cadena, tabaquismo, sufrir, fabricacion, recurso, proteina, practica, cualquiera, planta, piercing, instrumento, incorporar, ensenanza, nomenclador, importacion, vacuna, deportivo, aptitud, perforacion, prohibir, tatuaj, droga, odontologico, medicamentosa}
# 100                                                                        {vegetal, consejo, fitoterapicos, paliativo, comision, maternidad, dato, tecnologico, frio, recoleccion, cadena, pami, resolucion, medicamento, financiero, medicinal, autorizar, tecnologia, fortalecimiento, entidad, inssjp, planta, braille, deber, autonoma, vencido, comercialicir, digno, muerte, pensionado, seguro, dengue, materia, anmat, jubilado, droga}
# 62                                                         {primaria, medicina, paliativo, comision, declaracion, marzo, maternidad, cancer, febrero, enfermo, julio, ninez, financiero, mes, prestacion, accion, nacion, natural, fortalecimiento, calidad, victima, octubre, enero, listado, desarrollo, afiliado, mental, mayo, familia, digno, organismo, adiccion, proceso, prepagar, licenciado, marco, violencia, ambito, estatal, valor}
# 221                                                                                                    {fetal, masivo, diagnostico, sexo, tipo, muerte_subita, dispositivo, precio, realizacion, cirugia, diabetico, concurrencia, desfibrilador, comida, practica, general, mama, medica, semana, celiaca, piercing, incorporar, apto, ensenanza, externo, existir, deportivo, osteoporosis, aptitud, loteria, celiaco, prenupcial, automatico}
# 106                                       {paliativo, area, cancer, masivo, nacimiento, intrahospitalaria, administracion, ninez, julio, nosocomial, septiembre, mes, agencia, nacion, vacunacion, seguridad, privado, semana, octubre, derivado, ministerio, sexual, familia, implementar, proceso, difusion, fiebre, observatorio, tumor, comunitario, complemento, provincial, procreacion, osteoporosis, loteria, dengue, ambito, prevenibl}
# 241                                                                          {punto, establecido, dependencia, frio, sexo, guarderia, consumar, farmacia, geriatrico, institucion, alimenticio, cadena, asiento, prioritario, television, desfibrilador, comida, camara, general, geneticamente, envase, cerrado, lugar, deber, comercialicir, externo, acreditar, menu, instalacion, organizacion, deportivo, masa, solar, circuito, capacidad}
# 192                                                                                                                                                                           {ingreso, terapia, politica, explotacion, judicial, cerebrovascular, piercing, sancion, activo, monodroga, juego, azar, acvo, demas, principio, perforacion, vacunacion, control, equinoterapia, tatuaj, recurso, misoprostol, fondo, maquina, apuesta, prevenibl}
# 228                                                                                                                                                               {obstetricia, congreso, ejercicio, tecnologico, frio, listado, afiliado, receta, farmacia, principio, cadena, habilitado, licenciado, medicinal, especialidad, terapeutico, republica, farmaceutico, pension, cumplimiento, otorgar, suspension, tecnico, relacion, profesion}
# 310                                                                                                                                                                                                        {equivalente, mercurio, vino, envase, grasa, vascular, afectar, instrumento, laser, identificacion, alimenticio, malformacion, mancha, ftalato, elemento, leyendo, oporto, alergena, accidente, gestion, odontologico, empleo, sodio}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 vt2_top10_union
# 143                  {respectivamente, punto, establecido, fisico, publicitario, domiciliario, regional, denominado, septiembre, correspondiente, medida, muscular, otorgar, traves, hijo, gluten, cualquiera, actualizacion, indice, secundario, automatico, semana, mundial, celiaca, primario, bis, nomenclador, familia, digno, comite, modificatoria, corporal, organizacion, funcion, condicion, relacionado, seguro, modelo, sindrome, ter, droga, trabajo, espinal, perjudicial, valor}
# 317                                                                                                                                                                                                                                              {secundario, visual, braille, judicial, animal, trasplantado, afectar, sustitucion, discapacidad, educacion, tecnica, certificado, trabajo, domiciliario, extension, pensionado, prepagar, fisico, droga, identificacion, diabetes, capacidad}
# 100                                                                                                                            {respectivamente, paliativo, fisico, educacion, trasplantado, tecnologico, certificado, adecuado, tipo, acompanante, financiero, fondo, hijo, tecnico, cuidado, actividad, ejercicio, cualquiera, formacion, diabetes, obstetricia, especial, animal, primario, rehabilitacion, extension, tumor, organizacion, terapeutico, equinoterapia, ter, trabajo, forma}
# 62                                                                                                                                                                                    {objeto, punto, trabajador, establecido, grasa, obstetricia, escolar, norma, reconocimiento, capacitacion, presupuesto, estetico, agente, corporal, tumor, organizacion, modificatoria, registro, regulacion, tecnologia, especialidad, situacion, complejidad, fortalecimiento, comida, ejercicio, cuyo}
# 221  {terapia, provision, biomedico, comercializacion, manejo, publicitario, mujer, norma, aplv, llamado, farmacia, recoleccion, principio, reproduccion, malformacion, precio, cronico, mancha, oporto, correspondiente, quimico, accion, cirugia, tecnologia, proteina, maquina, acv, misoprostol, acceso, consecuencia, vino, produccion, vascular, espinal, alcohol, organismo, importacion, grupo, fiebre, relacionado, sustancia, dengue, promover, forma, sodio, perjudicial, capacidad}
# 106                                                                                                                                                                                              {respectivamente, articulo, fisico, tecnologico, domiciliario, tipo, enfermeria, acompanante, septiembre, financiero, recurso, fondo, profesion, diabetes, semana, obstetricia, especial, el, alzheimer, mayo, odontologia, pensionado, corporal, licenciado, ter, trabajo, disponer, cordoba}
# 241                                                                                                                                                                                                                                                                                 {consejo, ambiental, red, externo, ciudadano, celula, epidemiologico, recoleccion, instalacion, ejecutivo, fabricacion, desfibrilador, exigencia, virus, concurrencia, laboratorio, clinico, investigacion}
# 192                                                                                                                   {terapia, biomedico, mujer, norma, adecuado, organo, geriatrico, principio, reproduccion, necesario, denominado, elemento, oporto, personal, correspondiente, virus, complejidad, hijo, practica, diabetes, ambiental, pmo, nomenclador, padecer, responsable, obligatorio, hepatitis, relacionado, funcion, deportivo, procreacion, laboratorio, prenupcial, automatico}
# 228                                                                                                                                                                                                                                                    {respectivamente, biomedico, envase, medicina, cobertura, periodo, valor, animal, judicial, afectar, rehabilitacion, listado, organo, alcoholica, obra, estetico, prepagar, leyenda, etiqueta, banco, lactancia, donante, solar, sangre}
# 310                                                                                                                                                                          {centro, comercializacion, periodo, norma, legal, rotulo, suplemento, geriatrico, alimenticio, necesario, autorizar, etiquetado, complementario, secundario, grasa, rehabilitacion, efecto, apto, derivado, alcohol, consumo, padecer, adiccion, importacion, prorrogable, materia, sodio, perjudicial, encontrar}

# %%
# GUARDAR OBJETO
with open(modelo_dir+'/top250_periodos_procrustes_df.pkl', 'wb') as file: 
    pickle.dump(topn_periodo,file)

# %% [markdown]
# Palabras comunes entre los pares de períodos

# %%
# palabra común en entre períodos
palabra_comun = set(topn_periodo[(2009, 2014)]['palabra'].unique()) & set(topn_periodo[(2014, 2019)]['palabra'].unique())
print("Cantidad de palabras en común:",len(palabra_comun))
# Out:
# Cantidad de palabras en común: 276

# %% [markdown]
# Top 10

# %%
# Período (2009, 2014)
df = topn_periodo[(2009, 2014)]
df = df[df['palabra'].isin(palabra_comun)]
df = df[['palabra','similaridad_semantica_mean','similaridad_semantica_confidence_intervals','vt1_top10','vt2_top10']]
df.columns = ['palabra','ss_mean_2009_2014','ss_ci_2009_2014','vt1_top10_2009_2014','vt2_top10_2009_2014']
# Período (2014, 2019)
df2 = topn_periodo[(2014, 2019)]
df2 = df2[df2['palabra'].isin(palabra_comun)]
df2 = df2[['palabra','similaridad_semantica_mean','similaridad_semantica_confidence_intervals','vt1_top10','vt2_top10']]
df2.columns = ['palabra','ss_mean_2014_2019','ss_ci_2014_2019','vt1_top10_2014_2019','vt2_top10_2014_2019']
# Unión
df = df.merge(df2, how='inner', on='palabra')
df = df[['palabra', 'ss_mean_2009_2014', 'ss_mean_2014_2019', 'ss_ci_2009_2014','ss_ci_2014_2019','vt1_top10_2009_2014','vt2_top10_2009_2014', 'vt1_top10_2014_2019','vt2_top10_2014_2019']]
df['peso'] = (df['ss_mean_2009_2014'] + df['ss_mean_2014_2019'] )/2
print("Top 10 de palabras comunes con Fuerte cambio semántco entre Período [2009, 2014) - > [2014, 2019)  ")
print("Palabras:",df[df['peso']<=0.3].sort_values('peso').head(10)['palabra'].unique() )
display(df[df['peso']<=0.3].sort_values('peso').head(10))
print("Top 10 de palabras comunes con moderado cambio semántco entre Período [2009, 2014) - > [2014, 2019)  ")
print("Palabras:",df[(df['peso']>0.3) & (df['peso']<=0.5)].sort_values('peso').head(10)['palabra'].unique() )
display(df[(df['peso']>0.3) & (df['peso']<=0.5)].sort_values('peso').head(10))
# Out:
# Top 10 de palabras comunes con Fuerte cambio semántco entre Período [2009, 2014) - > [2014, 2019)
# Palabras: []
# Empty DataFrame
# Columns: [palabra, ss_mean_2009_2014, ss_mean_2014_2019, ss_ci_2009_2014, ss_ci_2014_2019, vt1_top10_2009_2014, vt2_top10_2009_2014, vt1_top10_2014_2019, vt2_top10_2014_2019, peso]
# Index: []
# Top 10 de palabras comunes con moderado cambio semántco entre Período [2009, 2014) - > [2014, 2019)
# Palabras: ['tipo' 'legal' 'ingreso' 'materia' 'forma' 'argentina' 'comunitario'
#  'respectivamente' 'domiciliario' 'derivado']
#              palabra  ss_mean_2009_2014  ss_mean_2014_2019  \
# 260             tipo           0.369607           0.316068
# 149            legal           0.230416           0.531215
# 141          ingreso           0.371601           0.397244
# 159          materia           0.347583           0.422933
# 120            forma           0.484979           0.302599
# 22         argentina           0.408254           0.382985
# 50       comunitario           0.460755           0.339957
# 236  respectivamente           0.326138           0.479367
# 82      domiciliario           0.495901           0.333025
# 71          derivado           0.459340           0.390248
#
#                                 ss_ci_2009_2014  \
# 260   (0.35189076832918387, 0.3869733164046924)
# 149  (0.21918460401466147, 0.24316196816925545)
# 141   (0.35578361207707604, 0.3872754203331894)
# 159    (0.3322674175455796, 0.3619563159131458)
# 120    (0.4665327142841819, 0.5009133483967529)
# 22     (0.3958283777904521, 0.4203712582242761)
# 50     (0.4459668303655224, 0.4748261881042146)
# 236  (0.31000066329099835, 0.34259649436498296)
# 82    (0.47952582331516275, 0.5109570484530604)
# 71     (0.44563523807165345, 0.471862724692613)
#
#                                 ss_ci_2014_2019  \
# 260    (0.2983191971361545, 0.3331165147781076)
# 149    (0.5117833939128683, 0.5447925434450439)
# 141    (0.3841834612507075, 0.4099497013901893)
# 159    (0.4094772437019852, 0.4364269540652596)
# 120     (0.2882390375204928, 0.316838888095242)
# 22   (0.36590119343130795, 0.39967891989958326)
# 50    (0.32505722278001153, 0.3541252435676746)
# 236   (0.4617260213965058, 0.49642280060125143)
# 82     (0.317037690697097, 0.35246236927276287)
# 71    (0.37203290551394896, 0.4056632749626365)
#
#                                                                              vt1_top10_2009_2014  \
# 260                                {h1n1, virus, gripe, causado, papiloma, influenza, aparicion}
# 149  {odontologia, obstetricia, auxiliar, colaborador, loteria, norma, ejercicio, musicoterapia}
# 141                                    {basico, ninez, fincini, ciudadano, geriatrico, ganancia}
# 159              {primaria, adopcion, basica, fortalecimiento, estr, presupuesto, postraumatico}
# 120                                       {realizacion, indirecto, transmision, directo, chagas}
# 22            {comercializado, limitacion, prioritario, bioetica, republica, cigarrillo, chagas}
# 50                      {radicacion, direccion, voluntario, revestir, militar, hogar, sanitaria}
# 236                                                {potable, semana, gasificado, ajuste, gravis}
# 82         {partos, mercurio, instrumento, vencido, odontologico, civil, recoleccion, capacidad}
# 71                                                     {alergena, envase, geneticamente, gluten}
#
#                                         vt2_top10_2009_2014  \
# 260                                 {ensenanza, cualquiera}
# 149                                      {monodroga, droga}
# 141                                      {ninez, categoria}
# 159  {politica, vacunacion, congreso, cumplimiento, muerte}
# 120                                 {transmision, proteina}
# 22                           {natural, republica, comision}
# 50                                          {accion, marzo}
# 236                                 {autoridad, gasificado}
# 82                                   {recoleccion, vencido}
# 71                  {modificado, exposicion, geneticamente}
#
#                                         vt1_top10_2014_2019  \
# 260                                 {ensenanza, cualquiera}
# 149                                      {monodroga, droga}
# 141                                      {ninez, categoria}
# 159  {politica, vacunacion, congreso, cumplimiento, muerte}
# 120                                 {transmision, proteina}
# 22                           {natural, republica, comision}
# 50                                          {accion, marzo}
# 236                                 {autoridad, gasificado}
# 82                                   {recoleccion, vencido}
# 71                  {modificado, exposicion, geneticamente}
#
#                                                           vt2_top10_2014_2019  \
# 260                                                {braille, droga, diabetes}
# 149                                                             {obstetricia}
# 141  {pensionado, beneficiario, primario, otorgar, fortalecimiento, jubilado}
# 159                             {vih, prorrogable, infeccion, desastre, zona}
# 120                            {actualizacion, organizacion, correspondiente}
# 22     {tecnologia, republica, desfibrilador, exigencia, pobreza, evaluacion}
# 50                                            {agente, organizacion, escolar}
# 236                                                      {publicidad, fisico}
# 82                                               {educacion, ter, financiero}
# 71                                             {medicinal, planta, organismo}
#
#          peso
# 260  0.342838
# 149  0.380816
# 141  0.384422
# 159  0.385258
# 120  0.393789
# 22   0.395619
# 50   0.400356
# 236  0.402753
# 82   0.414463
# 71   0.424794

# %%
# GUARDAR OBJETO
with open(modelo_dir+'/palComun_cambioSem_procrustes_df.pkl', 'wb') as file: 
    pickle.dump(df,file)

# %% [markdown]
# ### Chat GPT
#
# #### Breve historia del sistema argentino de salud entre 2009 a 2023
#
# Destacando los principales cambios, políticas y desafíos en ese período:
#
# **2009-2015: Ampliación de cobertura y enfoque en salud pública**
# * Programa Nacer (iniciado antes) se transformó en Programa SUMAR (2012), ampliando la cobertura sanitaria gratuita a población sin obra social, especialmente niños, embarazadas y adultos hasta 64 años.
#
# * Se fortalecieron las políticas de atención primaria, la distribución gratuita de medicamentos esenciales y el control de enfermedades crónicas.
#
# * Ley Nacional de Salud Mental (2010): marcó un cambio paradigmático hacia una atención centrada en la comunidad, con foco en derechos humanos.
#
# * Inversión en infraestructura y en redes de servicios provinciales, aunque con desigualdades persistentes entre regiones.
#
# **2016-2019: Intento de reformas estructurales y retrocesos por la crisis**
#
# * Lanzamiento de la Cobertura Universal de Salud (CUS) en 2016, con el objetivo de mejorar el acceso de personas sin cobertura formal; sin embargo, tuvo una implementación limitada.
#
# * La crisis económica (inflación, devaluación, recorte del gasto) afectó recursos para salud pública y programas nacionales.
#
# * Tensiones con obras sociales y prepagas por regulaciones, deudas y aranceles.
#
# * En 2018, debate parlamentario por la legalización del aborto generó una movilización social histórica, aunque fue rechazado por el Senado.
#
# **2020-2023: Pandemia, legalización del aborto y digitalización**
# * COVID-19 (2020-2021) puso al sistema bajo gran presión: se ampliaron camas, respiradores, se contrató personal y se distribuyeron recursos federales.
#
# * Se desarrolló un plan nacional de vacunación masivo y gratuito, con campañas públicas y centros de vacunación en todo el país.
#
# * En diciembre de 2020 se aprobó la Ley 27.610 de Interrupción Voluntaria del Embarazo, garantizando el derecho a acceder a un aborto legal y seguro hasta la semana 14.
#
# * Se fortaleció la telemedicina y se impulsó la digitalización de historiales clínicos, aunque de manera desigual según la provincia.
#
# * En 2022-2023, el sistema volvió a enfrentar restricciones presupuestarias por la crisis económica, con reclamos de trabajadores de salud, atraso en pagos a proveedores y conflicto con prepagas por aumentos de cuotas y regulación estatal.
#
# #### Conclusión
# El sistema de salud argentino entre 2009 y 2023 mostró avances importantes en derechos y cobertura, especialmente con programas públicos y leyes clave (salud mental, aborto). Pero también atravesó crisis económicas y desafíos estructurales que afectaron la calidad y equidad del acceso, manteniéndose como un sistema fragmentado y desigual, con fuerte dependencia de decisiones políticas nacionales y provinciales.

# %% [markdown]
# # Anexo

# %% [markdown]
# #### Como detectar cambios liguistico con chatgpt

# %% [markdown]
# Detectar cambios lingüísticos con ChatGPT u otros modelos de lenguaje puede hacerse de varias formas, dependiendo de qué tipo de cambio te interesa (léxico, semántico, sintáctico, etc.).

# %% [markdown]
# * Comparación sincrónica: simular diferentes “épocas” pidiéndole al modelo que hable como si fuera de cierto año:
#
# 🗣️ Prompt:
# “¿Cómo se usaba la palabra ‘cuidar’ en el contexto de salud pública en Argentina en 2010?”
# vs.
# “¿Cómo se usa la palabra ‘cuidar’ en el contexto de salud pública en Argentina en 2023?”

# %% [markdown]
# * Análisis con embeddings + ChatGPT
#
# Asistente para interpretar cambios de significado basados en embeddings entrenados por año. Ejemplo:
# Entrenás vectores (word embeddings) para distintos años. Medís distancia o cambio de contexto de ciertas palabras clave. Usás ChatGPT para ayudarte a interpretar esos cambios
#
# 🔍 Prompt:
# “En 2010, la palabra ‘prevención’ estaba más cerca de ‘vacuna’, ‘campaña’, ‘dengue’. En 2023, está más cerca de ‘cuidado’, ‘género’, ‘territorio’. ¿Qué tipo de cambio semántico puede estar ocurriendo?”
