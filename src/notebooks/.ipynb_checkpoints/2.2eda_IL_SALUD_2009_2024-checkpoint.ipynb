# %% [markdown]
# # Iniciativas legislativas publicadas entre 2009-2024
# ## Período ordinal 127-141

# %%
# Cargar las librerías necesarias
from dotenv import load_dotenv
import pandas as pd
import pickle 
import os
import sys
import numpy as np
import sweetviz as sv
import webbrowser
from ydata_profiling import ProfileReport

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
load_dotenv()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# True

# %%
### CONFIGURACION DATOS
BASE_DIR =  os.getenv("DIR_BASE")
sys.path.append(BASE_DIR)
pd.set_option('display.max_colwidth', None)
RESULTADOS_DIR = os.getenv("DIR_DATOS_PROCESADOS") # Acceder a las variables de entorno
sys.path.append(RESULTADOS_DIR)

# %%
# abrir el archivo binario proyecto filtrado
with open(RESULTADOS_DIR+'proyecto_2009_2024_LIMPIO2_df.pkl', 'rb') as file:
    proyecto_2009_2024_LIMPIO_df = pickle.load(file)

# %%
proyecto_2009_2024_LIMPIO_df.shape
# Out:
# (97738, 21)

# %%
proyecto_2009_2024_LIMPIO_df.head(3)
# Out:
#   Proyecto.ID  \
# 0  HCDN280534
# 1  HCDN280537
# 2  HCDN280533
#
#                                                                                                                                                                                                                                                                                           Título  \
# 0                                                                                                                                                                            ANULENSE LOS DECRETOS 1107/2024 Y 1112/2024, SOBRE MODIFICACIONES EN LAS FUNCIONES DE LAS FUERZAS ARMADAS - FFAA -.
# 1  PEDIDO DE INFORMES VERBALES AL CANCILLER ARGENTINO GERARDO WERTHEIN, ANTE LA COMISION DE LIBERTAD DE EXPRESION, SOBRE LA INTIMACION CURSADA A LA PERIODISTA NATASHA NIEBIESKIKWIAT A RAIZ DE SUS PUBLICACIONES EN TORNO A LA DETENCION DEL GENDARME NAHUEL GALLO, Y OTRAS CUESTIONES CONEXAS.
# ...

# %%
proyecto_2009_2024_LIMPIO_df.describe(include='all').T
# Out:
#                                       count unique  \
# Proyecto.ID                           97738  97738
# Título                                97738  94663
# Publicación.Fecha                     97738    NaN
# Publicación.ID                        97041   3238
# Exp..Diputados                        97738  97738
# Tipo                                  97738      5
# Max_Orden                           97738.0    NaN
# Proyecto_girado_a_comisiones_SALUD  97738.0    NaN
# Proyecto_SALUD                      97738.0    NaN
# Resultado                             97738      7
# Tiene_info_movimiento                 97738      2
# Duración_dias_prep                  97738.0    NaN
# Años_mes                              97738    191
# Año                                 97738.0    NaN
# Mes                                 97738.0    NaN
# Nombre_dia_semana                     97738      7
# Tiempo_desde_public_anterior        97738.0    NaN
# ...

# %% [markdown]
# ### Ver por período parlamentario

# %%
# https://www2.hcdn.gob.ar/export/hcdn/secparl/dgral_info_parlamentaria/dip/archivos/Estadistica_leyes_83-23.pdf
d = {'Período' :[127,128,129,130,131,132,133,134,135,136,137,138,139,140,141],
     'Desde' : ['1/3/2009','1/3/2010','1/3/2011','1/3/2012', '1/3/2013','1/3/2014','1/3/2015','1/3/2016','1/3/2017','1/3/2018','1/3/2019','1/3/2020','1/3/2021','1/3/2022','1/3/2023'],
     'Hasta' : ['28/02/2010','28/02/2011','29/02/2012','28/02/2013','28/02/2014','28/02/2015','29/02/2016','28/02/2017','28/02/2018','28/02/2019', '29/02/2020', '28/02/2021', '28/02/2022','28/02/2023','29/02/2024']}

periodo_HCD_df = pd.DataFrame(d)

# Tipo fecha en python
periodo_HCD_df['Desde'] = pd.to_datetime(periodo_HCD_df['Desde'],  dayfirst=True ,errors='coerce')
periodo_HCD_df['Hasta'] = pd.to_datetime(periodo_HCD_df['Hasta'],  dayfirst=True ,errors='coerce')

# Mostrar
periodo_HCD_df.describe()
# Out:
#           Período                Desde                Hasta
# count   15.000000                   15                   15
# mean   134.000000  2016-02-29 14:24:00  2017-02-27 20:48:00
# min    127.000000  2009-03-01 00:00:00  2010-02-28 00:00:00
# 25%    130.500000  2012-08-30 12:00:00  2013-08-29 12:00:00
# 50%    134.000000  2016-03-01 00:00:00  2017-02-28 00:00:00
# 75%    137.500000  2019-08-31 00:00:00  2020-08-29 12:00:00
# max    141.000000  2023-03-01 00:00:00  2024-02-29 00:00:00
# std      4.472136                  NaN                  NaN

# %%
periodo_HCD_df
# Out:
#     Período      Desde      Hasta
# 0       127 2009-03-01 2010-02-28
# 1       128 2010-03-01 2011-02-28
# 2       129 2011-03-01 2012-02-29
# 3       130 2012-03-01 2013-02-28
# 4       131 2013-03-01 2014-02-28
# 5       132 2014-03-01 2015-02-28
# 6       133 2015-03-01 2016-02-29
# 7       134 2016-03-01 2017-02-28
# 8       135 2017-03-01 2018-02-28
# 9       136 2018-03-01 2019-02-28
# 10      137 2019-03-01 2020-02-29
# 11      138 2020-03-01 2021-02-28
# 12      139 2021-03-01 2022-02-28
# 13      140 2022-03-01 2023-02-28
# 14      141 2023-03-01 2024-02-29

# %%
#proy_fechas_df = proyecto_2009_2024_LIMPIO_df[['Publicación.Fecha']] #'Proyecto.ID',
#proy_fechas_df = proy_fechas_df.sort_values('Publicación.Fecha')

# %%
def asig_periodo (x):
    periodo =  periodo_HCD_df.loc[(periodo_HCD_df['Desde']<=x) & (x <= periodo_HCD_df['Hasta']) ,'Período']
    if len(periodo)> 0 : 
        periodo = periodo.values[0]
    else: 
        periodo = np.nan
    #print(periodo)
    return periodo

# %%
fechas_df = pd.DataFrame(proyecto_2009_2024_LIMPIO_df['Publicación.Fecha'].unique())
fechas_df.columns = ['Fecha']
fechas_df['Periodo'] = 0

# Asignar período
fechas_df['Periodo'] = fechas_df['Fecha'].apply(asig_periodo)

# Integrar
proyecto_2009_2024_LIMPIO_df = pd.merge(proyecto_2009_2024_LIMPIO_df,fechas_df, how ='left', left_on = 'Publicación.Fecha', right_on = 'Fecha' )

# %%
proyecto_2009_2024_LIMPIO_df.columns
# Out:
# Index(['Proyecto.ID', 'Título', 'Publicación.Fecha', 'Publicación.ID',
#        'Exp..Diputados', 'Tipo', 'Max_Orden',
#        'Proyecto_girado_a_comisiones_SALUD', 'Proyecto_SALUD', 'Resultado',
#        'Tiene_info_movimiento', 'Duración_dias_prep', 'Años_mes', 'Año', 'Mes',
#        'Nombre_dia_semana', 'Tiempo_desde_public_anterior',
#        'Tiempo_desde_Proyecto.ID_anterior', 'ID', 'Diferencia_ID',
#        'Tiene_antecedente_por_titulo_proy', 'Fecha', 'Periodo'],
#       dtype='object')

# %%
proyecto_2009_2024_LIMPIO_df['Periodo'].describe()
# Out:
# count    92535.000000
# mean       133.643432
# std          4.175614
# min        127.000000
# 25%        130.000000
# 50%        133.000000
# 75%        137.000000
# max        141.000000
# Name: Periodo, dtype: float64

# %%
### Valores faltantes
proyecto_2009_2024_LIMPIO_df.loc[proyecto_2009_2024_LIMPIO_df['Periodo'].isna(),['Proyecto.ID','Publicación.Fecha','Periodo','Año']].describe()
# Out:
#                    Publicación.Fecha  Periodo          Año
# count                           5203      0.0  5203.000000
# mean   2024-02-08 05:45:24.043820800      NaN  2023.605036
# min              2009-01-05 00:00:00      NaN  2009.000000
# 25%              2024-04-10 00:00:00      NaN  2024.000000
# 50%              2024-06-25 00:00:00      NaN  2024.000000
# 75%              2024-09-18 00:00:00      NaN  2024.000000
# max              2024-12-23 00:00:00      NaN  2024.000000
# std                              NaN      NaN     2.401995

# %%
proyecto_2009_2024_LIMPIO_df.loc[proyecto_2009_2024_LIMPIO_df['Periodo'].isna(),['Proyecto.ID','Publicación.Fecha','Periodo','Año']]['Año'].unique()
# Out:
# array([2024, 2009])

# %%
# PARA 2009 ES CORRECTO
proyecto_2009_2024_LIMPIO_df.loc[(proyecto_2009_2024_LIMPIO_df['Periodo'].isna()) &  (proyecto_2009_2024_LIMPIO_df['Año']==2009),['Proyecto.ID','Publicación.Fecha','Periodo','Año']].describe()
# Out:
#                    Publicación.Fecha  Periodo     Año
# count                            137      0.0   137.0
# mean   2009-02-11 18:13:08.321167872      NaN  2009.0
# min              2009-01-05 00:00:00      NaN  2009.0
# 25%              2009-02-10 00:00:00      NaN  2009.0
# 50%              2009-02-10 00:00:00      NaN  2009.0
# 75%              2009-02-18 00:00:00      NaN  2009.0
# max              2009-02-23 00:00:00      NaN  2009.0
# std                              NaN      NaN     0.0

# %%
# # PARA 2024 ES CORRECTO
proyecto_2009_2024_LIMPIO_df.loc[(proyecto_2009_2024_LIMPIO_df['Periodo'].isna()) &  (proyecto_2009_2024_LIMPIO_df['Año']==2024),['Proyecto.ID','Publicación.Fecha','Periodo','Año']].describe()
# Out:
#                    Publicación.Fecha  Periodo     Año
# count                           5066      0.0  5066.0
# mean   2024-07-05 06:52:26.624556032      NaN  2024.0
# min              2024-03-04 00:00:00      NaN  2024.0
# 25%              2024-04-15 00:00:00      NaN  2024.0
# 50%              2024-06-28 00:00:00      NaN  2024.0
# 75%              2024-09-19 00:00:00      NaN  2024.0
# max              2024-12-23 00:00:00      NaN  2024.0
# std                              NaN      NaN     0.0

# %% [markdown]
# #### VISUALIZACIONES

# %%
proyecto_2009_2024_LIMPIO_df = proyecto_2009_2024_LIMPIO_df[proyecto_2009_2024_LIMPIO_df['Periodo'].notna()]
display(proyecto_2009_2024_LIMPIO_df.head(2))
proyecto_2009_2024_LIMPIO_df.info()
# Out:
#      Proyecto.ID  \
# 5066  HCDN272754
# 5067  HCDN272752
#
#                                                                                                                                                      Título  \
# 5066                                                   SOLICITAR AL PODER EJECUTIVO DISPONGA SOSTENER EL PLENO FUNCIONAMIENTO DE TELAM SOCIEDAD DEL ESTADO.
# 5067  SOLICITAR AL PODER EJECUTIVO DISPONGA ENVIAR EL NUEVO PROYECTO DE LA LEY DE PRESUPUESTO GENERAL DE LA ADMINISTRACION NACIONAL PARA EL EJERCICIO 2024.
#
#      Publicación.Fecha Publicación.ID Exp..Diputados        Tipo  Max_Orden  \
# 5066        2024-02-29   HCDN141TP249    5410-D-2023  RESOLUCION          2
# 5067        2024-02-29   HCDN141TP249    5409-D-2023  RESOLUCION          1
#
#       Proyecto_girado_a_comisiones_SALUD  Proyecto_SALUD  \
# 5066                                 0.0             0.0
# 5067                                 0.0             0.0
#
# ...

# %%
proyecto_2009_2024_LIMPIO_df['Proyecto_SALUD'].value_counts() # SALUD
# Out:
# Proyecto_SALUD
# 0.0    84291
# 1.0     8244
# Name: count, dtype: int64

# %%
proyecto_2009_2024_LIMPIO_df['Tipo'].value_counts() # TIPO
# Out:
# Tipo
# RESOLUCION                   41840
# LEY                          33097
# DECLARACION                  16642
# MENSAJE                        708
# MENSAJE Y PROYECTO DE LEY      248
# Name: count, dtype: int64

# %%
# Preparar datos
summary_df = proyecto_2009_2024_LIMPIO_df.groupby('Periodo').agg(
    total_proyectos=('Proyecto.ID', 'count'),
    proyectos_salud=('Proyecto_SALUD', 'sum')
).reset_index()

summary_df['pct_salud'] = (summary_df['proyectos_salud'] / summary_df['total_proyectos']) * 100

# Datos para gráficos de torta
total_proyectos = summary_df['total_proyectos'].sum()
total_salud = summary_df['proyectos_salud'].sum()
total_no_salud = total_proyectos - total_salud

# %%
# Configurar el estilo y crear la grilla
# Configurar el estilo y crear la grilla
plt.style.use('default')
fig, ax = plt.subplots(1, 1, figsize=(10, 8))  # Tamaño aumentado para mejor legibilidad

# --- GRÁFICO 1: TORTA - TOTAL PROYECTOS VS SALUD ---
labels_pie1 = ['OTROS PROYECTOS', 'PROYECTOS DE SALUD']
sizes_pie1 = [total_no_salud, total_salud]

# Paleta de colores accesible para daltonismo (protanopia, deuteranopia)
# Colores con alto contraste y diferenciables para la mayoría de tipos de daltonismo
colors_pie1 = ['#4D4D4D', '#5DA5DA']  # Gris oscuro y Azul claro (alto contraste)
# Alternativas: ['#F15854', '#5DA5DA'] (Rojo y Azul) o ['#60BD68', '#B2912F'] (Verde y Amarillo-marrón)


# Función personalizada para mostrar valor y porcentaje con formato accesible
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct * total / 100.0))
        return f'{val:,}\n({pct:.1f}%)'
    return my_autopct

# Crear el gráfico de torta
wedges, texts, autotexts = ax.pie(sizes_pie1,  labels=labels_pie1, colors=colors_pie1,
                                  autopct=make_autopct(sizes_pie1), startangle=90,
                                  textprops={'fontsize': 12, 'fontweight': 'bold'})  # Texto más grande

# Mejorar la apariencia de los textos para máxima accesibilidad
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')
    autotext.set_fontsize(12)
    autotext.set_bbox(dict(boxstyle="round,pad=0.3", facecolor='black', alpha=0.7))  # Fondo negro para mejor contraste

for text in texts:
    text.set_fontsize(12)
    text.set_fontweight('bold')
    text.set_color('#2E2E2E')  # Texto oscuro para mejor legibilidad

ax.set_title('Proyectos de salud vs otros \n', pad=20, fontsize=14)
ax.axis('equal')


# --- AJUSTES FINALES ---
plt.tight_layout(pad=3)
plt.subplots_adjust(bottom=0.25, right=0.7)  # Más espacio para leyenda y texto

# Guardar en alta calidad para accesibilidad
plt.savefig(BASE_DIR+'imagenes/proyectosTotalvsSalud_accesible.png', 
            dpi=300, bbox_inches='tight', 
            facecolor='white', edgecolor='none')

plt.show()

# Limpiar para próximos gráficos
plt.cla()
plt.clf()
plt.close(fig)

# %%
import seaborn as sns
# Generar una paleta categórica apta para daltónicos
paleta_daltónicos = sns.color_palette("colorblind", 5)
paleta_daltónicos
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844)]

# %%
# Configurar el estilo y crear la grilla
plt.style.use('default')
fig, ax = plt.subplots(1, 1, figsize=(10, 8))  # Tamaño aumentado para mejor legibilidad

# --- GRÁFICO: TORTA - PROYECTOS DE SALUD POR TIPO ---
# Preparar datos (asegurarse de que tipo_salud_counts existe)
if 'tipo_salud_counts' not in locals():
    # Si no existe, calcularlo desde el DataFrame
    tipo_salud_counts = proyecto_2009_2024_LIMPIO_df[proyecto_2009_2024_LIMPIO_df['Proyecto_SALUD'] == 1]['Tipo'].value_counts()

labels_pie2 = tipo_salud_counts.index.tolist()
sizes_pie2 = tipo_salud_counts.values.tolist()

# Paleta de colores accesible para daltonismo con 4 colores diferenciables
colors_pie2 = paleta_daltónicos #['#F15854','#5DA5DA', '#60BD68', '#B2912F','#FAA43A']  # Azul, Rojo, Verde, Amarillo-marrón
# Para más categorías, agregar: '#FAA43A' (naranja), '#CC79A7' (rosa), '#4D4D4D' (gris)

# Ajustar colores según el número de categorías
if len(labels_pie2) > len(colors_pie2):
    # Extender la paleta si hay más categorías
    colors_pie2 = colors_pie2 * (len(labels_pie2) // len(colors_pie2) + 1)
colors_pie2 = colors_pie2[:len(labels_pie2)]



# Función personalizada para mostrar valor y porcentaje con formato accesible
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct * total / 100.0))
        return f'{val:,}\n({pct:.1f}%)'
    return my_autopct

# Crear el gráfico de torta
wedges, texts, autotexts = ax.pie(sizes_pie2,  labels=labels_pie2, colors=colors_pie2,
                                  autopct=make_autopct(sizes_pie2),  startangle=90,
                                  textprops={'fontsize': 11, 'fontweight': 'bold'})

# Mejorar la apariencia de los textos para máxima accesibilidad
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')
    autotext.set_fontsize(12)
    autotext.set_bbox(dict(boxstyle="round,pad=0.3", facecolor='black', alpha=0.7))

for text in texts:
    text.set_fontsize(12)
    text.set_fontweight('bold')
    text.set_color('#2E2E2E')

ax.set_title(' Proyectos de salud por Tipo\n', pad=20, fontsize=14)

ax.axis('equal')

# --- AJUSTES FINALES ---
plt.tight_layout(pad=3)
plt.subplots_adjust(bottom=0.25, right=0.7)  # Más espacio para leyenda y texto

# Guardar en alta calidad para accesibilidad
plt.savefig(BASE_DIR+'imagenes/proyectosSaludTipo.png', 
            dpi=300, bbox_inches='tight', 
            facecolor='white', edgecolor='none')

plt.show()

# Limpiar para próximos gráficos
plt.cla()
plt.clf()
plt.close(fig)

# %%
def periodos_a_fechas(periodo):

    period_dict = {
                  127:'01/03/2009-28/02/2010',
                  128:'01/03/2010-28/02/2011',
                  129:'01/03/2011-29/02/2012',
                  130:'01/03/2012-28/02/2013',
                  131:'01/03/2013-28/02/2014',
                  132:'01/03/2014-28/02/2015',
                  133:'01/03/2015-29/02/2016',
                  134:'01/03/2016-28/02/2017',
                  135:'01/03/2017-28/02/2018',
                  136:'01/03/2018-28/02/2019',
                  137:'01/03/2019-29/02/2020', 
                  138:'01/03/2020-28/02/2021', 
                  139:'01/03/2021-28/02/2022',
                  140:'01/03/2022-28/02/2023',
                  141:'01/03/2023-29/02/2024',
    }
    
    if isinstance(periodo, int):
#         return r"$\bf{" + str(periods[0]) + "\ &\ " +str(periods[1]) + "}$" + "\n" +period_dict[periods[0]]+' &\n '+period_dict[periods[1]]
        return f'{str(periodo)} ({period_dict[periodo]})'
    return ''

# %%
# Configurar el estilo y crear la grilla
from matplotlib.ticker import PercentFormatter

period_dict = {
        127: '03/2009-02/2010',
        128: '03/2010-02/2011',
        129: '03/2011-02/2012',
        130: '03/2012-02/2013',
        131: '03/2013-02/2014',
        132: '03/2014-02/2015',
        133: '03/2015-02/2016',
        134: '03/2016-02/2017',
        135: '03/2017-02/2018',
        136: '03/2018-02/2019',
        137: '03/2019-02/2020', 
        138: '03/2020-02/2021', 
        139: '03/2021-02/2022',
        140: '03/2022-02/2023',
        141: '03/2023-02/2024',
    }

def periodos_a_fechas(periodo):
    
    if periodo in period_dict:
        return f'{periodo}\n{period_dict[periodo]}'
    return ''

# Configurar el estilo con colores accesibles
plt.style.use('default')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10), sharex=True)

# Colores accesibles (contraste adecuado y distinguibles para daltónicos)
colors = {
    'total_proyectos': '#4D4D4D',  # Azul
    'proyectos_salud': '#5DA5DA',  # Rojo
    'pct_salud': 'blue',        # Verde
    'grid': '#cccccc',
    'text': '#333333'
}

# --- GRÁFICO 1: LÍNEA - TENDENCIA ANUAL (FRECUENCIA ABSOLUTA) ---
line_total = ax1.plot(summary_df['Periodo'], summary_df['total_proyectos'], 
         marker='o', linewidth=2.5, label='Total proyectos', 
         color=colors['total_proyectos'], markersize=6)

line_salud = ax1.plot(summary_df['Periodo'], summary_df['proyectos_salud'], 
         marker='s', linewidth=2.5, label='Proyectos salud', 
         color=colors['proyectos_salud'], markersize=6)

ax1.set_ylabel('Cantidad de proyectos', fontsize=12, fontweight='bold', color=colors['text'])
ax1.set_title('Distribución de proyectos por período parlamentario', fontweight='bold', fontsize=14, pad=20)
ax1.legend(loc='upper right', framealpha=0.9)
ax1.grid(True, alpha=0.4, color=colors['grid'])
ax1.tick_params(axis='x', which='both', bottom=False, labelbottom=False)  # Ocultar labels del x-axis superior

# Añadir valores en los puntos
for i, (periodo, total, salud) in enumerate(zip(summary_df['Periodo'], 
                                              summary_df['total_proyectos'], 
                                              summary_df['proyectos_salud'])):
    # Anotaciones para total proyectos (arriba del punto)
    ax1.annotate(f'{total}', 
                 xy=(periodo, total),
                 xytext=(0, 8), textcoords='offset points', 
                 ha='center', fontsize=9, fontweight='bold',
                 color=colors['total_proyectos'])
    
    # Anotaciones para proyectos salud (debajo del punto)
    ax1.annotate(f'{salud}', 
                 xy=(periodo, salud),
                 xytext=(0, -12), textcoords='offset points', 
                 ha='center', fontsize=9, fontweight='bold',
                 color=colors['proyectos_salud'])

# --- GRÁFICO 2: LÍNEA - TENDENCIA ANUAL (FRECUENCIA RELATIVA) ---
ax2.plot(summary_df['Periodo'], summary_df['pct_salud'],  # Convertir a porcentaje
         marker='D', linewidth=2.5, color=colors['pct_salud'], 
         label='% Proyectos salud del total', markersize=6)

ax2.set_xlabel('Período y fechas correspondientes', fontsize=12, fontweight='bold', color=colors['text'])
ax2.set_ylabel('Porcentaje (%)', fontsize=12, fontweight='bold', color=colors['text'])
ax2.legend(loc='upper right', framealpha=0.9, ncols = 2)
ax2.grid(True, alpha=0.4, color=colors['grid'])
ax2.yaxis.set_major_formatter(PercentFormatter(decimals=0))

# Configurar los ticks del eje X con las fechas
xticks = sorted(summary_df['Periodo'].unique())
xtick_labels = [periodos_a_fechas(x) for x in xticks]

ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, 
                   rotation=20, 
                   ha='right', 
                   fontsize=12,           # Tamaño de fuente más grande
                   family='monospace')    # Fuente monoespaciada para mejor alineación
# Ajustar los márgenes para que las etiquetas no se corten
ax2.tick_params(axis='x', which='major', pad=10)  # Más espacio entre labels y eje

# Añadir fondo alternado para mejor lectura
ax2.set_axisbelow(True)
for i, periodo in enumerate(xticks):
    if i % 2 == 0:  # Fondos alternados
        ax2.axvspan(periodo - 0.4, periodo + 0.4, alpha=0.05, color='gray')

# Ajustar los límites del eje X para mejor visualización
ax2.set_xlim(xticks[0] - 0.5, xticks[-1] + 0.5)

# Añadir título descriptivo al eje X
ax2.set_xlabel('Períodos y sus fechas correspondientes', 
              fontsize=12, 
              fontweight='bold', 
              labelpad=20)

# Añadir valores de porcentaje
for i, (periodo, pct) in enumerate(zip(summary_df['Periodo'], summary_df['pct_salud'])):
    ax2.annotate(f'{pct:.1f}%', 
                 xy=(periodo, pct),
                 xytext=(0, 8), textcoords='offset points', 
                 ha='center', fontsize=9, fontweight='bold',
                 color=colors['pct_salud'],
                 bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8, edgecolor='none'))



# Mejorar la legibilidad del grid
for ax in [ax1, ax2]:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color(colors['grid'])
    ax.spines['bottom'].set_color(colors['grid'])

# Guardar en alta calidad para accesibilidad
plt.savefig(BASE_DIR+'imagenes/evolucion_proyectos.png', 
            dpi=300, bbox_inches='tight', 
            facecolor='white', edgecolor='none')

# Ajustar el espacio entre subplots
plt.subplots_adjust(hspace=0.15)
# --- AJUSTES FINALES ---
plt.tight_layout(pad=2)
plt.subplots_adjust(hspace=0.1, bottom=0.25)  # Ajustar espacio inferior
plt.show()

# %%
# Preparar los datos
salud_df = proyecto_2009_2024_LIMPIO_df[proyecto_2009_2024_LIMPIO_df['Proyecto_SALUD'] == 1]
tipo_counts = salud_df.groupby(['Periodo', 'Tipo']).size().unstack(fill_value=0)
display(tipo_counts)
# Calcular porcentajes por período
tipo_percentages = tipo_counts.div(tipo_counts.sum(axis=1), axis=0) * 100
display(tipo_percentages)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18816\3270396289.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tipo_counts = salud_df.groupby(['Periodo', 'Tipo']).size().unstack(fill_value=0)
# Tipo     DECLARACION  LEY  MENSAJE  MENSAJE Y PROYECTO DE LEY  RESOLUCION
# Periodo
# 127.0             87  151        0                          0         316
# 128.0            113  164        0                          0         314
# 129.0             98  144        0                          0         198
# 130.0            100  150        0                          0         264
# 131.0            106  167        0                          0         257
# 132.0            101  225        0                          0         322
# ...

# %%
# Paleta de colores accesible
colors_pie2 = ['#F15854', '#5DA5DA', '#60BD68', '#B2912F','#FAA43A']  # Rojo, Azul, Verde, Amarillo-marrón

# Configurar el estilo
plt.style.use('default')
fig, ax = plt.subplots(figsize=(14, 8))

# Crear el gráfico de líneas para cada tipo
for i, (tipo, color) in enumerate(zip(tipo_percentages.columns, colors_pie2)):
    ax.plot(tipo_percentages.index, tipo_percentages[tipo], 
            marker='o', linewidth=2.5, markersize=8,
            label=tipo, color=color)
    
    # Añadir anotaciones de valores porcentuales
    for periodo, valor in zip(tipo_percentages.index, tipo_percentages[tipo]):
        if valor > 0:  # Solo annotar valores mayores a 0
            ax.annotate(f'{valor:.1f}%', 
                       xy=(periodo, valor),
                       xytext=(0, 8), textcoords='offset points',
                       ha='center', fontsize=9, fontweight='bold',
                       color=color,
                       bbox=dict(boxstyle="round,pad=0.2", 
                                facecolor='white', 
                                alpha=0.8, 
                                edgecolor='none'))

# Configurar el eje X con las fechas
xticks = sorted(tipo_percentages.index)
xtick_labels = [periodos_a_fechas(x) for x in xticks]

ax.set_xticks(xticks)
ax.set_xticklabels(xtick_labels, rotation=20, ha='right', fontsize=12)


# Configuraciones del gráfico

ax.set_xlabel('Períodos y sus fechas correspondientes', 
              fontsize=12, 
              fontweight='bold', 
              labelpad=20)

ax.set_ylabel('Porcentaje (%)', fontsize=12, fontweight='bold')
ax.set_title('Distribución porcentual de tipos de proyectos de salud por período', 
             fontsize=14, fontweight='bold', pad=20)

ax.legend(title='Tipo de proyecto', loc='best', framealpha=0.9)
ax.grid(True, alpha=0.3)
ax.set_axisbelow(True)

# Formatear eje Y como porcentaje
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))

# Añadir línea de referencia en 0%
ax.axhline(y=0, color='gray', linestyle='-', alpha=0.5, linewidth=0.5)

# Ajustar límites para mejor visualización
ax.set_xlim(xticks[0] - 0.5, xticks[-1] + 0.5)
ax.set_ylim(bottom=0)  # Empezar desde 0%

# Mejorar estética
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#cccccc')
ax.spines['bottom'].set_color('#cccccc')

# Añadir fondo alternado para mejor lectura de períodos
for i, periodo in enumerate(xticks):
    if i % 2 == 0:
        ax.axvspan(periodo - 0.4, periodo + 0.4, alpha=0.05, color='gray')

# Ajustar layout
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)

plt.show()

# Mostrar estadísticas resumen
print("="*60)
print("RESUMEN - DISTRIBUCIÓN DE TIPOS DE PROYECTOS DE SALUD")
print("="*60)
print(f"Período analizado: {min(xticks)} - {max(xticks)}")
print(f"Total proyectos de salud: {len(salud_df)}")
print("\nDistribución general por tipo:")
for tipo in tipo_percentages.columns:
    total_tipo = tipo_counts[tipo].sum()
    pct_tipo = (total_tipo / len(salud_df)) * 100
    print(f"  {tipo}: {total_tipo} proyectos ({pct_tipo:.1f}%)")
# Out:
# ...
# RESUMEN - DISTRIBUCIÓN DE TIPOS DE PROYECTOS DE SALUD
# ...
# Período analizado: 127.0 - 141.0
# Total proyectos de salud: 8244
#
# Distribución general por tipo:
#   DECLARACION: 1361 proyectos (16.5%)
#   LEY: 2848 proyectos (34.5%)
#   MENSAJE: 1 proyectos (0.0%)
#   MENSAJE Y PROYECTO DE LEY: 2 proyectos (0.0%)
#   RESOLUCION: 4032 proyectos (48.9%)

# %%
# Guardamos el archivo binario proyecto filtrado
with open(RESULTADOS_DIR+'proyecto_2009_2024_LIMPIO2_df.pkl', 'wb') as file:
    pickle.dump(proyecto_2009_2024_LIMPIO_df,file)

# %%
salud_df = proyecto_2009_2024_LIMPIO_df[proyecto_2009_2024_LIMPIO_df['Proyecto_SALUD']==1]

# %%
salud_df.describe(include='all').T
# Out:
#                                      count unique  \
# Proyecto.ID                           8244   8244
# Título                                8244   8023
# Publicación.Fecha                     8244    NaN
# Publicación.ID                        8244   2460
# Exp..Diputados                        8244   8244
# Tipo                                  8244      5
# Max_Orden                           8244.0    NaN
# Proyecto_girado_a_comisiones_SALUD  8244.0    NaN
# Proyecto_SALUD                      8244.0    NaN
# Resultado                             8244      5
# Tiene_info_movimiento                 8244      2
# Duración_dias_prep                  8244.0    NaN
# Años_mes                              8244    174
# Año                                 8244.0    NaN
# Mes                                 8244.0    NaN
# Nombre_dia_semana                     8244      7
# Tiempo_desde_public_anterior        8244.0    NaN
# Tiempo_desde_Proyecto.ID_anterior   8244.0    NaN
# ...

# %%
salud_df['Periodo'].value_counts()
# Out:
# Periodo
# 138.0    1192
# 139.0     662
# 132.0     648
# 128.0     591
# 127.0     554
# 136.0     550
# 131.0     530
# 130.0     514
# 137.0     507
# 134.0     461
# 129.0     440
# 133.0     435
# 140.0     422
# 135.0     421
# 141.0     317
# Name: count, dtype: int64

# %%
salud_df['Periodo'].value_counts().mean()
# Out:
# 549.6

# %% [markdown]
# Fórmula de tasa de crecimiento anual (porcentual)
#
# Tasa de crecimiento = ((Valor actual − Valor anterior)/ Valor anterior) × 100

# %%
df = salud_df['Periodo'].value_counts().reset_index()
df.head()
# Out:
#    Periodo  count
# 0    138.0   1192
# 1    139.0    662
# 2    132.0    648
# 3    128.0    591
# 4    127.0    554

# %%
# Ordenar por año (por si acaso)
df = df.sort_values('Periodo')

# Calcular la tasa de crecimiento porcentual año a año
df['tasa_crecimiento'] = df['count'].pct_change() * 100

# %%
df
# Out:
#     Periodo  count  tasa_crecimiento
# 4     127.0    554               NaN
# 3     128.0    591          6.678700
# 10    129.0    440        -25.549915
# 7     130.0    514         16.818182
# 6     131.0    530          3.112840
# 2     132.0    648         22.264151
# 11    133.0    435        -32.870370
# 9     134.0    461          5.977011
# 13    135.0    421         -8.676790
# 5     136.0    550         30.641330
# 8     137.0    507         -7.818182
# 0     138.0   1192        135.108481
# 1     139.0    662        -44.463087
# 12    140.0    422        -36.253776
# 14    141.0    317        -24.881517

# %%
period_dict = {
        127: '03/2009-02/2010',
        128: '03/2010-02/2011',
        129: '03/2011-02/2012',
        130: '03/2012-02/2013',
        131: '03/2013-02/2014',
        132: '03/2014-02/2015',
        133: '03/2015-02/2016',
        134: '03/2016-02/2017',
        135: '03/2017-02/2018',
        136: '03/2018-02/2019',
        137: '03/2019-02/2020', 
        138: '03/2020-02/2021', 
        139: '03/2021-02/2022',
        140: '03/2022-02/2023',
        141: '03/2023-02/2024',
    }

def periodos_a_fechas(periodo):
    
    if periodo in period_dict:
        return f'{periodo}\n{period_dict[periodo]}'
    return ''

# %%
import matplotlib.ticker as ticker
sns.color_palette("pastel")


plt.figure(figsize=(14,8 ))
ax= sns.barplot(data=df, x='Periodo', y='tasa_crecimiento')
# Configurar el eje X con las fechas
xticks = sorted(df['Periodo'].values)
xtick_labels = [periodos_a_fechas(x) for x in xticks]

ax.set_xticks(range(len(xticks)))  # Usar índices en lugar de valores
ax.set_xticklabels(xtick_labels, rotation=20, ha='right', fontsize=12)
ax.set_xlabel('Períodos y sus fechas correspondientes', 
              fontsize=12, 
              fontweight='bold', 
              labelpad=20)

plt.title('Evolución por período parlamentario de la Tasa de Crecimiento entre 2009-2024')
plt.ylabel('Crecimiento (%)')

# Asegurar que el eje X muestre solo enteros
#plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True, nbins=15))

plt.axhline(0, color='black', linestyle='--')
# Agregar etiquetas con colores
for i, v in enumerate(df['tasa_crecimiento']):
    if pd.notna(v):
        color = 'red' if v < 0 else 'black'
        offset = 1 if v >= 0 else -2  # Más espacio visual
        ax.text(i, v + offset, f'{v:.1f}%', ha='center',
                va='bottom' if v >= 0 else 'top', color=color)
        



ax.margins(y=.1, x=.1)
plt.subplots_adjust(bottom=0.2)
plt.tight_layout()
plt.savefig(BASE_DIR+"imagenes/evolucion_IL_periodo_salud_tasa_crecimiento.png")
plt.show()

# %% [markdown]
# Para ver informes
# * https://www4.hcdn.gob.ar/archivos/genero/archivos/informe_proyectos_tipo_comision_2022.pdf
# * https://www4.hcdn.gob.ar/archivos/genero/archivos/infomujlgbt.pdf
