# %% [markdown]
# # Analizar el uso responsable de datos y algorítmo

# %% [markdown]
# En 2025, hablar del uso responsable de datos y algoritmos implica considerar temas actuales, tensiones normativas y contextos sociotécnicos específicos.
# En este trabajo se considera datos abiertos, corpus pequeños y casos con potencial impacto político, por lo que hay consideraciones éticas clave que conviene validar.
# Para el analisis no se contempla guías enfocadas en licencias de software o hardware.

# %% [markdown]
# ## Visión
#
# Modelo algorítmico que
# ayudará en el proceso de toma de decisiones a actores de salud interesados en iniciativas legislativas de argentina y que impactará su accionar.

# %% [markdown]
# ## Dimensiones a analizar:
# En base a marcos éticos y legales, se consideran las siguientes dimensiones de analisis para este trabajo:
#
# * Uso y protección de datos personales o Privacidad y protección de datos personales.
# * Transparencia y rendición de cuentas o Transparencia y explicabilidad.
# * Sesgos y discriminación o Justicia, sesgo y discriminación algorítmica.
#
# La selección de las mismas esta sujeto a la aplicación de guías generadas desde los gobiernos y organizaciones de Argentina y Chile, que adaptan las recomendaciones internacionales a la realidad local.
#
#
# **Referencia bibliográfica**
# * Kunst, M.; Luvini, P. y Dias, J. M. (2025).Guía práctica para la
# clasificación de datos. https://fund.ar/publicacion/guia-practica-para-la-clasificacion-de-datos/
# https://fund.ar/wp-content/uploads/2025/01/Fundar_Guia-practica-para-la-clasificacion-de-datos_Titulo_CC-BY-NC-ND-4.0-1.pdf
#
# * Agencia de Acceso a la Información Pública (AAIP). Guía de recomendaciones para entidades públicas y privadas en
# materia de transparencia y protección de datos personales para una Inteligencia Artificial responsable. Buenos Aires,
# junio de 2024. https://www.argentina.gob.ar/sites/default/files/aaip-argentina-guia_para_usar_la_ia_de_manera_responsable.pdf
#
#     * https://www.argentina.gob.ar/sites/default/files/guia_final.pdf
#
# * Feole, M.; Dias, J. M.; Kunst, M.; Carrizo, Z. y Lavalle, G. G. (2023) Guía práctica para el desarrollo ético de sistemas basados en IA.https://fund.ar/wp-content/uploads/2023/11/Fundar_Guia-practica-para-el-desarrollo-etico-de-sistemas-basados-en-IA_CC-BY-NC-ND-4.0-3.pdf
#
# * AA VV (2023). Declaración de Montevideo sobre
# Inteligencia Artificial y su impacto en América Latina.
# Varias instituciones.https://docs.google.com/document/d/1maoIc9BKnJbM_iv1QXvbU0DofgmmOQne3qjmQb0rFHM/edit?tab=t.0#heading=h.ljg5gyyr7rmv
# * Martínez, M. V., Dumas, V. G., Sarabia, M., y Feldfeber
# Kisilevsky, I. (2022). Innovar con Ciencia de Datos en el
# sector público. Fundación Sadosky. https://innovacionpublicacondatos.fundacionsadosky.org.ar/descargar/HojaDeRuta.pdf
# * Formulación ética de proyectos de ciencia de datos
# (2022), División de Gobierno Digital y Universidad
# Adolfo Ibáñez.https://goblab.uai.cl/wp-content/uploads/2022/08/Guia_Formulacion_etica_proyectos_ciencia_datos.pdf

# %% [markdown]
# ###  Uso y protección de datos personales o Privacidad y protección de datos personales

# %% [markdown]
# **Dataset**
# * ¿Cuál es su tamaño?
#
# Partimos de un conjunto de datos de proyectos de ley sobre  salud presentados en la Cámara de Diputados de la Nación Argentina, correspondientes al período parlamentario 127 al 141 (años 2009–2024).
#     * 2848 iniciativas legislativas (IL) o proyectos de ley sobre Salud. Este conjunto contiendo datos sobre el titulo de proyecto, publicación, giros, entre otros.
#
#     * Para entrenar los embedding se genera un corpus para cada período de cinco años. Se consideran 3 periodos : [2009,2014), [2014,2019), [2019, 2024)
#         * [2019 - 2024) o [137 - 142) -> 1065 IL -> Número de tokens únicos: 1875
#         * [2014 - 2019) o [132 - 137) -> 1008 IL -> Número de tokens únicos: 1967
#         * [2009 - 2014) o [127 - 132) ->  775 IL -> Número de tokens únicos: 1713
#
#
# * ¿Qué variables contiene? Hacer una descripción general de cada variable y tipo de dato que contiene.
#
# VER notebooks 2  https://github.com/AmaliaGuaymasCanavire/iamas_iniciativasleg_salud/blob/main/src/notebooks/2.1eda_IL_2009_2024.ipynb
#
# Los corpus contienen información sobre periodos de comparación y titulos sobre los proyectos de ley analizados.
# * ¿Hay variables que contengan información personal o confidencial? NO
#
# **Calidad**
#  ¿Cuál es la calidad de los datos? ¿Hay datos faltantes?
#  Para seleccionar los proyectos, se tuvo en cuenta principalmente que no haya datos faltantes en títulos y fecha de publicación, como así tambien se esté cargados correctamente o contengan valores validos.
#  Ver notebook 2. https://github.com/AmaliaGuaymasCanavire/iamas_iniciativasleg_salud/blob/main/src/notebooks/2.2eda_IL_SALUD_2009_2024.ipynb
#
#  ¿Contienen errores o inconsistencias? (por ejemplo, por carga manual). ¿Hay algún procedimiento para detectar esto?
#
#
#
#
# ¿Qué variables contiene? Hacer una descripción general de cada variable y tipo de
# dato que contiene. ¿Hay variables que contengan información personal o confidencial? (ver principio
# ético de

# %% [markdown]
# * ¿Estás trabajando con datos
# personales y/o sensibles identificables
# a nivel individual? ¿Cuáles? Por
# ejemplo: nombre (dato personal),
# información socioeconómica
# (dato personal sensible).
#     * No. Estoy trabajando con datos abiertos de proyectos legislativos que no tienen adjunto datos personales de las personas firmantes del proyecto.
#
#     * El procesamiento de proyectos de ley implica trabajar con textos legislativos y metadatos relacionados, y puede involucrar datos personales de las personas en su rol de diputado que presentan dichas iniciativas. Los cuales podrían ser: Nombre y apellido. Circunscripción electoral.Afiliación política. Fechas de presentación y firma de proyectos.
#     * En algunos casos, también pueden estar involucradas posiciones ideológicas o valores expresados en las iniciativas, podrían ser sensibles si se analizan en profundidad.
#
#
# * ¿Has identificado la justificación o base
# legal para trabajar con esos datos?
#     * Son datos abiertos. Por otro lado con respecto al  Consentimiento implícito y contexto, Los datos de las personas en su rol de diputados suelen ser públicos porque forman parte de su función oficial. Sin embargo, deben ser procesados respetando el contexto para el cual fueron publicados, evitando usos que desvirtúen su finalidad original.
#     * En Argentina:
#         * Ley de Protección de Datos Personales (Ley 25.326): Permite el tratamiento de datos personales siempre que estén destinados al ejercicio de funciones propias del ámbito legislativo. Sin embargo, este uso debe ser proporcional y transparente.
#         * Principio de acceso público: Los datos publicados en registros oficiales o en la actividad legislativa no requieren consentimiento para su uso, siempre que se respeten los fines públicos y no se generen perjuicios.
#
#
#
# * ¿Está dentro de las facultades de la
# institución el manejo de los datos?
#
#     * Los datos son abiertos. Los datos abiertos son datos que:
#
#         * Son accesibles públicamente, sin restricciones técnicas, legales o económicas.
#
#         * Están en formatos legibles por máquina (por ejemplo, CSV, JSON, XML).
#
#         * Se pueden reutilizar, redistribuir y combinar con otros datos libremente.
#
#         * Están publicados bajo una licencia abierta (como Creative Commons o datos públicos por ley).
#
# * ¿Has identificado las regulaciones
# que podrían impactar en el proyecto?
#     * Los datos abiertos se basan en los principios de transparencia gubernamental, innovación, participación ciudadana y ciencia abierta.
#     * Si trabajo con los textos de los proyectos que están en formato pdf publicados en boletines oficiales y/o datos de los firmantes habría que analizar si los datos generados del analisis se categorizan como datos sensibles, datos de opiniones personales o afiliaciones.
#
#
# * ¿Existen regulaciones específicas
# que afectan el proyecto, como por
# ejemplo en el área de salud?
#     * Al ser título de proyectos de iniciativas legislativas sobre salud, que corresponde al topíco en el ambito público, no habría problema.
#     * Se entiende que la clasificación de proyectos como de salud, no tiene problemas legales.
#
# * ¿Serán necesarios mecanismos
# para garantizar la calidad de los
# datos personales, como por ejemplo
# mecanismos de acceso, eliminación
# o rectificación? ¿Cuáles?
#     * En el caso de integrar fuentes, es importante los mecanismo de minimización de datos y anonimización principalmente si se analiza los textos completos de los proyectos ley.

# %% [markdown]
# #### Clasificación de datos
# En base al documento de Fundar, la guía contempla la legislación argentina existente y propone tres niveles de criticidad, baja, media y alta, considerando los criterios de confidencialidad, integridad y disponibi-
# lidad.
#
#     *  Criticidad baja: ninguno de los valores asignados superan el 1.
#     * Criticidad media: alguno de los valores asignados es 2.
#     * Criticidad alta: alguno de los valores asignados es 3
#
# En base a la Metodología para evaluar un activo de datos según los principios de seguridad de la información
#
# **En el proyecto se utilizan datos abiertos, que son datos públicos pero con la característica adicional de ser de libre acceso y uso. Si se utilizan los pdf asociados a cada proyecto de ley estariamos hablando de datos de acceso público irrestricto ya que son publicados en boletines oficiales. En ambos casos la criticidad es baja.**
#
# Con respecto a los datos generados:
# * corpus de títulos de proyectos de ley:
# * corpus textos de proyectos de ley en formato pdf
#
# **La criticidad es baja. La Confidencialidad y Disponibilidad toman valores 0 y, la Integridad valor 1.
# **
#
# **Los datos pueden ser conocido y utilizados sin
# autorización por cualquier persona tal que la inaccesi-
# bilidad no afecta el trabajo o a terceros. En relación a la integridad la modificación no autorizada de los datos e información pueden repararse aunque podría
# ocasionar pérdidas, afectar a terceros, sobre todo a quienes forman parte de la Cámara de diputados de la Nación.**
#
# Si estos datos se particularizan en base a los firmantes con el objetivo de un análisis ideologíco o politico podría ser tomados en la categoría de datos sensibles,
# datos de opiniones personales o afiliaciones que pueden ser utilizados para discriminar o estigmatizar a una
# persona, o mismo ser utilizados por empresas con fines comerciales sin el consentimiento del individuo y, por lo tanto, requieren una protección especial. Habría que ver que sucede ante cargos y labores públicos. En este caso la criticidad es media.
#
# En cuanto a uso de datos personales de diputados, según ley 25326 y entendimiento, no sería necesario el consentimiento ya que los datos se obtienen de fuentes de acceso público irrestricto o se recaben para el ejercicio de funciones propias de los poderes del Estado o en virtud de una obligación legal. https://www.argentina.gob.ar/normativa/nacional/ley-25326-64790/actualizacion

# %% [markdown]
# Datos públicos: Información contenida en documentos oficiales accesibles al público, como acuerdos, directivas,
# resoluciones, expedientes, informes, actas, contratos,
# convenios, estadísticas, etc. Estos datos son generados y mantenidos por organismos públicos y están disponibles para cualquier ciudadano.
#     *  Datos de acceso público irrestricto: Información publicada en boletines oficiales, medios de  comunicación escritos, guías telefónicas, listas
# de profesionales, etc. Estos datos están disponibles sin restricciones y pueden ser utilizados por cualquier persona.

# %% [markdown]
# ###  Transparencia y rendición de cuentas o Transparencia y explicabilidad.

# %% [markdown]
# * ¿Crees que un sistema de ciencia de datos/IA es
# el medio adecuado para resolver el problema?
# Es un camino.
#
# * ¿Por qué? ¿Has evaluado otras alternativas?
# No
#
# * ¿Qué impactos negativos podría tener tu
# proyecto? Revisa casos de uso similares.
# Para la limpieza de datos en lenguaje español, la lematización no es la mejor.
# Al trbajar con pequeños datos , es necesario garantizar cierta estabilidad de los modelos. Contemplando que los resultados son meramente exploratorios.
#
# * ¿Crees que los usuarios/afectados encontrarán
# aceptable el uso de datos planteado
# para resolver el problema? ¿Por qué?
# Si
#
# * Si la población completa del país se entera
# de tu proyecto, ¿lo aprobará? ¿Por qué?
#
# Si porque es sistema pensado en la transparencia y visibilización del trabajo en el congreso o iniciativas generadas en argentina sobre salud.
#
# Definición de los algoritmos de optimización que van a ser probados para su entrenamiento. ¿Son explicables o de caja negra?
#
# Podrían ser explicables

# %% [markdown]
# ### Sesgos y discriminación o Justicia, sesgo y discriminación algorítmica

# %% [markdown]
# * ¿Qué inequidades de base hay en el
# proceso/entorno donde se inserta
# el proyecto? Por ejemplo, si se
# requiere de acceso a internet
#
# Se requiere internet, entendimiento de gráficas asociadas a NLP.
#
# * ¿Existen grupos específicos (vulnerables) para los que deseas garantizar la equidad de los resultados o la protección de sus derechos? Por ejemplo, grupos dado su
# género, edad, localización, clase social, nivel educativo, urbano-rural, etnia.
#
# Se analiza datos en lenguaje español asociado a Salud. El analisis de cambio semantico no tiene perspectiva de género.
#
#
# ¿Qué sesgos crees que podrían tener los datos?
#
# Considera las Iniciativas generadas en la cámara de diputados, disponibles como datos abiertos.
#
#
#
# Sesgos I. Realizar un análisis preliminar de sesgos y problemas de representatividad en los datos.
# ¿Se hacen suposiciones sobre los datos? ¿Qué criterios de sesgos y representatividad se probaron?
# Definir valores aceptables de sesgos
#
# Sesgos II. Realizar un análisis de sesgos en el algoritmo finalizado. ¿Qué criterios de sesgos se pro-
# baron? Definir valores aceptables de sesgos
