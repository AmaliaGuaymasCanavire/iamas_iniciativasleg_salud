# %% [markdown]
# # Proyectos
# Se denominan proyectos a las iniciativas legislativas de los Diputados ,Senadores y Poder Ejecutivo. Hay distintos tipos de proyectos:
#
# * Proyectos de ley: destinados a crear, modificar, sustituir o abrogar una ley, institución o norma de caracter general.
#
# * Proyectos de resolución: destinados a la adopción de medidas relativas a la composición u organización interna del cuerpo, las modificaciones del reglamento y, en general, de toda disposición de carácter imperativo que pueda adoptar la Cámara.
#
# * Proyectos de declaración: destinados a expresar una opinión del cuerpo sobre cualquier hecho de carácter público o privado, o manifestar la voluntad de que el Poder Ejecutivo practique algún acto en particular.
#
# ## Sitio web : Buscador de proyecto
# Link: https://www.diputados.gov.ar/proyectos/
#
#
# * Visto 14/06/2024
# * Resultados de Búsqueda (sin filtro): 262025
#  Proyectos Encontrados
# * Proyecto presentados desde : 1999
#
# * Datos de Actualización
#   * Carga de	Cámara	Hasta Expte.	Fecha	Publicación	Nro.
#   Proyectos	Diputados	2905-D-2024	05/06/2024	Tramite parlamentario	70
#   Proyectos	Senado	0915-S-2024	28/05/2024	Diario de Asuntos Entrados	45
# * Ejes:  Proyectos, Trámites,  Dictámenes, Firmantes,  Comisiones

# %% [markdown]
# ### CONTEXTO
# #### LEYES: https://www.congreso.gob.ar/leyes.php
# * La “iniciativa legislativa”, es decir la facultad de presentar proyectos de ley, corresponde a los diputados, senadores y al presidente de la Nación. La última reforma constitucional de 1994 incorporó también el derecho de “iniciativa popular”. Si un proyecto ingresa al Congreso por la Cámara de Diputados, esta se convierte en la cámara de origen del proyecto y el Senado pasa a ser la cámara revisora. Cuando un proyecto se presenta en el Senado, este se convierte en cámara de origen y la Cámara de Diputados, en cámara revisora.
#   * En otra parte – Art. 39 CN- se reconoce la iniciativa popular:
# “Los ciudadanos tienen el derecho de iniciativa para presentar
# proyectos de ley en la Cámara de Diputados”.
#
# * El camino de la ley
#   * Presentación de un proyecto en mesa de entradas de la Cámara de Diputados o del Senado.
#   * Tratamiento en comisiones. El proyecto pasa a una o más comisiones de asesoramiento, que emiten un dictamen. En ocasiones, frente a temas de gran urgencia o relevancia, un proyecto puede ser tratado “sobre tablas” en el recinto sin que haya pasado previamente por las comisiones.
#   * Debate parlamentario en ambas cámaras.
#
# #### ELABORACIÓN Y PROCEDIMIENTO DE UN PROYECTO: LEGISLATIVO EN EL SENADO DE LA NACIÓN, nociones básicas. Ver [pdf](https://www.senado.gob.ar/bundles/senadomicrositios/pdf/ELABORACION%20Y%20PROCEDIMIENTO%20DE%20UN%20PROYECTO%20LEGISLATIVO.pdf)
#
# * Tipos de proyectos: Proyectos de ley. Proyectos de decreto. Proyectos de resolución. Proyectos de comunicación. Proyectos de declaración.
# * Proyecto de ley: Los avances de la comunicación informática han logrado
# mejorar el conocimiento material de la ley, el sitio
# www.infoleg.gov.ar es la base de datos jurídica on line del Ministerio
# de Economía que permite el conocimiento de la legislación nacional
# vigente en la Argentina; el CEDOM publica la legislación de la
# Ciudad de Buenos Aires, entre otras páginas oficiales en la red.
#  De este modo el sistema representativo se fortalece pues el
# ciudadano puede conocer la actividad de sus representantes; en la
# página www.senado.gov.ar (Cámara de Senadores) o
# www.hcdn.gov.ar (Cámara de Diputados) se indican los proyectos
# presentado por casa senador o diputado nacional, el tramite
# legislativo y las versiones taquigráficas de las sesiones legislativas,
# entre otros datos de interés.
# * TRAMITE ESPECÍFICO PASO POR PASO : Mesa de Entradas. Cámara. Giro. Cómisiones.
# Labor parlamentaria. Cámara. Camara de Diputados. Promulgación.
# * ELABORACIÓN DEL PROYECTO: Inicio; búsqueda de antecedentes; análisis jurídico, sociológico y valorativo; política y planificación estratégica.
#
#
# #### PROYECTOS DE LEY: ¿QUÉ SON Y CÓMO SE ESCRIBEN? (versión niños). Ver [pdf](https://chicos.congreso.gob.ar/public/materiales/secundario/proyectos_ley_que_son_como_se_escriben.pdf)
#
# * Todo proyecto de ley tiene al menos tres partes: encabezamiento, articulado y
# fundamentos
# * Redactar el articulado en tiempo presente y en modo imperativo. ● Evitar el uso de gerundios, adverbios y adjetivos. ● Evitar el uso de voz pasiva.
# ● Evitar el uso de abreviaturas. ● Evitar el uso de palabras en idioma extranjero. ● Evitar el uso innecesario de mayúsculas. ● En caso de usar siglas, aclarar siempre su significado la primera vez que se utilicen.
# ● Frente a textos dispositivos muy extensos y complejos, usar divisiones internas que faciliten su comprensión, como: libros, partes, títulos, capítulos y secciones. ● Respetar las fórmulas de encabezado y cierre.

# %%
import pandas as pd
import numpy as np

# %%
# !pip install sweetviz

# %%
import os
os.chdir('/content/drive/MyDrive/Tesis 2024/datos/diputados')

# %% [markdown]
# ## Datos abiertos
# link: https://datos.hcdn.gob.ar/dataset
# * Visto 14/06/2024
# * 31 Dataset

# %% [markdown]
# ### PROYECTOS PARLAMENTARIOS
#
# Proyectos parlamentarios iniciados desde el período parlamentario 126º (01/03/2008) y que tuvieron tratamiento en la H. Cámara de Diputados.

# %%
# https://datos.hcdn.gob.ar/dataset/proyectos-parlamentarios
# Documentación	http://www4.hcdn.gob.ar/Datos_doc/DOCUMENTACION - PROYECTOS PARLAMENTARIOS.pdf
# Responsable	Dirección de Información Parlamentaria
# Última actualización	13 de diciembre de 2023, 11:22 (UTC-03:00)
# Creado	14 de junio de 2018, 11:20 (UTC-03:00)
# Frecuencia de actualización	Eventual
proyecto_df = pd.read_csv('proyectos_parlamentarios1.10.csv')

# %% [markdown]
# * proyecto_id: identificador único de registro.
# * publicación_fecha: Fecha en que se publicara el proyecto, ya sea que fuera
# publicado en cualquier publicación del Congreso, o sin publicación, se registra el primer movimiento en Comisión o en Recinto.
# * publicacion_id: identificador único de la publicación correspondiente. (ver dataset ‘Publicaciones’ [https://datos.hcdn.gob.ar/dataset/publicaciones/resource/9ef22cd7-b7d8-47a6-bbf3-79095d47275c] En proyectos iniciados en la Cámara de Senadores, este valor será nulo. También será nulo cuando el proyecto no tuviere publicación por ser iniciado en recinto o dictamen directo en comisión.
# * camara_origen: Cámara donde se inició el expediente; Diputados o Senadores.
# * expediente_diputados: Número, identificador y año del expediente.
# * expediente_senado: Número, identificador y año del expediente, cuando el
# expediente se girara al Senado.
# * proyecto_tipo: tipo de proyecto que puede ser de ley, de resolución o declaración.

# %%
proyecto_df.head()
# Out:
#   proyecto_id                                             titulo  \
# 0  HCDN272061  ACEPTAR LA RENUNCIA DE LA SEÑORA DIPUTADA VICT...
# 1  HCDN272062  ACEPTAR LA RENUNCIA DE LA SEÑORA DIPUTADA MARI...
# 2  HCDN272060  ACEPTAR LA RENUNCIA DE LA SEÑORA DIPUTADA SUSA...
# 3  HCDN272059  ACEPTAR LA RENUNCIA DEL SEÑOR DIPUTADO MATIAS ...
# 4  HCDN272058  ACEPTAR LA RENUNCIA DEL SEÑOR DIPUTADO CLAUDIO...
#
#      publicacion_fecha publicacion_id camara_origen exp_diputados  \
# 0  2023-12-09T00:00:00  HCDN141BAE000     Diputados   4814-D-2023
# 1  2023-12-09T00:00:00  HCDN141BAE000     Diputados   4688-D-2023
# 2  2023-12-09T00:00:00  HCDN141BAE000     Diputados   4621-D-2023
# 3  2023-12-08T00:00:00  HCDN141BAE000     Diputados   4407-D-2023
# 4  2023-12-07T00:00:00  HCDN141BAE000     Diputados   4747-D-2023
#
#   exp_senadores        tipo
# 0           NaN  RESOLUCION
# 1           NaN  RESOLUCION
# 2           NaN  RESOLUCION
# 3           NaN  RESOLUCION
# 4           NaN  RESOLUCION

# %%
proyecto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99972 entries, 0 to 99971
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   proyecto_id        99972 non-null  object
#  1   titulo             99972 non-null  object
#  2   publicacion_fecha  99972 non-null  object
#  3   publicacion_id     97326 non-null  object
#  4   camara_origen      99972 non-null  object
#  5   exp_diputados      99972 non-null  object
#  6   exp_senadores      3210 non-null   object
#  7   tipo               99972 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
proyecto_df.describe(include='all')
# Out:
#        proyecto_id                         titulo    publicacion_fecha  \
# count        99972                          99972                99972
# unique       99972                          97199                 3308
# top     HCDN272061  JUICIO POR JURADOS. CREACION.  2010-03-02T00:00:00
# freq             1                             18                  270
#
#        publicacion_id camara_origen exp_diputados exp_senadores        tipo
# count           97326         99972         99972          3210       99972
# unique           3160             2         99972          3198           5
# top      HCDN127TP001     Diputados   4814-D-2023  0149-CD-2015  RESOLUCION
# freq              202         98026             1             5       45063

# %%
proyecto_df['publicacion_fecha'] = pd.to_datetime(proyecto_df['publicacion_fecha'])
proyecto_df['publicacion_fecha'].describe()
# Out:
# count                            99972
# mean     2015-08-18 05:00:47.101188096
# min                2008-03-03 00:00:00
# 25%                2012-02-07 00:00:00
# 50%                2015-04-22 00:00:00
# 75%                2019-04-09 00:00:00
# max                2023-12-09 00:00:00
# Name: publicacion_fecha, dtype: object

# %%
# Resolución - Declaración - Comunicación - Resolución/Declaración - Mensaje PEN
# Habría que ver que pasa con el tipo Resolución/Declaración que aparece en buscador pero no en datos abiertos
proyecto_df.tipo.unique()
# Out:
# array(['RESOLUCION', 'LEY', 'DECLARACION', 'MENSAJE',
#        'MENSAJE Y PROYECTO DE LEY'], dtype=object)

# %%
import sweetviz as sv
my_report = sv.analyze(proyecto_df)
my_report.show_html(filepath='/SWEETVIZ_REPORT_proyecto.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report /SWEETVIZ_REPORT_proyecto.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report.show_notebook(  w=None,
                h=None,
                scale=None,
                layout='widescreen',
                filepath=None,
                file_layout=None,
                file_scale=None)
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# En el buscador del sitio web se identifican 72 proyectos asociados a la palabra "muerte súbita" (indicado en buscador), esto se debe en que se muestran proyectos presentados desde 1999 y en los archivos de datos abiertos existen desde 2008.https://www.hcdn.gob.ar/proyectos/resultado.html

# %%
proyecto_SUBITA_df = proyecto_df[proyecto_df.titulo.str.contains(pat = 'MUERTE SUBITA')]
proyecto_SUBITA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 2342 to 95318
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   proyecto_id        16 non-null     object
#  1   titulo             16 non-null     object
#  2   publicacion_fecha  16 non-null     datetime64[ns]
#  3   publicacion_id     15 non-null     object
#  4   camara_origen      16 non-null     object
#  5   exp_diputados      16 non-null     object
#  6   exp_senadores      1 non-null      object
#  7   tipo               16 non-null     object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 1.1+ KB

# %%
proyecto_SUBITA_df.tipo.unique()
# Out:
# array(['DECLARACION', 'LEY', 'RESOLUCION'], dtype=object)

# %% [markdown]
# ### Dictamenes
# Resoluciones fundadas de las comisiones sobre los expedientes parlamentarios.
# El Dictamen también llamado “Despacho de Comisión”, contiene todas aquellas modificaciones a un asunto o proyecto sometido a estudio de la misma. El despacho de Comisión debe contener el dictamen concreto a que se ha arribado respecto del tema en estudio, y un informe escrito aclaratorio de sus motivaciones. En cierta forma se podría decir que estamos en presencia de recomendaciones que los legisladores miembros de la/s Comisión/es le formulan al resto de sus pares a efectos de aprobar o no una iniciativa. Cada despacho se publica íntegramente como Orden del Día, conteniendo un dictamen de Comisión. La tarea de las Comisiones finaliza con la emisión del dictamen.

# %%
#Documentación	http://www4.hcdn.gob.ar/Datos_doc/Documentacion-dictamenes.pdf
#Responsable	Secretaría Parlamentaria
#Versión	1.0
#Última actualización	21 de marzo de 2024, 11:35 (UTC-03:00)
#Creado	8 de agosto de 2019, 11:39 (UTC-03:00)
dictamenes_df = pd.read_csv('dictamenes2.4.csv')
display(dictamenes_df.head())
dictamenes_df['Fecha'] = pd.to_datetime(dictamenes_df['Fecha'], errors='coerce') # fecha = 0 ignore?
print(dictamenes_df.describe(include='all'))
# Out:
#   expediente_id                                               giro  orden  \
# 0    HCDN109387                      ACCION SOCIAL Y SALUD PUBLICA      1
# 1    HCDN107137  ASUNTOS COOPERATIVOS, MUTUALES Y DE ORG.NO GUB...      1
# 2    HCDN104164                                            CULTURA      1
# 3    HCDN104942                                            CULTURA      1
# 4    HCDN107779                                            CULTURA      1
#
#            tipo                                      observaciones  numero  \
# 0  ARTICULO 114  ARTICULO 114 DEL REGLAMENTO DE LA H. CAMARA DE...       0
# 1  ARTICULO 114  ARTICULO 114 DEL REGLAMENTO DE LA H. CAMARA DE...       0
# 2  ARTICULO 114  ARTICULO 114 DEL REGLAMENTO DE LA H. CAMARA DE...       0
# 3  ARTICULO 114  ARTICULO 114 DEL REGLAMENTO DE LA H. CAMARA DE...       0
# 4  ARTICULO 114  ARTICULO 114 DEL REGLAMENTO DE LA H. CAMARA DE...       0
#
#   Fecha  expedientes
# 0     0            1
# 1     0            1
# ...

# %% [markdown]
# ### MOVIMIENTO DE PROYECtO/ TRAMITES?
# No se encuentra archivo con nombre trámite (rápida asociacion en base al buscador de proyecto).
# Últimos resultados de los proyectos parlamentarios con tratamiento en la H. Cámara
# de Diputados desde el período parlamentario 126º (01/03/2008).

# %%
#Documentación	http://www4.hcdn.gob.ar/Datos_doc/Documentacion-movimientos proyectos .pdf
#Responsable	Secretaría Parlamentaria
#Versión	1.0
#Última actualización	13 de diciembre de 2023, 11:19 (UTC-03:00)
#Creado	8 de agosto de 2019, 11:24 (UTC-03:00)
#Frecuencia de actualización	eventual

# %%
# Última actualización de los datos	Diciembre 13, 2023 / Última actualización de los metadatos	Agosto 8, 2019
# Creado	Agosto 8, 2019
movimiento_df = pd.read_csv('movimientos_proyectos1.5.csv')
movimiento_df['fecha'] = pd.to_datetime(movimiento_df['fecha'], errors='coerce') # fecha = 0 ignore?
display(movimiento_df.head())
print(movimiento_df.describe(include='all'))
# Out:
#   proyecto_id fecha movimiento  orden
# 0  HCDN272079   NaT        NaN    NaN
# 1  HCDN272078   NaT        NaN    NaN
# 2  HCDN272077   NaT        NaN    NaN
# 3  HCDN272076   NaT        NaN    NaN
# 4  HCDN272075   NaT        NaN    NaN
#        proyecto_id                          fecha                  movimiento  \
# count       123275                          17067                       58990
# unique       99938                            NaN                       13336
# top     HCDN248259                            NaN  CONSIDERACION Y APROBACION
# freq            63                            NaN                        4715
# mean           NaN  2013-01-19 12:42:39.043768576                         NaN
# min            NaN            2007-11-07 00:00:00                         NaN
# 25%            NaN            2009-11-04 00:00:00                         NaN
# 50%            NaN            2011-11-30 00:00:00                         NaN
# ...

# %% [markdown]
# ### RESULTADO PROYECTOS/TRAMITES?
# Últimos movimientos y resultados de los proyectos parlamentarios con tratamiento en la H. Cámara de Diputados que se iniciaran desde el período parlamentario 126º (01/03/2008).

# %%
# https://datos.hcdn.gob.ar/dataset/resultado-proyectos
# Documentación	http://www4.hcdn.gob.ar/Datos_doc/DOCUMENTACION – resultado proyectos.pdf
# Responsable	Secretaria Parlamentaria
# Última actualización	13 de diciembre de 2023, 11:25 (UTC-03:00)
# Creado	7 de agosto de 2019, 9:48 (UTC-03:00)
# Frecuencia de actualización	eventual

# %%
resultado_df = pd.read_csv('resultado_proyectos1.8.csv')
display(resultado_df.head())
print(resultado_df.describe(include='all'))
# Out:
#   expediente_id    cabecera  dictamen_tipo  od_numero       od_publicacion  \
# 0    HCDN261442  HCDN261442  Orden del Dia      721.0  2023-07-06T00:00:00
# 1    HCDN118409  HCDN118409  Orden del Dia     1291.0  2010-09-28T00:00:00
# 2    HCDN118409  HCDN118409  Orden del Dia     1291.0  2010-09-28T00:00:00
# 3    HCDN255496  HCDN255496  Orden del Dia      532.0  2022-11-17T00:00:00
# 4    HCDN126867  HCDN126867  Orden del Dia     2152.0  2011-05-10T00:00:00
#
#   fecha resultado
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN       NaN
# 4   NaN       NaN
#        expediente_id  cabecera  dictamen_tipo     od_numero  \
# count         103822     21801          22309  21606.000000
# unique         99389      1572              5           NaN
# top       HCDN160118  cabecera  Orden del Dia           NaN
# freq              79     17934          21607           NaN
# mean             NaN       NaN            NaN   1216.953254
# ...

# %% [markdown]
# ### COMISIONES
# Comisiones parlamentarias permanentes, especiales y bicamerales en las que interviene la Cámara de Diputados.
#
# Las presentes son replicas en formatos abiertos de la información publicada en la pagina oficial de la HCDN (http://hcdn.gob.ar/comisiones/index.html) Cualquier error o diferencia se tomara como valida la información publicada en la pagina oficial.

# %%
# Documentación	http://www4.hcdn.gob.ar/Datos_doc/DOCUMENTACION – COMISIONES.pdf
# Responsable	Dirección de Información Parlamentaria
# Versión	1.0
# Última actualización	21 de marzo de 2024, 11:38 (UTC-03:00)
# Creado	5 de junio de 2018, 11:03 (UTC-03:00)
# Frecuencia de actualización	Eventual
comisiones_df = pd.read_csv('comisiones1.9.csv',encoding='latin-1') #  'utf-8' codec can't decode byte 0xd1 in position 1619: invalid continuation byte
display(comisiones_df.head())
print(comisiones_df.describe(include='all'))
# Out:
#           id                                    comision_nombre  \
# 0  HCDN00014  ESPECIAL ANALISIS DEL SISTEMA POR PEAJE Y FINA...
# 1  HCDN00015  ESPECIAL INVESTIGADORA DE HECHOS ILICITOS Y CO...
# 2  HCDN00016  ESPECIAL INVESTIGADORA CONTRATACIONES ESTADO A...
# 3  HCDN00020  ESPECIAL INVESTIGADORA ADMINISTRACION NACIONAL...
# 4  HCDN00022                                ASUNTOS MUNICIPALES
#
#   comision_grupo  periodo_inicio  periodo_finaliacion fecha_inicio  \
# 0             CD             116                  999   01/03/1998
# 1             CD             116                  999   01/03/1998
# 2             CD             116                  999   01/03/1998
# 3             CD             116                  999   01/03/1998
# 4             CD             116                  999   01/03/1998
#
#   fecha_finalizacion Tipo de ComisiÃ³n
# 0                  0                 E
# 1                  0                 E
# 2                  0                 E
# ...

# %% [markdown]
# ## FIRMANTES : DE LEYES SANCIONADAS
# Firmantes y cofirmantes de proyectos de ley que resultaron sancionados definitivamente.

# %%
# Documentación	http://www4.hcdn.gob.ar/Datos_doc/Doc_Firmantes leyes sancionadas.pdf
# Responsable	Dirección de Información Parlamentaria
# Versión	1.0
# Última actualización	27 de febrero de 2020, 10:41 (UTC-03:00)
# Creado	27 de abril de 2018, 11:39 (UTC-03:00)
# Frecuencia de actualización	Eventual
firmantes_df = pd.read_csv('firmantes-leyes-sancionadas1.8.csv')
#firmantes_df['fecha'] = pd.to_datetime(movimiento_df['fecha'], errors='coerce') # fecha = 0 ignore?
display(firmantes_df.head())
print(firmantes_df.describe(include='all'))
# Out:
#      ley camara_iniciadora  firmante_orden                    firmante  \
# 0  27544         Diputados               1          FERNANDEZ, ALBERTO
# 1  27544         Diputados               2    CAFIERO, SANTIAGO ANDRES
# 2  27544         Diputados               3  GUZMAN, MARTIN MAXIMILIANO
# 3  27543            Senado               1             MACRI, MAURICIO
# 4  27543            Senado               2                PEÑA, MARCOS
#
#   firmante_distrito  firmante_bloque
# 0               NaN  PODER EJECUTIVO
# 1               NaN  PODER EJECUTIVO
# 2               NaN  PODER EJECUTIVO
# 3               NaN  PODER EJECUTIVO
# 4               NaN  PODER EJECUTIVO
#                  ley camara_iniciadora  firmante_orden  \
# count    4285.000000              4285     4285.000000
# unique           NaN                 2             NaN
# top              NaN         Diputados             NaN
# freq             NaN              2680             NaN
# ...

# %% [markdown]
# #### LEYES
# Trámite parlamentario de los proyectos convertidos en ley.
# Existe un archivo llamado "Sumario de leyes" para información semántica para referencias temáticas.

# %%
#Documentación	http://www4.hcdn.gob.ar/Datos_doc/Doc_leyes_sancionadas.pdf
#Responsable	Secretaria Parlamentaria
#Versión	1.0
#Última actualización	21 de marzo de 2024, 11:54 (UTC-03:00)
#Creado	11 de julio de 2019, 13:39 (UTC-03:00)
#Frecuencia de actualización	eventual

# %%
proyLey_df = pd.read_csv('leyes_sancionadas1.8.csv')
proyLey_df['primera_media_sancion'] = pd.to_datetime(proyLey_df['primera_media_sancion'], errors='coerce') # fecha = 0 ignore?
proyLey_df['segunda_media_sancion'] = pd.to_datetime(proyLey_df['segunda_media_sancion'], errors='coerce') # fecha = 0 ignore?
proyLey_df['sancion_definitiva'] = pd.to_datetime(proyLey_df['sancion_definitiva'], errors='coerce') # fecha = 0 ignore?
display(proyLey_df.head())
print(proyLey_df.describe(include='all'))
# Out:
#   proyecto_id camara_sancionadora sancion_definitiva    ley  \
# 0  HCDN262688           Diputados         2023-10-10  27738
# 1  HCDN248064           Diputados         2023-10-10  27737
# 2  HCDN259273           Diputados         2023-10-10  27736
# 3  HCDN266777              Senado         2023-09-28  27735
# 4  HCDN265329              Senado         2023-09-28  27734
#
#   expediente_inicial primera_media_sancion segunda_media_sancion
# 0        0057-S-2022            2022-10-27                   NaT
# 1        0387-D-2021            2023-08-23            2023-09-28
# 2        2756-D-2022            2023-07-05            2023-09-28
# 3       0001-PE-2023            2023-04-19                   NaT
# 4        6777-D-2022            2023-07-05                   NaT
#        proyecto_id camara_sancionadora             sancion_definitiva  \
# count         1262                1262                           1262
# unique        1259                   2                            NaN
# ...

# %% [markdown]
# ### Muerte súbita
#
# Teniendo en cuenta https://public.tableau.com/app/profile/amalia.guaymas/viz/RCP-muertesubitanormas-base/Presentacin?publish=yes
#
#
#
# * Nacional
# Ley 27159. Sistema de Prevención Integral de Muerte Súbita.// HCDN150412
# * Nacional
# Ley 26835. Ley de Promoción y Capacitación en las Técnicas de Preanimación Cardiopulmonar Básicas.
# * Nacional
# Ley 25501. Programa Nacional de Prevención de las Enfermedades Cardiovasculares.
# * Nacional
# Decreto 223/2010. Reglamentación de la ley 25501.
# * Nacional
# Resolución 908/2009. Programa Nacional de Reanimación Neonatal y Pediátrica.
# * Nacional
# Resolución 182-E/2016. Semana de la Lucha contra la Muerte Súbita.
# * Nacional
# Decreto 402 / 2022. Reglamentación de la ley 27159.
# Nacional
# Resolución 1827 / 2022 - REGISTRO NACIONAL DE DESFIBRILADORES EXTERNOS AUTOMÁTICOS

# %%
# Proyectos parlamentarios iniciados desde el período parlamentario 126º (01/03/2008) y que tuvieron tratamiento en la H. Cámara de Diputados.
proyecto_SUBITA_df
# Out:
#       proyecto_id                                             titulo  \
# 2342   HCDN268152  EXPRESAR QUE VERIA CON AGRADO QUE EL PODER EJE...
# 2866   HCDN266842  PROTECCION DEL EMBARAZO Y DEL RECIEN NACIDO - ...
# 9605   HCDN255602  PROGRAMA DE DIFUSION E INFORMACION A PADRES Y ...
# 15924  HCDN245760  EXPRESAR BENEPLACITO A LA PROFESORA DOCTORA MA...
# 17284  HCDN243571  MUERTE SUBITA. SISTEMA DE PREVENCION INTEGRAL ...
# 21083  HCDN238109  PROGRAMA DE DIFUSION E INFORMACION A PADRES Y ...
# 30870  HCDN215087  PROGRAMA DE DIFUSION E INFORMACION A PADRES Y ...
# 36649  HCDN200176  SOLICITAR AL PODER EJECUTIVO DISPONGA REGLAMEN...
# 42701  HCDN188215  SOLICITAR AL PODER EJECUTIVO REGLAMENTE LA LEY...
# 44296  HCDN185534  PROGRAMA DE PREVENCION DE MUERTE SUBITA EN NIÑ...
# 48057  HCDN179252  INSTITUYENDO EL MES DE OCTUBRE DE CADA AÑO COM...
# 55924  HCDN165110  MUERTE SUBITA: SE INCORPORA AL "PROGRAMA MEDIC...
# 59532  HCDN160273  MUERTE SUBITA: REGIMEN PARA SU PREVENCION EN E...
# ...

# %%
# lista de leyes asociadas a muerte súbita
subitaLey_l = [27159,26835,25501]

# %%
# Trámite parlamentario de los proyectos convertidos en ley asociados a muerte súbita
proyLey_df[proyLey_df['ley'].isin(subitaLey_l)]
# Out:
#     proyecto_id camara_sancionadora sancion_definitiva    ley  \
# 579  HCDN150412              Senado         2015-07-01  27159
# 900  HCDN133967              Senado         2012-11-29  26835
#
#     expediente_inicial primera_media_sancion segunda_media_sancion
# 579        2031-D-2013            2014-11-19                   NaT
# 900        0409-D-2012            2012-11-14                   NaT

# %%
#proyecto_SUBITA_df[proyecto_SUBITA_df['proyecto_id'].isin(['HCDN150412','HCDN133967'])]
proyecto_df[proyecto_df['proyecto_id'].isin(['HCDN150412','HCDN133967'])]
# Out:
#       proyecto_id                                             titulo  \
# 65176  HCDN150412  INSTALACION DE DESFIBRILADORES EXTERNOS AUTOMA...
# 74214  HCDN133967  "TECNICAS DE REANIMACION CARDIOPULMONAR Y PRIM...
#
#       publicacion_fecha publicacion_id camara_origen exp_diputados  \
# 65176        2013-04-16   HCDN131TP029     Diputados   2031-D-2013
# 74214        2012-03-07   HCDN130TP004     Diputados   0409-D-2012
#
#       exp_senadores tipo
# 65176  0134-CD-2014  LEY
# 74214  0111-CD-2012  LEY

# %% [markdown]
# ## Generado dataset para ML

# %% [markdown]
# #### ANALISIS DE GRAFOS/REDES

# %%
import networkx as nx
import seaborn as sns

# %%
print(firmantes_df.shape)
display(firmantes_df.head())
# Out:
# (4285, 6)
#      ley camara_iniciadora  firmante_orden                    firmante  \
# 0  27544         Diputados               1          FERNANDEZ, ALBERTO
# 1  27544         Diputados               2    CAFIERO, SANTIAGO ANDRES
# 2  27544         Diputados               3  GUZMAN, MARTIN MAXIMILIANO
# 3  27543            Senado               1             MACRI, MAURICIO
# 4  27543            Senado               2                PEÑA, MARCOS
#
#   firmante_distrito  firmante_bloque
# 0               NaN  PODER EJECUTIVO
# 1               NaN  PODER EJECUTIVO
# 2               NaN  PODER EJECUTIVO
# 3               NaN  PODER EJECUTIVO
# 4               NaN  PODER EJECUTIVO

# %%
firmantes_muestra_df = firmantes_df.sample(frac=0.1, replace=True, random_state=1)

# %%
firmantes_muestra_df[['firmante','ley']]
# Out:
#                              firmante    ley
# 235            DE PONTI, LUCILA MARIA  27488
# 3980  FERNANDEZ DE KIRCHNER, CRISTINA  26551
# 905          ALONSO, HORACIO FERNANDO  27309
# 2763       MARTIARENA, MARIO HUMBERTO  26873
# 2895             CONTI, DIANA BEATRIZ  26838
# ...                               ...    ...
# 838            MALDONADO, VICTOR HUGO  27324
# 1018            VERNA, CARLOS ALBERTO  27278
# 1547        PASTORIZA, MIRTA AMELIANA  27157
# 1473                 LARROQUE, ANDRES  27179
# 271       BARRIONUEVO, WALTER BASILIO  27479
#
# [428 rows x 2 columns]

# %%
edge_df = pd.merge(firmantes_muestra_df[['firmante','ley']],firmantes_muestra_df[['firmante','ley']],on='ley')
# https://networkx.org/documentation/stable/reference/generated/networkx.convert_matrix.from_pandas_edgelist.html#from-pandas-edgelist
G = nx.from_pandas_edgelist(edge_df, 'firmante_x', "firmante_y",['ley'])

# %%
print(f'The number of edges in the graph: {len(G.nodes())}')
print(f'The number of nodes in the graph: {len(G.edges())}')
# Out:
# The number of edges in the graph: 219
# The number of nodes in the graph: 138

# %%
# Remove self-loops if any
G.remove_edges_from(nx.selfloop_edges(G))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
nx.draw(G, with_labels=False, node_color='skyblue', node_size=10, edge_color='gray')
plt.title("Red de actores legislativos de proyectos de ley")
plt.show()

# %%
# Degree Centrality
centrality = nx.degree_centrality(G)
centrality_df = pd.DataFrame.from_dict(centrality, orient='index')
centrality_df.columns = ['centrality']
centrality_df.head()
# Out:
#                                  centrality
# DE PONTI, LUCILA MARIA             0.009174
# FERNANDEZ DE KIRCHNER, CRISTINA    0.018349
# FERNANDEZ, ANIBAL                  0.027523
# ALONSO, HORACIO FERNANDO           0.009174
# LAGORIA, ELIA NELLY                0.004587

# %%
#https://www.datacamp.com/datalab/templates/playbook-python-network-analysis
b = nx.shortest_path_length(G)
#shortest_paths_df = pd.DataFrame()
shortest_paths_dict = {}
for spl in b:
    shortest_paths_dict[spl[0]] = spl[1]

shortest_paths_df = pd.DataFrame.from_dict(shortest_paths_dict)
shortest_paths_df.sort_index(inplace=True)

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(shortest_paths_df, dtype=bool))

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(11, 9))                    # Set figure size

# Generate a custom diverging colormap
cmap=sns.color_palette("rocket_r", as_cmap=True)

sns.heatmap(shortest_paths_df,
            mask = mask,
            cmap = cmap,
            square = True,                                 # Ensure perfect squares
            linewidths = 0.5,                              # Set linewidth between squares
            cbar_kws = {"shrink": .8},                     # Set size of color bar
            annot = True                                   # Include values within squares
           );

plt.xticks(rotation=90)                                    # Rotate x labels
plt.title('Shortest Path Lengths Between Two Nodes', size=20, y=1.05);   # Set plot title and position

# %%
display(firmantes_df[firmantes_df['ley'].isin(subitaLey_l)])
# Out:
#         ley camara_iniciadora  firmante_orden              firmante  \
# 1535  27159         Diputados               1      YARADE, FERNANDO
# 2913  26835         Diputados               1  BIANCHI, IVANA MARIA
#
#      firmante_distrito               firmante_bloque
# 1535             SALTA  FRENTE PARA LA VICTORIA - PJ
# 2913          SAN LUIS              FRENTE PERONISTA

# %%
centrality_df.loc[['YARADE, FERNANDO','BIANCHI, IVANA MARIA']]
# Out:
#                       centrality
# YARADE, FERNANDO             0.0
# BIANCHI, IVANA MARIA         0.0

# %%
firmantes_df[['firmante_bloque']].value_counts().reset_index().sort_values(by = 'count', ascending=False)
# Out:
#                   firmante_bloque  count
# 0    FRENTE PARA LA VICTORIA - PJ   1690
# 1                 PODER EJECUTIVO   1351
# 2                             UCR    282
# 3                       UNION PRO     90
# 4              PARTIDO SOCIALISTA     72
# ..                            ...    ...
# 89                    SUMA + UNEN      1
# 88           VALORES PARA MI PAIS      1
# 87                           UNIR      1
# 86           UNION POR ENTRE RIOS      1
# 110  VECINALISTA -  PARTIDO NUEVO      1
#
# [111 rows x 2 columns]

# %%
# nodos
firmantes_df[['firmante','firmante_bloque']].value_counts().reset_index().sort_values(by = 'count', ascending=False)
# Out:
#                                firmante               firmante_bloque  count
# 0       FERNANDEZ DE KIRCHNER, CRISTINA               PODER EJECUTIVO    328
# 1                     FERNANDEZ, ANIBAL               PODER EJECUTIVO    133
# 2               TIMERMAN, HECTOR MARCOS               PODER EJECUTIVO    131
# 3              ABAL MEDINA, JUAN MANUEL               PODER EJECUTIVO     90
# 4                          PEÑA, MARCOS               PODER EJECUTIVO     78
# ..                                  ...                           ...    ...
# 642                   COPES, ANA ISABEL         DEMOCRATA PROGRESISTA      1
# 641  CORPACCI DE MERCADO, LUCIA BENIGNA  FRENTE PARA LA VICTORIA - PJ      1
# 640                  COUSINET, GRACIELA                LIBRES DEL SUR      1
# 639     CREMER DE BUSTI, MARIA CRISTINA          UNION POR ENTRE RIOS      1
# 844                      ZOTTOS, ANDRES                 JUSTICIALISTA      1
#
# [845 rows x 3 columns]
